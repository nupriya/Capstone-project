# %% [markdown]
# # NUPRIYA SAXENA
# # Batch-DS0622
#
# # Capstone Project-- IMDb Dataset
# This capstone is divided into a 4-phase duration.
#
# # Phase 2
# Make two tables and corresponding columns provided in the above CSV files in SQLite DBMS. Insert all data of each CSV file in each of the created tables. Now start querying the table(s) in the SQL workbench / SQLite database :
#
# Table 1: Sno, MovieName, Director Name, Duration, genre, ratings
#
# 1) Display all the details of movies created by directors Christopher and Matt Reeves.
#
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
#
# 3) Display all details of movies with ratings above 7 in ascending order.
#
# 4) Display all movie names in descending order.
#
# 5) Display movie name starts with ‘P’ and their rating is greater than 7.
#
# Table 2: Movie Name, stars, votes, Genre, Gross collection, Certification
#
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.
#
# 2 2) Display all details of the movie with the highest number of votes.
#
# 3) Display movie names with gross collections in descending order.
#
# 4) Display the gross collection of movies with the star Arnold.
#
# 5) Display all details of movies with comedy and action genres.
#
# Make subquery :
#
# 1) Display all details from both tables where movie names are the same.
#
# 2) Display all movie names, Director, ratings, and gross collection where the genre is action.
#
# 3) Display all details from both tables with the highest gross collection.
#
# 4) Display all details from both tables with the highest ratings
#
# 5) Display all details from both tables with the lowest gross collection and lowest ratings
#
# Now once completed with queries in the SQLite database, then make the exact query solutions by using PANDAS SQL in the data frame. Load the CSV data in a data frame and start making solutions for all the above 15 queries using PANDAS SQL. You may use concat or merge joins per the requirements basis to make 5 join queries.

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import sqlite3
import csv

# %% [markdown]
# # CREATING DATABASE 1

# %%
db=sqlite3.connect("ImdbMovie1_database.db")
cur=db.cursor()

# %% [markdown]
# # CREATING TABLE 1

# %%
cur.execute('create table Imdbmovie1(Sno Int primary key,Movie_Name text,Director_1 text,Director_2 text,Duration_in_mins Int,year Int,ratings_out_of_10 Int,Metascore Int)')

# %% [markdown]
# # EXTRACTING FROM CSV FILE AND INSERTING VALUES INTO TABLE

# %%
with open("c:\Users\dell\Downloads\movie1.csv",'r')as file:
    total_movies=0
    for i in file:
        cur.execute("insert into Imdbmovie1 values(?,?,?,?,?,?,?,?)",i.split(","))
        db.commit()
        total_movies+=1
print("records inserted", total_movies)
# Out:
# records inserted 1552

# %% [markdown]
# # CREATING DATABASE 2

# %%
db1=sqlite3.connect("ImdbMovie_database.db")
cur1=db1.cursor()

# %% [markdown]
# # CREATING TABLE 2

# %%
cur1.execute('create table Imdbmovie2(Movie_Name text,star_1 text,star_2 text,star_3 text,star_4 text,votes Int,Genre_1 text,Genre_2 text,Genre_3 text,Gross_collection Int,Certification text)')

# %% [markdown]
# # EXTRACTING FROM CSV FILE AND INSERTING VALUES INTO TABLE

# %%
with open("c:\Users\dell\Downloads\movie2.csv",'r',errors='ignore')as file:
    contents=csv.reader(file)
    total_movies=0
    for i in contents:
        cur1.execute("insert into Imdbmovie2 values(?,?,?,?,?,?,?,?,?,?,?)",i)
        db1.commit()
        total_movies+=1
print("records inserted", total_movies)
# Out:
# records inserted 1552

# %% [markdown]
# # QUERYING  TABLE 1

# %% [markdown]
# Table 1: Sno, MovieName, Director Name, Duration, genre, ratings
#
# 1) Display all the details of movies created by directors Christopher and Matt Reeves.
#
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
#
# 3) Display all details of movies with ratings above 7 in ascending order.
#
# 4) Display all movie names in descending order.
#
# 5) Display movie name starts with ‘P’ and their rating is greater than 7.

# %% [markdown]
# 1) Display all the details of movies created by directors Christopher and Matt Reeves

# %%
movies_of_chris=cur.execute("select * from Imdbmovie1 where Director_1 like 'Christophe%' ")
movies_of_chris.fetchall()
# Out:
# [(1, 'The Dark Knight', 'Christopher Nolan ', 'None', 152, 2008, 9, 84),
#  (3, 'Inception', 'Christopher Nolan ', 'None', 148, 2010, 8.8, 74),
#  (21,
#   'The Dark Knight Rises',
#   'Christopher Nolan ',
#   'None',
#   164,
#   2012,
#   8.4,
#   78),
#  (42, 'Batman Begins', 'Christopher Nolan ', 'None', 140, 2005, 8.2, 84),
#  (138, 'Dunkirk', 'Christopher Nolan ', 'None', 106, 2017, 7.8, 87),
#  (166,
#   'Mission: Impossible - Fallout',
#   'Christopher McQuarrie ',
#   'None',
#   147,
#   2018,
#   7.7,
#   66),
#  (292,
#   'Mission: Impossible - Rogue Nation',
#   'Christopher McQuarrie ',
#   'None',
#   131,
#   2015,
#   7.4,
#   81),
#  (321, 'Tenet', 'Christopher Nolan ', 'None', 150, 2020, 7.3, 59),
#  (497, 'Jack Reacher', 'Christopher McQuarrie ', 'None', 130, 2012, 7, 63),
#  (512,
#   'Brotherhood of the Wolf',
#   'Christophe Gans ',
#   'None',
#   142,
#   2001,
#   7,
#   69),
#  (642, 'Young Guns', 'Christopher Cain ', 'None', 107, 1988, 6.8, 60),
#  (824,
#   'The Way of the Gun',
#   'Christopher McQuarrie ',
#   'None',
#   119,
#   2000,
#   6.6,
#   49),
#  (972, 'Black Death', 'Christopher Smith ', 'None', 102, 2010, 6.4, 68),
#  (1024,
#   'Scouts Guide to the Zombie Apocalypse',
#   'Christopher Landon ',
#   'None',
#   93,
#   2015,
#   6.3,
#   56)]

# %%
movies_of_chris1=cur.execute("select * from Imdbmovie1 where Director_2 like 'Christophe%' ")
movies_of_chris1.fetchall()
# Out:
# [(171,
#   'The Lego Movie',
#   ' Phil Lord',
#   'Christopher Miller ',
#   100,
#   2014,
#   7.7,
#   68),
#  (381,
#   '21 Jump Street',
#   ' Phil Lord',
#   'Christopher Miller ',
#   109,
#   2012,
#   7.2,
#   56),
#  (519,
#   '22 Jump Street',
#   ' Phil Lord',
#   'Christopher Miller ',
#   112,
#   2014,
#   7,
#   87)]

# %%
movies_of_matt=cur.execute("select * from Imdbmovie1 where Director_1 like 'Matt Reeve%' ")
movies_of_matt.fetchall()
# Out:
# [(130, 'The Batman', 'Matt Reeves ', 'None', 176, 2022, 7.8, 73),
#  (224,
#   'Dawn of the Planet of the Apes',
#   'Matt Reeves ',
#   'None',
#   130,
#   2014,
#   7.6,
#   66),
#  (305,
#   'War for the Planet of the Apes',
#   'Matt Reeves ',
#   'None',
#   140,
#   2017,
#   7.4,
#   73),
#  (503, 'Cloverfield', 'Matt Reeves ', 'None', 85, 2008, 7, 57)]

# %% [markdown]
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.

# %%
duration=cur.execute('select * from Imdbmovie1 where Duration_in_mins >= 140 and Duration_in_mins <=190')
duration.fetchall()
# Out:
# [(1, 'The Dark Knight', 'Christopher Nolan ', 'None', 152, 2008, 9, 84),
#  (3, 'Inception', 'Christopher Nolan ', 'None', 148, 2010, 8.8, 74),
#  (4,
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Peter Jackson ',
#   'None',
#   178,
#   2001,
#   8.8,
#   92),
#  (5,
#   'The Lord of the Rings: The Two Towers',
#   'Peter Jackson ',
#   'None',
#   179,
#   2002,
#   8.8,
#   87),
#  (8, 'Soorarai Pottru', 'Sudha Kongara ', 'None', 153, 2020, 8.7, 90),
#  (13, 'Sita Ramam', 'Hanu Raghavapudi ', 'None', 163, 2022, 8.6, 67),
#  (15, 'Gladiator', 'Ridley Scott ', 'None', 155, 2000, 8.5, 78),
#  (17, 'Avengers: Endgame', 'Anthony Russo', 'Joe Russo', 181, 2019, 8.4, 68),
#  (19,
#   'Avengers: Infinity War',
#   'Anthony Russo',
#   'Joe Russo',
#   149,
#   2018,
#   8.4,
#   78),
#  (21,
#   'The Dark Knight Rises',
#   'Christopher Nolan ',
#   'None',
#   164,
#   2012,
#   8.4,
#   78),
#  (23, 'Kaithi', 'Lokesh Kanagaraj ', 'None', 145, 2019, 8.4, 58),
#  (24, 'Asuran', 'Vetrimaaran ', 'None', 141, 2019, 8.4, 76),
#  (26, 'Heat', 'Michael Mann ', 'None', 170, 1995, 8.3, 64),
#  (30, 'Kantara', 'Rishab Shetty ', 'None', 148, 2022, 8.3, 78),
#  (31, 'Dangal', 'Nitesh Tiwari ', 'None', 161, 2016, 8.3, 69),
#  (32, 'K.G.F: Chapter 2', 'Prashanth Neel ', 'None', 168, 2022, 8.3, 70),
#  (33, 'Vikram', 'Lokesh Kanagaraj ', 'None', 175, 2022, 8.3, 72),
#  (34, 'Raatchasan', 'Ram Kumar ', 'None', 170, 2018, 8.3, 62),
#  (36,
#   'Guardians of the Galaxy Vol. 3',
#   'James Gunn ',
#   'None',
#   150,
#   2023,
#   8.2,
#   97),
#  (37, 'Spider-Man: No Way Home', 'Jon Watts ', 'None', 148, 2021, 8.2, 89),
#  (42, 'Batman Begins', 'Christopher Nolan ', 'None', 140, 2005, 8.2, 84),
#  (46, 'Ran', 'Akira Kurosawa ', 'None', 162, 1985, 8.2, 75),
#  (48, 'Vikram Vedha', 'Gayatri', 'Pushkar', 147, 2017, 8.2, 74),
#  (49,
#   'Baahubali 2: The Conclusion',
#   'S.S. Rajamouli ',
#   'None',
#   167,
#   2017,
#   8.2,
#   85),
#  (52, 'K.G.F: Chapter 1', 'Prashanth Neel ', 'None', 156, 2018, 8.2, 76),
#  (54, 'Rangasthalam 1985', 'Sukumar ', 'None', 170, 2018, 8.2, 81),
#  (58, 'Ford v Ferrari', 'James Mangold ', 'None', 152, 2019, 8.1, 90),
#  (59,
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Gore Verbinski ',
#   'None',
#   143,
#   2003,
#   8.1,
#   80),
#  (65, 'Warrior', 'Gavin OConnor ', 'None', 140, 2011, 8.1, 75),
#  (69, 'Sholay', 'Ramesh Sippy ', 'None', 162, 1975, 8.1, 64),
#  (70, 'Bajrangi Bhaijaan', 'Kabir Khan', 'Mehmet Tutkun', 163, 2015, 8.1, 74),
#  (75, 'Major', 'Sashi Kiran Tikka ', 'None', 150, 2022, 8.1, 84),
#  (76, 'Sarfarosh', 'John Mathew Matthan ', 'None', 174, 1999, 8.1, 75),
#  (77, 'Hera Pheri', 'Priyadarshan ', 'None', 156, 2000, 8.1, 81),
#  (78, 'Kaththi', 'A.R. Murugadoss ', 'None', 166, 2014, 8.1, 68),
#  (79, 'Thuppakki', 'A.R. Murugadoss ', 'None', 165, 2012, 8.1, 60),
#  (80, 'John Wick: Chapter 4', 'Chad Stahelski ', 'None', 169, 2023, 8, 94),
#  (82, 'Dune', 'Denis Villeneuve ', 'None', 155, 2021, 8, 65),
#  (83, 'Blade Runner 2049', 'Denis Villeneuve ', 'None', 164, 2017, 8, 71),
#  (85, 'The Avengers', 'Joss Whedon ', 'None', 143, 2012, 8, 85),
#  (88, 'Casino Royale', 'Martin Campbell ', 'None', 144, 2006, 8, 97),
#  (89,
#   'The Revenant (I)',
#   'Alejandro G. IÃ±Ã¡rritu  ',
#   'None',
#   156,
#   2015,
#   8,
#   81),
#  (94, 'Baahubali: The Beginning', 'S.S. Rajamouli ', 'None', 159, 2015, 8, 78),
#  (98, 'Haider', 'Vishal Bhardwaj ', 'None', 160, 2014, 8, 94),
#  (101,
#   'Tae Guk Gi: The Brotherhood of War',
#   'Je-kyu Kang ',
#   'None',
#   140,
#   2004,
#   8,
#   81),
#  (102, 'Andaz Apna Apna', 'Rajkumar Santoshi ', 'None', 160, 1994, 8, 75),
#  (103, 'Karthikeya 2', 'Chandoo Mondeti ', 'None', 150, 2022, 8, 51),
#  (104, 'Arjun Reddy', 'Sandeep Reddy Vanga ', 'None', 182, 2017, 8, 81),
#  (105, '1: Nenokkadine', 'Sukumar ', 'None', 170, 2014, 8, 70),
#  (108, 'Avatar', 'James Cameron ', 'None', 162, 2009, 7.9, 82),
#  (120, 'The Raid 2', 'Gareth Evans ', 'None', 150, 2014, 7.9, 60),
#  (123, 'Letters from Iwo Jima', 'Clint Eastwood ', 'None', 141, 2006, 7.9, 74),
#  (126, 'Baby (I)', 'Neeraj Pandey ', 'None', 159, 2015, 7.9, 76),
#  (128, 'Vishwaroopam', 'Kamal Haasan ', 'None', 148, 2013, 7.9, 65),
#  (130, 'The Batman', 'Matt Reeves ', 'None', 176, 2022, 7.8, 73),
#  (131, 'RRR', 'S.S. Rajamouli ', 'None', 187, 2022, 7.8, 47),
#  (133,
#   'All Quiet on the Western Front',
#   'Edward Berger ',
#   'None',
#   148,
#   2022,
#   7.8,
#   74),
#  (142,
#   'Captain America: Civil War',
#   ' Anthony Russo',
#   ' Joe Russo ',
#   147,
#   2016,
#   7.8,
#   94),
#  (144, 'Skyfall', 'Sam Mendes ', 'None', 143, 2012, 7.8, 77),
#  (149, 'I Saw the Devil', 'Jee-woon Kim ', 'None', 144, 2010, 7.8, 63),
#  (150, 'The Last Samurai', 'Edward Zwick ', 'None', 154, 2003, 7.8, 67),
#  (152, 'Thirteen Lives', 'Ron Howard ', 'None', 147, 2022, 7.8, 82),
#  (162, 'Minnal Murali', 'Basil Joseph ', 'None', 158, 2021, 7.8, 65),
#  (166,
#   'Mission: Impossible - Fallout',
#   'Christopher McQuarrie ',
#   'None',
#   147,
#   2018,
#   7.7,
#   66),
#  (167, 'Black Hawk Down', 'Ridley Scott ', 'None', 144, 2001, 7.7, 56),
#  (174, 'The Dirty Dozen', 'Robert Aldrich ', 'None', 150, 1967, 7.7, 63),
#  (175, 'Man on Fire', 'Tony Scott ', 'None', 146, 2004, 7.7, 68),
#  (181, 'The Longest Day', ' Ken Annakin', 'Andrew Marton', 178, 1962, 7.7, 62),
#  (190, 'Ponniyin Selvan: Part I', 'Mani Ratnam ', 'None', 167, 2022, 7.7, 65),
#  (197, 'Eega', 'S.S. Rajamouli ', 'None', 145, 2012, 7.7, 64),
#  (198, 'Udta Punjab', 'Abhishek Chaubey ', 'None', 148, 2016, 7.7, 76),
#  (206,
#   'Star Wars: Episode III - Revenge of the Sith',
#   'George Lucas ',
#   'None',
#   140,
#   2005,
#   7.6,
#   81),
#  (208, 'Watchmen', 'Zack Snyder ', 'None', 162, 2009, 7.6, 74),
#  (209,
#   'Harry Potter and the Half-Blood Prince',
#   'David Yates ',
#   'None',
#   153,
#   2009,
#   7.6,
#   58),
#  (220, 'Minority Report', 'Steven Spielberg ', 'None', 145, 2002, 7.6, 74),
#  (225, 'Where Eagles Dare', 'Brian G. Hutton ', 'None', 158, 1968, 7.6, 68),
#  (239, 'Pushpa: The Rise - Part 1', 'Sukumar ', 'None', 179, 2021, 7.6, 83),
#  (240, 'Ludo', 'Anurag Basu ', 'None', 149, 2020, 7.6, 58),
#  (253,
#   'The Hunger Games: Catching Fire',
#   'Francis Lawrence ',
#   'None',
#   146,
#   2013,
#   7.5,
#   65),
#  (263, 'Munich', 'Steven Spielberg ', 'None', 164, 2005, 7.5, 68),
#  (267, 'The Guns of Navarone', 'J. Lee Thompson ', 'None', 158, 1961, 7.5, 70),
#  (268,
#   'Tora! Tora! Tora!',
#   ' Richard Fleischer',
#   'Akira Kurosawa ',
#   144,
#   1970,
#   7.5,
#   59),
#  (272, '13 Assassins', 'Takashi Miike ', 'None', 141, 2010, 7.5, 66),
#  (282, 'Mersal', 'Atlee ', 'None', 172, 2017, 7.5, 75),
#  (291, 'Ready Player One', 'Steven Spielberg ', 'None', 140, 2018, 7.4, 75),
#  (294, 'The Last Duel', 'Ridley Scott ', 'None', 152, 2021, 7.4, 62),
#  (295, 'Wonder Woman', 'Patty Jenkins ', 'None', 141, 2017, 7.4, 74),
#  (296, 'Superman', 'Richard Donner ', 'None', 143, 1978, 7.4, 56),
#  (305,
#   'War for the Planet of the Apes',
#   'Matt Reeves ',
#   'None',
#   140,
#   2017,
#   7.4,
#   73),
#  (321, 'Tenet', 'Christopher Nolan ', 'None', 150, 2020, 7.3, 59),
#  (324, 'No Time to Die', 'Cary Joji Fukunaga ', 'None', 163, 2021, 7.3, 81),
#  (325, 'True Lies', 'James Cameron ', 'None', 141, 1994, 7.3, 63),
#  (332, 'Avengers: Age of Ultron', 'Joss Whedon ', 'None', 141, 2015, 7.3, 69),
#  (336, '13 Hours', 'Michael Bay ', 'None', 144, 2016, 7.3, 67),
#  (341,
#   'Pirates of the Caribbean: Dead Mans Chest',
#   'Gore Verbinski ',
#   'None',
#   151,
#   2006,
#   7.3,
#   59),
#  (355, 'The Negotiator', 'F. Gary Gray ', 'None', 140, 1998, 7.3, 75),
#  (366, 'Red Cliff', 'John Woo ', 'None', 148, 2008, 7.3, 71),
#  (369, 'Ghajini', 'A.R. Murugadoss ', 'None', 186, 2008, 7.3, 64),
#  (371, 'The Baader Meinhof Complex', 'Uli Edel ', 'None', 150, 2008, 7.3, 53),
#  (372, 'Master (I)', 'Lokesh Kanagaraj ', 'None', 178, 2021, 7.3, 68),
#  (374, 'The Hunger Games', 'Gary Ross ', 'None', 142, 2012, 7.2, 62),
#  (380, 'Kingdom of Heaven', 'Ridley Scott ', 'None', 144, 2005, 7.2, 66),
#  (387, 'King Kong', 'Peter Jackson ', 'None', 187, 2005, 7.2, 60),
#  (388, 'The Patriot', 'Roland Emmerich ', 'None', 165, 2000, 7.2, 70),
#  (401,
#   'Batman v Superman: Dawn of Justice (Ultimate Edition)',
#   'Zack Snyder ',
#   'None',
#   182,
#   2016,
#   7.2,
#   69),
#  (406, 'War Horse', 'Steven Spielberg ', 'None', 146, 2011, 7.2, 56),
#  (422,
#   'Bajirao Mastani',
#   'Sanjay Leela Bhansali ',
#   'None',
#   158,
#   2015,
#   7.2,
#   50),
#  (429,
#   'Holiday: A Soldier is Never Off Duty',
#   'A.R. Murugadoss ',
#   'None',
#   160,
#   2014,
#   7.2,
#   49),
#  (437, 'Man of Steel', 'Zack Snyder ', 'None', 143, 2013, 7.1, 75),
#  (447,
#   'Pirates of the Caribbean: At Worlds End',
#   'Gore Verbinski ',
#   'None',
#   169,
#   2007,
#   7.1,
#   57),
#  (481, 'Don (I)', 'Farhan Akhtar ', 'None', 171, 2006, 7.1, 62),
#  (483, 'Koi... Mil Gaya', 'Rakesh Roshan ', 'None', 171, 2003, 7.1, 66),
#  (484, 'Fanaa', 'Kunal Kohli ', 'None', 168, 2006, 7.1, 59),
#  (485, 'Marighella', 'Wagner Moura ', 'None', 155, 2019, 7.1, 84),
#  (486, 'Enthiran', 'S. Shankar ', 'None', 174, 2010, 7.1, 56),
#  (493, 'Transformers', 'Michael Bay ', 'None', 144, 2007, 7, 51),
#  (496, 'Independence Day', 'Roland Emmerich ', 'None', 145, 1996, 7, 60),
#  (512,
#   'Brotherhood of the Wolf',
#   'Christophe Gans ',
#   'None',
#   142,
#   2001,
#   7,
#   69),
#  (513, 'Den of Thieves', 'Christian Gudegast ', 'None', 140, 2018, 7, 82),
#  (521, 'Public Enemies', 'Michael Mann ', 'None', 140, 2009, 7, 72),
#  (532, 'The Towering Inferno', 'John Guillermin ', 'None', 165, 1974, 7, 58),
#  (551, 'Don 2', 'Farhan Akhtar ', 'None', 148, 2011, 7, 53),
#  (552, 'Sultan', 'Ali Abbas Zafar ', 'None', 170, 2016, 7, 65),
#  (553, 'Kabir Singh', 'Sandeep Reddy Vanga ', 'None', 173, 2019, 7, 64),
#  (554, 'Main Hoon Na', 'Farah Khan ', 'None', 179, 2004, 7, 83),
#  (555, 'The Legend', ' Jerry', 'Joseph D. Sami ', 161, 2022, 7, 69),
#  (556, 'Vikrant Rona', 'Anup Bhandari ', 'None', 148, 2022, 7, 61),
#  (573,
#   'Star Wars: Episode VIII - The Last Jedi',
#   'Rian Johnson ',
#   'None',
#   152,
#   2017,
#   6.9,
#   44),
#  (576, 'X-Men: Apocalypse', 'Bryan Singer ', 'None', 144, 2016, 6.9, 55),
#  (581,
#   'Robin Hood: Prince of Thieves',
#   'Kevin Reynolds ',
#   'None',
#   143,
#   1991,
#   6.9,
#   55),
#  (584,
#   'Dragged Across Concrete',
#   'S. Craig Zahler ',
#   'None',
#   159,
#   2018,
#   6.9,
#   32),
#  (593,
#   'Clear and Present Danger',
#   'Phillip Noyce ',
#   'None',
#   141,
#   1994,
#   6.9,
#   38),
#  (612, 'Agneepath', 'Karan Malhotra ', 'None', 174, 2012, 6.9, 47),
#  (615, 'Fan (I)', 'Maneesh Sharma ', 'None', 142, 2016, 6.9, 67),
#  (619, 'Aquaman', 'James Wan ', 'None', 143, 2018, 6.8, 43),
#  (629, 'Spectre (I)', 'Sam Mendes ', 'None', 148, 2015, 6.8, 43),
#  (632,
#   'Kisi Ka Bhai Kisi Ki Jaan',
#   'Farhad Samji ',
#   'None',
#   145,
#   2023,
#   6.8,
#   58),
#  (667,
#   'Black Panther: Wakanda Forever',
#   'Ryan Coogler ',
#   'None',
#   161,
#   2022,
#   6.7,
#   68),
#  (669,
#   'Kingsman: The Golden Circle',
#   'Matthew Vaughn ',
#   'None',
#   141,
#   2017,
#   6.7,
#   40),
#  (681, 'Armageddon', 'Michael Bay ', 'None', 151, 1998, 6.7, 47),
#  (712,
#   'On Her Majestys Secret Service',
#   'Peter R. Hunt ',
#   'None',
#   142,
#   1969,
#   6.7,
#   49),
#  (739, 'Om Shanti Om', 'Farah Khan ', 'None', 162, 2007, 6.7, 53),
#  (748,
#   'Star Wars: Episode II - Attack of the Clones',
#   'George Lucas ',
#   'None',
#   142,
#   2002,
#   6.6,
#   40),
#  (749, 'Red Sparrow', 'Francis Lawrence ', 'None', 140, 2018, 6.6, 73),
#  (761, 'The Amazing Spider-Man 2', 'Marc Webb ', 'None', 142, 2014, 6.6, 46),
#  (772, 'Robin Hood', 'Ridley Scott ', 'None', 140, 2010, 6.6, 58),
#  (793, 'Bad Boys II', 'Michael Bay ', 'None', 147, 2003, 6.6, 64),
#  (827, 'Raees', 'Rahul Dholakia ', 'None', 143, 2017, 6.6, 57),
#  (831, 'Wanted (I)', 'Prabhu Deva ', 'None', 147, 2009, 6.6, 45),
#  (837,
#   'Star Wars: Episode IX - The Rise of Skywalker',
#   'J.J. Abrams ',
#   'None',
#   141,
#   2019,
#   6.5,
#   51),
#  (860,
#   'The Chronicles of Narnia: Prince Caspian',
#   'Andrew Adamson ',
#   'None',
#   150,
#   2008,
#   6.5,
#   44),
#  (898, 'Flyboys', 'Tony Bill ', 'None', 140, 2006, 6.5, 52),
#  (902, 'War', 'Siddharth Anand ', 'None', 154, 2019, 6.5, 40),
#  (905, 'Dhoom 2', 'Sanjay Gadhvi ', 'None', 152, 2006, 6.5, 36),
#  (907, 'Conquest 1453', 'Faruk Aksoy ', 'None', 162, 2012, 6.5, 61),
#  (915,
#   'Batman v Superman: Dawn of Justice',
#   'Zack Snyder ',
#   'None',
#   151,
#   2016,
#   6.4,
#   29),
#  (945, 'The Lone Ranger', 'Gore Verbinski ', 'None', 150, 2013, 6.4, 54),
#  (989, 'Fast X', 'Louis Leterrier ', 'None', 141, 2023, 6.3, 42),
#  (993, 'Eternals', 'ChloÃ© Zhao', 'None', 156, 2021, 6.3, 57),
#  (1012, 'Waterworld', 'Kevin Reynolds ', 'None', 177, 1995, 6.3, 42),
#  (1066, 'Toofaan', 'Rakeysh Omprakash Mehra ', 'None', 163, 2021, 6.3, 35),
#  (1073, 'Pearl Harbor', 'Michael Bay ', 'None', 183, 2001, 6.2, 41),
#  (1075,
#   'Transformers: Dark of the Moon',
#   'Michael Bay ',
#   'None',
#   154,
#   2011,
#   6.2,
#   42),
#  (1077, 'The Karate Kid', 'Harald Zwart ', 'None', 140, 2010, 6.2, 55),
#  (1099,
#   'Maze Runner: The Death Cure',
#   'Wes Ball ',
#   'None',
#   143,
#   2018,
#   6.2,
#   42),
#  (1157, 'The Legend of Tomiris', 'Akan Satayev ', 'None', 156, 2019, 6.2, 23),
#  (1177, 'Superman Returns', 'Bryan Singer ', 'None', 154, 2006, 6.1, 47),
#  (1195, 'The Postman', 'Kevin Costner ', 'None', 177, 1997, 6.1, 47),
#  (1240, 'Chennai Express', 'Rohit Shetty ', 'None', 141, 2013, 6.1, 41),
#  (1242, 'Thunivu', 'H. Vinoth ', 'None', 145, 2023, 6.1, 42),
#  (1243, 'Sooryavanshi', 'Rohit Shetty ', 'None', 145, 2021, 6.1, 35),
#  (1244, '2.o', 'S. Shankar ', 'None', 148, 2018, 6.1, 33),
#  (1250, 'Exodus: Gods and Kings', 'Ridley Scott ', 'None', 150, 2014, 6, 36),
#  (1296, 'Varisu', 'Vamshi Paidipally ', 'None', 169, 2023, 6, 54),
#  (1306, 'Kick', 'Sajid Nadiadwala ', 'None', 146, 2014, 6, 52),
#  (1315,
#   'Transformers: Revenge of the Fallen',
#   'Michael Bay ',
#   'None',
#   149,
#   2009,
#   5.9,
#   50),
#  (1316, 'Pathaan', 'Siddharth Anand ', 'None', 146, 2023, 5.9, 45),
#  (1358,
#   'Tiger Lives',
#   ' Mehmet Tutkun',
#   'Musa Muhammed Olayinka ',
#   161,
#   2017,
#   5.9,
#   38),
#  (1360,
#   'The School for Good and Evil',
#   'Paul Feig ',
#   'None',
#   147,
#   2022,
#   5.8,
#   37),
#  (1361, '2012 (I)', 'Roland Emmerich ', 'None', 158, 2009, 5.8, 44),
#  (1363, 'Army of the Dead', 'Zack Snyder ', 'None', 148, 2021, 5.8, 48),
#  (1412,
#   'The Matrix Resurrections (I)',
#   'Lana Wachowski ',
#   'None',
#   148,
#   2021,
#   5.7,
#   27),
#  (1464,
#   'Jurassic World: Dominion',
#   'Colin Trevorrow ',
#   'None',
#   147,
#   2022,
#   5.6,
#   34),
#  (1466,
#   'Transformers: Age of Extinction',
#   'Michael Bay ',
#   'None',
#   165,
#   2014,
#   5.6,
#   33),
#  (1477, 'Alexander', 'Oliver Stone ', 'None', 175, 2004, 5.6, 34),
#  (1498,
#   'Brahmastra Part One: Shiva',
#   'Ayan Mukerji ',
#   'None',
#   167,
#   2022,
#   5.6,
#   38),
#  (1513, 'Bang Bang (I)', 'Siddharth Anand ', 'None', 153, 2014, 5.6, 30)]

# %% [markdown]
# 3). Display all details of movies with ratings above 7 in ascending order.

# %%
ratings=cur.execute("select * from Imdbmovie1 where ratings_out_of_10 > 7 order by ratings_out_of_10 asc ")
ratings.fetchall()
# Out:
# [(430, 'Furious 7', 'James Wan ', 'None', 137, 2015, 7.1, 42),
#  (431, 'The Mummy', 'Stephen Sommers ', 'None', 124, 1999, 7.1, 61),
#  (432, 'Mission: Impossible', 'Brian De Palma ', 'None', 110, 1996, 7.1, 64),
#  (433, 'Free Guy', 'Shawn Levy ', 'None', 115, 2021, 7.1, 57),
#  (434, 'Wrath of Man', 'Guy Ritchie ', 'None', 119, 2021, 7.1, 49),
#  (435, 'Tropic Thunder', 'Ben Stiller ', 'None', 107, 2008, 7.1, 60),
#  (436, 'Prey (I)', 'Dan Trachtenberg ', 'None', 100, 2022, 7.1, 42),
#  (437, 'Man of Steel', 'Zack Snyder ', 'None', 143, 2013, 7.1, 75),
#  (438, 'Everest', 'Baltasar KormÃ¡kur', 'None', 121, 2015, 7.1, 56),
#  (439, 'Blade', 'Stephen Norrington ', 'None', 120, 1998, 7.1, 78),
#  (440, 'Shooter (I)', 'Antoine Fuqua ', 'None', 124, 2007, 7.1, 71),
#  (441, 'Batman Returns', 'Tim Burton ', 'None', 126, 1992, 7.1, 71),
#  (442, 'Highlander', 'Russell Mulcahy ', 'None', 116, 1986, 7.1, 70),
#  (443, 'Iron Man 3', 'Shane Black ', 'None', 130, 2013, 7.1, 52),
#  (444, 'WarGames', 'John Badham ', 'None', 114, 1983, 7.1, 69),
#  (445, 'Dredd', 'Pete Travis ', 'None', 95, 2012, 7.1, 66),
#  (446, 'Snowpiercer', 'Bong Joon Ho ', 'None', 126, 2013, 7.1, 79),
#  (447,
#   'Pirates of the Caribbean: At Worlds End',
#   'Gore Verbinski ',
#   'None',
#   169,
#   2007,
#   7.1,
#   57),
#  (448, 'American Made', 'Doug Liman ', 'None', 115, 2017, 7.1, 46),
#  (449, 'Creed II', 'Steven Caple Jr. ', 'None', 130, 2018, 7.1, 60),
#  (450,
#   'DC League of Super-Pets',
#   ' Jared Stern',
#   'Sam J. Levine ',
#   105,
#   2022,
#   7.1,
#   78),
#  (451, 'Desperado', 'Robert Rodriguez ', 'None', 104, 1995, 7.1, 55),
#  (452, 'I Robot', 'Alex Proyas ', 'None', 115, 2004, 7.1, 69),
#  (453, 'Escape from New York', 'John Carpenter ', 'None', 99, 1981, 7.1, 62),
#  (454, 'We Were Soldiers', 'Randall Wallace ', 'None', 138, 2002, 7.1, 56),
#  (455, 'Live Free or Die Hard', 'Len Wiseman ', 'None', 128, 2007, 7.1, 56),
#  (456, 'Allied', 'Robert Zemeckis ', 'None', 124, 2016, 7.1, 55),
#  (457, 'The Poseidon Adventure', 'Ronald Neame ', 'None', 117, 1972, 7.1, 63),
#  (458,
#   'Kung Fu Panda 3',
#   ' Alessandro Carloni',
#   'Jennifer Yuh Nelson ',
#   95,
#   2016,
#   7.1,
#   62),
#  (459, 'Planet Terror', 'Robert Rodriguez ', 'None', 105, 2007, 7.1, 55),
#  (460, 'Casualties of War', 'Brian De Palma ', 'None', 113, 1989, 7.1, 62),
#  (461, 'No Way Out', 'Roger Donaldson ', 'None', 114, 1987, 7.1, 60),
#  (462, 'Rocky Balboa', 'Sylvester Stallone ', 'None', 102, 2006, 7.1, 78),
#  (463, 'Deepwater Horizon', 'Peter Berg ', 'None', 107, 2016, 7.1, 66),
#  (464, 'Deja Vu', 'Tony Scott ', 'None', 126, 2006, 7.1, 58),
#  (465, 'Defiance (I)', 'Edward Zwick ', 'None', 137, 2008, 7.1, 57),
#  (466, 'Three Kings', 'David O. Russell ', 'None', 114, 1999, 7.1, 69),
#  (467, 'Die Hard 2', 'Renny Harlin ', 'None', 124, 1990, 7.1, 52),
#  (468,
#   'Brawl in Cell Block 99',
#   'S. Craig Zahler ',
#   'None',
#   132,
#   2017,
#   7.1,
#   70),
#  (469, 'Payback (I)', 'Brian Helgeland ', 'None', 100, 1999, 7.1, 49),
#  (470, 'Flags of Our Fathers', 'Clint Eastwood ', 'None', 135, 2006, 7.1, 70),
#  (471,
#   'Ong-Bak: The Thai Warrior',
#   'Prachya Pinkaew ',
#   'None',
#   105,
#   2003,
#   7.1,
#   50),
#  (472, 'Megan Leavey', 'Gabriela Cowperthwaite ', 'None', 116, 2017, 7.1, 48),
#  (473, 'District B13', 'Pierre Morel ', 'None', 84, 2004, 7.1, 43),
#  (474, 'Mosul (I)', 'Matthew Michael Carnahan ', 'None', 101, 2019, 7.1, 60),
#  (475,
#   'The Girl Who Played with Fire',
#   'Daniel Alfredson ',
#   'None',
#   129,
#   2009,
#   7.1,
#   59),
#  (476, 'God Bless America', 'Bobcat Goldthwait ', 'None', 105, 2011, 7.1, 66),
#  (477,
#   'In Order of Disappearance',
#   'Hans Petter Moland ',
#   'None',
#   116,
#   2014,
#   7.1,
#   58),
#  (478, 'Kaabil', 'Sanjay Gupta ', 'None', 139, 2017, 7.1, 66),
#  (479, 'JCVD', 'Mabrouk El Mechri ', 'None', 97, 2008, 7.1, 56),
#  (480,
#   'Dragon Ball Z: Battle of Gods',
#   'Masahiro Hosoda ',
#   'None',
#   85,
#   2013,
#   7.1,
#   66),
#  (481, 'Don (I)', 'Farhan Akhtar ', 'None', 171, 2006, 7.1, 62),
#  (482, 'Micmacs', 'Jean-Pierre Jeunet ', 'None', 105, 2009, 7.1, 64),
#  (483, 'Koi... Mil Gaya', 'Rakesh Roshan ', 'None', 171, 2003, 7.1, 66),
#  (484, 'Fanaa', 'Kunal Kohli ', 'None', 168, 2006, 7.1, 59),
#  (485, 'Marighella', 'Wagner Moura ', 'None', 155, 2019, 7.1, 84),
#  (486, 'Enthiran', 'S. Shankar ', 'None', 174, 2010, 7.1, 56),
#  (487,
#   'Gabbar Is Back',
#   'Radha Krishna Jagarlamudi ',
#   'None',
#   128,
#   2015,
#   7.1,
#   52),
#  (373, 'The Suicide Squad', 'James Gunn ', 'None', 132, 2021, 7.2, 24),
#  (374, 'The Hunger Games', 'Gary Ross ', 'None', 142, 2012, 7.2, 62),
#  (375, 'From Dusk Till Dawn', 'Robert Rodriguez ', 'None', 108, 1996, 7.2, 77),
#  (376, 'The Equalizer', 'Antoine Fuqua ', 'None', 132, 2014, 7.2, 60),
#  (377, 'Willow', 'Ron Howard ', 'None', 126, 1988, 7.2, 84),
#  (378, 'Point Break', 'Kathryn Bigelow ', 'None', 122, 1991, 7.2, 50),
#  (379, 'The Man from U.N.C.L.E.', 'Guy Ritchie ', 'None', 116, 2015, 7.2, 65),
#  (380, 'Kingdom of Heaven', 'Ridley Scott ', 'None', 144, 2005, 7.2, 66),
#  (381,
#   '21 Jump Street',
#   ' Phil Lord',
#   'Christopher Miller ',
#   109,
#   2012,
#   7.2,
#   56),
#  (382, 'Natural Born Killers', 'Oliver Stone ', 'None', 119, 1994, 7.2, 55),
#  (383, 'GoldenEye', 'Martin Campbell ', 'None', 130, 1995, 7.2, 59),
#  (384, 'Unbroken (I)', 'Angelina Jolie ', 'None', 137, 2014, 7.2, 76),
#  (385,
#   'The Matrix Reloaded',
#   ' Lana Wachowski',
#   'Lilly Wachowski ',
#   138,
#   2003,
#   7.2,
#   65),
#  (386, 'They Live', 'John Carpenter ', 'None', 94, 1988, 7.2, 69),
#  (387, 'King Kong', 'Peter Jackson ', 'None', 187, 2005, 7.2, 60),
#  (388, 'The Patriot', 'Roland Emmerich ', 'None', 165, 2000, 7.2, 70),
#  (389, 'I Am Legend', 'Francis Lawrence ', 'None', 101, 2007, 7.2, 66),
#  (390,
#   'The Life Aquatic with Steve Zissou',
#   'Wes Anderson ',
#   'None',
#   119,
#   2004,
#   7.2,
#   75),
#  (391, 'The Croods', ' Kirk DeMicco', ' Chris Sanders ', 98, 2013, 7.2, 77),
#  (392,
#   'Big Trouble in Little China',
#   'John Carpenter ',
#   'None',
#   99,
#   1986,
#   7.2,
#   63),
#  (393, 'Rango', 'Gore Verbinski ', 'None', 107, 2011, 7.2, 68),
#  (394, 'RocknRolla', 'Guy Ritchie ', 'None', 114, 2008, 7.2, 59),
#  (395, 'Old Henry', 'Potsy Ponciroli ', 'None', 99, 2021, 7.2, 58),
#  (396, 'Dr. No', 'Terence Young ', 'None', 110, 1962, 7.2, 82),
#  (397, 'Friday Night Lights', 'Peter Berg ', 'None', 118, 2004, 7.2, 67),
#  (398,
#   'Team America: World Police',
#   'Trey Parker ',
#   'None',
#   98,
#   2004,
#   7.2,
#   79),
#  (399, 'Ronin', 'John Frankenheimer ', 'None', 122, 1998, 7.2, 46),
#  (400, 'Kung Fu Panda 2', 'Jennifer Yuh Nelson ', 'None', 90, 2011, 7.2, 79),
#  (401,
#   'Batman v Superman: Dawn of Justice (Ultimate Edition)',
#   'Zack Snyder ',
#   'None',
#   182,
#   2016,
#   7.2,
#   69),
#  (402, 'Runaway Train', 'Andrey Konchalovskiy ', 'None', 111, 1985, 7.2, 66),
#  (403,
#   'Star Trek VI: The Undiscovered Country',
#   'Nicholas Meyer ',
#   'None',
#   110,
#   1991,
#   7.2,
#   70),
#  (404, 'The Italian Job', 'Peter Collinson ', 'None', 99, 1969, 7.2, 71),
#  (405, 'Anthropoid', 'Sean Ellis ', 'None', 120, 2016, 7.2, 66),
#  (406, 'War Horse', 'Steven Spielberg ', 'None', 146, 2011, 7.2, 56),
#  (407, 'Magnum Force', 'Ted Post ', 'None', 124, 1973, 7.2, 74),
#  (408,
#   'In the Line of Fire',
#   'Wolfgang Petersen ',
#   'None',
#   128,
#   1993,
#   7.2,
#   64),
#  (409, 'Silverado', 'Lawrence Kasdan ', 'None', 133, 1985, 7.2, 62),
#  (410, 'Rise of the Guardians', 'Peter Ramsey ', 'None', 97, 2012, 7.2, 70),
#  (411, 'The Way of the Dragon', 'Bruce Lee ', 'None', 90, 1972, 7.2, 57),
#  (412, 'Vanishing Point', 'Richard C. Sarafian ', 'None', 99, 1971, 7.2, 61),
#  (413, 'Lethal Weapon 2', 'Richard Donner ', 'None', 114, 1989, 7.2, 71),
#  (414,
#   'The Transformers: The Movie',
#   'Nelson Shin ',
#   'None',
#   84,
#   1986,
#   7.2,
#   68),
#  (415, 'Arlington Road', 'Mark Pellington ', 'None', 117, 1999, 7.2, 61),
#  (416, 'Kon-Tiki', 'Joachim RÃ¸nning', ' Espen Sandberg ', 118, 2012, 7.2, 82),
#  (417, 'The Hitcher', 'Robert Harmon ', 'None', 97, 1986, 7.2, 70),
#  (418,
#   'The Witcher: Nightmare of the Wolf',
#   'Kwang Il Han ',
#   'None',
#   83,
#   2021,
#   7.2,
#   59),
#  (419, 'Django', 'Sergio Corbucci ', 'None', 91, 1966, 7.2, 50),
#  (420, 'The Siege of Jadotville', 'Richie Smyth ', 'None', 108, 2016, 7.2, 63),
#  (421, '71', 'Yann Demange ', 'None', 99, 2014, 7.2, 72),
#  (422,
#   'Bajirao Mastani',
#   'Sanjay Leela Bhansali ',
#   'None',
#   158,
#   2015,
#   7.2,
#   50),
#  (423, 'Fist of Fury', 'Wei Lo ', 'None', 107, 1972, 7.2, 68),
#  (424, 'Harry Brown', 'Daniel Barber ', 'None', 103, 2009, 7.2, 64),
#  (425,
#   'The Good the Bad the Weird',
#   'Jee-woon Kim ',
#   'None',
#   130,
#   2008,
#   7.2,
#   60),
#  (426, 'Marshland', 'Alberto RodrÃ\xadguez', 'None', 105, 2014, 7.2, 68),
#  (427,
#   'Final Fantasy VII: Advent Children',
#   ' Tetsuya Nomura',
#   'Takeshi Nozue ',
#   101,
#   2005,
#   7.2,
#   50),
#  (428,
#   'Mongol: The Rise of Genghis Khan',
#   'Sergei Bodrov ',
#   'None',
#   126,
#   2007,
#   7.2,
#   54),
#  (429,
#   'Holiday: A Soldier is Never Off Duty',
#   'A.R. Murugadoss ',
#   'None',
#   160,
#   2014,
#   7.2,
#   49),
#  (318,
#   'Dungeons & Dragons: Honor Among Thieves',
#   ' John Francis Daley',
#   'Jonathan Goldstein ',
#   134,
#   2023,
#   7.3,
#   69),
#  (319, 'Bullet Train', 'David Leitch ', 'None', 127, 2022, 7.3, 74),
#  (320, 'Fast Five', 'Justin Lin ', 'None', 130, 2011, 7.3, 65),
#  (321, 'Tenet', 'Christopher Nolan ', 'None', 150, 2020, 7.3, 59),
#  (322, 'Ant-Man', 'Peyton Reed ', 'None', 117, 2015, 7.3, 62),
#  (323, 'Starship Troopers', 'Paul Verhoeven ', 'None', 129, 1997, 7.3, 55),
#  (324, 'No Time to Die', 'Cary Joji Fukunaga ', 'None', 163, 2021, 7.3, 81),
#  (325, 'True Lies', 'James Cameron ', 'None', 141, 1994, 7.3, 63),
#  (326, 'Men in Black', 'Barry Sonnenfeld ', 'None', 98, 1997, 7.3, 65),
#  (327, 'The Accountant', 'Gavin OConnor ', 'None', 128, 2016, 7.3, 62),
#  (328, 'The Nice Guys', 'Shane Black ', 'None', 116, 2016, 7.3, 55),
#  (329, 'Dawn of the Dead', 'Zack Snyder ', 'None', 101, 2004, 7.3, 53),
#  (330, 'Black Panther', 'Ryan Coogler ', 'None', 134, 2018, 7.3, 75),
#  (331, 'Speed', 'Jan de Bont ', 'None', 116, 1994, 7.3, 53),
#  (332, 'Avengers: Age of Ultron', 'Joss Whedon ', 'None', 141, 2015, 7.3, 69),
#  (333, 'Beverly Hills Cop', 'Martin Brest ', 'None', 105, 1984, 7.3, 78),
#  (334, 'Face/Off', 'John Woo ', 'None', 138, 1997, 7.3, 70),
#  (335, 'X-Men', 'Bryan Singer ', 'None', 104, 2000, 7.3, 64),
#  (336, '13 Hours', 'Michael Bay ', 'None', 144, 2016, 7.3, 67),
#  (337, 'Alita: Battle Angel', 'Robert Rodriguez ', 'None', 122, 2019, 7.3, 67),
#  (338, 'American Sniper', 'Clint Eastwood ', 'None', 133, 2014, 7.3, 67),
#  (339, 'The Karate Kid', 'John G. Avildsen ', 'None', 126, 1984, 7.3, 65),
#  (340,
#   'El Camino: A Breaking Bad Movie',
#   'Vince Gilligan ',
#   'None',
#   122,
#   2019,
#   7.3,
#   70),
#  (341,
#   'Pirates of the Caribbean: Dead Mans Chest',
#   'Gore Verbinski ',
#   'None',
#   151,
#   2006,
#   7.3,
#   59),
#  (342,
#   'Raya and the Last Dragon',
#   'Don Hall',
#   ' John Ripa ',
#   107,
#   2021,
#   7.3,
#   72),
#  (343, 'The Lego Batman Movie', 'Chris McKay ', 'None', 104, 2017, 7.3, 58),
#  (344, 'Equilibrium', 'Kurt Wimmer ', 'None', 107, 2002, 7.3, 74),
#  (345, 'Patriots Day', 'Peter Berg ', 'None', 133, 2016, 7.3, 64),
#  (346, 'Southpaw', 'Antoine Fuqua ', 'None', 124, 2015, 7.3, 58),
#  (347, 'Layer Cake', 'Matthew Vaughn ', 'None', 105, 2004, 7.3, 58),
#  (348, 'Megamind', 'Tom McGrath ', 'None', 95, 2010, 7.3, 61),
#  (349, 'Eye in the Sky', 'Gavin Hood ', 'None', 102, 2015, 7.3, 70),
#  (350,
#   'The Adventures of Tintin',
#   'Steven Spielberg ',
#   'None',
#   107,
#   2011,
#   7.3,
#   43),
#  (351, 'Enemy of the State', 'Tony Scott ', 'None', 132, 1998, 7.3, 65),
#  (352, 'Okja', 'Bong Joon Ho ', 'None', 120, 2017, 7.3, 62),
#  (353,
#   'To Live and Die in L.A.',
#   'William Friedkin ',
#   'None',
#   116,
#   1985,
#   7.3,
#   32),
#  (354, 'The Next Three Days', 'Paul Haggis ', 'None', 133, 2010, 7.3, 67),
#  (355, 'The Negotiator', 'F. Gary Gray ', 'None', 140, 1998, 7.3, 75),
#  (356, 'Invictus', 'Clint Eastwood ', 'None', 134, 2009, 7.3, 83),
#  (357, 'Nikita', 'Luc Besson ', 'None', 117, 1990, 7.3, 68),
#  (358,
#   'Star Trek IV: The Voyage Home',
#   'Leonard Nimoy ',
#   'None',
#   119,
#   1986,
#   7.3,
#   55),
#  (359, 'Crimson Tide', 'Tony Scott ', 'None', 116, 1995, 7.3, 69),
#  (360, 'Grosse Pointe Blank', 'George Armitage ', 'None', 107, 1997, 7.3, 74),
#  (361, 'Running Scared', 'Wayne Kramer ', 'None', 122, 2006, 7.3, 67),
#  (362, 'Shaolin Soccer', 'Stephen Chow ', 'None', 87, 2001, 7.3, 48),
#  (363, 'Assault on Precinct 13', 'John Carpenter ', 'None', 91, 1976, 7.3, 59),
#  (364, 'Jason and the Argonauts', 'Don Chaffey ', 'None', 104, 1963, 7.3, 62),
#  (365, 'The Getaway', 'Sam Peckinpah ', 'None', 123, 1972, 7.3, 57),
#  (366, 'Red Cliff', 'John Woo ', 'None', 148, 2008, 7.3, 71),
#  (367,
#   'Bacurau',
#   'Juliano Dornelles',
#   'Kleber MendonÃ§a Filho',
#   131,
#   2019,
#   7.3,
#   71),
#  (368, 'Get Carter', 'Mike Hodges ', 'None', 112, 1971, 7.3, 55),
#  (369, 'Ghajini', 'A.R. Murugadoss ', 'None', 186, 2008, 7.3, 64),
#  (370,
#   'Max Manus: Man of War',
#   'Joachim RÃ¸nning',
#   'Espen Sandberg ',
#   118,
#   2008,
#   7.3,
#   47),
#  (371, 'The Baader Meinhof Complex', 'Uli Edel ', 'None', 150, 2008, 7.3, 53),
#  (372, 'Master (I)', 'Lokesh Kanagaraj ', 'None', 178, 2021, 7.3, 68),
#  (284, 'John Wick', 'Chad Stahelski', 'David Leitch ', 101, 2014, 7.4, 69),
#  (285,
#   'John Wick: Chapter 3 - Parabellum',
#   'Chad Stahelski ',
#   'None',
#   130,
#   2019,
#   7.4,
#   57),
#  (286, 'John Wick: Chapter 2', 'Chad Stahelski ', 'None', 122, 2017, 7.4, 73),
#  (287,
#   'Shang-Chi and the Legend of the Ten Rings',
#   'Destin Daniel Cretton ',
#   'None',
#   132,
#   2021,
#   7.4,
#   63),
#  (288, 'Spider-Man: Homecoming', 'Jon Watts ', 'None', 133, 2017, 7.4, 73),
#  (289, 'Nobody (I)', 'Ilya Naishuller ', 'None', 92, 2021, 7.4, 68),
#  (290, 'Spider-Man', 'Sam Raimi ', 'None', 121, 2002, 7.4, 67),
#  (291, 'Ready Player One', 'Steven Spielberg ', 'None', 140, 2018, 7.4, 75),
#  (292,
#   'Mission: Impossible - Rogue Nation',
#   'Christopher McQuarrie ',
#   'None',
#   131,
#   2015,
#   7.4,
#   81),
#  (293,
#   'Mission: Impossible - Ghost Protocol',
#   'Brad Bird ',
#   'None',
#   132,
#   2011,
#   7.4,
#   52),
#  (294, 'The Last Duel', 'Ridley Scott ', 'None', 152, 2021, 7.4, 62),
#  (295, 'Wonder Woman', 'Patty Jenkins ', 'None', 141, 2017, 7.4, 74),
#  (296, 'Superman', 'Richard Donner ', 'None', 143, 1978, 7.4, 56),
#  (297, 'Spider-Man: Far from Home', 'Jon Watts ', 'None', 129, 2019, 7.4, 71),
#  (298, 'Spider-Man 2', 'Sam Raimi ', 'None', 127, 2004, 7.4, 66),
#  (299, 'The Rock', 'Michael Bay ', 'None', 136, 1996, 7.4, 76),
#  (300,
#   'Predestination (I)',
#   ' Michael Spierig',
#   'Peter Spierig ',
#   97,
#   2014,
#   7.4,
#   41),
#  (301, 'Looper', 'Rian Johnson ', 'None', 119, 2012, 7.4, 68),
#  (302,
#   'A History of Violence',
#   'David Cronenberg ',
#   'None',
#   96,
#   2005,
#   7.4,
#   89),
#  (303, 'Law Abiding Citizen', 'F. Gary Gray ', 'None', 109, 2009, 7.4, 69),
#  (304, 'X2: X-Men United', 'Bryan Singer ', 'None', 134, 2003, 7.4, 55),
#  (305,
#   'War for the Planet of the Apes',
#   'Matt Reeves ',
#   'None',
#   140,
#   2017,
#   7.4,
#   73),
#  (306,
#   'How to Train Your Dragon: The Hidden World',
#   'Dean DeBlois ',
#   'None',
#   104,
#   2019,
#   7.4,
#   82),
#  (307,
#   'Sherlock Holmes: A Game of Shadows',
#   'Guy Ritchie ',
#   'None',
#   129,
#   2011,
#   7.4,
#   80),
#  (308, 'Bullitt', 'Peter Yates ', 'None', 114, 1968, 7.4, 60),
#  (309, 'From Russia with Love', 'Terence Young ', 'None', 115, 1963, 7.4, 76),
#  (310, 'Open Range', 'Kevin Costner ', 'None', 139, 2003, 7.4, 72),
#  (311, 'Thief', 'Michael Mann ', 'None', 123, 1981, 7.4, 68),
#  (312, 'Mission Majnu', 'Shantanu Bagchi ', 'None', 129, 2023, 7.4, 48),
#  (313, 'Black Dynamite', 'Scott Sanders ', 'None', 84, 2009, 7.4, 57),
#  (314,
#   'Rurouni Kenshin Part I: Origins',
#   'Keishi Otomo ',
#   'None',
#   134,
#   2012,
#   7.4,
#   47),
#  (315, 'Drunken Master', 'Woo-Ping Yuen ', 'None', 111, 1978, 7.4, 59),
#  (316, 'Summer Wars', 'Mamoru Hosoda ', 'None', 114, 2009, 7.4, 56),
#  (317,
#   'Mesrine: Public Enemy No. 1',
#   'Jean-FranÃ§ois Richet ',
#   'None',
#   133,
#   2008,
#   7.4,
#   63),
#  (246,
#   'Its a Mad Mad Mad Mad World',
#   'Stanley Kramer ',
#   'None',
#   210,
#   1963,
#   7.5,
#   82),
#  (247,
#   'Indiana Jones and the Temple of Doom',
#   'Steven Spielberg ',
#   'None',
#   118,
#   1984,
#   7.5,
#   71),
#  (248, 'Lone Survivor', 'Peter Berg ', 'None', 121, 2013, 7.5, 48),
#  (249, 'Batman', 'Tim Burton ', 'None', 126, 1989, 7.5, 81),
#  (250,
#   'Scott Pilgrim vs. the World',
#   'Edgar Wright ',
#   'None',
#   112,
#   2010,
#   7.5,
#   83),
#  (251,
#   'Harry Potter and the Order of the Phoenix',
#   'David Yates ',
#   'None',
#   138,
#   2007,
#   7.5,
#   67),
#  (252, 'Fury', 'David Ayer ', 'None', 134, 2014, 7.5, 78),
#  (253,
#   'The Hunger Games: Catching Fire',
#   'Francis Lawrence ',
#   'None',
#   146,
#   2013,
#   7.5,
#   65),
#  (254, 'Upgrade', 'Leigh Whannell ', 'None', 100, 2018, 7.5, 68),
#  (255, 'The Crow', 'Alex Proyas ', 'None', 102, 1994, 7.5, 63),
#  (256, 'Total Recall', 'Paul Verhoeven ', 'None', 113, 1990, 7.5, 72),
#  (257, 'Doctor Strange', 'Scott Derrickson ', 'None', 115, 2016, 7.5, 72),
#  (258,
#   'Master and Commander: The Far Side of the World',
#   'Peter Weir ',
#   'None',
#   138,
#   2003,
#   7.5,
#   49),
#  (259, 'Collateral', 'Michael Mann ', 'None', 120, 2004, 7.5, 66),
#  (260,
#   'Enemy at the Gates',
#   'Jean-Jacques Annaud ',
#   'None',
#   131,
#   2001,
#   7.5,
#   69),
#  (261,
#   'Riders of Justice',
#   'Anders Thomas Jensen ',
#   'None',
#   116,
#   2020,
#   7.5,
#   64),
#  (262, 'Source Code', 'Duncan Jones ', 'None', 93, 2011, 7.5, 52),
#  (263, 'Munich', 'Steven Spielberg ', 'None', 164, 2005, 7.5, 68),
#  (264,
#   'The Hunt for Red October',
#   'John McTiernan ',
#   'None',
#   135,
#   1990,
#   7.5,
#   63),
#  (265, 'Grindhouse', ' Robert Rodriguez', 'Eli Roth', 191, 2007, 7.5, 71),
#  (266, 'Midnight Run', 'Martin Brest ', 'None', 126, 1988, 7.5, 51),
#  (267, 'The Guns of Navarone', 'J. Lee Thompson ', 'None', 158, 1961, 7.5, 70),
#  (268,
#   'Tora! Tora! Tora!',
#   ' Richard Fleischer',
#   'Akira Kurosawa ',
#   144,
#   1970,
#   7.5,
#   59),
#  (269, 'Headhunters', 'Morten Tyldum ', 'None', 100, 2011, 7.5, 88),
#  (270, 'Police Story', 'Jackie Chan', ' Chi-Hwa Chen ', 100, 1985, 7.5, 78),
#  (271, 'Ip Man 2', 'Wilson Yip ', 'None', 108, 2010, 7.5, 66),
#  (272, '13 Assassins', 'Takashi Miike ', 'None', 141, 2010, 7.5, 66),
#  (273, 'New World', 'Park Hoon-jung ', 'None', 135, 2013, 7.5, 82),
#  (274, 'House of Flying Daggers', 'Yimou Zhang ', 'None', 119, 2004, 7.5, 64),
#  (275, 'A Bittersweet Life', 'Jee-woon Kim ', 'None', 119, 2005, 7.5, 48),
#  (276,
#   'The Legend of Drunken Master',
#   'Chia-Liang Liu',
#   'Jackie Chan',
#   102,
#   1994,
#   7.5,
#   53),
#  (277, 'Tanhaji: The Unsung Warrior', 'Om Raut ', 'None', 135, 2020, 7.5, 72),
#  (278,
#   'The Blind Swordsman: Zatoichi',
#   'Takeshi Kitano ',
#   'None',
#   116,
#   2003,
#   7.5,
#   60),
#  (279,
#   'Mesrine: Killer Instinct',
#   'Jean-FranÃ§ois Richet ',
#   'None',
#   113,
#   2008,
#   7.5,
#   72),
#  (280, 'Jodhaa Akbar', 'Ashutosh Gowariker ', 'None', 213, 2008, 7.5, 53),
#  (281, 'Delhi Belly', 'Abhinay Deo', 'Akshat Verma ', 103, 2011, 7.5, 74),
#  (282, 'Mersal', 'Atlee ', 'None', 172, 2017, 7.5, 75),
#  (283, 'To Strike', 'Bilal Lashari ', 'None', 130, 2013, 7.5, 33),
#  (200,
#   'Guy Ritchies The Covenant',
#   'Guy Ritchie ',
#   'None',
#   123,
#   2023,
#   7.6,
#   71),
#  (201,
#   'Guardians of the Galaxy Vol. 2',
#   'James Gunn ',
#   'None',
#   136,
#   2017,
#   7.6,
#   60),
#  (202, 'The Fifth Element', 'Luc Besson ', 'None', 126, 1997, 7.6, 72),
#  (203, 'Sicario', 'Denis Villeneuve ', 'None', 121, 2015, 7.6, 81),
#  (204, '300', 'Zack Snyder ', 'None', 117, 2006, 7.6, 71),
#  (205, 'Baby Driver', 'Edgar Wright ', 'None', 113, 2017, 7.6, 53),
#  (206,
#   'Star Wars: Episode III - Revenge of the Sith',
#   'George Lucas ',
#   'None',
#   140,
#   2005,
#   7.6,
#   81),
#  (207, 'Deadpool 2', 'David Leitch ', 'None', 119, 2018, 7.6, 74),
#  (208, 'Watchmen', 'Zack Snyder ', 'None', 162, 2009, 7.6, 74),
#  (209,
#   'Harry Potter and the Half-Blood Prince',
#   'David Yates ',
#   'None',
#   153,
#   2009,
#   7.6,
#   58),
#  (210, 'Kung Fu Panda', 'Mark Osborne', 'John Stevenson', 92, 2008, 7.6, 77),
#  (211, 'RoboCop', 'Paul Verhoeven ', 'None', 102, 1987, 7.6, 78),
#  (212, 'Train to Busan', 'Sang-ho Yeon ', 'None', 118, 2016, 7.6, 72),
#  (213, 'The Warriors', 'Walter Hill ', 'None', 93, 1979, 7.6, 46),
#  (214, 'Creed (II)', 'Ryan Coogler ', 'None', 133, 2015, 7.6, 72),
#  (215, 'Incredibles 2', 'Brad Bird ', 'None', 118, 2018, 7.6, 78),
#  (216, 'The Road Warrior', 'George Miller ', 'None', 96, 1981, 7.6, 67),
#  (217, 'Kick-Ass', 'Matthew Vaughn ', 'None', 117, 2010, 7.6, 84),
#  (218, 'Falling Down', 'Joel Schumacher ', 'None', 113, 1993, 7.6, 58),
#  (219, 'Zombieland', 'Ruben Fleischer ', 'None', 88, 2009, 7.6, 89),
#  (220, 'Minority Report', 'Steven Spielberg ', 'None', 145, 2002, 7.6, 74),
#  (221, 'Sherlock Holmes', 'Guy Ritchie ', 'None', 128, 2009, 7.6, 75),
#  (222,
#   'Rise of the Planet of the Apes',
#   'Rupert Wyatt ',
#   'None',
#   105,
#   2011,
#   7.6,
#   71),
#  (223, 'The Raid: Redemption', 'Gareth Evans ', 'None', 101, 2011, 7.6, 69),
#  (224,
#   'Dawn of the Planet of the Apes',
#   'Matt Reeves ',
#   'None',
#   130,
#   2014,
#   7.6,
#   66),
#  (225, 'Where Eagles Dare', 'Brian G. Hutton ', 'None', 158, 1968, 7.6, 68),
#  (226, 'End of Watch', 'David Ayer ', 'None', 109, 2012, 7.6, 73),
#  (227, 'Lethal Weapon', 'Richard Donner ', 'None', 109, 1987, 7.6, 75),
#  (228, 'Battle Royale', 'Kinji Fukasaku ', 'None', 114, 2000, 7.6, 71),
#  (229, 'Enter the Dragon', 'Robert Clouse ', 'None', 102, 1973, 7.6, 73),
#  (230,
#   'Die Hard with a Vengeance',
#   'John McTiernan ',
#   'None',
#   128,
#   1995,
#   7.6,
#   64),
#  (231,
#   'Star Trek: First Contact',
#   'Jonathan Frakes ',
#   'None',
#   111,
#   1996,
#   7.6,
#   73),
#  (232, 'Hotel Mumbai', 'Anthony Maras ', 'None', 123, 2018, 7.6, 64),
#  (233, 'Only the Brave', 'Joseph Kosinski ', 'None', 134, 2017, 7.6, 75),
#  (234, 'Escape from Alcatraz', 'Don Siegel ', 'None', 112, 1979, 7.6, 73),
#  (235, 'United 93', 'Paul Greengrass ', 'None', 111, 2006, 7.6, 67),
#  (236,
#   'The Taking of Pelham One Two Three',
#   'Joseph Sargent ',
#   'None',
#   104,
#   1974,
#   7.6,
#   76),
#  (237,
#   'Vampire Hunter D: Bloodlust',
#   'Jack Fletcher',
#   'Yoshiaki Kawajiri ',
#   103,
#   2000,
#   7.6,
#   82),
#  (238, 'Fearless', 'Ronny Yu ', 'None', 104, 2006, 7.6, 69),
#  (239, 'Pushpa: The Rise - Part 1', 'Sukumar ', 'None', 179, 2021, 7.6, 83),
#  (240, 'Ludo', 'Anurag Basu ', 'None', 149, 2020, 7.6, 58),
#  (241,
#   'Evangelion: 1.0 You Are (Not) Alone',
#   ' Masayuki',
#   'Hideaki Anno ',
#   98,
#   2007,
#   7.6,
#   69),
#  (242, 'Cell 211', 'Daniel MonzÃ³n ', 'None', 113, 2009, 7.6, 84),
#  (243,
#   'Lupin III: The Castle of Cagliostro',
#   'Hayao Miyazaki ',
#   'None',
#   102,
#   1979,
#   7.6,
#   82),
#  (244, 'The Boy and the Beast', 'Mamoru Hosoda ', 'None', 119, 2015, 7.6, 34),
#  (245, 'Mortal World', 'Ali Atay ', 'None', 107, 2018, 7.6, 68),
#  (163,
#   'Avatar: The Way of Water',
#   'James Cameron ',
#   'None',
#   192,
#   2022,
#   7.7,
#   82),
#  (164,
#   'Kingsman: The Secret Service',
#   'Matthew Vaughn ',
#   'None',
#   129,
#   2014,
#   7.7,
#   80),
#  (165, 'Star Trek Into Darkness', 'J.J. Abrams ', 'None', 132, 2013, 7.7, 77),
#  (166,
#   'Mission: Impossible - Fallout',
#   'Christopher McQuarrie ',
#   'None',
#   147,
#   2018,
#   7.7,
#   66),
#  (167, 'Black Hawk Down', 'Ridley Scott ', 'None', 144, 2001, 7.7, 56),
#  (168,
#   'The Count of Monte Cristo',
#   'Kevin Reynolds ',
#   'None',
#   131,
#   2002,
#   7.7,
#   73),
#  (169, '3:10 to Yuma', 'James Mangold ', 'None', 122, 2007, 7.7, 80),
#  (170,
#   'The Last of the Mohicans',
#   'Michael Mann ',
#   'None',
#   112,
#   1992,
#   7.7,
#   57),
#  (171,
#   'The Lego Movie',
#   ' Phil Lord',
#   'Christopher Miller ',
#   100,
#   2014,
#   7.7,
#   68),
#  (172, 'X-Men: First Class', 'Matthew Vaughn ', 'None', 131, 2011, 7.7, 73),
#  (173, 'Training Day', 'Antoine Fuqua ', 'None', 122, 2001, 7.7, 79),
#  (174, 'The Dirty Dozen', 'Robert Aldrich ', 'None', 150, 1967, 7.7, 63),
#  (175, 'Man on Fire', 'Tony Scott ', 'None', 146, 2004, 7.7, 68),
#  (176, 'First Blood', 'Ted Kotcheff ', 'None', 93, 1982, 7.7, 68),
#  (177, 'The Magnificent Seven', 'John Sturges ', 'None', 128, 1960, 7.7, 81),
#  (178, 'Kung Fu Hustle', 'Stephen Chow ', 'None', 99, 2004, 7.7, 83),
#  (179, 'The Boondock Saints', 'Troy Duffy ', 'None', 108, 1999, 7.7, 58),
#  (180, 'Goldfinger', 'Guy Hamilton ', 'None', 110, 1964, 7.7, 71),
#  (181, 'The Longest Day', ' Ken Annakin', 'Andrew Marton', 178, 1962, 7.7, 62),
#  (182, 'Dirty Harry', 'Don Siegel', 'Clint Eastwood ', 102, 1971, 7.7, 72),
#  (183,
#   'Star Trek II: The Wrath of Khan',
#   'Nicholas Meyer ',
#   'None',
#   113,
#   1982,
#   7.7,
#   76),
#  (184, 'The Bourne Supremacy', 'Paul Greengrass ', 'None', 108, 2004, 7.7, 90),
#  (185, 'Bonnie and Clyde', 'Arthur Penn ', 'None', 111, 1967, 7.7, 68),
#  (186,
#   'The French Connection',
#   'William Friedkin ',
#   'None',
#   104,
#   1971,
#   7.7,
#   62),
#  (187, 'Badlands', 'Terrence Malick ', 'None', 94, 1973, 7.7, 70),
#  (188, 'Run Lola Run', 'Tom Tykwer ', 'None', 80, 1998, 7.7, 66),
#  (189,
#   'Kubo and the Two Strings',
#   'Travis Knight ',
#   'None',
#   101,
#   2016,
#   7.7,
#   72),
#  (190, 'Ponniyin Selvan: Part I', 'Mani Ratnam ', 'None', 167, 2022, 7.7, 65),
#  (191, 'Key Largo', 'John Huston ', 'None', 100, 1948, 7.7, 59),
#  (192, 'The Man from Nowhere', 'Jeong-beom Lee ', 'None', 119, 2010, 7.7, 57),
#  (193, 'Hard Boiled', 'John Woo ', 'None', 128, 1992, 7.7, 60),
#  (194, 'Scarface', 'Howard Hawks ', 'Richard Rosson', 93, 1932, 7.7, 69),
#  (195,
#   'Dragon Ball Super: Broly',
#   'Tatsuya Nagamine ',
#   'None',
#   100,
#   2018,
#   7.7,
#   69),
#  (196, 'Joint Security Area', 'Park Chan-wook ', 'None', 110, 2000, 7.7, 71),
#  (197, 'Eega', 'S.S. Rajamouli ', 'None', 145, 2012, 7.7, 64),
#  (198, 'Udta Punjab', 'Abhishek Chaubey ', 'None', 148, 2016, 7.7, 76),
#  (199, 'Raazi', 'Meghna Gulzar ', 'None', 138, 2018, 7.7, 67),
#  (129,
#   'Everything Everywhere All at Once',
#   'Daniel Kwan',
#   ' Daniel Scheinert ',
#   139,
#   2022,
#   7.8,
#   69),
#  (130, 'The Batman', 'Matt Reeves ', 'None', 176, 2022, 7.8, 73),
#  (131, 'RRR', 'S.S. Rajamouli ', 'None', 187, 2022, 7.8, 47),
#  (132, 'The Gentlemen', 'Guy Ritchie ', 'None', 113, 2019, 7.8, 61),
#  (133,
#   'All Quiet on the Western Front',
#   'Edward Berger ',
#   'None',
#   148,
#   2022,
#   7.8,
#   74),
#  (134, 'Drive (I)', 'Nicolas Winding Refn ', 'None', 100, 2011, 7.8, 78),
#  (135,
#   'Rogue One: A Star Wars Story',
#   'Gareth Edwards ',
#   'None',
#   133,
#   2016,
#   7.8,
#   44),
#  (136,
#   'Star Wars: Episode VII - The Force Awakens',
#   'J.J. Abrams ',
#   'None',
#   138,
#   2015,
#   7.8,
#   87),
#  (137, 'Apocalypto', 'Mel Gibson ', 'None', 139, 2006, 7.8, 75),
#  (138, 'Dunkirk', 'Christopher Nolan ', 'None', 106, 2017, 7.8, 87),
#  (139, 'Ghostbusters', 'Ivan Reitman ', 'None', 105, 1984, 7.8, 68),
#  (140, 'Predator', 'John McTiernan ', 'None', 107, 1987, 7.8, 73),
#  (141, 'Hot Fuzz', 'Edgar Wright ', 'None', 121, 2007, 7.8, 86),
#  (142,
#   'Captain America: Civil War',
#   ' Anthony Russo',
#   ' Joe Russo ',
#   147,
#   2016,
#   7.8,
#   94),
#  (143, 'Taken (I)', 'Pierre Morel ', 'None', 90, 2008, 7.8, 93),
#  (144, 'Skyfall', 'Sam Mendes ', 'None', 143, 2012, 7.8, 77),
#  (145,
#   'Captain America: The Winter Soldier',
#   'Anthony Russo',
#   ' Joe Russo ',
#   136,
#   2014,
#   7.8,
#   84),
#  (146, 'The Fugitive', 'Andrew Davis ', 'None', 130, 1993, 7.8, 90),
#  (147, 'Big Hero 6', 'Don Hall', 'Chris Williams ', 102, 2014, 7.8, 59),
#  (148, 'Captain Phillips', 'Paul Greengrass ', 'None', 134, 2013, 7.8, 58),
#  (149, 'I Saw the Devil', 'Jee-woon Kim ', 'None', 144, 2010, 7.8, 63),
#  (150, 'The Last Samurai', 'Edward Zwick ', 'None', 154, 2003, 7.8, 67),
#  (151, 'Serenity', 'Joss Whedon ', 'None', 119, 2005, 7.8, 52),
#  (152, 'Thirteen Lives', 'Ron Howard ', 'None', 147, 2022, 7.8, 82),
#  (153, 'The Fighter (I)', 'David O. Russell ', 'None', 116, 2010, 7.8, 52),
#  (154,
#   'How to Train Your Dragon 2',
#   'Dean DeBlois ',
#   'None',
#   102,
#   2014,
#   7.8,
#   86),
#  (155, 'The Chaser', 'Na Hong-jin ', 'None', 125, 2008, 7.8, 68),
#  (156,
#   'Aguirre the Wrath of God',
#   'Werner Herzog ',
#   'None',
#   95,
#   1972,
#   7.8,
#   66),
#  (157, 'Ninja Scroll', 'Yoshiaki Kawajiri ', 'None', 94, 1993, 7.8, 56),
#  (158,
#   'Batman: Mask of the Phantasm',
#   ' Bruce Timm',
#   'Dan Riba',
#   76,
#   1993,
#   7.8,
#   78),
#  (159, 'The Killer', 'John Woo ', 'None', 111, 1989, 7.8, 74),
#  (160,
#   'Cowboy Bebop: The Movie',
#   ' Yoshiyuki Takei',
#   ' Hiroyuki Okiura',
#   115,
#   2001,
#   7.8,
#   70),
#  (161, 'Knockin on Heavens Door', 'Thomas Jahn ', 'None', 87, 1997, 7.8, 73),
#  (162, 'Minnal Murali', 'Basil Joseph ', 'None', 158, 2021, 7.8, 65),
#  (107, 'Thor: Ragnarok', 'Taika Waititi ', 'None', 130, 2017, 7.9, 74),
#  (108, 'Avatar', 'James Cameron ', 'None', 162, 2009, 7.9, 82),
#  (109, 'Iron Man', 'Jon Favreau ', 'None', 126, 2008, 7.9, 67),
#  (110, 'Star Trek', 'J.J. Abrams ', 'None', 127, 2009, 7.9, 55),
#  (111, 'Edge of Tomorrow', 'Doug Liman ', 'None', 113, 2014, 7.9, 74),
#  (112, 'Children of Men', 'Alfonso CuarÃ³n', 'None', 109, 2006, 7.9, 66),
#  (113,
#   'X-Men: Days of Future Past',
#   'Bryan Singer ',
#   'None',
#   132,
#   2014,
#   7.9,
#   79),
#  (114, 'District 9', 'Neill Blomkamp ', 'None', 112, 2009, 7.9, 77),
#  (115, 'The Bourne Identity', 'Doug Liman ', 'None', 119, 2002, 7.9, 64),
#  (116, 'The Blues Brothers', 'John Landis ', 'None', 133, 1980, 7.9, 65),
#  (117,
#   'Crouching Tiger Hidden Dragon',
#   'Ang Lee ',
#   'None',
#   120,
#   2000,
#   7.9,
#   82),
#  (118, 'Ghost in the Shell', 'Mamoru Oshii ', 'None', 83, 1995, 7.9, 61),
#  (119, 'A Fistful of Dollars', 'Sergio Leone ', 'None', 99, 1964, 7.9, 67),
#  (120, 'The Raid 2', 'Gareth Evans ', 'None', 150, 2014, 7.9, 60),
#  (121, 'The Wild Bunch', 'Sam Peckinpah ', 'None', 135, 1969, 7.9, 72),
#  (122, 'Hero', 'Yimou Zhang ', 'None', 120, 2002, 7.9, 86),
#  (123, 'Letters from Iwo Jima', 'Clint Eastwood ', 'None', 141, 2006, 7.9, 74),
#  (124, 'A Taxi Driver', 'Hun Jang ', 'None', 137, 2017, 7.9, 61),
#  (125,
#   'The Adventures of Robin Hood',
#   ' Michael Curtiz',
#   'William Keighley ',
#   102,
#   1938,
#   7.9,
#   76),
#  (126, 'Baby (I)', 'Neeraj Pandey ', 'None', 159, 2015, 7.9, 76),
#  (127, 'Airlift', 'Raja Menon ', 'None', 130, 2016, 7.9, 83),
#  (128, 'Vishwaroopam', 'Kamal Haasan ', 'None', 148, 2013, 7.9, 65),
#  (80, 'John Wick: Chapter 4', 'Chad Stahelski ', 'None', 169, 2023, 8, 94),
#  (81, 'Guardians of the Galaxy', 'James Gunn ', 'None', 121, 2014, 8, 76),
#  (82, 'Dune', 'Denis Villeneuve ', 'None', 155, 2021, 8, 65),
#  (83, 'Blade Runner 2049', 'Denis Villeneuve ', 'None', 164, 2017, 8, 71),
#  (84, 'Deadpool', 'Tim Miller ', 'None', 108, 2016, 8, 98),
#  (85, 'The Avengers', 'Joss Whedon ', 'None', 143, 2012, 8, 85),
#  (86, 'Zack Snyders Justice League', 'Zack Snyder ', 'None', 242, 2021, 8, 89),
#  (87, 'The Incredibles', 'Brad Bird ', 'None', 115, 2004, 8, 69),
#  (88, 'Casino Royale', 'Martin Campbell ', 'None', 144, 2006, 8, 97),
#  (89,
#   'The Revenant (I)',
#   'Alejandro G. IÃ±Ã¡rritu  ',
#   'None',
#   156,
#   2015,
#   8,
#   81),
#  (90, 'Akira', ' Katsuhiro Ã”tomo', 'None', 124, 1988, 8, 72),
#  (91, 'Kill Bill: Vol. 2', 'Quentin Tarantino ', 'None', 137, 2004, 8, 83),
#  (92, 'Ip Man', 'Wilson Yip ', 'None', 106, 2008, 8, 51),
#  (93, 'The Bourne Ultimatum', 'Paul Greengrass ', 'None', 115, 2007, 8, 76),
#  (94, 'Baahubali: The Beginning', 'S.S. Rajamouli ', 'None', 159, 2015, 8, 78),
#  (95, 'Infernal Affairs', 'Andrew Lau', 'Alan Mak ', 101, 2002, 8, 65),
#  (96, 'Wolfwalkers', 'Tomm Moore', 'Ross Stewart ', 103, 2020, 8, 80),
#  (97, 'Elite Squad', ' JosÃ© Padilha ', 'None', 115, 2007, 8, 68),
#  (98, 'Haider', 'Vishal Bhardwaj ', 'None', 160, 2014, 8, 94),
#  (99, 'Sanjuro', 'Akira Kurosawa ', 'None', 96, 1962, 8, 71),
#  (100,
#   'Elite Squad 2: The Enemy Within',
#   ' JosÃ© Padilha ',
#   'None',
#   115,
#   2010,
#   8,
#   47),
#  (101,
#   'Tae Guk Gi: The Brotherhood of War',
#   'Je-kyu Kang ',
#   'None',
#   140,
#   2004,
#   8,
#   81),
#  (102, 'Andaz Apna Apna', 'Rajkumar Santoshi ', 'None', 160, 1994, 8, 75),
#  (103, 'Karthikeya 2', 'Chandoo Mondeti ', 'None', 150, 2022, 8, 51),
#  (104, 'Arjun Reddy', 'Sandeep Reddy Vanga ', 'None', 182, 2017, 8, 81),
#  (105, '1: Nenokkadine', 'Sukumar ', 'None', 170, 2014, 8, 70),
#  (106, 'The Breath', 'Levent Semerci ', 'None', 128, 2009, 8, 87),
#  (57, 'Mad Max: Fury Road', 'George Miller ', 'None', 120, 2015, 8.1, 54),
#  (58, 'Ford v Ferrari', 'James Mangold ', 'None', 152, 2019, 8.1, 90),
#  (59,
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Gore Verbinski ',
#   'None',
#   143,
#   2003,
#   8.1,
#   80),
#  (60, 'Blade Runner', 'Ridley Scott ', 'None', 117, 1982, 8.1, 76),
#  (61, 'The Terminator', 'James Cameron ', 'None', 107, 1984, 8.1, 67),
#  (62, 'Logan', 'James Mangold ', 'None', 137, 2017, 8.1, 83),
#  (63,
#   'Lock Stock and Two Smoking Barrels',
#   'Guy Ritchie ',
#   'None',
#   107,
#   1998,
#   8.1,
#   59),
#  (64,
#   'How to Train Your Dragon',
#   'Dean DeBlois',
#   'Chris Sanders',
#   98,
#   2010,
#   8.1,
#   85),
#  (65, 'Warrior', 'Gavin OConnor ', 'None', 140, 2011, 8.1, 75),
#  (66, 'Rush (I)', 'Ron Howard ', 'None', 123, 2013, 8.1, 87),
#  (67, 'The Iron Giant', 'Brad Bird ', 'None', 86, 1999, 8.1, 33),
#  (68,
#   'Neon Genesis Evangelion: The End of Evangelion',
#   'Hideaki Anno',
#   'Kazuya Tsurumaki ',
#   87,
#   1997,
#   8.1,
#   71),
#  (69, 'Sholay', 'Ramesh Sippy ', 'None', 162, 1975, 8.1, 64),
#  (70, 'Bajrangi Bhaijaan', 'Kabir Khan', 'Mehmet Tutkun', 163, 2015, 8.1, 74),
#  (71, 'The General', ' Clyde Bruckman', 'Buster Keaton ', 67, 1926, 8.1, 83),
#  (72, 'The Hidden Fortress', 'Akira Kurosawa ', 'None', 126, 1958, 8.1, 79),
#  (73, 'White Heat', 'Raoul Walsh ', 'None', 114, 1949, 8.1, 82),
#  (74, 'A Wednesday', 'Neeraj Pandey ', 'None', 104, 2008, 8.1, 71),
#  (75, 'Major', 'Sashi Kiran Tikka ', 'None', 150, 2022, 8.1, 84),
#  (76, 'Sarfarosh', 'John Mathew Matthan ', 'None', 174, 1999, 8.1, 75),
#  (77, 'Hera Pheri', 'Priyadarshan ', 'None', 156, 2000, 8.1, 81),
#  (78, 'Kaththi', 'A.R. Murugadoss ', 'None', 166, 2014, 8.1, 68),
#  (79, 'Thuppakki', 'A.R. Murugadoss ', 'None', 165, 2012, 8.1, 60),
#  (36,
#   'Guardians of the Galaxy Vol. 3',
#   'James Gunn ',
#   'None',
#   150,
#   2023,
#   8.2,
#   97),
#  (37, 'Spider-Man: No Way Home', 'Jon Watts ', 'None', 148, 2021, 8.2, 89),
#  (38, 'Jurassic Park', 'Steven Spielberg ', 'None', 127, 1993, 8.2, 93),
#  (39,
#   'Indiana Jones and the Last Crusade',
#   'Steven Spielberg ',
#   'None',
#   127,
#   1989,
#   8.2,
#   90),
#  (40, '1917', 'Sam Mendes ', 'None', 119, 2019, 8.2, 81),
#  (41, 'Kill Bill: Vol. 1', 'Quentin Tarantino ', 'None', 111, 2003, 8.2, 63),
#  (42, 'Batman Begins', 'Christopher Nolan ', 'None', 140, 2005, 8.2, 84),
#  (43, 'Die Hard', 'John McTiernan ', 'None', 132, 1988, 8.2, 84),
#  (44, 'V for Vendetta', 'James McTeigue ', 'None', 132, 2005, 8.2, 77),
#  (45,
#   'Demon Slayer the Movie: Mugen Train',
#   'Haruo Sotozaki ',
#   'None',
#   117,
#   2020,
#   8.2,
#   66),
#  (46, 'Ran', 'Akira Kurosawa ', 'None', 162, 1985, 8.2, 75),
#  (47, 'Gangs of Wasseypur', 'Anurag Kashyap ', 'None', 321, 2012, 8.2, 71),
#  (48, 'Vikram Vedha', 'Gayatri', 'Pushkar', 147, 2017, 8.2, 74),
#  (49,
#   'Baahubali 2: The Conclusion',
#   'S.S. Rajamouli ',
#   'None',
#   167,
#   2017,
#   8.2,
#   85),
#  (50, 'Yojimbo', 'Akira Kurosawa ', 'None', 110, 1961, 8.2, 89),
#  (51, 'Uri: The Surgical Strike', 'Aditya Dhar ', 'None', 138, 2019, 8.2, 78),
#  (52, 'K.G.F: Chapter 1', 'Prashanth Neel ', 'None', 156, 2018, 8.2, 76),
#  (53, 'Sherlock Jr.', 'Buster Keaton ', 'None', 45, 1924, 8.2, 74),
#  (54, 'Rangasthalam 1985', 'Sukumar ', 'None', 170, 2018, 8.2, 81),
#  (55, 'The Mountain II', 'Alper Caglar ', 'None', 135, 2016, 8.2, 65),
#  (56, 'Paan Singh Tomar', 'Tigmanshu Dhulia ', 'None', 135, 2012, 8.2, 69),
#  (25, 'Top Gun: Maverick', 'Joseph Kosinski ', 'None', 130, 2022, 8.3, 98),
#  (26, 'Heat', 'Michael Mann ', 'None', 170, 1995, 8.3, 64),
#  (27,
#   'Star Wars: Episode VI - Return of the Jedi',
#   'Richard Marquand ',
#   'None',
#   131,
#   1983,
#   8.3,
#   71),
#  (28, 'Princess Mononoke', 'Hayao Miyazaki ', 'None', 134, 1997, 8.3, 68),
#  (29, 'North by Northwest', 'Alfred Hitchcock ', 'None', 136, 1959, 8.3, 65),
#  (30, 'Kantara', 'Rishab Shetty ', 'None', 148, 2022, 8.3, 78),
#  (31, 'Dangal', 'Nitesh Tiwari ', 'None', 161, 2016, 8.3, 69),
#  (32, 'K.G.F: Chapter 2', 'Prashanth Neel ', 'None', 168, 2022, 8.3, 70),
#  (33, 'Vikram', 'Lokesh Kanagaraj ', 'None', 175, 2022, 8.3, 72),
#  (34, 'Raatchasan', 'Ram Kumar ', 'None', 170, 2018, 8.3, 62),
#  (35, 'Shershaah', 'Vishnuvardhan ', 'None', 135, 2021, 8.3, 72),
#  (16,
#   'Spider-Man: Into the Spider-Verse',
#   'Bob Persichetti',
#   'Peter Ramsay',
#   117,
#   2018,
#   8.4,
#   85),
#  (17, 'Avengers: Endgame', 'Anthony Russo', 'Joe Russo', 181, 2019, 8.4, 68),
#  (18,
#   'Indiana Jones and the Raiders of the Lost Ark',
#   'Steven Spielberg ',
#   'None',
#   115,
#   1981,
#   8.4,
#   77),
#  (19,
#   'Avengers: Infinity War',
#   'Anthony Russo',
#   'Joe Russo',
#   149,
#   2018,
#   8.4,
#   78),
#  (20, 'Oldboy', 'Park Chan-wook ', 'None', 101, 2003, 8.4, 84),
#  (21,
#   'The Dark Knight Rises',
#   'Christopher Nolan ',
#   'None',
#   164,
#   2012,
#   8.4,
#   78),
#  (22, 'Aliens', 'James Cameron ', 'None', 137, 1986, 8.4, 76),
#  (23, 'Kaithi', 'Lokesh Kanagaraj ', 'None', 145, 2019, 8.4, 58),
#  (24, 'Asuran', 'Vetrimaaran ', 'None', 141, 2019, 8.4, 76),
#  (14, 'Leon : The Professional', 'Luc Besson ', 'None', 110, 1994, 8.5, 87),
#  (15, 'Gladiator', 'Ridley Scott ', 'None', 155, 2000, 8.5, 78),
#  (9,
#   'Star Wars: Episode IV - A New Hope',
#   'George Lucas ',
#   'None',
#   121,
#   1977,
#   8.6,
#   75),
#  (10,
#   'Terminator 2: Judgment Day',
#   'James Cameron ',
#   'None',
#   137,
#   1991,
#   8.6,
#   98),
#  (11, 'Seven Samurai', 'Akira Kurosawa ', 'None', 207, 1954, 8.6, 85),
#  (12, 'Harakiri', 'Masaki Kobayashi ', 'None', 133, 1962, 8.6, 64),
#  (13, 'Sita Ramam', 'Hanu Raghavapudi ', 'None', 163, 2022, 8.6, 67),
#  (6, 'The Matrix', 'Lana Wachowski', 'Lilly Wachowski', 136, 1999, 8.7, 73),
#  (7,
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Irvin Kershner ',
#   'None',
#   124,
#   1980,
#   8.7,
#   82),
#  (8, 'Soorarai Pottru', 'Sudha Kongara ', 'None', 153, 2020, 8.7, 90),
#  (3, 'Inception', 'Christopher Nolan ', 'None', 148, 2010, 8.8, 74),
#  (4,
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Peter Jackson ',
#   'None',
#   178,
#   2001,
#   8.8,
#   92),
#  (5,
#   'The Lord of the Rings: The Two Towers',
#   'Peter Jackson ',
#   'None',
#   179,
#   2002,
#   8.8,
#   87),
#  (1, 'The Dark Knight', 'Christopher Nolan ', 'None', 152, 2008, 9, 84),
#  (2,
#   'The Lord of the Rings: The Return of the King',
#   'Peter Jackson ',
#   'None',
#   201,
#   2003,
#   9,
#   94),
#  ('ï»¿Sno',
#   'Movie_Name',
#   'Director_1',
#   'Director_2',
#   'Duration_in_mins',
#   'year',
#   'ratings_out_of_10',
#   'Metascore\n')]

# %% [markdown]
# 4) Display all movie names in descending order.

# %%
movienames=cur.execute("select Movie_Name from Imdbmovie1 order by Movie_Name desc ")
movienames.fetchall()
# Out:
# [('xXx',),
#  ('Zombieland: Double Tap',),
#  ('Zombieland',),
#  ('Zathura: A Space Adventure',),
#  ('Zack Snyders Justice League',),
#  ('Your Highness',),
#  ('Young Guns II',),
#  ('Young Guns',),
#  ('You Only Live Twice',),
#  ('You Dont Mess with the Zohan',),
#  ('Yojimbo',),
#  ('X2: X-Men United',),
#  ('X-Men: The Last Stand',),
#  ('X-Men: First Class',),
#  ('X-Men: Days of Future Past',),
#  ('X-Men: Dark Phoenix',),
#  ('X-Men: Apocalypse',),
#  ('X-Men Origins: Wolverine',),
#  ('X-Men',),
#  ('Wyatt Earp',),
#  ('Wrongfully Accused',),
#  ('Wrath of the Titans',),
#  ('Wrath of Man',),
#  ('World War Z',),
#  ('Wonder Woman',),
#  ('Wolfwalkers',),
#  ('Without Remorse (II)',),
#  ('Windtalkers',),
#  ('Willys Wonderland',),
#  ('Willow',),
#  ('Wild Target',),
#  ('Wild Hogs',),
#  ('Wild Card',),
#  ('Who Am I?',),
#  ('Whiteout',),
#  ('White House Down',),
#  ('White Heat',),
#  ('Where Eagles Dare',),
#  ('What Happened to Monday',),
#  ('Westworld',),
#  ('Welcome to the Punch',),
#  ('We Were Soldiers',),
#  ('We Own the Night',),
#  ('Waterworld',),
#  ('Watchmen',),
#  ('Wasabi',),
#  ('Warrior',),
#  ('Warcraft',),
#  ('WarGames',),
#  ('War of the Worlds',),
#  ('War for the Planet of the Apes',),
#  ('War Horse',),
#  ('War',),
#  ('War',),
#  ('Wanted (I)',),
#  ('Wanted',),
#  ('Walking Tall',),
#  ('Volcano',),
#  ('Vishwaroopam',),
#  ('Virtuosity',),
#  ('Violent Night',),
#  ('Vikrant Rona',),
#  ('Vikram Vedha',),
#  ('Vikram',),
#  ('Vertical Limit',),
#  ('Venom: Let There Be Carnage',),
#  ('Venom',),
#  ('Varisu',),
#  ('Vantage Point',),
#  ('Vanishing Point',),
#  ('Van Helsing',),
#  ('Vampires',),
#  ('Vampire Hunter D: Bloodlust',),
#  ('Valhalla Rising',),
#  ('Valerian and the City of a Thousand Planets',),
#  ('V for Vendetta',),
#  ('Uri: The Surgical Strike',),
#  ('Upgrade',),
#  ('Unstoppable',),
#  ('Unlocked (I)',),
#  ('Unleashed',),
#  ('Unknown (I)',),
#  ('Universal Soldier',),
#  ('United 93',),
#  ('Unhinged (I)',),
#  ('Undisputed',),
#  ('Underworld: Rise of the Lycans',),
#  ('Underworld: Evolution',),
#  ('Underworld: Blood Wars',),
#  ('Underworld: Awakening',),
#  ('Underworld',),
#  ('Underwater',),
#  ('Undercover Brother',),
#  ('Under Siege 2: Dark Territory',),
#  ('Under Siege',),
#  ('Uncharted',),
#  ('Unbroken (I)',),
#  ('Udta Punjab',),
#  ('U.S. Marshals',),
#  ('U-571',),
#  ('Twister (I)',),
#  ('Turbo Kid',),
#  ('True Lies',),
#  ('Tropic Thunder',),
#  ('Tron',),
#  ('Troll',),
#  ('Tristan + Isolde',),
#  ('Triple Frontier',),
#  ('Triple 9',),
#  ('Transporter 3',),
#  ('Transporter 2',),
#  ('Transformers: Revenge of the Fallen',),
#  ('Transformers: Dark of the Moon',),
#  ('Transformers: Age of Extinction',),
#  ('Transformers',),
#  ('Transcendence (I)',),
#  ('Traitor',),
#  ('Training Day',),
#  ('Train to Busan',),
#  ('Tower Heist',),
#  ('Total Recall (I)',),
#  ('Total Recall',),
#  ('Tora! Tora! Tora!',),
#  ('Top Gun: Maverick',),
#  ('Top Gun',),
#  ('Toofaan',),
#  ('Tomorrowland',),
#  ('Tomorrow When the War Began',),
#  ('Tomorrow Never Dies',),
#  ('Tomb Raider',),
#  ('To Strike',),
#  ('To Live and Die in L.A.',),
#  ('Titan A.E.',),
#  ('Timeline',),
#  ('Timecop',),
#  ('Time Trap',),
#  ('Tiger Lives',),
#  ('Thuppakki',),
#  ('Thunivu',),
#  ('Thunderbolt and Lightfoot',),
#  ('Thunderball',),
#  ('Three Steps Above Heaven',),
#  ('Three Kings',),
#  ('Those Who Wish Me Dead',),
#  ('Thor: The Dark World',),
#  ('Thor: Ragnarok',),
#  ('Thor: Love and Thunder',),
#  ('Thor',),
#  ('This Means War',),
#  ('Thirteen Lives',),
#  ('Thief',),
#  ('They Live',),
#  ('The Worlds End',),
#  ('The World Is Not Enough',),
#  ('The Woman King',),
#  ('The Wolverine',),
#  ('The Witcher: Nightmare of the Wolf',),
#  ('The Wild Bunch',),
#  ('The Way of the Gun',),
#  ('The Way of the Dragon',),
#  ('The Wave',),
#  ('The Warriors Way',),
#  ('The Warriors',),
#  ('The Warlords',),
#  ('The War of the Worlds',),
#  ('The Wandering Earth',),
#  ('The Wall (II)',),
#  ('The Vault',),
#  ('The Unbearable Weight of Massive Talent',),
#  ('The Transporter',),
#  ('The Transformers: The Movie',),
#  ('The Toxic Avenger',),
#  ('The Towering Inferno',),
#  ('The Tournament',),
#  ('The Tourist (I)',),
#  ('The Tomorrow War',),
#  ('The Time Machine',),
#  ('The Three Musketeers',),
#  ('The Three Musketeers',),
#  ('The Terminator',),
#  ('The Taking of Pelham One Two Three',),
#  ('The Taking of Pelham 123',),
#  ('The Take',),
#  ('The Sum of All Fears',),
#  ('The Suicide Squad',),
#  ('The Spy Who Loved Me',),
#  ('The Spy Who Dumped Me',),
#  ('The Spiderwick Chronicles',),
#  ('The Specialist',),
#  ('The Sorcerers Apprentice',),
#  ('The Skulls',),
#  ('The Silencing',),
#  ('The Siege of Jadotville',),
#  ('The Siege',),
#  ('The Shallows',),
#  ('The Shadow',),
#  ('The Sentinel',),
#  ('The Scorpion King',),
#  ('The Score',),
#  ('The School for Good and Evil',),
#  ('The Salvation',),
#  ('The Saint',),
#  ('The Running Man',),
#  ('The Rundown',),
#  ('The Rover',),
#  ('The Rookie',),
#  ('The Rocketeer',),
#  ('The Rock',),
#  ('The Road Warrior',),
#  ('The Revenant (I)',),
#  ('The Replacement Killers',),
#  ('The Recruit',),
#  ('The Raid: Redemption',),
#  ('The Raid 2',),
#  ('The Quick and the Dead',),
#  ('The Quest',),
#  ('The Purge: Election Year',),
#  ('The Purge: Anarchy',),
#  ('The Punisher',),
#  ('The ProtÃ©gÃ©',),
#  ('The Protector',),
#  ('The Prophecy',),
#  ('The Promise (II)',),
#  ('The Postman',),
#  ('The Poseidon Adventure',),
#  ('The Pink Panther 2',),
#  ('The Perfect Storm',),
#  ('The Peacemaker',),
#  ('The Patriot',),
#  ('The Pacifier',),
#  ('The Outsider (I)',),
#  ('The Outpost',),
#  ('The Other Guys',),
#  ('The One',),
#  ('The Omega Man',),
#  ('The Old Guard',),
#  ('The November Man',),
#  ('The Northman',),
#  ('The Night Comes for Us',),
#  ('The Nice Guys',),
#  ('The Next Three Days',),
#  ('The Net (I)',),
#  ('The Negotiator',),
#  ('The Mummy Returns',),
#  ('The Mummy',),
#  ('The Mountain II',),
#  ('The Mother',),
#  ('The Mortal Instruments: City of Bones',),
#  ('The Monster Squad',),
#  ('The Meg',),
#  ('The Mechanic',),
#  ('The Maze Runner',),
#  ('The Matrix Revolutions',),
#  ('The Matrix Resurrections (I)',),
#  ('The Matrix Reloaded',),
#  ('The Matrix',),
#  ('The Mask of Zorro',),
#  ('The Mask',),
#  ('The Marksman',),
#  ('The Man with the Golden Gun',),
#  ('The Man in the Iron Mask (I)',),
#  ('The Man from U.N.C.L.E.',),
#  ('The Man from Toronto',),
#  ('The Man from Nowhere',),
#  ('The Man',),
#  ('The Magnificent Seven',),
#  ('The Magnificent Seven',),
#  ('The Machine (I)',),
#  ('The Lovebirds',),
#  ('The Lost World: Jurassic Park',),
#  ('The Lost City',),
#  ('The Losers (I)',),
#  ('The Lord of the Rings: The Two Towers',),
#  ('The Lord of the Rings: The Return of the King',),
#  ('The Lord of the Rings: The Fellowship of the Ring',),
#  ('The Longest Day',),
#  ('The Long Kiss Goodnight',),
#  ('The Lone Ranger',),
#  ('The Living Daylights',),
#  ('The Life Aquatic with Steve Zissou',),
#  ('The Lego Ninjago Movie',),
#  ('The Lego Movie 2: The Second Part',),
#  ('The Lego Movie',),
#  ('The Lego Batman Movie',),
#  ('The Legend of Zorro',),
#  ('The Legend of Tomiris',),
#  ('The Legend of Tarzan',),
#  ('The Legend of Drunken Master',),
#  ('The Legend Is Born: Ip Man',),
#  ('The Legend',),
#  ('The League of Extraordinary Gentlemen',),
#  ('The Last of the Mohicans',),
#  ('The Last Witch Hunter',),
#  ('The Last Starfighter',),
#  ('The Last Stand',),
#  ('The Last Samurai',),
#  ('The Last Kingdom: Seven Kings Must Die',),
#  ('The Last Duel',),
#  ('The Last Castle',),
#  ('The Last Boy Scout',),
#  ('The Kings Man',),
#  ('The Kingdom',),
#  ('The Killer',),
#  ('The Karate Kid Part II',),
#  ('The Karate Kid',),
#  ('The Karate Kid',),
#  ('The Jewel of the Nile',),
#  ('The Jackal',),
#  ('The Italian Job',),
#  ('The Italian Job',),
#  ('The Island',),
#  ('The Iron Giant',),
#  ('The Interview (II)',),
#  ('The International (I)',),
#  ('The Informer',),
#  ('The Incredibles',),
#  ('The Incredible Hulk',),
#  ('The Ice Road',),
#  ('The Huntsman: Winters War',),
#  ('The Hunted',),
#  ('The Hunt for Red October',),
#  ('The Hunt (II)',),
#  ('The Hunger Games: Mockingjay - Part 2',),
#  ('The Hunger Games: Mockingjay - Part 1',),
#  ('The Hunger Games: Catching Fire',),
#  ('The Hunger Games',),
#  ('The Host',),
#  ('The Hitmans Bodyguard',),
#  ('The Hitcher',),
#  ('The Hidden Fortress',),
#  ('The Heat (I)',),
#  ('The Harder They Fall',),
#  ('The Guns of Navarone',),
#  ('The Gunman',),
#  ('The Guardian (I)',),
#  ('The Grey',),
#  ('The Green Hornet',),
#  ('The Great Wall (I)',),
#  ('The Gray Man',),
#  ('The Grandmaster',),
#  ('The Good the Bad the Weird',),
#  ('The Golden Child',),
#  ('The Girl with All the Gifts',),
#  ('The Girl in the Spiders Web',),
#  ('The Girl Who Played with Fire',),
#  ('The Getaway',),
#  ('The Gentlemen',),
#  ('The General',),
#  ('The Fugitive',),
#  ('The French Connection',),
#  ('The Four Feathers',),
#  ('The Forever Purge',),
#  ('The Foreigner (I)',),
#  ('The Forbidden Kingdom',),
#  ('The Finest Hours',),
#  ('The Final Countdown',),
#  ('The Fighter (I)',),
#  ('The Fifth Element',),
#  ('The Fate of the Furious',),
#  ('The Fast and the Furious: Tokyo Drift',),
#  ('The Fast and the Furious',),
#  ('The Fan',),
#  ('The Expendables 3',),
#  ('The Expendables 2',),
#  ('The Expendables',),
#  ('The Equalizer 2',),
#  ('The Equalizer',),
#  ('The Enforcer',),
#  ('The Edge',),
#  ('The Eagle',),
#  ('The Double (I)',),
#  ('The Do-Over',),
#  ('The Divergent Series: Insurgent',),
#  ('The Dirty Dozen',),
#  ('The Devils Own',),
#  ('The Dead Pool',),
#  ('The Day After Tomorrow',),
#  ('The Darkest Minds',),
#  ('The Dark Tower',),
#  ('The Dark Knight Rises',),
#  ('The Dark Knight',),
#  ('The Crow',),
#  ('The Croods',),
#  ('The Count of Monte Cristo',),
#  ('The Core',),
#  ('The Contract',),
#  ('The Condemned',),
#  ('The Commuter (I)',),
#  ('The Collector (I)',),
#  ('The Collection (II)',),
#  ('The Code (I)',),
#  ('The Cloverfield Paradox',),
#  ('The Chronicles of Riddick',),
#  ('The Chronicles of Narnia: Prince Caspian',),
#  ('The Chaser',),
#  ('The Cannonball Run',),
#  ('The Brothers Grimsby',),
#  ('The Brothers Grimm',),
#  ('The Brothers Bloom',),
#  ('The Breath',),
#  ('The Brave One',),
#  ('The Boy and the Beast',),
#  ('The Bourne Ultimatum',),
#  ('The Bourne Supremacy',),
#  ('The Bourne Legacy',),
#  ('The Bourne Identity',),
#  ('The Bounty Hunter (I)',),
#  ('The Boondock Saints II: All Saints Day',),
#  ('The Boondock Saints',),
#  ('The Book of Eli',),
#  ('The Bodyguard',),
#  ('The Blues Brothers',),
#  ('The Blind Swordsman: Zatoichi',),
#  ('The Black Hole',),
#  ('The Black Cauldron',),
#  ('The Big Hit',),
#  ('The Big Boss',),
#  ('The Batman',),
#  ('The Baader Meinhof Complex',),
#  ('The Avengers',),
#  ('The Art of War',),
#  ('The Art of Self-Defense',),
#  ('The Angry Birds Movie 2',),
#  ('The Angry Birds Movie',),
#  ('The American',),
#  ('The Amazing Spider-Man 2',),
#  ('The Amazing Spider-Man',),
#  ('The Aeronauts',),
#  ('The Adventures of Tintin',),
#  ('The Adventures of Robin Hood',),
#  ('The Adam Project',),
#  ('The Accountant',),
#  ('The A-Team',),
#  ('The 6th Day',),
#  ('The 355',),
#  ('The 13th Warrior',),
#  ('Terminator: Dark Fate',),
#  ('Terminator Salvation',),
#  ('Terminator Genisys',),
#  ('Terminator 3: Rise of the Machines',),
#  ('Terminator 2: Judgment Day',),
#  ('Tenet',),
#  ('Teenage Mutant Ninja Turtles: Out of the Shadows',),
#  ('Teenage Mutant Ninja Turtles II: The Secret of the Ooze',),
#  ('Teenage Mutant Ninja Turtles',),
#  ('Teenage Mutant Ninja Turtles',),
#  ('Tears of the Sun',),
#  ('Team America: World Police',),
#  ('Taxi 4',),
#  ('Taxi 3',),
#  ('Taxi 2',),
#  ('Taxi (I)',),
#  ('Tanhaji: The Unsung Warrior',),
#  ('Tango & Cash',),
#  ('Tales from the Crypt: Demon Knight',),
#  ('Takers',),
#  ('Taken 3',),
#  ('Taken 2',),
#  ('Taken (I)',),
#  ('Tag (I)',),
#  ('Tae Guk Gi: The Brotherhood of War',),
#  ('TRON: Legacy',),
#  ('TMNT',),
#  ('Swordfish',),
#  ('Sweet Girl',),
#  ('Survivor (I)',),
#  ('Surrogates',),
#  ('Superman Returns',),
#  ('Superman II',),
#  ('Superman',),
#  ('Super 8',),
#  ('Super (I)',),
#  ('Summer Wars',),
#  ('Sultan',),
#  ('Suicide Squad',),
#  ('Sudden Impact',),
#  ('Sudden Death',),
#  ('Sucker Punch',),
#  ('Stuber',),
#  ('Striking Distance',),
#  ('Street Kings',),
#  ('Straw Dogs',),
#  ('Strange World',),
#  ('Stolen',),
#  ('Starship Troopers',),
#  ('Stargate',),
#  ('Star Wars: The Clone Wars',),
#  ('Star Wars: Episode VIII - The Last Jedi',),
#  ('Star Wars: Episode VII - The Force Awakens',),
#  ('Star Wars: Episode VI - Return of the Jedi',),
#  ('Star Wars: Episode V - The Empire Strikes Back',),
#  ('Star Wars: Episode IX - The Rise of Skywalker',),
#  ('Star Wars: Episode IV - A New Hope',),
#  ('Star Wars: Episode III - Revenge of the Sith',),
#  ('Star Wars: Episode II - Attack of the Clones',),
#  ('Star Wars: Episode I - The Phantom Menace',),
#  ('Star Trek: Nemesis',),
#  ('Star Trek: Insurrection',),
#  ('Star Trek: Generations',),
#  ('Star Trek: First Contact',),
#  ('Star Trek VI: The Undiscovered Country',),
#  ('Star Trek V: The Final Frontier',),
#  ('Star Trek Into Darkness',),
#  ('Star Trek IV: The Voyage Home',),
#  ('Star Trek III: The Search for Spock',),
#  ('Star Trek II: The Wrath of Khan',),
#  ('Star Trek Beyond',),
#  ('Star Trek',),
#  ('Stakeout',),
#  ('Spy Kids',),
#  ('Spy Game',),
#  ('Spy',),
#  ('Spies in Disguise',),
#  ('Spider-Man: No Way Home',),
#  ('Spider-Man: Into the Spider-Verse',),
#  ('Spider-Man: Homecoming',),
#  ('Spider-Man: Far from Home',),
#  ('Spider-Man 3',),
#  ('Spider-Man 2',),
#  ('Spider-Man',),
#  ('Sphere',),
#  ('Spenser Confidential',),
#  ('Speed Racer',),
#  ('Speed',),
#  ('Spectre (I)',),
#  ('Spectral',),
#  ('Species',),
#  ('Spartan',),
#  ('Space Sweepers',),
#  ('Space Cowboys',),
#  ('Southpaw',),
#  ('Source Code',),
#  ('Sooryavanshi',),
#  ('Soorarai Pottru',),
#  ('Sonic the Hedgehog 2',),
#  ('Sonic the Hedgehog',),
#  ('Son of a Gun',),
#  ('Son of Rambow',),
#  ('Solomon Kane',),
#  ('Solo: A Star Wars Story',),
#  ('Soldier (I)',),
#  ('Snowpiercer',),
#  ('Snow White and the Huntsman',),
#  ('Snitch (I)',),
#  ('Snakes on a Plane',),
#  ('Smokin Aces',),
#  ('Smokey and the Bandit',),
#  ('Small Soldiers',),
#  ('Slow West',),
#  ('Sleepless (III)',),
#  ('Skyscraper',),
#  ('Skyfall',),
#  ('Sky High',),
#  ('Sky Captain and the World of Tomorrow',),
#  ('Six Days Seven Nights',),
#  ('Sita Ramam',),
#  ('Sisu',),
#  ('Sin City: A Dame to Kill For',),
#  ('Silverado',),
#  ('Sicario: Day of the Soldado',),
#  ('Sicario',),
#  ('Showtime',),
#  ('Shooter (I)',),
#  ('Shoot Em Up',),
#  ('Sholay',),
#  ('Shin Godzilla',),
#  ('Shershaah',),
#  ('Sherlock Jr.',),
#  ('Sherlock Holmes: A Game of Shadows',),
#  ('Sherlock Holmes',),
#  ('Shazam! Fury of the Gods',),
#  ('Shazam!',),
#  ('Shaolin Soccer',),
#  ('Shanghai Noon',),
#  ('Shanghai Knights',),
#  ('Shang-Chi and the Legend of the Ten Rings',),
#  ('Shaft',),
#  ('Shaft',),
#  ('Seventh Son (I)',),
#  ('Seven Samurai',),
#  ('Serenity',),
#  ('Seraphim Falls',),
#  ('Self/less',),
#  ('Seeking Justice',),
#  ('Scouts Guide to the Zombie Apocalypse',),
#  ('Scott Pilgrim vs. the World',),
#  ('Scarface',),
#  ('Savages (I)',),
#  ('Sarfarosh',),
#  ('Sanjuro',),
#  ('Sand Castle',),
#  ('Sanctum',),
#  ('San Andreas',),
#  ('Samrat Prithviraj',),
#  ('Samaritan',),
#  ('Salt',),
#  ('Sahara',),
#  ('Safe House',),
#  ('Safe (I)',),
#  ('Sabotage',),
#  ('S.W.A.T.',),
#  ('Rush Hour 3',),
#  ('Rush Hour 2',),
#  ('Rush Hour',),
#  ('Rush (I)',),
#  ('Rurouni Kenshin Part I: Origins',),
#  ('Running Scared',),
#  ('Runaway Train',),
#  ('Run Lola Run',),
#  ('Run Hide Fight',),
#  ('Run All Night',),
#  ('Rumble in the Bronx',),
#  ('Ronin',),
#  ('Romeo Must Die',),
#  ('Romancing the Stone',),
#  ('Rollerball',),
#  ('Rogue One: A Star Wars Story',),
#  ('Rogue',),
#  ('Rocky Balboa',),
#  ('RocknRolla',),
#  ('RoboCop 2',),
#  ('RoboCop',),
#  ('RoboCop',),
#  ('Robin Hood: Prince of Thieves',),
#  ('Robin Hood',),
#  ('Road House',),
#  ('Rising Sun',),
#  ('Risen',),
#  ('Rise of the Planet of the Apes',),
#  ('Rise of the Guardians',),
#  ('Riders of Justice',),
#  ('Ride Along 2',),
#  ('Ride Along',),
#  ('Riddick',),
#  ('Revolver',),
#  ('Revenge (II)',),
#  ('Resident Evil: The Final Chapter',),
#  ('Resident Evil: Extinction',),
#  ('Resident Evil: Degeneration',),
#  ('Resident Evil: Apocalypse',),
#  ('Resident Evil: Afterlife',),
#  ('Resident Evil',),
#  ('Repo Men',),
#  ('Repo Man',),
#  ('Reindeer Games',),
#  ('Reign of Fire',),
#  ('Redirected',),
#  ('Redemption (I)',),
#  ('Red Tails',),
#  ('Red State',),
#  ('Red Sparrow',),
#  ('Red Planet',),
#  ('Red Notice',),
#  ('Red Heat',),
#  ('Red Dawn',),
#  ('Red Cliff',),
#  ('Real Steel',),
#  ('Ready or Not (I)',),
#  ('Ready Player One',),
#  ('Raya and the Last Dragon',),
#  ('Raw Deal',),
#  ('Rat Race',),
#  ('Ransom',),
#  ('Rango',),
#  ('Rangasthalam 1985',),
#  ('Ran',),
#  ('Rampage',),
#  ('Rambo: Last Blood',),
#  ('Rambo: First Blood Part II',),
#  ('Rambo III',),
#  ('Rambo',),
#  ('Raees',),
#  ('Race to Witch Mountain',),
#  ('Raazi',),
#  ('Raatchasan',),
#  ('RRR',),
#  ('RED 2',),
#  ('RED',),
#  ('R.I.P.D.',),
#  ('Quantum of Solace',),
#  ('Pushpa: The Rise - Part 1',),
#  ('Push',),
#  ('Punisher: War Zone',),
#  ('Public Enemies',),
#  ('Proof of Life',),
#  ('Project Power',),
#  ('Princess Mononoke',),
#  ('Prince of Persia: The Sands of Time',),
#  ('Priest',),
#  ('Pride and Prejudice and Zombies',),
#  ('Prey (I)',),
#  ('Premium Rush',),
#  ('Predestination (I)',),
#  ('Predators',),
#  ('Predator 2',),
#  ('Predator',),
#  ('Power Rangers',),
#  ('Poseidon',),
#  ('Ponniyin Selvan: Part I',),
#  ('Pompeii (I)',),
#  ('Police Story',),
#  ('Polar (I)',),
#  ('Pokemon: The First Movie - Mewtwo Strikes Back',),
#  ('Pokemon: Detective Pikachu',),
#  ('Point of No Return',),
#  ('Point Break',),
#  ('Planet of the Apes',),
#  ('Planet Terror',),
#  ('Plane',),
#  ('Pixels',),
#  ('Pitch Black',),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl',),
#  ('Pirates of the Caribbean: On Stranger Tides',),
#  ('Pirates of the Caribbean: Dead Men Tell No Tales',),
#  ('Pirates of the Caribbean: Dead Mans Chest',),
#  ('Pirates of the Caribbean: At Worlds End',),
#  ('Pineapple Express',),
#  ('Petes Dragon',),
#  ('Peppermint',),
#  ('Peninsula',),
#  ('Penguins of Madagascar',),
#  ('Pearl Harbor',),
#  ('Paycheck',),
#  ('Payback (I)',),
#  ('Patriots Day',),
#  ('Patriot Games',),
#  ('Pathaan',),
#  ('Passenger 57',),
#  ('Parker',),
#  ('Pandorum',),
#  ('Pan',),
#  ('Pain & Gain',),
#  ('Pacific Rim: Uprising',),
#  ('Pacific Rim',),
#  ('Paan Singh Tomar',),
#  ('Overlord',),
#  ('Over the Top',),
#  ('Outlaw King',),
#  ('Outlander',),
#  ('Outland',),
#  ('Outbreak',),
#  ('Out of the Furnace',),
#  ('Osmosis Jones',),
#  ('Operation Fortune: Ruse de Guerre',),
#  ('Open Range',),
#  ('Only the Brave',),
#  ('Only God Forgives',),
#  ('Ong-Bak: The Thai Warrior',),
#  ('Ong Bak 2',),
#  ('Once Upon a Time in Mexico',),
#  ('Once There Was a Tiger',),
#  ('On Her Majestys Secret Service',),
#  ('Om Shanti Om',),
#  ('Olympus Has Fallen',),
#  ('Oldboy',),
#  ('Oldboy',),
#  ('Old Henry',),
#  ('Okja',),
#  ('Octopussy',),
#  ('Oceans Eight',),
#  ('Oblivion (I)',),
#  ('Nowhere to Run',),
#  ('Now You See Me 2',),
#  ('Nothing to Lose',),
#  ('North by Northwest',),
#  ('Non-Stop',),
#  ('Nobody (I)',),
#  ('Noah',),
#  ('No Way Out',),
#  ('No Time to Die',),
#  ('No Escape (I)',),
#  ('Ninja Scroll',),
#  ('Ninja Assassin',),
#  ('Nikita',),
#  ('Night Watch',),
#  ('Nick of Time',),
#  ('Next',),
#  ('News of the World',),
#  ('New World',),
#  ('New Police Story',),
#  ('New Jack City',),
#  ('Never Say Never Again',),
#  ('Never Back Down',),
#  ('Nerve (I)',),
#  ('Neon Genesis Evangelion: The End of Evangelion',),
#  ('Need for Speed',),
#  ('Ned Kelly',),
#  ('Natural Born Killers',),
#  ('National Treasure: Book of Secrets',),
#  ('National Treasure',),
#  ('National Security',),
#  ('Mystery Men',),
#  ('My Spy',),
#  ('Murder at 1600',),
#  ('Murder Mystery 2',),
#  ('Murder Mystery',),
#  ('Muppet Treasure Island',),
#  ('Munich',),
#  ('Mulan',),
#  ('Mr. Right (I)',),
#  ('Mr. Nice Guy',),
#  ('Mr. & Mrs. Smith',),
#  ('Movie_Name',),
#  ('Mosul (I)',),
#  ('Mortdecai',),
#  ('Mortal World',),
#  ('Mortal Kombat',),
#  ('Mortal Kombat',),
#  ('Mortal Engines',),
#  ('Morgan',),
#  ('Moonraker',),
#  ('Monsters vs. Aliens',),
#  ('Mongol: The Rise of Genghis Khan',),
#  ('Money Train',),
#  ('Money Talks',),
#  ('Mission: Impossible III',),
#  ('Mission: Impossible II',),
#  ('Mission: Impossible - Rogue Nation',),
#  ('Mission: Impossible - Ghost Protocol',),
#  ('Mission: Impossible - Fallout',),
#  ('Mission: Impossible',),
#  ('Mission Majnu',),
#  ('Miss Congeniality',),
#  ('Minority Report',),
#  ('Minnal Murali',),
#  ('Mile 22',),
#  ('Mighty Joe Young',),
#  ('Midway',),
#  ('Midnight Run',),
#  ('Micmacs',),
#  ('Miami Vice',),
#  ('Metro',),
#  ('Mesrine: Public Enemy No. 1',),
#  ('Mesrine: Killer Instinct',),
#  ('Mersal',),
#  ('Mercury Rising',),
#  ('Men in Black: International',),
#  ('Men in Black II',),
#  ('Men in Black 3',),
#  ('Men in Black',),
#  ('Men at Work',),
#  ('Memphis Belle',),
#  ('Memory (I)',),
#  ('Megan Leavey',),
#  ('Megamind',),
#  ('Mechanic: Resurrection',),
#  ('Maze Runner: The Scorch Trials',),
#  ('Maze Runner: The Death Cure',),
#  ('Max Manus: Man of War',),
#  ('Maverick',),
#  ('Master and Commander: The Far Side of the World',),
#  ('Master (I)',),
#  ('Marshland',),
#  ('Marighella',),
#  ('Mandy (I)',),
#  ('Man on a Ledge',),
#  ('Man on Fire',),
#  ('Man of Tai Chi',),
#  ('Man of Steel',),
#  ('Major',),
#  ('Main Hoon Na',),
#  ('Magnum Force',),
#  ('Mad Max: Fury Road',),
#  ('Mad Max Beyond Thunderdome',),
#  ('Mad Max',),
#  ('Machine Gun Preacher',),
#  ('Machete Kills',),
#  ('Machete',),
#  ('MacGruber',),
#  ('Lupin III: The Castle of Cagliostro',),
#  ('Ludo',),
#  ('Lucy (I)',),
#  ('Love and Monsters',),
#  ('Lou (I)',),
#  ('Looper',),
#  ('Lone Survivor',),
#  ('London Has Fallen',),
#  ('Logans Run',),
#  ('Logan Lucky',),
#  ('Logan',),
#  ('Lockout',),
#  ('Lock Up',),
#  ('Lock Stock and Two Smoking Barrels',),
#  ('Loaded Weapon 1',),
#  ('Live by Night',),
#  ('Live and Let Die',),
#  ('Live Free or Die Hard',),
#  ('Lionheart',),
#  ('Lightyear',),
#  ('Lifeforce',),
#  ('Licence to Kill',),
#  ('Letters from Iwo Jima',),
#  ('Lets Be Cops',),
#  ('Lethal Weapon 4',),
#  ('Lethal Weapon 3',),
#  ('Lethal Weapon 2',),
#  ('Lethal Weapon',),
#  ('Leon : The Professional',),
#  ('Legend of the Guardians: The Owls of GaHoole',),
#  ('Layer Cake',),
#  ('Law Abiding Citizen',),
#  ('Last Seen Alive',),
#  ('Last Man Standing',),
#  ('Last Knights',),
#  ('Last Action Hero',),
#  ('Lara Croft: Tomb Raider - The Cradle of Life',),
#  ('Lara Croft: Tomb Raider',),
#  ('Lake Placid',),
#  ('Ladder 49',),
#  ('Kung Pow: Enter the Fist',),
#  ('Kung Fu Panda 3',),
#  ('Kung Fu Panda 2',),
#  ('Kung Fu Panda',),
#  ('Kung Fu Hustle',),
#  ('Kubo and the Two Strings',),
#  ('Krull',),
#  ('Kong: Skull Island',),
#  ('Kon-Tiki',),
#  ('Koi... Mil Gaya',),
#  ('Knowing',),
#  ('Knockin on Heavens Door',),
#  ('Knight and Day',),
#  ('Kiss of the Dragon',),
#  ('Kisi Ka Bhai Kisi Ki Jaan',),
#  ('Kingsman: The Secret Service',),
#  ('Kingsman: The Golden Circle',),
#  ('Kingdom of Heaven',),
#  ('King Kong',),
#  ('King Arthur: Legend of the Sword',),
#  ('King Arthur',),
#  ('Kindergarten Cop',),
#  ('Killer Elite',),
#  ('Kill List',),
#  ('Kill Bill: Vol. 2',),
#  ('Kill Bill: Vol. 1',),
#  ('Kidnap (I)',),
#  ('Kickboxer',),
#  ('Kick-Ass 2',),
#  ('Kick-Ass',),
#  ('Kick',),
#  ('Key Largo',),
#  ('Keeping Up with the Joneses',),
#  ('Keanu',),
#  ('Kaththi',),
#  ('Kate (I)',),
#  ('Karthikeya 2',),
#  ('Kantara',),
#  ('Kaithi',),
#  ('Kabir Singh',),
#  ('Kaabil',),
#  ('K.G.F: Chapter 2',),
#  ('K.G.F: Chapter 1',),
#  ('K-9',),
#  ('Justice League',),
#  ('Just Cause',),
#  ('Jurassic World: Fallen Kingdom',),
#  ('Jurassic World: Dominion',),
#  ('Jurassic World',),
#  ('Jurassic Park III',),
#  ('Jurassic Park',),
#  ('Jungle Cruise',),
#  ('Jungle (I)',),
#  ('Jumper',),
#  ('Jumanji: Welcome to the Jungle',),
#  ('Jumanji: The Next Level',),
#  ('Juice',),
#  ('Judge Dredd',),
#  ('Joy Ride',),
#  ('Journey to the Center of the Earth',),
#  ('Journey 2: The Mysterious Island',),
#  ('Jolt',),
#  ('Joint Security Area',),
#  ('Johnny Mnemonic',),
#  ('Johnny English Strikes Again',),
#  ('Johnny English Reborn',),
#  ('Johnny English',),
#  ('John Wick: Chapter 4',),
#  ('John Wick: Chapter 3 - Parabellum',),
#  ('John Wick: Chapter 2',),
#  ('John Wick',),
#  ('John Carter',),
#  ('Jodhaa Akbar',),
#  ('Jimmy Neutron: Boy Genius',),
#  ('Jay and Silent Bob Reboot',),
#  ('Jason and the Argonauts',),
#  ('Jason Bourne (I)',),
#  ('Jack the Giant Slayer',),
#  ('Jack Ryan: Shadow Recruit',),
#  ('Jack Reacher: Never Go Back',),
#  ('Jack Reacher',),
#  ('JCVD',),
#  ('Its a Mad Mad Mad Mad World',),
#  ('Ironclad',),
#  ('Iron Sky',),
#  ('Iron Man 3',),
#  ('Iron Man 2',),
#  ('Iron Man',),
#  ('Ip Man 4: The Finale',),
#  ('Ip Man 3',),
#  ('Ip Man 2',),
#  ...]

# %% [markdown]
# 5) Display movie name starts with ‘P’ and their rating is greater than 7.

# %%
movie_rating=cur.execute("select Movie_Name,ratings_out_of_10 from Imdbmovie1 where Movie_Name like 'P%'and ratings_out_of_10 > 7  ")
movie_rating.fetchall()
# Out:
# [('Princess Mononoke', 8.3),
#  ('Paan Singh Tomar', 8.2),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl', 8.1),
#  ('Predator', 7.8),
#  ('Ponniyin Selvan: Part I', 7.7),
#  ('Pushpa: The Rise - Part 1', 7.6),
#  ('Police Story', 7.5),
#  ('Predestination (I)', 7.4),
#  ('Pirates of the Caribbean: Dead Mans Chest', 7.3),
#  ('Patriots Day', 7.3),
#  ('Point Break', 7.2),
#  ('Prey (I)', 7.1),
#  ('Pirates of the Caribbean: At Worlds End', 7.1),
#  ('Planet Terror', 7.1),
#  ('Payback (I)', 7.1)]

# %% [markdown]
# # QUERYING TABLE 2

# %% [markdown]
# Table 2: Movie Name, stars, votes, Genre, Gross collection, Certification
#
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.
#
# 2 2) Display all details of the movie with the highest number of votes.
#
# 3) Display movie names with gross collections in descending order.
#
# 4) Display the gross collection of movies with the star Arnold.
#
# 5) Display all details of movies with comedy and action genres.

# %% [markdown]
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.

# %%
movie_asc=cur1.execute("select Movie_Name,star_1 from Imdbmovie2 where star_1='Arnold Schwarzenegger'order by Movie_Name asc")
movie_asc.fetchall()
# Out:
# []

# %%
movie_Arnold=cur1.execute("select Movie_Name,star_1 from Imdbmovie2  order by Movie_Name  asc")
movie_Arnold.fetchall()
# Out:
# [('#Alive', '  Yoo Ah-in'),
#  ('12 Rounds', '  John Cena'),
#  ('12 Strong', '  Chris Hemsworth'),
#  ('13 Assassins', '  KÃƒÂ´ji Yakusho'),
#  ('13 Hours', '  John Krasinski'),
#  ('15 Minutes', '  Robert De Niro'),
#  ('16 Blocks', '  Bruce Willis'),
#  ('1917', '  Dean-Charles Chapman'),
#  ('1941', '  John Belushi'),
#  ('1: Nenokkadine', '  Mahesh Babu'),
#  ('2 Fast 2 Furious', '  Paul Walker'),
#  ('2 Guns', '  Denzel Washington'),
#  ('2.o', '  Rajinikanth'),
#  ('2012 (I)', '  John Cusack'),
#  ('21 Bridges', '  Chadwick Boseman'),
#  ('21 Jump Street', '  Jonah Hill'),
#  ('22 Bullets', '  Jean Reno'),
#  ('22 Jump Street', '  Channing Tatum'),
#  ('28 Weeks Later', '  Jeremy Renner'),
#  ('3 Days to Kill', 'None'),
#  ('30 Days of Night', '  Josh Hartnett'),
#  ('30 Minutes or Less', '  Jesse Eisenberg'),
#  ('300', '  Gerard Butler'),
#  ('3000 Miles to Graceland', '  Kurt Russell'),
#  ('300: Rise of an Empire', '  Sullivan Stapleton'),
#  ('3:10 to Yuma', '  Russell Crowe'),
#  ('47 Ronin', '  Keanu Reeves'),
#  ('48 Hrs.', '  Nick Nolte'),
#  ('6 Underground', '  Ryan Reynolds'),
#  ('65', '  Adam Driver'),
#  ('71', '  Jack OConnell'),
#  ('7500', '  Joseph Gordon-Levitt'),
#  ('9 (I)', '  Elijah Wood'),
#  ('A Bittersweet Life', '  Lee Byung-hun'),
#  ('A Fistful of Dollars', '  Clint Eastwood'),
#  ('A History of Violence', '  Viggo Mortensen'),
#  ('A Knights Tale', '  Heath Ledger'),
#  ('A Lonely Place to Die', '  Alec Newman'),
#  ('A Man Apart', '  Vin Diesel'),
#  ('A Most Violent Year', '  Oscar Isaac'),
#  ('A Taxi Driver', '  Song Kang-ho'),
#  ('A View to a Kill', '  Roger Moore'),
#  ('A Walk Among the Tombstones', '  Liam Neeson'),
#  ('A Wednesday', '  Anupam Kher'),
#  ('ARQ', '  Robbie Amell'),
#  ('Above the Law', '  Steven Seagal'),
#  ('Abraham Lincoln: Vampire Hunter', '  Benjamin Walker'),
#  ('Absolute Power', '  Clint Eastwood'),
#  ('Act of Valor', '  Alex Veadov'),
#  ('Adrift (I)', '  Shailene Woodley'),
#  ('After the Sunset', '  Pierce Brosnan'),
#  ('Agneepath', '  Hrithik Roshan'),
#  ('Aguirre the Wrath of God', '  Klaus Kinski'),
#  ('Air America', '  Mel Gibson'),
#  ('Air Force One', '  Harrison Ford'),
#  ('Airlift', '  Akshay Kumar'),
#  ('Akira', '  Mitsuo Iwata'),
#  ('Alan Partridge', '  Steve Coogan'),
#  ('Alexander', '  Colin Farrell'),
#  ('Alien vs. Predator', '  Sanaa Lathan'),
#  ('Alien: Resurrection', '  Sigourney Weaver'),
#  ('Aliens', '  Sigourney Weaver'),
#  ('AlienÃ‚Â³', '  Sigourney Weaver'),
#  ('Alita: Battle Angel', '  Rosa Salazar'),
#  ('All Is Lost', ' Star: Robert Redford'),
#  ('All Quiet on the Western Front', '  Felix Kammerer'),
#  ('Allegiant', '  Shailene Woodley'),
#  ('Allied', '  Brad Pitt'),
#  ('Alpha (II)', '  Kodi Smit-McPhee'),
#  ('Ambulance', '  Jake Gyllenhaal'),
#  ('American Assassin', '  Dylan OBrien'),
#  ('American Made', '  Tom Cruise'),
#  ('American Sniper', '  Bradley Cooper'),
#  ('American Ultra', '  Jesse Eisenberg'),
#  ('An Action Hero', '  Ayushmann Khurrana'),
#  ('Andaz Apna Apna', '  Aamir Khan'),
#  ('Angel Has Fallen', '  Gerard Butler'),
#  ('Angels & Demons', '  Tom Hanks'),
#  ('Anna (II)', '  Sasha Luss'),
#  ('Another 48 Hrs.', '  Eddie Murphy'),
#  ('Ant-Man', '  Paul Rudd'),
#  ('Ant-Man and the Wasp', '  Paul Rudd'),
#  ('Ant-Man and the Wasp: Quantumania', '  Paul Rudd'),
#  ('Anthropoid', '  Jamie Dornan'),
#  ('Antim: The Final Truth', '  Salman Khan'),
#  ('Antitrust', '  Ryan Phillippe'),
#  ('Apocalypto', '  Gerardo Taracena'),
#  ('Appaloosa', '  Ed Harris'),
#  ('Aquaman', '  Jason Momoa'),
#  ('Arjun Reddy', '  Vijay Deverakonda'),
#  ('Arlington Road', '  Jeff Bridges'),
#  ('Armageddon', '  Bruce Willis'),
#  ('Armored', '  Columbus Short'),
#  ('Army of Thieves', '  Matthias SchweighÃƒÂ¶fer'),
#  ('Army of the Dead', '  Dave Bautista'),
#  ('Around the World in 80 Days', '  Jackie Chan'),
#  ('Assassins', '  Sylvester Stallone'),
#  ('Assassins Creed', '  Michael Fassbender'),
#  ('Assault on Precinct 13', '  Austin Stoker'),
#  ('Assault on Precinct 13', '  Ethan Hawke'),
#  ('Astro Boy', '  Freddie Highmore'),
#  ('Asuran', '  Dhanush'),
#  ('Atlantis: The Lost Empire', '  Michael J. Fox'),
#  ('Atomic Blonde', '  Charlize Theron'),
#  ('Attack the Block', '  John Boyega'),
#  ('Austin Powers in Goldmember', '  Mike Myers'),
#  ('Austin Powers: The Spy Who Shagged Me', '  Mike Myers'),
#  ('Automata (I)', '  Antonio Banderas'),
#  ('Avatar', '  Sam Worthington'),
#  ('Avatar: The Way of Water', '  Sam Worthington'),
#  ('Avengers: Age of Ultron', '  Robert Downey Jr.'),
#  ('Avengers: Endgame', '  Robert Downey Jr.'),
#  ('Avengers: Infinity War', '  Robert Downey Jr.'),
#  ('Baahubali 2: The Conclusion', '  Prabhas'),
#  ('Baahubali: The Beginning', '  Prabhas'),
#  ('Baby (I)', '  Akshay Kumar'),
#  ('Baby Driver', '  Ansel Elgort'),
#  ('Babylon A.D.', '  Vin Diesel'),
#  ('Backdraft', '  Kurt Russell'),
#  ('Bacurau', '  BÃƒÂ¡rbara Colen'),
#  ('Bad Boys', '  Will Smith'),
#  ('Bad Boys II', '  Will Smith'),
#  ('Bad Boys for Life', '  Will Smith'),
#  ('Bad Company', '  Anthony Hopkins'),
#  ('Badlands', '  Martin Sheen'),
#  ('Bajirao Mastani', '  Ranveer Singh'),
#  ('Bajrangi Bhaijaan', '  Salman Khan'),
#  ('Bandidas', '  PenÃƒÂ©lope Cruz'),
#  ('Bang Bang (I)', '  Hrithik Roshan'),
#  ('Basic', '  John Travolta'),
#  ('Batman', '  Michael Keaton'),
#  ('Batman Begins', '  Christian Bale'),
#  ('Batman Returns', '  Michael Keaton'),
#  ('Batman v Superman: Dawn of Justice', '  Ben Affleck'),
#  ('Batman v Superman: Dawn of Justice (Ultimate Edition)', '  Amy Adams'),
#  ('Batman: Mask of the Phantasm', '  Kevin Conroy'),
#  ('Batman: The Killing Joke', '  Kevin Conroy'),
#  ('Batman: The Movie', '  Adam West'),
#  ('Battle Los Angeles', '  Aaron Eckhart'),
#  ('Battle Royale', '  Tatsuya Fujiwara'),
#  ('Battleship', '  Alexander SkarsgÃƒÂ¥rd'),
#  ('Baywatch', '  Dwayne Johnson'),
#  ('Beast (I)', '  Liyabuya Gongo'),
#  ('Beckett', '  John David Washington'),
#  ('Behind Enemy Lines', '  Gene Hackman'),
#  ('Ben-Hur', '  Jack Huston'),
#  ('Beneath the Planet of the Apes', '  James Franciscus'),
#  ('Beowulf', '  Ray Winstone'),
#  ('Beverly Hills Cop', '  Eddie Murphy'),
#  ('Beverly Hills Cop II', '  Eddie Murphy'),
#  ('Beverly Hills Cop III', '  Eddie Murphy'),
#  ('Beverly Hills Ninja', '  Chris Farley'),
#  ('Big Hero 6', '  Ryan Potter'),
#  ('Big Stan', '  Rob Schneider'),
#  ('Big Trouble in Little China', '  Kurt Russell'),
#  ('Bird on a Wire', '  Mel Gibson'),
#  ('Birds of Prey', '  Margot Robbie'),
#  ('Black Adam', '  Dwayne Johnson'),
#  ('Black Death', '  Eddie Redmayne'),
#  ('Black Dynamite', '  Michael Jai White'),
#  ('Black Hawk Down', '  Josh Hartnett'),
#  ('Black Panther',
#   '  Chadwick Boseman, Michael B. Jordan, Lupita Nyongo, Danai Gurira'),
#  ('Black Panther: Wakanda Forever', '  Letitia Wright'),
#  ('Black Rain', '  Michael Douglas'),
#  ('Black Widow', '  Scarlett Johansson'),
#  ('Black and Blue (I)', '  Naomie Harris'),
#  ('Blade', '  Wesley Snipes'),
#  ('Blade II', '  Wesley Snipes'),
#  ('Blade Runner', '  Harrison Ford'),
#  ('Blade Runner 2049', '  Harrison Ford'),
#  ('Blade: Trinity', '  Wesley Snipes'),
#  ('Blitz', '  Jason Statham'),
#  ('Blood Father', '  Mel Gibson'),
#  ('Blood Red Sky', '  Peri Baumeister'),
#  ('Blood Work', '  Clint Eastwood'),
#  ('Blood and Bone', '  Michael Jai White'),
#  ('Bloodshot', '  Vin Diesel'),
#  ('Bloodsport', '  Jean-Claude Van Damme'),
#  ('Blown Away', '  Jeff Bridges'),
#  ('Blue Streak', '  Martin Lawrence'),
#  ('Body of Lies', '  Leonardo DiCaprio'),
#  ('Bonnie and Clyde', '  Warren Beatty'),
#  ('Boss Level', '  Frank Grillo'),
#  ('Brahmastra Part One: Shiva', '  Amitabh Bachchan'),
#  ('Braven', '  Jason Momoa'),
#  ('Brawl in Cell Block 99', '  Vince Vaughn'),
#  ('Brick Mansions', '  Paul Walker'),
#  ('Bright (I)', '  Will Smith'),
#  ('Broken Arrow', '  John Travolta'),
#  ('Broken City', '  Mark Wahlberg'),
#  ('Bronson', '  Tom Hardy'),
#  ('Brooklyns Finest', '  Richard Gere'),
#  ('Brotherhood of the Wolf', '  Samuel Le Bihan'),
#  ('Buffy the Vampire Slayer', '  Kristy Swanson'),
#  ('Bullet Train', '  Brad Pitt'),
#  ('Bullet to the Head', '  Sylvester Stallone'),
#  ('Bulletproof', '  Damon Wayans'),
#  ('Bullitt', '  Steve McQueen'),
#  ('Bumblebee (I)', '  Hailee Steinfeld'),
#  ('CHIPS', '  Michael PeÃƒÂ±a'),
#  ('Captain America: Civil War', '  Chris Evans'),
#  ('Captain America: The First Avenger', '  Chris Evans'),
#  ('Captain America: The Winter Soldier', '  Chris Evans'),
#  ('Captain Marvel', '  Brie Larson'),
#  ('Captain Phillips', '  Tom Hanks'),
#  ('Captain Underpants: The First Epic Movie', '  Kevin Hart'),
#  ('Captive State', '  John Goodman'),
#  ('Carriers', '  Chris Pine'),
#  ('Casino Royale', '  Daniel Craig'),
#  ('Casualties of War', '  Michael J. Fox'),
#  ('Cell 211', '  Luis Tosar'),
#  ('Cellular', '  Kim Basinger'),
#  ('Central Intelligence', '  Dwayne Johnson'),
#  ('Centurion', '  Michael Fassbender'),
#  ('Chain Reaction', '  Keanu Reeves'),
#  ('Chaos (II)', '  Jason Statham'),
#  ('Chaos Walking', '  Tom Holland'),
#  ('Chappie', '  Sharlto Copley'),
#  ('Charlie Countryman', '  Shia LaBeouf'),
#  ('Charlies Angels', 'None'),
#  ('Chennai Express', '  Deepika Padukone'),
#  ('Children of Men', '  Julianne Moore'),
#  ('Chip n Dale: Rescue Rangers', '  Andy Samberg'),
#  ('Chronicle', '  Dane DeHaan'),
#  ('Cirque du Freak: The Vampires Assistant', '  Chris Massoglia'),
#  ('Clash of the Titans', '  Laurence Olivier'),
#  ('Clash of the Titans', '  Sam Worthington'),
#  ('Clear and Present Danger', '  Harrison Ford'),
#  ('Cliffhanger', '  Sylvester Stallone'),
#  ('Close (I)', '  Noomi Rapace'),
#  ('Cloverfield', '  Mike Vogel'),
#  ('Cobra', '  Sylvester Stallone'),
#  ('Code 8', '  Kari Matchett'),
#  ('Cold Pursuit', '  Liam Neeson'),
#  ('Collateral', '  Tom Cruise'),
#  ('Collateral Damage', '  Arnold Schwarzenegger'),
#  ('Colombiana', '  Zoe Saldana'),
#  ('Colors', '  Sean Penn'),
#  ('Commando', '  Arnold Schwarzenegger'),
#  ('Con Air', '  Nicolas Cage'),
#  ('Conan the Barbarian', '  Arnold Schwarzenegger'),
#  ('Conan the Destroyer', '  Arnold Schwarzenegger'),
#  ('Conquest 1453', '  Devrim Evin'),
#  ('Conquest of the Planet of the Apes', '  Roddy McDowall'),
#  ('Conspiracy Theory', '  Mel Gibson'),
#  ('Constantine', '  Keanu Reeves'),
#  ('Contraband', '  Mark Wahlberg'),
#  ('Cooties', '  Elijah Wood'),
#  ('Cop Out', '  Bruce Willis'),
#  ('Copshop', '  Gerard Butler'),
#  ('Courage Under Fire', '  Denzel Washington'),
#  ('Cowboy Bebop: The Movie', '  Beau Billingslea'),
#  ('Cowboys & Aliens', '  Daniel Craig'),
#  ('Cradle 2 the Grave', '  Jet Li'),
#  ('Crank', '  Jason Statham'),
#  ('Crank: High Voltage', '  Jason Statham'),
#  ('Crawl (I)', '  Kaya Scodelario'),
#  ('Creed (II)', '  Michael B. Jordan'),
#  ('Creed II', '  Michael B. Jordan'),
#  ('Criminal', '  Kevin Costner'),
#  ('Crimson Tide', '  Gene Hackman'),
#  ('Crocodile Dundee', '  Paul Hogan'),
#  ('Crocodile Dundee II', '  Paul Hogan'),
#  ('Crouching Tiger Hidden Dragon', '  Chow Yun-Fat'),
#  ('Curse of the Golden Flower', '  Chow Yun-Fat'),
#  ('Cutthroat Island', '  Geena Davis'),
#  ('DC League of Super-Pets', '  Dwayne Johnson'),
#  ('Dabangg', '  Salman Khan'),
#  ('Dangal', '  Aamir Khan'),
#  ('Dantes Peak', '  Pierce Brosnan'),
#  ('Darkman', '  Liam Neeson'),
#  ('Dawn of the Dead', '  Sarah Polley'),
#  ('Dawn of the Planet of the Apes', '  Gary Oldman'),
#  ('Day Shift', '  Jamie Foxx'),
#  ('Day Watch', '  Konstantin Khabenskiy'),
#  ('Daybreakers', '  Ethan Hawke'),
#  ('Daylight', '  Sylvester Stallone'),
#  ('Days of Thunder', '  Tom Cruise'),
#  ('Dead Man Down', '  Colin Farrell'),
#  ('Dead Snow 2: Red vs. Dead', '  Geir Vegar Hoel'),
#  ('Deadpool', '  Ryan Reynolds'),
#  ('Deadpool 2', '  Ryan Reynolds'),
#  ('Death Proof', '  Kurt Russell'),
#  ('Death Race', '  Jason Statham'),
#  ('Death Race 2000', '  David Carradine'),
#  ('Death Sentence', '  Kevin Bacon'),
#  ('Death Wish', '  Charles Bronson'),
#  ('Death Wish', '  Bruce Willis'),
#  ('Deep Blue Sea', '  Thomas Jane'),
#  ('Deep Impact', '  Robert Duvall'),
#  ('Deep Rising', '  Treat Williams'),
#  ('Deepwater Horizon', '  Mark Wahlberg'),
#  ('Defiance (I)', '  Daniel Craig'),
#  ('Deja Vu', '  Denzel Washington'),
#  ('Delhi Belly', '  Imran Khan'),
#  ('Deliver Us from Evil (I)', '  Eric Bana'),
#  ('Demolition Man', '  Sylvester Stallone'),
#  ('Demon Slayer the Movie: Mugen Train', '  Natsuki Hanae'),
#  ('Den of Thieves', '  Gerard Butler'),
#  ('Desperado', '  Antonio Banderas'),
#  ('Destroyer', '  Nicole Kidman'),
#  ('Dhoom 2', '  Hrithik Roshan'),
#  ('Diamonds Are Forever', '  Sean Connery'),
#  ('Dick Tracy', '  Warren Beatty'),
#  ('Die Another Day', '  Pierce Brosnan'),
#  ('Die Hard', '  Bruce Willis'),
#  ('Die Hard 2', '  Bruce Willis'),
#  ('Die Hard with a Vengeance', '  Bruce Willis'),
#  ('Dirty Harry', '  Clint Eastwood'),
#  ('District 13: Ultimatum', '  Cyril Raffaelli'),
#  ('District 9', '  Sharlto Copley'),
#  ('District B13', '  Cyril Raffaelli'),
#  ('Divergent', '  Shailene Woodley'),
#  ('Django', '  Franco Nero'),
#  ('Doctor Strange', '  Benedict Cumberbatch'),
#  ('Doctor Strange in the Multiverse of Madness', '  Benedict Cumberbatch'),
#  ('Dog Soldiers', '  Sean Pertwee'),
#  ('Domino', '  Keira Knightley'),
#  ('Don (I)', '  Shah Rukh Khan'),
#  ('Don 2', '  Shah Rukh Khan'),
#  ('Dont Breathe 2', '  Stephen Lang'),
#  ('Doomsday', '  Rhona Mitra'),
#  ('Dora and the Lost City of Gold', '  Isabela Merced'),
#  ('Double Impact', '  Jean-Claude Van Damme'),
#  ('Dr. No', '  Sean Connery'),
#  ('Dracula Untold', '  Luke Evans'),
#  ('Dragged Across Concrete', '  Mel Gibson'),
#  ('Dragon Ball Super: Broly', '  Masako Nozawa'),
#  ('Dragon Ball Z: Battle of Gods', '  Masako Nozawa'),
#  ('Dragon: The Bruce Lee Story', '  Jason Scott Lee'),
#  ('DragonHeart', '  Dennis Quaid'),
#  ('Dredd', '  Karl Urban'),
#  ('Drillbit Taylor', '  Owen Wilson'),
#  ('Drive (I)', '  Ryan Gosling'),
#  ('Drunken Master', '  Jackie Chan'),
#  ('Dune', '  TimothÃƒÂ©e Chalamet'),
#  ('Dune', '  Kyle MacLachlan'),
#  ('Dungeons & Dragons: Honor Among Thieves', '  Chris Pine'),
#  ('Dunkirk', '  Fionn Whitehead'),
#  ('Eagle Eye', '  Shia LaBeouf'),
#  ('Edge of Darkness', '  Mel Gibson'),
#  ('Edge of Tomorrow', '  Tom Cruise'),
#  ('Eega', '  Sudeep'),
#  ('Eight Legged Freaks', '  David Arquette'),
#  ('El Camino: A Breaking Bad Movie', '  Aaron Paul'),
#  ('El Mariachi', '  Carlos Gallardo'),
#  ('Elite Squad', '  Wagner Moura'),
#  ('Elite Squad 2: The Enemy Within', '  Wagner Moura'),
#  ('Elysium (I)', '  Matt Damon'),
#  ('End of Days', '  Arnold Schwarzenegger'),
#  ('End of Watch', '  Jake Gyllenhaal'),
#  ('Enders Game', '  Harrison Ford'),
#  ('Enemy Mine', '  Dennis Quaid'),
#  ('Enemy at the Gates', '  Jude Law'),
#  ('Enemy of the State', '  Will Smith'),
#  ('Enola Holmes', '  Millie Bobby Brown'),
#  ('Enola Holmes 2', '  Millie Bobby Brown'),
#  ('Enter the Dragon', '  Bruce Lee'),
#  ('Enthiran', '  Rajinikanth'),
#  ('Entrapment', '  Sean Connery'),
#  ('Epic', '  Amanda Seyfried'),
#  ('Equilibrium', '  Christian Bale'),
#  ('Erased', '  Aaron Eckhart'),
#  ('Eraser', '  Arnold Schwarzenegger'),
#  ('Escape Plan', '  Sylvester Stallone'),
#  ('Escape Room (I)', '  Taylor Russell'),
#  ('Escape Room: Tournament of Champions', '  Taylor Russell'),
#  ('Escape from Alcatraz', '  Clint Eastwood'),
#  ('Escape from L.A.', '  Kurt Russell'),
#  ('Escape from New York', '  Kurt Russell'),
#  ('Escape from the Planet of the Apes', '  Roddy McDowall'),
#  ('Eternals', '  Gemma Chan'),
#  ('Evangelion: 1.0 You Are (Not) Alone', '  Megumi Ogata'),
#  ('Everest', '  Jason Clarke'),
#  ('Every Which Way But Loose', '  Clint Eastwood'),
#  ('Everything Everywhere All at Once', '  Michelle Yeoh'),
#  ('Executive Decision', '  Kurt Russell'),
#  ('Exit Wounds', '  Steven Seagal'),
#  ('Exodus: Gods and Kings', '  Christian Bale'),
#  ('Extinction', '  Michael PeÃƒÂ±a'),
#  ('Extraction', '  Chris Hemsworth'),
#  ('Eye in the Sky', '  Helen Mirren'),
#  ('Face/Off', '  John Travolta'),
#  ('Fallen', '  Denzel Washington'),
#  ('Falling Down', '  Michael Douglas'),
#  ('Fan (I)', '  Shah Rukh Khan'),
#  ('Fanaa', '  Aamir Khan'),
#  ('Fantastic Four (I)', '  Ioan Gruffudd'),
#  ('Fantastic Four: Rise of the Silver Surfer', '  Ioan Gruffudd'),
#  ('Fast & Furious', '  Vin Diesel'),
#  ('Fast & Furious 6', '  Vin Diesel'),
#  ('Fast & Furious Presents: Hobbs & Shaw', '  Dwayne Johnson'),
#  ('Fast Five', '  Vin Diesel'),
#  ('Fast X', '  Vin Diesel'),
#  ('Faster', '  Dwayne Johnson'),
#  ('Fatman', '  Mel Gibson'),
#  ('Fearless', '  Jet Li'),
#  ('Feast', '  Navi Rawat'),
#  ('Fighting', '  Channing Tatum'),
#  ('Filth (I)', '  James McAvoy'),
#  ('Final Fantasy VII: Advent Children', '  Takahiro Sakurai'),
#  ('Final Fantasy: The Spirits Within', '  Alec Baldwin'),
#  ('Fire with Fire (II)', '  Josh Duhamel'),
#  ('Firefox', '  Clint Eastwood'),
#  ('Firestarter', '  Drew Barrymore'),
#  ('Firewall', '  Harrison Ford'),
#  ('First Blood', '  Sylvester Stallone'),
#  ('First Knight', '  Sean Connery'),
#  ('Fist of Fury', '  Bruce Lee'),
#  ('Flags of Our Fathers', '  Ryan Phillippe'),
#  ('Flash Gordon', '  Sam J. Jones'),
#  ('Flight of the Phoenix', '  Dennis Quaid'),
#  ('Flushed Away', '  Hugh Jackman'),
#  ('Flyboys', '  James Franco'),
#  ('Fools Gold (I)', '  Matthew McConaughey'),
#  ('For Your Eyes Only', '  Roger Moore'),
#  ('Ford v Ferrari', '  Matt Damon'),
#  ('Formula 51', '  Samuel L. Jackson'),
#  ('Fortress', '  Christopher Lambert'),
#  ('Four Brothers', '  Mark Wahlberg'),
#  ('Freddy vs. Jason', '  Robert Englund'),
#  ('Free Fire', '  Sharlto Copley'),
#  ('Free Guy', '  Ryan Reynolds'),
#  ('Free State of Jones', '  Matthew McConaughey'),
#  ('Friday Night Lights', '  Billy Bob Thornton'),
#  ('From Dusk Till Dawn', '  Harvey Keitel'),
#  ('From Paris with Love', '  John Travolta'),
#  ('From Russia with Love', '  Sean Connery'),
#  ('Furious 7', '  Vin Diesel'),
#  ('Fury', '  Brad Pitt'),
#  ('G.I. Jane', '  Demi Moore'),
#  ('G.I. Joe: Retaliation', '  Dwayne Johnson'),
#  ('G.I. Joe: The Rise of Cobra', '  Dennis Quaid'),
#  ('Gabbar Is Back', '  Akshay Kumar'),
#  ('Game Night (I)', '  Jason Bateman'),
#  ('Gamer', '  Gerard Butler'),
#  ('Gangs of Wasseypur', '  Manoj Bajpayee'),
#  ('Gangster Squad', '  Sean Penn'),
#  ('Gemini Man', '  Will Smith'),
#  ('George of the Jungle', '  Brendan Fraser'),
#  ('Get Carter', '  Michael Caine'),
#  ('Get Smart', '  Steve Carell'),
#  ('Get the Gringo', '  Mel Gibson'),
#  ('Ghajini', '  Aamir Khan'),
#  ('Ghost in the Shell', '  Atsuko Tanaka'),
#  ('Ghost in the Shell', '  Scarlett Johansson'),
#  ('Ghostbusters', '  Bill Murray'),
#  ('Ghostbusters', '  Melissa McCarthy'),
#  ('Ghostbusters II', '  Bill Murray'),
#  ('Ghosted (I)', '  Chris Evans'),
#  ('Gladiator', '  Russell Crowe'),
#  ('God Bless America', '  Joel Murray'),
#  ('Gods of Egypt', '  Brenton Thwaites'),
#  ('Godzilla', '  Aaron Taylor-Johnson'),
#  ('Godzilla vs. Kong', '  Alexander SkarsgÃƒÂ¥rd'),
#  ('Godzilla: King of the Monsters', '  Kyle Chandler'),
#  ('GoldenEye', '  Pierce Brosnan'),
#  ('Goldfinger', '  Sean Connery'),
#  ('Gone (I)', '  Amanda Seyfried'),
#  ('Gone in 60 Seconds', '  Nicolas Cage'),
#  ('Green Lantern', '  Ryan Reynolds'),
#  ('Green Zone', '  Matt Damon'),
#  ('Greenland', '  Gerard Butler'),
#  ('Greyhound', '  Tom Hanks'),
#  ('Grindhouse', '  Kurt Russell'),
#  ('Gringo', '  Joel Edgerton'),
#  ('Grosse Pointe Blank', '  John Cusack'),
#  ('Guardians of the Galaxy', '  Chris Pratt'),
#  ('Guardians of the Galaxy Vol. 2', '  Chris Pratt'),
#  ('Guardians of the Galaxy Vol. 3', '  Chris Pratt'),
#  ('Gunjan Saxena: The Kargil Girl', '  Janhvi Kapoor'),
#  ('Gunpowder Milkshake', '  Karen Gillan'),
#  ('Guns Akimbo', '  Daniel Radcliffe'),
#  ('Guy Ritchies The Covenant', '  Jake Gyllenhaal'),
#  ('Haider', '  Shahid Kapoor'),
#  ('Hamburger Hill', '  Anthony Barrile'),
#  ('Hancock', '  Will Smith'),
#  ('Hanna', '  Saoirse Ronan'),
#  ('Hansel & Gretel: Witch Hunters', '  Jeremy Renner'),
#  ('Harakiri', '  Tatsuya Nakadai'),
#  ('Hard Boiled', '  Chow Yun-Fat'),
#  ('Hard Rain', '  Morgan Freeman'),
#  ('Hard Target', '  Jean-Claude Van Damme'),
#  ('Hard to Kill', '  Steven Seagal'),
#  ('Hardcore Henry', '  Sharlto Copley'),
#  ('Harriet (I)', '  Cynthia Erivo'),
#  ('Harry Brown', '  Michael Caine'),
#  ('Harry Potter and the Half-Blood Prince', '  Daniel Radcliffe'),
#  ('Harry Potter and the Order of the Phoenix', '  Daniel Radcliffe'),
#  ('Harsh Times', '  Christian Bale'),
#  ('Haywire', '  Gina Carano'),
#  ('Headhunters', '  Aksel Hennie'),
#  ('Heat', '  Al Pacino'),
#  ('Heist', '  Gene Hackman'),
#  ('Heist (III)', '  Robert De Niro'),
#  ('Hellboy', '  Ron Perlman'),
#  ('Hellboy II: The Golden Army', '  Ron Perlman'),
#  ('Hera Pheri', '  Akshay Kumar'),
#  ('Hercules (I)', '  Dwayne Johnson'),
#  ('Here Comes the Boom', '  Kevin James'),
#  ('Hero', '  Jet Li'),
#  ('Hidalgo', '  Viggo Mortensen'),
#  ('Highlander', '  Christopher Lambert'),
#  ('Hit and Run (I)', '  Dax Shepard'),
#  ('Hitman (I)', '  Timothy Olyphant'),
#  ('Hitman: Agent 47', '  Rupert Friend'),
#  ('Hitmans Wifes Bodyguard', '  Ryan Reynolds'),
#  ('Hobo with a Shotgun', '  Rutger Hauer'),
#  ('Hold the Dark', '  Jeffrey Wright'),
#  ('Holiday: A Soldier is Never Off Duty', '  Akshay Kumar'),
#  ('Hollow Man', '  Kevin Bacon'),
#  ('Homefront (I)', '  Jason Statham'),
#  ('Honest Thief', '  Liam Neeson'),
#  ('Hostage', '  Bruce Willis'),
#  ('Hot Fuzz', '  Simon Pegg'),
#  ('Hot Shots!', '  Charlie Sheen'),
#  ('Hot Shots! Part Deux', '  Charlie Sheen'),
#  ('Hotel Artemis', '  Jodie Foster'),
#  ('Hotel Mumbai', '  Dev Patel'),
#  ('House of Flying Daggers', '  Ziyi Zhang'),
#  ('How I Live Now', '  Saoirse Ronan'),
#  ('How to Train Your Dragon', '  Jay Baruchel'),
#  ('How to Train Your Dragon 2', '  Jay Baruchel'),
#  ('How to Train Your Dragon: The Hidden World', '  Jay Baruchel'),
#  ('Hudson Hawk', '  Bruce Willis'),
#  ('Hulk', '  Eric Bana'),
#  ('Hunter Killer', '  Gerard Butler'),
#  ('I Am Legend', '  Will Smith'),
#  ('I Am Number Four', '  Alex Pettyfer'),
#  ('I Robot', '  Will Smith'),
#  ('I Saw the Devil', '  Lee Byung-hun'),
#  ('Ichi the Killer', '  Tadanobu Asano'),
#  ('Immortals', '  Henry Cavill'),
#  ('In Order of Disappearance', '  Stellan SkarsgÃƒÂ¥rd'),
#  ('In Time', '  Justin Timberlake'),
#  ('In the Heart of the Sea', '  Chris Hemsworth'),
#  ('In the Line of Fire', '  Clint Eastwood'),
#  ('In the Shadow of the Moon', '  Boyd Holbrook'),
#  ('Inception', '  Leonardo DiCaprio'),
#  ('Incredibles 2', '  Craig T. Nelson'),
#  ('Independence Day', '  Will Smith'),
#  ('Indiana Jones and the Kingdom of the Crystal Skull', '  Harrison Ford'),
#  ('Indiana Jones and the Last Crusade', '  Harrison Ford'),
#  ('Indiana Jones and the Raiders of the Lost Ark', '  Harrison Ford'),
#  ('Indiana Jones and the Temple of Doom', '  Harrison Ford'),
#  ('Infernal Affairs', '  Andy Lau'),
#  ('Inferno (I)', '  Tom Hanks'),
#  ('Innerspace', '  Dennis Quaid'),
#  ('Into the Blue', '  Paul Walker'),
#  ('Into the Storm', '  Richard Armitage'),
#  ('Invictus', '  Morgan Freeman'),
#  ('Ip Man', '  Donnie Yen'),
#  ('Ip Man 2', '  Donnie Yen'),
#  ('Ip Man 3', '  Donnie Yen'),
#  ('Ip Man 4: The Finale', '  Donnie Yen'),
#  ('Iron Man', '  Robert Downey Jr.'),
#  ('Iron Man 2', '  Robert Downey Jr.'),
#  ('Iron Man 3', '  Robert Downey Jr.'),
#  ('Iron Sky', '  Julia Dietze'),
#  ('Ironclad', '  Paul Giamatti'),
#  ('Its a Mad Mad Mad Mad World', '  Spencer Tracy'),
#  ('JCVD', '  Jean-Claude Van Damme'),
#  ('Jack Reacher', '  Tom Cruise'),
#  ('Jack Reacher: Never Go Back', '  Tom Cruise'),
#  ('Jack Ryan: Shadow Recruit', '  Chris Pine'),
#  ('Jack the Giant Slayer', '  Nicholas Hoult'),
#  ('Jason Bourne (I)', '  Matt Damon'),
#  ('Jason and the Argonauts', '  Todd Armstrong'),
#  ('Jay and Silent Bob Reboot', '  Joey Lauren Adams'),
#  ('Jimmy Neutron: Boy Genius', '  Debi Derryberry'),
#  ('Jodhaa Akbar', '  Hrithik Roshan'),
#  ('John Carter', '  Taylor Kitsch'),
#  ('John Wick', '  Keanu Reeves'),
#  ('John Wick: Chapter 2', '  Keanu Reeves'),
#  ('John Wick: Chapter 3 - Parabellum', '  Keanu Reeves'),
#  ('John Wick: Chapter 4', '  Keanu Reeves'),
#  ('Johnny English', '  Rowan Atkinson'),
#  ('Johnny English Reborn', '  Rowan Atkinson'),
#  ('Johnny English Strikes Again', '  Rowan Atkinson'),
#  ('Johnny Mnemonic', '  Keanu Reeves'),
#  ('Joint Security Area', '  Lee Yeong-ae'),
#  ('Jolt', '  Kate Beckinsale'),
#  ('Journey 2: The Mysterious Island', '  Josh Hutcherson'),
#  ('Journey to the Center of the Earth', '  Brendan Fraser'),
#  ('Joy Ride', '  Steve Zahn'),
#  ('Judge Dredd', '  Sylvester Stallone'),
#  ('Juice', '  Omar Epps'),
#  ('Jumanji: The Next Level', '  Dwayne Johnson'),
#  ('Jumanji: Welcome to the Jungle', '  Dwayne Johnson'),
#  ('Jumper', '  Hayden Christensen'),
#  ('Jungle (I)', '  Daniel Radcliffe'),
#  ('Jungle Cruise', '  Dwayne Johnson'),
#  ('Jurassic Park', '  Sam Neill'),
#  ('Jurassic Park III', '  Sam Neill'),
#  ('Jurassic World', '  Chris Pratt'),
#  ('Jurassic World: Dominion', '  Chris Pratt'),
#  ('Jurassic World: Fallen Kingdom', '  Chris Pratt'),
#  ('Just Cause', '  Sean Connery'),
#  ('Justice League', '  Ben Affleck'),
#  ('K-9', '  Jim Belushi'),
#  ('K.G.F: Chapter 1', '  Yash'),
#  ('K.G.F: Chapter 2', '  Yash'),
#  ('Kaabil', '  Hrithik Roshan'),
#  ('Kabir Singh', '  Shahid Kapoor'),
#  ('Kaithi', '  Karthi'),
#  ('Kantara', '  Rishab Shetty'),
#  ('Karthikeya 2', '  Nikhil Siddharth'),
#  ('Kate (I)', '  Mary Elizabeth Winstead'),
#  ('Kaththi', '  Joseph Vijay'),
#  ('Keanu', '  Keegan-Michael Key'),
#  ('Keeping Up with the Joneses', '  Zach Galifianakis'),
#  ('Key Largo', '  Humphrey Bogart'),
#  ('Kick', '  Salman Khan'),
#  ('Kick-Ass', '  Aaron Taylor-Johnson'),
#  ('Kick-Ass 2', '  Aaron Taylor-Johnson'),
#  ('Kickboxer', '  Jean-Claude Van Damme'),
#  ('Kidnap (I)', '  Halle Berry'),
#  ('Kill Bill: Vol. 1', '  Uma Thurman'),
#  ('Kill Bill: Vol. 2', '  Uma Thurman'),
#  ('Kill List', '  Neil Maskell'),
#  ('Killer Elite', '  Jason Statham'),
#  ('Kindergarten Cop', '  Arnold Schwarzenegger'),
#  ('King Arthur', '  Clive Owen'),
#  ('King Arthur: Legend of the Sword', '  Charlie Hunnam'),
#  ('King Kong', '  Naomi Watts'),
#  ('Kingdom of Heaven', '  Orlando Bloom'),
#  ('Kingsman: The Golden Circle', '  Taron Egerton'),
#  ('Kingsman: The Secret Service', '  Colin Firth'),
#  ('Kisi Ka Bhai Kisi Ki Jaan', '  Salman Khan'),
#  ('Kiss of the Dragon', '  Jet Li'),
#  ('Knight and Day', '  Tom Cruise'),
#  ('Knockin on Heavens Door', '  Til Schweiger'),
#  ('Knowing', '  Nicolas Cage'),
#  ('Koi... Mil Gaya', '  Hrithik Roshan'),
#  ('Kon-Tiki', '  PÃƒÂ¥l Sverre Hagen'),
#  ('Kong: Skull Island', '  Tom Hiddleston'),
#  ('Krull', '  Ken Marshall'),
#  ('Kubo and the Two Strings', '  Charlize Theron'),
#  ('Kung Fu Hustle', '  Stephen Chow'),
#  ('Kung Fu Panda', '  Jack Black'),
#  ('Kung Fu Panda 2', '  Jack Black'),
#  ('Kung Fu Panda 3', '  Jack Black'),
#  ('Kung Pow: Enter the Fist', '  Steve Oedekerk'),
#  ('Ladder 49', '  Joaquin Phoenix'),
#  ('Lake Placid', '  Bridget Fonda'),
#  ('Lara Croft: Tomb Raider', '  Angelina Jolie'),
#  ('Lara Croft: Tomb Raider - The Cradle of Life', '  Angelina Jolie'),
#  ('Last Action Hero', '  Arnold Schwarzenegger'),
#  ('Last Knights', '  Clive Owen'),
#  ('Last Man Standing', '  Bruce Willis'),
#  ('Last Seen Alive', '  Gerard Butler'),
#  ('Law Abiding Citizen', '  Gerard Butler'),
#  ('Layer Cake', '  Daniel Craig'),
#  ('Legend of the Guardians: The Owls of GaHoole', '  Jim Sturgess'),
#  ('Leon: The Professional', '  Jean Reno'),
#  ('Lethal Weapon', '  Mel Gibson'),
#  ('Lethal Weapon 2', '  Mel Gibson'),
#  ('Lethal Weapon 3', '  Mel Gibson'),
#  ('Lethal Weapon 4', '  Mel Gibson'),
#  ('Lets Be Cops', '  Jake Johnson'),
#  ('Letters from Iwo Jima', '  Ken Watanabe'),
#  ('Licence to Kill', '  Timothy Dalton'),
#  ('Lifeforce', '  Steve Railsback'),
#  ('Lightyear', '  Chris Evans'),
#  ('Lionheart', '  Jean-Claude Van Damme'),
#  ('Live Free or Die Hard', '  Bruce Willis'),
#  ('Live and Let Die', '  Roger Moore'),
#  ('Live by Night', '  Ben Affleck'),
#  ('Loaded Weapon 1', '  Emilio Estevez'),
#  ('Lock Stock and Two Smoking Barrels', '  Jason Flemyng'),
#  ('Lock Up', '  Sylvester Stallone'),
#  ('Lockout', '  Guy Pearce'),
#  ('Logan', '  Hugh Jackman'),
#  ('Logan Lucky', '  Channing Tatum'),
#  ('Logans Run', '  Michael York'),
#  ('London Has Fallen', '  Gerard Butler'),
#  ('Lone Survivor', '  Mark Wahlberg'),
#  ('Looper', '  Joseph Gordon-Levitt'),
#  ('Lou (I)', '  Allison Janney'),
#  ('Love and Monsters', '  Dylan OBrien'),
#  ('Lucy (I)', '  Scarlett Johansson'),
#  ('Ludo', '  Pankaj Tripathi'),
#  ('Lupin III: The Castle of Cagliostro', '  Yasuo Yamada'),
#  ('MacGruber', '  Will Forte'),
#  ('Machete', '  Danny Trejo'),
#  ('Machete Kills', '  Danny Trejo'),
#  ('Machine Gun Preacher', '  Gerard Butler'),
#  ('Mad Max', '  Mel Gibson'),
#  ('Mad Max Beyond Thunderdome', '  Mel Gibson'),
#  ('Mad Max: Fury Road', '  Tom Hardy'),
#  ('Magnum Force', '  Clint Eastwood'),
#  ('Main Hoon Na', '  Shah Rukh Khan'),
#  ('Major', '  Adivi Sesh'),
#  ('Man of Steel', '  Henry Cavill'),
#  ('Man of Tai Chi', '  Tiger Hu Chen'),
#  ('Man on Fire', '  Denzel Washington'),
#  ('Man on a Ledge', '  Sam Worthington'),
#  ('Mandy (I)', '  Nicolas Cage'),
#  ('Marighella', '  Seu Jorge'),
#  ('Marshland', '  Javier GutiÃƒÂ©rrez'),
#  ('Master (I)', '  Joseph Vijay'),
#  ('Master and Commander: The Far Side of the World', '  Russell Crowe'),
#  ('Maverick', '  Mel Gibson'),
#  ('Max Manus: Man of War', '  Aksel Hennie'),
#  ('Maze Runner: The Death Cure', '  Dylan OBrien'),
#  ('Maze Runner: The Scorch Trials', '  Dylan OBrien'),
#  ('Mechanic: Resurrection', '  Jason Statham'),
#  ('Megamind', '  Will Ferrell'),
#  ('Megan Leavey', '  Kate Mara'),
#  ('Memory (I)', '  Liam Neeson'),
#  ('Memphis Belle', '  Matthew Modine'),
#  ('Men at Work', '  Charlie Sheen'),
#  ('Men in Black', '  Tommy Lee Jones'),
#  ('Men in Black 3', '  Will Smith'),
#  ('Men in Black II', '  Tommy Lee Jones'),
#  ('Men in Black: International', '  Chris Hemsworth'),
#  ('Mercury Rising', '  Bruce Willis'),
#  ('Mersal', '  Joseph Vijay'),
#  ('Mesrine: Killer Instinct', '  Vincent Cassel'),
#  ('Mesrine: Public Enemy No. 1', '  Vincent Cassel'),
#  ('Metro', '  Eddie Murphy'),
#  ('Miami Vice', '  Colin Farrell'),
#  ('Micmacs', '  Dany Boon'),
#  ('Midnight Run', '  Robert De Niro'),
#  ('Midway', '  Ed Skrein'),
#  ('Mighty Joe Young', '  Bill Paxton'),
#  ('Mile 22', '  Mark Wahlberg'),
#  ('Minnal Murali', '  Tovino Thomas'),
#  ('Minority Report', '  Tom Cruise'),
#  ('Miss Congeniality', '  Sandra Bullock'),
#  ('Mission Majnu', '  Sidharth Malhotra'),
#  ('Mission: Impossible', '  Tom Cruise'),
#  ('Mission: Impossible - Fallout', '  Tom Cruise'),
#  ('Mission: Impossible - Ghost Protocol', '  Tom Cruise'),
#  ('Mission: Impossible - Rogue Nation', '  Tom Cruise'),
#  ('Mission: Impossible II', '  Tom Cruise'),
#  ('Mission: Impossible III', '  Tom Cruise'),
#  ('Money Talks', '  Charlie Sheen'),
#  ('Money Train', '  Wesley Snipes'),
#  ('Mongol: The Rise of Genghis Khan', '  Tadanobu Asano'),
#  ('Monsters vs. Aliens', '  Reese Witherspoon'),
#  ('Moonraker', '  Roger Moore'),
#  ('Morgan', '  Kate Mara'),
#  ('Mortal Engines', '  Hera Hilmar'),
#  ('Mortal Kombat', '  Lewis Tan'),
#  ('Mortal Kombat', '  Christopher Lambert'),
#  ('Mortal World', '  Ahmet MÃƒÂ¼mtaz Taylan'),
#  ('Mortdecai', '  Johnny Depp'),
#  ('Mosul (I)', '  Waleed Elgadi'),
#  ('Mr. & Mrs. Smith', '  Brad Pitt'),
#  ('Mr. Nice Guy', '  Jackie Chan'),
#  ('Mr. Right (I)', '  Anna Kendrick'),
#  ('Mulan', '  Liu Yifei'),
#  ('Munich', '  Eric Bana'),
#  ('Muppet Treasure Island', '  Tim Curry'),
#  ('Murder Mystery', '  Adam Sandler'),
#  ('Murder Mystery 2', '  Adam Sandler'),
#  ('Murder at 1600', '  Wesley Snipes'),
#  ('My Spy', '  Dave Bautista'),
#  ('Mystery Men', '  Ben Stiller'),
#  ('National Security', '  Martin Lawrence'),
#  ('National Treasure', '  Nicolas Cage'),
#  ('National Treasure: Book of Secrets', '  Nicolas Cage'),
#  ('Natural Born Killers', '  Woody Harrelson'),
#  ('Ned Kelly', '  Heath Ledger'),
#  ('Need for Speed', '  Aaron Paul'),
#  ('Neon Genesis Evangelion: The End of Evangelion', '  Megumi Ogata'),
#  ('Nerve (I)', '  Emma Roberts'),
#  ('Never Back Down', '  Sean Faris'),
#  ('Never Say Never Again', '  Sean Connery'),
#  ('New Jack City', '  Wesley Snipes'),
#  ('New Police Story', '  Jackie Chan'),
#  ('New World', '  Lee Jung-jae'),
#  ('News of the World', '  Tom Hanks'),
#  ('Next', '  Nicolas Cage'),
#  ('Nick of Time', '  Johnny Depp'),
#  ('Night Watch', '  Konstantin Khabenskiy'),
#  ('Nikita', '  Anne Parillaud'),
#  ('Ninja Assassin', '  Rain'),
#  ('Ninja Scroll', '  KÃƒÂ´ichi Yamadera'),
#  ('No Escape (I)', '  Lake Bell'),
#  ('No Time to Die', '  Daniel Craig'),
#  ('No Way Out', '  Kevin Costner'),
#  ('Noah', '  Russell Crowe'),
#  ('Nobody (I)', '  Bob Odenkirk'),
#  ('Non-Stop', '  Liam Neeson'),
#  ('North by Northwest', '  Cary Grant'),
#  ('Nothing to Lose', '  Martin Lawrence'),
#  ('Now You See Me 2', '  Jesse Eisenberg'),
#  ('Nowhere to Run', '  Jean-Claude Van Damme'),
#  ('Oblivion (I)', '  Tom Cruise'),
#  ('Oceans Eight', '  Sandra Bullock'),
#  ('Octopussy', '  Roger Moore'),
#  ('Okja', '  Tilda Swinton'),
#  ('Old Henry', '  Tim Blake Nelson'),
#  ('Oldboy', '  Choi Min-sik'),
#  ('Oldboy', '  Josh Brolin'),
#  ('Olympus Has Fallen', '  Gerard Butler'),
#  ('Om Shanti Om', '  Shah Rukh Khan'),
#  ('On Her Majestys Secret Service', '  George Lazenby'),
#  ('Once There Was a Tiger', '  Salman Khan'),
#  ('Once Upon a Time in Mexico', '  Antonio Banderas'),
#  ('Ong Bak 2', '  Tony Jaa'),
#  ('Ong-Bak: The Thai Warrior', '  Tony Jaa'),
#  ('Only God Forgives', '  Ryan Gosling'),
#  ('Only the Brave', '  Josh Brolin'),
#  ('Open Range', '  Kevin Costner'),
#  ('Operation Fortune: Ruse de Guerre', '  Jason Statham'),
#  ('Osmosis Jones', '  Laurence Fishburne'),
#  ('Out of the Furnace', '  Christian Bale'),
#  ('Outbreak', '  Dustin Hoffman'),
#  ('Outland', '  Sean Connery'),
#  ('Outlander', '  Jim Caviezel'),
#  ('Outlaw King', '  Chris Pine'),
#  ('Over the Top', '  Sylvester Stallone'),
#  ('Overlord', '  Jovan Adepo'),
#  ('Paan Singh Tomar', '  Irrfan Khan'),
#  ('Pacific Rim', '  Idris Elba'),
#  ('Pacific Rim: Uprising', '  John Boyega'),
#  ('Pain & Gain', '  Mark Wahlberg'),
#  ('Pan', '  Levi Miller'),
#  ('Pandorum', '  Dennis Quaid'),
#  ('Parker', '  Jason Statham'),
#  ('Passenger 57', '  Wesley Snipes'),
#  ('Pathaan', '  Shah Rukh Khan'),
#  ('Patriot Games', '  Harrison Ford'),
#  ('Patriots Day', '  Mark Wahlberg'),
#  ('Payback (I)', '  Mel Gibson'),
#  ('Paycheck', '  Ben Affleck'),
#  ('Pearl Harbor', '  Ben Affleck'),
#  ('Penguins of Madagascar', '  Tom McGrath'),
#  ('Peninsula', '  Gang Dong-won'),
#  ('Peppermint', '  Jennifer Garner'),
#  ('Petes Dragon', '  Bryce Dallas Howard'),
#  ('Pineapple Express', '  Seth Rogen'),
#  ('Pirates of the Caribbean: At Worlds End', '  Johnny Depp'),
#  ('Pirates of the Caribbean: Dead Mans Chest', '  Johnny Depp'),
#  ('Pirates of the Caribbean: Dead Men Tell No Tales', '  Johnny Depp'),
#  ('Pirates of the Caribbean: On Stranger Tides', '  Johnny Depp'),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl', '  Johnny Depp'),
#  ('Pitch Black', '  Radha Mitchell'),
#  ('Pixels', '  Adam Sandler'),
#  ('Plane', '  Gerard Butler'),
#  ('Planet Terror', '  Rose McGowan'),
#  ('Planet of the Apes', '  Mark Wahlberg'),
#  ('Point Break', '  Patrick Swayze'),
#  ('Point of No Return', '  Bridget Fonda'),
#  ('Pokemon: Detective Pikachu', '  Ryan Reynolds'),
#  ('PokÃƒÂ©mon: The First Movie - Mewtwo Strikes Back', '  Veronica Taylor'),
#  ('Polar (I)', '  Mads Mikkelsen'),
#  ('Police Story', '  Jackie Chan'),
#  ('Pompeii (I)', '  Kit Harington'),
#  ('Ponniyin Selvan: Part I', '  Vikram'),
#  ('Poseidon', '  Richard Dreyfuss'),
#  ('Power Rangers', '  Dacre Montgomery'),
#  ('Predator', '  Arnold Schwarzenegger'),
#  ('Predator 2', '  Danny Glover'),
#  ('Predators', '  Adrien Brody'),
#  ('Predestination (I)', '  Ethan Hawke'),
#  ('Premium Rush', '  Joseph Gordon-Levitt'),
#  ('Prey (I)', '  Amber Midthunder'),
#  ('Pride and Prejudice and Zombies', '  Lily James'),
#  ('Priest', '  Paul Bettany'),
#  ('Prince of Persia: The Sands of Time', '  Jake Gyllenhaal'),
#  ('Princess Mononoke', '  YÃƒÂ´ji Matsuda'),
#  ('Project Power', '  Jamie Foxx'),
#  ('Proof of Life', '  Meg Ryan'),
#  ('Public Enemies', '  Christian Bale'),
#  ('Punisher: War Zone', '  Ray Stevenson'),
#  ('Push', '  Camilla Belle'),
#  ('Pushpa: The Rise - Part 1', '  Allu Arjun'),
#  ('Quantum of Solace', '  Daniel Craig'),
#  ('R.I.P.D.', '  Ryan Reynolds'),
#  ('RED', '  Bruce Willis'),
#  ('RED 2', '  Bruce Willis'),
#  ('RRR', '  N.T. Rama Rao Jr.'),
#  ('Raatchasan', '  Vishnu Vishal'),
#  ('Raazi', '  Alia Bhatt'),
#  ('Race to Witch Mountain', '  Dwayne Johnson'),
#  ('Raees', '  Sunny Leone'),
#  ('Rambo', '  Sylvester Stallone'),
#  ('Rambo III', '  Sylvester Stallone'),
#  ('Rambo: First Blood Part II', '  Sylvester Stallone'),
#  ('Rambo: Last Blood', '  Sylvester Stallone'),
#  ('Rampage', '  Dwayne Johnson'),
#  ('Ran', '  Tatsuya Nakadai'),
#  ('Rangasthalam 1985', '  Ram Charan'),
#  ('Rango', '  Johnny Depp'),
#  ('Ransom', '  Mel Gibson'),
#  ('Rat Race', '  Breckin Meyer'),
#  ('Raw Deal', '  Arnold Schwarzenegger'),
#  ('Raya and the Last Dragon', '  Kelly Marie Tran'),
#  ('Ready Player One', '  Tye Sheridan'),
#  ('Ready or Not (I)', '  Samara Weaving'),
#  ('Real Steel', '  Hugh Jackman'),
#  ('Red Cliff', '  Tony Leung Chiu-wai'),
#  ('Red Dawn', '  Patrick Swayze'),
#  ('Red Heat', '  Arnold Schwarzenegger'),
#  ('Red Notice', '  Dwayne Johnson'),
#  ('Red Planet', '  Val Kilmer'),
#  ('Red Sparrow', '  Jennifer Lawrence'),
#  ('Red State', '  Michael Parks'),
#  ('Red Tails', '  Cuba Gooding Jr.'),
#  ('Redemption (I)', '  Jason Statham'),
#  ('Redirected', '  Vinnie Jones'),
#  ('Reign of Fire', '  Matthew McConaughey'),
#  ('Reindeer Games', '  Ben Affleck'),
#  ('Repo Man', '  Harry Dean Stanton'),
#  ('Repo Men', '  Jude Law'),
#  ('Resident Evil', '  Milla Jovovich'),
#  ('Resident Evil: Afterlife', '  Milla Jovovich'),
#  ('Resident Evil: Apocalypse', '  Milla Jovovich'),
#  ('Resident Evil: Degeneration', '  Paul Mercier'),
#  ('Resident Evil: Extinction', '  Milla Jovovich'),
#  ('Resident Evil: The Final Chapter', '  Milla Jovovich'),
#  ('Revenge (II)', '  Matilda Anna Ingrid Lutz'),
#  ('Revolver', '  Jason Statham'),
#  ('Riddick', '  Vin Diesel'),
#  ('Ride Along', '  Ice Cube'),
#  ('Ride Along 2', '  Ice Cube'),
#  ('Riders of Justice', '  Mads Mikkelsen'),
#  ('Rise of the Guardians', '  Hugh Jackman'),
#  ('Rise of the Planet of the Apes', '  James Franco'),
#  ('Risen', '  Joseph Fiennes'),
#  ('Rising Sun', '  Sean Connery'),
#  ('Road House', '  Patrick Swayze'),
#  ('Robin Hood', '  Russell Crowe'),
#  ('Robin Hood: Prince of Thieves', '  Kevin Costner'),
#  ('RoboCop', '  Peter Weller'),
#  ('RoboCop', '  Joel Kinnaman'),
#  ('RoboCop 2', '  Peter Weller'),
#  ('RocknRolla', '  Gerard Butler'),
#  ('Rocky Balboa', '  Sylvester Stallone'),
#  ('Rogue', '  Michael Vartan'),
#  ('Rogue One: A Star Wars Story', '  Felicity Jones'),
#  ('Rollerball', '  James Caan'),
#  ('Romancing the Stone', '  Michael Douglas'),
#  ('Romeo Must Die', '  Jet Li'),
#  ('Ronin', '  Robert De Niro'),
#  ('Rumble in the Bronx', '  Jackie Chan'),
#  ('Run All Night', '  Liam Neeson'),
#  ('Run Hide Fight', '  Isabel May'),
#  ('Run Lola Run', '  Franka Potente'),
#  ('Runaway Train', '  Jon Voight'),
#  ('Running Scared', '  Paul Walker'),
#  ('Rurouni Kenshin Part I: Origins', '  Takeru Satoh'),
#  ('Rush (I)', '  Daniel BrÃƒÂ¼hl'),
#  ('Rush Hour', '  Jackie Chan'),
#  ('Rush Hour 2', '  Jackie Chan'),
#  ('Rush Hour 3', '  Jackie Chan'),
#  ('S.W.A.T.', '  Samuel L. Jackson'),
#  ('Sabotage', '  Arnold Schwarzenegger'),
#  ('Safe (I)', '  Jason Statham'),
#  ('Safe House', '  Denzel Washington'),
#  ('Sahara', '  Matthew McConaughey'),
#  ('Salt', '  Angelina Jolie'),
#  ('Samaritan', '  Sylvester Stallone'),
#  ('Samrat Prithviraj', '  Akshay Kumar'),
#  ('San Andreas', '  Dwayne Johnson'),
#  ('Sanctum', '  Rhys Wakefield'),
#  ('Sand Castle', '  Nicholas Hoult'),
#  ('Sanjuro', '  ToshirÃƒÂ´ Mifune'),
#  ('Sarfarosh', '  Aamir Khan'),
#  ('Savages (I)', '  Aaron Taylor-Johnson'),
#  ('Scarface', '  Paul Muni'),
#  ('Scott Pilgrim vs. the World', '  Michael Cera'),
#  ('Scouts Guide to the Zombie Apocalypse', '  Tye Sheridan'),
#  ('Seeking Justice', '  Nicolas Cage'),
#  ('Self/less', '  Ryan Reynolds'),
#  ('Seraphim Falls', '  Pierce Brosnan'),
#  ('Serenity', '  Nathan Fillion'),
#  ('Seven Samurai', '  ToshiroÂ´ Mifune'),
#  ('Seventh Son (I)', '  Ben Barnes'),
#  ('Shaft', '  Samuel L. Jackson'),
#  ('Shaft', '  Samuel L. Jackson'),
#  ('Shang-Chi and the Legend of the Ten Rings', '  Simu Liu'),
#  ('Shanghai Knights', '  Jackie Chan'),
#  ('Shanghai Noon', '  Jackie Chan'),
#  ('Shaolin Soccer', '  Stephen Chow'),
#  ('Shazam!', '  Zachary Levi'),
#  ('Shazam! Fury of the Gods', '  Zachary Levi'),
#  ('Sherlock Holmes', '  Robert Downey Jr.'),
#  ('Sherlock Holmes: A Game of Shadows', '  Robert Downey Jr.'),
#  ('Sherlock Jr.', '  Buster Keaton'),
#  ('Shershaah', '  Sidharth Malhotra'),
#  ('Shin Godzilla', '  Hiroki Hasegawa'),
#  ('Sholay', '  Sanjeev Kumar'),
#  ('Shoot Em Up', '  Clive Owen'),
#  ('Shooter (I)', '  Mark Wahlberg'),
#  ('Showtime', '  Robert De Niro'),
#  ('Sicario', '  Emily Blunt'),
#  ('Sicario: Day of the Soldado', '  Benicio Del Toro'),
#  ('Silverado', '  Kevin Kline'),
#  ('Sin City: A Dame to Kill For', '  Mickey Rourke'),
#  ('Sisu', '  Jorma Tommila'),
#  ('Sita Ramam', '  Dulquer Salmaan'),
#  ('Six Days Seven Nights', '  Harrison Ford'),
#  ('Sky Captain and the World of Tomorrow', '  Gwyneth Paltrow'),
#  ('Sky High', '  Kurt Russell'),
#  ('Skyfall', '  Daniel Craig'),
#  ...]

# %% [markdown]
# 2) Display all details of the movie with the highest number of votes.

# %%
highvote_movies=cur1.execute("select * from Imdbmovie2 order by votes desc")
highvote_movies.fetchall()
# Out:
# [('ï»¿Movie_Name',
#   'star_1',
#   'star_2',
#   'star_3',
#   'star_4',
#   'votes',
#   'Genre_1',
#   'Genre_2',
#   'Genre_3',
#   'Gross_collection',
#   'Certification'),
#  ('The Dark Knight',
#   'Christian Bale',
#   'Heath Ledger',
#   'Aaron Eckhart',
#   'Michael Caine',
#   2717521,
#   'Action',
#   ' Crime',
#   ' Drama',
#   534.86,
#   'PG-13'),
#  ('Inception',
#   '  Leonardo DiCaprio',
#   'Joseph Gordon-Levitt',
#   'Elliot Page',
#   ' Ken Watanabe',
#   2412332,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   292.58,
#   'PG-13'),
#  ('The Matrix',
#   '  Keanu Reeves',
#   'Laurence Fishburne',
#   ' Carrie-Anne Moss',
#   ' Hugo Weaving',
#   1957307,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   171.48,
#   'R'),
#  ('The Lord of the Rings: The Fellowship of the Ring',
#   '  Elijah Wood',
#   'Ian McKellen',
#   'Orlando Bloom',
#   'Sean Bean',
#   1915355,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   315.54,
#   'PG-13'),
#  ('The Lord of the Rings: The Return of the King',
#   '  Elijah Wood',
#   'Viggo Mortensen',
#   ' Ian McKellen',
#   'Orlando Bloom',
#   1886645,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   377.85,
#   'PG-13'),
#  ('The Dark Knight Rises',
#   '  Christian Bale',
#   ' Tom Hardy',
#   ' Anne Hathaway',
#   ' Gary Oldman',
#   1741135,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   448.14,
#   'PG-13'),
#  ('The Lord of the Rings: The Two Towers',
#   '  Elijah Wood',
#   ' Ian McKellen',
#   'Viggo Mortensen',
#   ' Orlando Bloom',
#   1702927,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   342.55,
#   'PG-13'),
#  ('Gladiator',
#   '  Russell Crowe',
#   ' Joaquin Phoenix',
#   ' Connie Nielsen',
#   ' Oliver Reed',
#   1535784,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   187.71,
#   'R'),
#  ('Batman Begins',
#   '  Christian Bale',
#   ' Michael Caine',
#   ' Ken Watanabe',
#   ' Liam Neeson',
#   1502882,
#   'Action',
#   ' Crime',
#   ' Drama',
#   206.85,
#   'PG-13'),
#  ('The Avengers',
#   '  Robert Downey Jr.',
#   ' Chris Evans',
#   ' Scarlett Johansson',
#   ' Jeremy Renner',
#   1415723,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   623.28,
#   'R'),
#  ('Star Wars: Episode IV - A New Hope',
#   '  Mark Hamill',
#   ' Harrison Ford',
#   ' Carrie Fisher',
#   ' Alec Guinness',
#   1393243,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   322.74,
#   'PG'),
#  ('Avatar',
#   '  Sam Worthington',
#   ' Zoe Saldana',
#   ' Sigourney Weaver',
#   ' Michelle Rodriguez',
#   1341931,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   760.51,
#   'PG-13'),
#  ('Star Wars: Episode V - The Empire Strikes Back',
#   '  Mark Hamill',
#   'Harrison Ford',
#   ' Carrie Fisher',
#   'Billy Dee Williams',
#   1320777,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   290.48,
#   'PG'),
#  ('Guardians of the Galaxy',
#   '  Chris Pratt',
#   ' Vin Diesel',
#   ' Bradley Cooper',
#   ' Zoe Saldana',
#   1217116,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   333.18,
#   'PG-13'),
#  ('Leon: The Professional',
#   '  Jean Reno',
#   ' Gary Oldman',
#   ' Natalie Portman',
#   ' Danny Aiello',
#   1189073,
#   'Action',
#   ' Crime',
#   ' Drama',
#   19.5,
#   'R'),
#  ('Avengers: Endgame',
#   '  Robert Downey Jr.',
#   ' Chris Evans',
#   ' Mark Ruffalo',
#   ' Chris Hemsworth',
#   1179423,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   858.37,
#   'PG-13'),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl',
#   '  Johnny Depp',
#   ' Geoffrey Rush',
#   ' Orlando Bloom',
#   ' Keira Knightley',
#   1153318,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   305.41,
#   'R'),
#  ('V for Vendetta',
#   '  Hugo Weaving',
#   ' Natalie Portman',
#   ' Rupert Graves',
#   ' Stephen Rea',
#   1140572,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   70.51,
#   'R'),
#  ('Kill Bill: Vol. 1',
#   '  Uma Thurman',
#   ' David Carradine',
#   ' Daryl Hannah',
#   ' Michael Madsen',
#   1140530,
#   'Action',
#   ' Crime',
#   ' Drama',
#   70.1,
#   'R'),
#  ('Avengers: Infinity War',
#   '  Robert Downey Jr.',
#   ' Chris Hemsworth',
#   ' Mark Ruffalo',
#   ' Chris Evans',
#   1122836,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   678.82,
#   'PG-13'),
#  ('Terminator 2: Judgment Day',
#   '  Arnold Schwarzenegger',
#   ' Linda Hamilton',
#   ' Edward Furlong',
#   ' Robert Patrick',
#   1122770,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   204.84,
#   'R'),
#  ('Iron Man',
#   '  Robert Downey Jr.',
#   ' Gwyneth Paltrow',
#   ' Terrence Howard',
#   ' Jeff Bridges',
#   1082141,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   318.41,
#   'PG-13'),
#  ('Star Wars: Episode VI - Return of the Jedi',
#   '  Mark Hamill',
#   ' Harrison Ford',
#   ' Carrie Fisher',
#   ' Billy Dee Williams',
#   1077310,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   309.13,
#   'PG'),
#  ('Deadpool',
#   '  Ryan Reynolds',
#   ' Morena Baccarin',
#   ' T.J. Miller',
#   ' Ed Skrein',
#   1067514,
#   'Action',
#   ' Comedy',
#   'None',
#   363.07,
#   'PG-13'),
#  ('Mad Max: Fury Road',
#   '  Tom Hardy',
#   ' Charlize Theron',
#   ' Nicholas Hoult',
#   ' ZoÃƒÂ« Kravitz',
#   1029852,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   154.06,
#   'PG-13'),
#  ('Jurassic Park',
#   '  Sam Neill',
#   ' Laura Dern',
#   ' Jeff Goldblum',
#   ' Richard Attenborough',
#   1013596,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   402.45,
#   'PG-13'),
#  ('Indiana Jones and the Raiders of the Lost Ark',
#   '  Harrison Ford',
#   ' Karen Allen',
#   ' Paul Freeman',
#   ' John Rhys-Davies',
#   985955,
#   'Action',
#   ' Adventure',
#   'None',
#   248.16,
#   'PG'),
#  ('The Hunger Games',
#   '  Jennifer Lawrence',
#   ' Josh Hutcherson',
#   ' Liam Hemsworth',
#   ' Stanley Tucci',
#   948048,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   408.01,
#   'R'),
#  ('Star Wars: Episode VII - The Force Awakens',
#   '  Daisy Ridley',
#   ' John Boyega',
#   ' Oscar Isaac',
#   ' Domhnall Gleeson',
#   947209,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   936.66,
#   'PG-13'),
#  ('Die Hard',
#   '  Bruce Willis',
#   ' Alan Rickman',
#   ' Bonnie Bedelia',
#   ' Reginald VelJohnson',
#   901160,
#   'Action',
#   ' Thriller',
#   'None',
#   83.01,
#   'R'),
#  ('Avengers: Age of Ultron',
#   '  Robert Downey Jr.',
#   ' Chris Evans',
#   ' Mark Ruffalo',
#   ' Chris Hemsworth',
#   885368,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   459.01,
#   'R'),
#  ('The Terminator',
#   '  Arnold Schwarzenegger',
#   ' Linda Hamilton',
#   ' Michael Biehn',
#   ' Paul Winfield',
#   885204,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   38.4,
#   'R'),
#  ('Iron Man 3',
#   '  Robert Downey Jr.',
#   ' Guy Pearce',
#   ' Gwyneth Paltrow',
#   ' Don Cheadle',
#   869213,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   409.01,
#   'PG-13'),
#  ('Thor',
#   '  Chris Hemsworth',
#   ' Anthony Hopkins',
#   ' Natalie Portman',
#   ' Tom Hiddleston',
#   867999,
#   'Action',
#   ' Fantasy',
#   'None',
#   181.03,
#   'R'),
#  ('Captain America: The Winter Soldier',
#   '  Chris Evans',
#   ' Samuel L. Jackson',
#   ' Scarlett Johansson',
#   ' Robert Redford',
#   866461,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   259.77,
#   'PG'),
#  ('Captain America: The First Avenger',
#   '  Chris Evans',
#   ' Hugo Weaving',
#   ' Samuel L. Jackson',
#   ' Hayley Atwell',
#   864464,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   176.65,
#   'PG-13'),
#  ('Spider-Man',
#   '  Tobey Maguire',
#   ' Kirsten Dunst',
#   ' Willem Dafoe',
#   ' James Franco',
#   838102,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   403.71,
#   'R'),
#  ('Iron Man 2',
#   '  Robert Downey Jr.',
#   ' Mickey Rourke',
#   ' Gwyneth Paltrow',
#   ' Don Cheadle',
#   836711,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   312.43,
#   'R'),
#  ('300',
#   '  Gerard Butler',
#   ' Lena Headey',
#   ' David Wenham',
#   ' Dominic West',
#   836319,
#   'Action',
#   ' Drama',
#   'None',
#   210.61,
#   'PG-13'),
#  ('The Revenant (I)',
#   '  Leonardo DiCaprio',
#   ' Tom Hardy',
#   ' Will Poulter',
#   ' Domhnall Gleeson',
#   827647,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   183.64,
#   'R'),
#  ('Star Wars: Episode I - The Phantom Menace',
#   '  Ewan McGregor',
#   ' Liam Neeson',
#   ' Natalie Portman',
#   ' Jake Lloyd',
#   824670,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   474.54,
#   'R'),
#  ('Star Wars: Episode III - Revenge of the Sith',
#   '  Hayden Christensen',
#   ' Natalie Portman',
#   ' Ewan McGregor',
#   ' Samuel L. Jackson',
#   811691,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   380.26,
#   'R'),
#  ('Captain America: Civil War',
#   '  Chris Evans',
#   ' Robert Downey Jr.',
#   ' Scarlett Johansson',
#   ' Sebastian Stan',
#   811441,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   408.08,
#   'PG-13'),
#  ('Black Panther',
#   '  Chadwick Boseman, Michael B. Jordan, Lupita Nyongo, Danai Gurira',
#   'None',
#   'None',
#   'None',
#   801782,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   700.06,
#   'R'),
#  ('Spider-Man: No Way Home',
#   '  Tom Holland',
#   ' Zendaya',
#   ' Benedict Cumberbatch',
#   ' Jacob Batalon',
#   796509,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   804.75,
#   'PG-13'),
#  ('Blade Runner',
#   '  Harrison Ford',
#   ' Rutger Hauer',
#   ' Sean Young',
#   ' Edward James Olmos',
#   787715,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   32.87,
#   'R'),
#  ('Logan',
#   '  Hugh Jackman',
#   ' Patrick Stewart',
#   ' Dafne Keen',
#   ' Boyd Holbrook',
#   787213,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   226.28,
#   'R'),
#  ('Man of Steel',
#   '  Henry Cavill',
#   ' Amy Adams',
#   ' Michael Shannon',
#   ' Diane Lane',
#   786058,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   291.05,
#   'PG-13'),
#  ('I Am Legend',
#   '  Will Smith',
#   ' Alice Braga',
#   ' Charlie Tahan',
#   ' Salli Richardson-Whitfield',
#   779785,
#   'Action',
#   ' Drama',
#   ' Horror',
#   256.39,
#   'PG'),
#  ('Thor: Ragnarok',
#   '  Chris Hemsworth',
#   ' Tom Hiddleston',
#   ' Cate Blanchett',
#   ' Mark Ruffalo',
#   775783,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   315.06,
#   'PG-13'),
#  ('Kill Bill: Vol. 2',
#   '  Uma Thurman',
#   ' David Carradine',
#   ' Michael Madsen',
#   ' Daryl Hannah',
#   773849,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   66.21,
#   'R'),
#  ('Indiana Jones and the Last Crusade',
#   '  Harrison Ford',
#   ' Sean Connery',
#   ' Alison Doody',
#   ' Denholm Elliott',
#   770923,
#   'Action',
#   ' Adventure',
#   'None',
#   197.17,
#   'PG-13'),
#  ('Doctor Strange',
#   '  Benedict Cumberbatch',
#   ' Chiwetel Ejiofor',
#   ' Rachel McAdams',
#   ' Benedict Wong',
#   765484,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   232.64,
#   'R'),
#  ('The Incredibles',
#   '  Craig T. Nelson',
#   ' Samuel L. Jackson',
#   ' Holly Hunter',
#   ' Jason Lee',
#   761142,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   261.44,
#   'PG-13'),
#  ('How to Train Your Dragon',
#   '  Jay Baruchel',
#   ' Gerard Butler',
#   ' Christopher Mintz-Plasse',
#   ' Craig Ferguson',
#   761030,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   217.58,
#   'PG-13'),
#  ('Pirates of the Caribbean: Dead Mans Chest',
#   '  Johnny Depp',
#   ' Orlando Bloom',
#   ' Keira Knightley',
#   ' Jack Davenport',
#   736561,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   423.32,
#   'R'),
#  ('Aliens',
#   '  Sigourney Weaver',
#   ' Michael Biehn',
#   ' Carrie Henn',
#   ' Paul Reiser',
#   732348,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   85.16,
#   'R'),
#  ('Star Wars: Episode II - Attack of the Clones',
#   '  Hayden Christensen',
#   ' Natalie Portman',
#   ' Ewan McGregor',
#   ' Christopher Lee',
#   729378,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   310.68,
#   'PG-13'),
#  ('X-Men: Days of Future Past',
#   '  Patrick Stewart',
#   ' Ian McKellen',
#   ' Hugh Jackman',
#   ' James McAvoy',
#   724918,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   233.92,
#   'PG-13'),
#  ('Guardians of the Galaxy Vol. 2',
#   '  Chris Pratt',
#   ' Zoe Saldana',
#   ' Dave Bautista',
#   ' Vin Diesel',
#   714414,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   389.81,
#   'R'),
#  ('Batman v Superman: Dawn of Justice',
#   '  Ben Affleck',
#   ' Henry Cavill',
#   ' Amy Adams',
#   ' Jesse Eisenberg',
#   712092,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   330.36,
#   'R'),
#  ('Skyfall',
#   '  Daniel Craig',
#   ' Javier Bardem',
#   ' Naomie Harris',
#   ' Judi Dench',
#   709652,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   304.36,
#   'PG-13'),
#  ('X-Men: First Class',
#   '  James McAvoy',
#   ' Michael Fassbender',
#   ' Jennifer Lawrence',
#   ' Kevin Bacon',
#   704696,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   146.41,
#   'Approved'),
#  ('The Batman',
#   '  Robert Pattinson',
#   ' ZoÃƒÂ« Kravitz',
#   ' Jeffrey Wright',
#   ' Colin Farrell',
#   699825,
#   'Action',
#   ' Crime',
#   ' Drama',
#   369.35,
#   'R'),
#  ('Thor: The Dark World',
#   '  Chris Hemsworth',
#   ' Natalie Portman',
#   ' Tom Hiddleston',
#   ' Stellan SkarsgÃƒÂ¥rd',
#   699494,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   206.36,
#   'R'),
#  ('Suicide Squad',
#   '  Will Smith',
#   ' Jared Leto',
#   ' Margot Robbie',
#   ' Viola Davis',
#   699148,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   325.1,
#   'PG-13'),
#  ('Edge of Tomorrow',
#   '  Tom Cruise',
#   ' Emily Blunt',
#   ' Bill Paxton',
#   ' Brendan Gleeson',
#   699063,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   100.21,
#   'PG-13'),
#  ('District 9',
#   '  Sharlto Copley',
#   ' David James',
#   ' Jason Cope',
#   ' Nathalie Boltt',
#   694854,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   115.65,
#   'R'),
#  ('John Wick',
#   '  Keanu Reeves',
#   ' Michael Nyqvist',
#   ' Alfie Allen',
#   ' Willem Dafoe',
#   693733,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   43.04,
#   'PG-13'),
#  ('Ant-Man',
#   '  Paul Rudd',
#   ' Michael Douglas',
#   ' Corey Stoll',
#   ' Evangeline Lilly',
#   692828,
#   'Action',
#   ' Comedy',
#   ' Sci-Fi',
#   180.2,
#   'PG-13'),
#  ('World War Z',
#   '  Brad Pitt',
#   ' Mireille Enos',
#   ' Daniella Kertesz',
#   ' James Badge Dale',
#   687369,
#   'Action',
#   ' Adventure',
#   ' Horror',
#   202.36,
#   'PG-13'),
#  ('Kingsman: The Secret Service',
#   '  Colin Firth',
#   ' Taron Egerton',
#   ' Samuel L. Jackson',
#   ' Michael Caine',
#   686315,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   128.26,
#   'PG-13'),
#  ('The Hunger Games: Catching Fire',
#   '  Jennifer Lawrence',
#   ' Josh Hutcherson',
#   ' Liam Hemsworth',
#   ' Philip Seymour Hoffman',
#   683641,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   424.67,
#   'R'),
#  ('Dunkirk',
#   '  Fionn Whitehead',
#   ' Barry Keoghan',
#   ' Mark Rylance',
#   ' Tom Hardy',
#   682150,
#   'Action',
#   ' Drama',
#   ' History',
#   188.37,
#   'R'),
#  ('Spider-Man: Homecoming',
#   '  Tom Holland',
#   ' Michael Keaton',
#   ' Robert Downey Jr.',
#   ' Marisa Tomei',
#   679799,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   334.2,
#   'PG-13'),
#  ('Dune',
#   '  TimothÃƒÂ©e Chalamet',
#   ' Rebecca Ferguson',
#   ' Zendaya',
#   ' Oscar Isaac',
#   677751,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   108.33,
#   'R'),
#  ('Heat',
#   '  Al Pacino',
#   ' Robert De Niro',
#   ' Val Kilmer',
#   ' Jon Voight',
#   675813,
#   'Action',
#   ' Crime',
#   ' Drama',
#   67.44,
#   'R'),
#  ('Wonder Woman',
#   '  Gal Gadot',
#   ' Chris Pine',
#   ' Robin Wright',
#   ' Lucy Davis',
#   674284,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   412.56,
#   'R'),
#  ('The Amazing Spider-Man',
#   '  Andrew Garfield',
#   ' Emma Stone',
#   ' Rhys Ifans',
#   ' Irrfan Khan',
#   672261,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   262.03,
#   'PG-13'),
#  ('Spider-Man 2',
#   '  Tobey Maguire',
#   ' Kirsten Dunst',
#   ' Alfred Molina',
#   ' James Franco',
#   672203,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   373.59,
#   'R'),
#  ('Casino Royale',
#   '  Daniel Craig',
#   ' Eva Green',
#   ' Judi Dench',
#   ' Jeffrey Wright',
#   670820,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   167.45,
#   'R'),
#  ('Pirates of the Caribbean: At Worlds End',
#   '  Johnny Depp',
#   ' Orlando Bloom',
#   ' Keira Knightley',
#   ' Geoffrey Rush',
#   666807,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   309.42,
#   'R'),
#  ('Drive (I)',
#   '  Ryan Gosling',
#   ' Carey Mulligan',
#   ' Bryan Cranston',
#   ' Albert Brooks',
#   664299,
#   'Action',
#   ' Drama',
#   'None',
#   35.06,
#   'PG-13'),
#  ('Rogue One: A Star Wars Story',
#   '  Felicity Jones',
#   ' Diego Luna',
#   ' Alan Tudyk',
#   ' Donnie Yen',
#   657650,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   532.18,
#   'R'),
#  ('Jurassic World',
#   '  Chris Pratt',
#   ' Bryce Dallas Howard',
#   ' Ty Simpkins',
#   ' Judy Greer',
#   656823,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   652.27,
#   'PG-13'),
#  ('Transformers',
#   '  Shia LaBeouf',
#   ' Megan Fox',
#   ' Josh Duhamel',
#   ' Tyrese Gibson',
#   651527,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   319.25,
#   'PG-13'),
#  ('Sherlock Holmes',
#   '  Robert Downey Jr.',
#   ' Jude Law',
#   ' Rachel McAdams',
#   ' Mark Strong',
#   648103,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   209.03,
#   'R'),
#  ('Star Wars: Episode VIII - The Last Jedi',
#   '  Daisy Ridley',
#   ' John Boyega',
#   ' Mark Hamill',
#   ' Carrie Fisher',
#   647682,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   620.18,
#   'PG-13'),
#  ('The Bourne Ultimatum',
#   '  Matt Damon',
#   ' Edgar RamÃƒÂ\xadrez',
#   ' Joan Allen',
#   ' Julia Stiles',
#   644032,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   227.47,
#   'Not Rated'),
#  ('X-Men',
#   '  Patrick Stewart',
#   ' Hugh Jackman',
#   ' Ian McKellen',
#   ' Famke Janssen',
#   627313,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   157.3,
#   'PG'),
#  ('1917',
#   '  Dean-Charles Chapman',
#   ' George MacKay',
#   ' Daniel Mays',
#   ' Colin Firth',
#   620672,
#   'Action',
#   ' Drama',
#   ' War',
#   159.23,
#   'R'),
#  ('Taken (I)',
#   '  Liam Neeson',
#   ' Maggie Grace',
#   ' Famke Janssen',
#   ' Leland Orser',
#   614638,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   145,
#   'PG-13'),
#  ('Star Trek',
#   '  Chris Pine',
#   ' Zachary Quinto',
#   ' Simon Pegg',
#   ' Leonard Nimoy',
#   610293,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   257.73,
#   'R'),
#  ('The Matrix Reloaded',
#   '  Keanu Reeves',
#   ' Laurence Fishburne',
#   ' Carrie-Anne Moss',
#   ' Hugo Weaving',
#   608540,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   281.49,
#   'PG-13'),
#  ('Spider-Man 3',
#   '  Tobey Maguire',
#   ' Kirsten Dunst',
#   ' Topher Grace',
#   ' Thomas Haden Church',
#   607525,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   336.53,
#   'PG-13'),
#  ('Deadpool 2',
#   '  Ryan Reynolds',
#   ' Josh Brolin',
#   ' Morena Baccarin',
#   ' Julian Dennison',
#   605012,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   324.59,
#   'PG'),
#  ('Blade Runner 2049',
#   '  Harrison Ford',
#   ' Ryan Gosling',
#   ' Ana de Armas',
#   ' Dave Bautista',
#   603524,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   92.05,
#   'R'),
#  ('Harry Potter and the Order of the Phoenix',
#   '  Daniel Radcliffe',
#   ' Emma Watson',
#   ' Rupert Grint',
#   ' Brendan Gleeson',
#   600982,
#   'Action',
#   ' Adventure',
#   ' Family',
#   292,
#   'R'),
#  ('Oldboy',
#   '  Choi Min-sik',
#   ' Yoo Ji-tae',
#   ' Kang Hye-jeong',
#   ' Kim Byeong-Ok',
#   596202,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   0.71,
#   'R'),
#  ('Zombieland',
#   '  Jesse Eisenberg',
#   ' Emma Stone',
#   ' Woody Harrelson',
#   ' Abigail Breslin',
#   595210,
#   'Action',
#   ' Comedy',
#   ' Horror',
#   75.59,
#   'PG-13'),
#  ('Lock Stock and Two Smoking Barrels',
#   '  Jason Flemyng',
#   ' Dexter Fletcher',
#   ' Nick Moran',
#   ' Jason Statham',
#   595108,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   3.9,
#   'PG'),
#  ('Top Gun: Maverick',
#   '  Tom Cruise',
#   ' Jennifer Connelly',
#   ' Miles Teller',
#   ' Val Kilmer',
#   588695,
#   'Action',
#   ' Drama',
#   'None',
#   718.73,
#   'PG-13'),
#  ('Looper',
#   '  Joseph Gordon-Levitt',
#   ' Bruce Willis',
#   ' Emily Blunt',
#   ' Paul Dano',
#   586887,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   66.49,
#   'PG-13'),
#  ('Independence Day',
#   '  Will Smith',
#   ' Bill Pullman',
#   ' Jeff Goldblum',
#   ' Mary McDonnell',
#   586492,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   306.17,
#   'R'),
#  ('Men in Black',
#   '  Tommy Lee Jones',
#   ' Will Smith',
#   ' Linda Fiorentino',
#   ' Vincent DOnofrio',
#   584418,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   250.69,
#   'PG-13'),
#  ('Captain Marvel',
#   '  Brie Larson',
#   ' Samuel L. Jackson',
#   ' Ben Mendelsohn',
#   ' Jude Law',
#   579180,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   426.83,
#   'TV-MA'),
#  ('Kick-Ass',
#   '  Aaron Taylor-Johnson',
#   ' Nicolas Cage',
#   ' ChloÃƒÂ« Grace Moretz',
#   ' Garrett M. Brown',
#   575103,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   48.07,
#   'R'),
#  ('21 Jump Street',
#   '  Jonah Hill',
#   ' Channing Tatum',
#   ' Ice Cube',
#   ' Brie Larson',
#   574792,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   138.45,
#   'R'),
#  ('Baby Driver',
#   '  Ansel Elgort',
#   ' Jon Bernthal',
#   ' Jon Hamm',
#   ' Eiza GonzÃƒÂ¡lez',
#   566453,
#   'Action',
#   ' Crime',
#   ' Drama',
#   107.83,
#   'R'),
#  ('Minority Report',
#   '  Tom Cruise',
#   ' Colin Farrell',
#   ' Samantha Morton',
#   ' Max von Sydow',
#   565154,
#   'Action',
#   ' Crime',
#   ' Mystery',
#   132.07,
#   'PG-13'),
#  ('Spider-Man: Into the Spider-Verse',
#   '  Shameik Moore',
#   ' Jake Johnson',
#   ' Hailee Steinfeld',
#   ' Mahershala Ali',
#   564456,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   190.24,
#   'PG'),
#  ('Harry Potter and the Half-Blood Prince',
#   '  Daniel Radcliffe',
#   ' Emma Watson',
#   ' Rupert Grint',
#   ' Michael Gambon',
#   564019,
#   'Action',
#   ' Adventure',
#   ' Family',
#   301.96,
#   'R'),
#  ('Watchmen',
#   '  Jackie Earle Haley',
#   ' Patrick Wilson',
#   ' Carla Gugino',
#   ' Malin Akerman',
#   562747,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   107.51,
#   'PG'),
#  ('X2: X-Men United',
#   '  Patrick Stewart',
#   ' Hugh Jackman',
#   ' Halle Berry',
#   ' Ian McKellen',
#   560786,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   214.95,
#   'M/PG'),
#  ('The Bourne Identity',
#   '  Franka Potente',
#   ' Matt Damon',
#   ' Chris Cooper',
#   ' Clive Owen',
#   558713,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   121.66,
#   'PG-13'),
#  ('I Robot',
#   '  Will Smith',
#   ' Bridget Moynahan',
#   ' Bruce Greenwood',
#   ' Alan Tudyk',
#   554599,
#   'Action',
#   ' Mystery',
#   ' Sci-Fi',
#   144.8,
#   'R'),
#  ('Pirates of the Caribbean: On Stranger Tides',
#   '  Johnny Depp',
#   ' PenÃƒÂ©lope Cruz',
#   ' Ian McShane',
#   ' Geoffrey Rush',
#   541387,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   241.06,
#   'PG-13'),
#  ('Rise of the Planet of the Apes',
#   '  James Franco',
#   ' Andy Serkis',
#   ' Freida Pinto',
#   ' Karin Konoval',
#   540181,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   176.76,
#   'PG-13'),
#  ('Oblivion (I)',
#   '  Tom Cruise',
#   ' Morgan Freeman',
#   ' Andrea Riseborough',
#   ' Olga Kurylenko',
#   537382,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   89.02,
#   'R'),
#  ('Source Code',
#   '  Jake Gyllenhaal',
#   ' Michelle Monaghan',
#   ' Vera Farmiga',
#   ' Jeffrey Wright',
#   530897,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   54.71,
#   'R'),
#  ('Tenet',
#   '  John David Washington',
#   ' Robert Pattinson',
#   ' Elizabeth Debicki',
#   ' Juhan Ulfsak',
#   530437,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   58.46,
#   'R'),
#  ('X-Men: The Last Stand',
#   '  Patrick Stewart',
#   ' Hugh Jackman',
#   ' Halle Berry',
#   ' Famke Janssen',
#   526778,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   234.36,
#   'PG-13'),
#  ('The Matrix Revolutions',
#   '  Keanu Reeves',
#   ' Laurence Fishburne',
#   ' Carrie-Anne Moss',
#   ' Hugo Weaving',
#   525511,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   139.31,
#   'R'),
#  ('Hot Fuzz',
#   '  Simon Pegg',
#   ' Nick Frost',
#   ' Martin Freeman',
#   ' Bill Nighy',
#   517068,
#   'Action',
#   ' Comedy',
#   ' Mystery',
#   23.64,
#   'PG-13'),
#  ('Spider-Man: Far from Home',
#   '  Tom Holland',
#   ' Samuel L. Jackson',
#   ' Jake Gyllenhaal',
#   ' Marisa Tomei',
#   515676,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   390.53,
#   'R'),
#  ('X-Men Origins: Wolverine',
#   '  Hugh Jackman',
#   ' Liev Schreiber',
#   ' Ryan Reynolds',
#   ' Danny Huston',
#   515382,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   179.88,
#   'R'),
#  ('Pacific Rim',
#   '  Idris Elba',
#   ' Charlie Hunnam',
#   ' Rinko Kikuchi',
#   ' Charlie Day',
#   513099,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   101.8,
#   'PG'),
#  ('The Amazing Spider-Man 2',
#   '  Andrew Garfield',
#   ' Emma Stone',
#   ' Jamie Foxx',
#   ' Paul Giamatti',
#   512539,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   202.85,
#   'R'),
#  ('Fury',
#   '  Brad Pitt',
#   ' Shia LaBeouf',
#   ' Logan Lerman',
#   ' Michael PeÃƒÂ±a',
#   512217,
#   'Action',
#   ' Drama',
#   ' War',
#   85.82,
#   'R'),
#  ('Mr. & Mrs. Smith',
#   '  Brad Pitt',
#   ' Angelina Jolie',
#   ' Adam Brody',
#   ' Vince Vaughn',
#   511932,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   186.34,
#   'R'),
#  ('Lucy (I)',
#   '  Scarlett Johansson',
#   ' Morgan Freeman',
#   ' Choi Min-sik',
#   ' Amr Waked',
#   511851,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   126.66,
#   'PG-13'),
#  ('Children of Men',
#   '  Julianne Moore',
#   ' Clive Owen',
#   ' Chiwetel Ejiofor',
#   ' Michael Caine',
#   511555,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   35.55,
#   'R'),
#  ('Venom',
#   '  Tom Hardy',
#   ' Michelle Williams',
#   ' Riz Ahmed',
#   ' Scott Haze',
#   505267,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   213.52,
#   'PG-13'),
#  ('The Incredible Hulk',
#   '  Edward Norton',
#   ' Liv Tyler',
#   ' Tim Roth',
#   ' William Hurt',
#   505177,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   134.52,
#   'PG-13'),
#  ('Indiana Jones and the Temple of Doom',
#   '  Harrison Ford',
#   ' Kate Capshaw',
#   ' Ke Huy Quan',
#   ' Amrish Puri',
#   503406,
#   'Action',
#   ' Adventure',
#   'None',
#   179.87,
#   'PG-13'),
#  ('American Sniper',
#   '  Bradley Cooper',
#   ' Sienna Miller',
#   ' Kyle Gallner',
#   ' Cole Konis',
#   503097,
#   'Action',
#   ' Biography',
#   ' Drama',
#   350.13,
#   'PG'),
#  ('Mission: Impossible - Ghost Protocol',
#   '  Tom Cruise',
#   ' Jeremy Renner',
#   ' Simon Pegg',
#   ' Paula Patton',
#   501423,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   209.4,
#   'PG-13'),
#  ('Hancock',
#   '  Will Smith',
#   ' Charlize Theron',
#   ' Jason Bateman',
#   ' Jae Head',
#   494952,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   227.95,
#   'PG-13'),
#  ('Aquaman',
#   '  Jason Momoa',
#   ' Amber Heard',
#   ' Willem Dafoe',
#   ' Patrick Wilson',
#   491117,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   335.06,
#   'PG-13'),
#  ('Rush (I)',
#   '  Daniel BrÃƒÂ¼hl',
#   ' Chris Hemsworth',
#   ' Olivia Wilde',
#   ' Alexandra Maria Lara',
#   490998,
#   'Action',
#   ' Biography',
#   ' Drama',
#   26.95,
#   'PG'),
#  ('Star Trek Into Darkness',
#   '  Chris Pine',
#   ' Zachary Quinto',
#   ' Zoe Saldana',
#   ' Benedict Cumberbatch',
#   489293,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   228.78,
#   'R'),
#  ('Kung Fu Panda',
#   '  Jack Black',
#   ' Ian McShane',
#   ' Angelina Jolie',
#   ' Dustin Hoffman',
#   488505,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   215.43,
#   'Not Rated'),
#  ('The Fifth Element',
#   '  Bruce Willis',
#   ' Milla Jovovich',
#   ' Gary Oldman',
#   ' Ian Holm',
#   485970,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   63.54,
#   'R'),
#  ('The Maze Runner',
#   '  Dylan OBrien',
#   ' Kaya Scodelario',
#   ' Will Poulter',
#   ' Thomas Brodie-Sangster',
#   483566,
#   'Action',
#   ' Mystery',
#   ' Sci-Fi',
#   102.43,
#   'TV-MA'),
#  ('Warrior',
#   '  Tom Hardy',
#   ' Nick Nolte',
#   ' Joel Edgerton',
#   ' Jennifer Morrison',
#   481730,
#   'Action',
#   ' Drama',
#   ' Sport',
#   13.66,
#   'R'),
#  ('The Wolverine',
#   '  Hugh Jackman',
#   ' Will Yun Lee',
#   ' Tao Okamoto',
#   ' Rila Fukushima',
#   477545,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   132.56,
#   'R'),
#  ('John Wick: Chapter 2',
#   '  Keanu Reeves',
#   ' Riccardo Scamarcio',
#   ' Ian McShane',
#   ' Ruby Rose',
#   476647,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   92.03,
#   'PG-13'),
#  ('Big Hero 6',
#   '  Ryan Potter',
#   ' Scott Adsit',
#   ' Jamie Chung',
#   ' T.J. Miller',
#   476426,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   222.53,
#   'Not Rated'),
#  ('Top Gun',
#   '  Tom Cruise',
#   ' Tim Robbins',
#   ' Kelly McGillis',
#   ' Val Kilmer',
#   474374,
#   'Action',
#   ' Drama',
#   'None',
#   179.8,
#   'R'),
#  ('The Bourne Supremacy',
#   '  Matt Damon',
#   ' Franka Potente',
#   ' Joan Allen',
#   ' Brian Cox',
#   473471,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   176.24,
#   'R'),
#  ('Captain Phillips',
#   '  Tom Hanks',
#   ' Barkhad Abdi',
#   ' Barkhad Abdirahman',
#   ' Catherine Keener',
#   473214,
#   'Action',
#   ' Biography',
#   ' Crime',
#   107.1,
#   'R'),
#  ('The Hunger Games: Mockingjay - Part 1',
#   '  Jennifer Lawrence',
#   ' Josh Hutcherson',
#   ' Liam Hemsworth',
#   ' Woody Harrelson',
#   471693,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   337.14,
#   'PG-13'),
#  ('Divergent',
#   '  Shailene Woodley',
#   ' Theo James',
#   ' Kate Winslet',
#   ' Jai Courtney',
#   471588,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   150.95,
#   'PG-13'),
#  ('Star Wars: Episode IX - The Rise of Skywalker',
#   '  Daisy Ridley',
#   ' John Boyega',
#   ' Oscar Isaac',
#   ' Adam Driver',
#   467497,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   515.2,
#   'PG'),
#  ('Sherlock Holmes: A Game of Shadows',
#   '  Robert Downey Jr.',
#   ' Jude Law',
#   ' Jared Harris',
#   ' Rachel McAdams',
#   465830,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   186.85,
#   'R'),
#  ('Indiana Jones and the Kingdom of the Crystal Skull',
#   '  Harrison Ford',
#   ' Cate Blanchett',
#   ' Shia LaBeouf',
#   ' Karen Allen',
#   465204,
#   'Action',
#   ' Adventure',
#   'None',
#   317.1,
#   'PG-13'),
#  ('Justice League',
#   '  Ben Affleck',
#   ' Gal Gadot',
#   ' Jason Momoa',
#   ' Ezra Miller',
#   462983,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   229.02,
#   'R'),
#  ('The Day After Tomorrow',
#   '  Dennis Quaid',
#   ' Jake Gyllenhaal',
#   ' Emmy Rossum',
#   ' Dash Mihok',
#   459885,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   186.74,
#   'PG'),
#  ('War of the Worlds',
#   '  Tom Cruise',
#   ' Dakota Fanning',
#   ' Tim Robbins',
#   ' Miranda Otto',
#   459533,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   234.28,
#   'R'),
#  ('Quantum of Solace',
#   '  Daniel Craig',
#   ' Olga Kurylenko',
#   ' Mathieu Amalric',
#   ' Judi Dench',
#   457783,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   168.37,
#   'R'),
#  ('Elysium (I)',
#   '  Matt Damon',
#   ' Jodie Foster',
#   ' Sharlto Copley',
#   ' Alice Braga',
#   457503,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   93.05,
#   'PG-13'),
#  ('Ready Player One',
#   '  Tye Sheridan',
#   ' Olivia Cooke',
#   ' Ben Mendelsohn',
#   ' Lena Waithe',
#   453860,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   137.69,
#   'PG-13'),
#  ('The Last Samurai',
#   '  Tom Cruise',
#   ' Ken Watanabe',
#   ' Billy Connolly',
#   ' William Atherton',
#   452033,
#   'Action',
#   ' Drama',
#   'None',
#   111.11,
#   'PG-13'),
#  ('Dawn of the Planet of the Apes',
#   '  Gary Oldman',
#   ' Keri Russell',
#   ' Andy Serkis',
#   ' Kodi Smit-McPhee',
#   451621,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   208.55,
#   'R'),
#  ('Spectre (I)',
#   '  Daniel Craig',
#   ' Christoph Waltz',
#   ' LÃƒÂ©a Seydoux',
#   ' Ralph Fiennes',
#   450822,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   200.07,
#   'PG-13'),
#  ('Training Day',
#   '  Denzel Washington',
#   ' Ethan Hawke',
#   ' Scott Glenn',
#   ' Tom Berenger',
#   450131,
#   'Action',
#   ' Crime',
#   ' Drama',
#   76.63,
#   'R'),
#  ('Everything Everywhere All at Once',
#   '  Michelle Yeoh',
#   ' Stephanie Hsu',
#   ' Jamie Lee Curtis',
#   ' Ke Huy Quan',
#   448150,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   72.86,
#   'Not Rated'),
#  ('Sicario',
#   '  Emily Blunt',
#   ' Josh Brolin',
#   ' Benicio Del Toro',
#   ' Jon Bernthal',
#   446130,
#   'Action',
#   ' Crime',
#   ' Drama',
#   46.89,
#   'R'),
#  ('X-Men: Apocalypse',
#   '  James McAvoy',
#   ' Michael Fassbender',
#   ' Jennifer Lawrence',
#   ' Nicholas Hoult',
#   445739,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   155.44,
#   'PG-13'),
#  ('The Mummy',
#   '  Brendan Fraser',
#   ' Rachel Weisz',
#   ' John Hannah',
#   ' Arnold Vosloo',
#   443668,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   155.25,
#   'R'),
#  ('Scott Pilgrim vs. the World',
#   '  Michael Cera',
#   ' Mary Elizabeth Winstead',
#   ' Kieran Culkin',
#   ' Anna Kendrick',
#   441598,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   31.49,
#   'PG-13'),
#  ('Doctor Strange in the Multiverse of Madness',
#   '  Benedict Cumberbatch',
#   ' Elizabeth Olsen',
#   ' Chiwetel Ejiofor',
#   ' Benedict Wong',
#   438724,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   411.33,
#   'PG-13'),
#  ('Mission: Impossible',
#   '  Tom Cruise',
#   ' Jon Voight',
#   ' Emmanuelle BÃƒÂ©art',
#   ' Henry Czerny',
#   438675,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   180.98,
#   'R'),
#  ('Armageddon',
#   '  Bruce Willis',
#   ' Billy Bob Thornton',
#   ' Ben Affleck',
#   ' Liv Tyler',
#   436275,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   201.57,
#   'PG-13'),
#  ('Predator',
#   '  Arnold Schwarzenegger',
#   ' Carl Weathers',
#   ' Kevin Peter Hall',
#   ' Elpidia Carrillo',
#   434375,
#   'Action',
#   ' Adventure',
#   ' Horror',
#   59.74,
#   'PG-13'),
#  ('King Kong',
#   '  Naomi Watts',
#   ' Jack Black',
#   ' Adrien Brody',
#   ' Thomas Kretschmann',
#   433226,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   218.08,
#   'PG'),
#  ('Tropic Thunder',
#   '  Ben Stiller',
#   ' Jack Black',
#   ' Robert Downey Jr.',
#   ' Jeff Kahn',
#   429158,
#   'Action',
#   ' Comedy',
#   ' War',
#   110.52,
#   'R'),
#  ('The Lost World: Jurassic Park',
#   '  Jeff Goldblum',
#   ' Julianne Moore',
#   ' Pete Postlethwaite',
#   ' Vince Vaughn',
#   428610,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   229.09,
#   'PG-13'),
#  ('Ghostbusters',
#   '  Bill Murray',
#   ' Dan Aykroyd',
#   ' Sigourney Weaver',
#   ' Harold Ramis',
#   425653,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   238.63,
#   'R'),
#  ('Ant-Man and the Wasp',
#   '  Paul Rudd',
#   ' Evangeline Lilly',
#   ' Michael PeÃƒÂ±a',
#   ' Walton Goggins',
#   424828,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   216.65,
#   'PG-13'),
#  ('In Time',
#   '  Justin Timberlake',
#   ' Amanda Seyfried',
#   ' Cillian Murphy',
#   ' Olivia Wilde',
#   422963,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   37.52,
#   'PG-13'),
#  ('Godzilla',
#   '  Aaron Taylor-Johnson',
#   ' Elizabeth Olsen',
#   ' Bryan Cranston',
#   ' Ken Watanabe',
#   422905,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   200.68,
#   'PG-13'),
#  ('No Time to Die',
#   '  Daniel Craig',
#   ' Ana de Armas',
#   ' Rami Malek',
#   ' LÃƒÂ©a Seydoux',
#   418774,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   160.87,
#   'R'),
#  ('Ford v Ferrari',
#   '  Matt Damon',
#   ' Christian Bale',
#   ' Jon Bernthal',
#   ' CaitrÃƒÂ\xadona Balfe',
#   418484,
#   'Action',
#   ' Biography',
#   ' Drama',
#   117.62,
#   'PG-13'),
#  ('Transformers: Dark of the Moon',
#   '  Shia LaBeouf',
#   ' Rosie Huntington-Whiteley',
#   ' Tyrese Gibson',
#   ' Josh Duhamel',
#   417993,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   352.39,
#   'PG-13'),
#  ('Collateral',
#   '  Tom Cruise',
#   ' Jamie Foxx',
#   ' Jada Pinkett Smith',
#   ' Mark Ruffalo',
#   415928,
#   'Action',
#   ' Crime',
#   ' Drama',
#   101.01,
#   'PG-13'),
#  ('Transformers: Revenge of the Fallen',
#   '  Shia LaBeouf',
#   ' Megan Fox',
#   ' Josh Duhamel',
#   ' Tyrese Gibson',
#   414789,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   402.11,
#   'PG-13'),
#  ('Zack Snyders Justice League',
#   '  Henry Cavill',
#   ' Ben Affleck',
#   ' Gal Gadot',
#   ' Amy Adams',
#   412561,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   0,
#   'PG'),
#  ('Live Free or Die Hard',
#   '  Bruce Willis',
#   ' Justin Long',
#   ' Timothy Olyphant',
#   ' Maggie Q',
#   412400,
#   'Action',
#   ' Thriller',
#   'None',
#   134.53,
#   'R'),
#  ('Cloverfield',
#   '  Mike Vogel',
#   ' Jessica Lucas',
#   ' Lizzy Caplan',
#   ' T.J. Miller',
#   408633,
#   'Action',
#   ' Adventure',
#   ' Horror',
#   80.05,
#   'R'),
#  ('Terminator 3: Rise of the Machines',
#   '  Arnold Schwarzenegger',
#   ' Nick Stahl',
#   ' Kristanna Loken',
#   ' Claire Danes',
#   407694,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   150.37,
#   'PG'),
#  ('Black Hawk Down',
#   '  Josh Hartnett',
#   ' Ewan McGregor',
#   ' Tom Sizemore',
#   ' Eric Bana',
#   407147,
#   'Action',
#   ' Drama',
#   ' History',
#   108.64,
#   'R'),
#  ('Princess Mononoke',
#   '  YÃƒÂ´ji Matsuda',
#   ' Yuriko Ishida',
#   ' YÃƒÂ»ko Tanaka',
#   ' Billy Crudup',
#   406641,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   2.38,
#   'PG-13'),
#  ('Fast & Furious 6',
#   '  Vin Diesel',
#   ' Paul Walker',
#   ' Dwayne Johnson',
#   ' Michelle Rodriguez',
#   403825,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   238.68,
#   'PG-13'),
#  ('Shang-Chi and the Legend of the Ten Rings',
#   '  Simu Liu',
#   ' Awkwafina',
#   ' Tony Leung Chiu-wai',
#   ' Ben Kingsley',
#   402309,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   224.54,
#   'PG-13'),
#  ('Furious 7',
#   '  Vin Diesel',
#   ' Paul Walker',
#   ' Dwayne Johnson',
#   ' Jason Statham',
#   400294,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   353.01,
#   'R'),
#  ('The Fast and the Furious',
#   '  Vin Diesel',
#   ' Paul Walker',
#   ' Michelle Rodriguez',
#   ' Jordana Brewster',
#   399093,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   144.53,
#   'PG-13'),
#  ('The Mask',
#   '  Jim Carrey',
#   ' Cameron Diaz',
#   ' Peter Riegert',
#   ' Peter Greene',
#   399028,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   119.94,
#   'PG-13'),
#  ('Wanted',
#   '  Angelina Jolie',
#   ' James McAvoy',
#   ' Morgan Freeman',
#   ' Terence Stamp',
#   397867,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   134.51,
#   'R'),
#  ('Black Widow',
#   '  Scarlett Johansson',
#   ' Florence Pugh',
#   ' David Harbour',
#   ' Rachel Weisz',
#   396868,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   183.65,
#   'R'),
#  ('Jumanji: Welcome to the Jungle',
#   '  Dwayne Johnson',
#   ' Karen Gillan',
#   ' Kevin Hart',
#   ' Jack Black',
#   396778,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   404.52,
#   'PG'),
#  ('Die Hard with a Vengeance',
#   '  Bruce Willis',
#   ' Jeremy Irons',
#   ' Samuel L. Jackson',
#   ' Graham Greene',
#   395889,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   100.01,
#   'R'),
#  ('Fast Five',
#   '  Vin Diesel',
#   ' Paul Walker',
#   ' Dwayne Johnson',
#   ' Jordana Brewster',
#   391952,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   209.84,
#   'PG-13'),
#  ('Free Guy',
#   '  Ryan Reynolds',
#   ' Jodie Comer',
#   ' Taika Waititi',
#   ' Lil Rel Howery',
#   390704,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   121.63,
#   'PG-13'),
#  ('John Wick: Chapter 3 - Parabellum',
#   '  Keanu Reeves',
#   ' Halle Berry',
#   ' Ian McShane',
#   ' Laurence Fishburne',
#   390068,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   171.02,
#   'R'),
#  ('22 Jump Street',
#   '  Channing Tatum',
#   ' Jonah Hill',
#   ' Ice Cube',
#   ' Nick Offerman',
#   389087,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   191.72,
#   'PG'),
#  ('Face/Off',
#   '  John Travolta',
#   ' Nicolas Cage',
#   ' Joan Allen',
#   ' Alessandro Nivola',
#   387457,
#   'Action',
#   ' Crime',
#   ' Sci-Fi',
#   112.23,
#   'R'),
#  ('Batman',
#   '  Michael Keaton',
#   ' Jack Nicholson',
#   ' Kim Basinger',
#   ' Robert Wuhl',
#   387228,
#   'Action',
#   ' Adventure',
#   'None',
#   251.19,
#   'R'),
#  ('Men in Black II',
#   '  Tommy Lee Jones',
#   ' Will Smith',
#   ' Rip Torn',
#   ' Lara Flynn Boyle',
#   386730,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   190.42,
#   'PG-13'),
#  ('2012 (I)',
#   '  John Cusack',
#   ' Thandiwe Newton',
#   ' Chiwetel Ejiofor',
#   ' Amanda Peet',
#   386112,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   166.11,
#   'PG-13'),
#  ('Avatar: The Way of Water',
#   '  Sam Worthington',
#   ' Zoe Saldana',
#   ' Sigourney Weaver',
#   ' Stephen Lang',
#   384846,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   659.68,
#   'PG-13'),
#  ('The Equalizer',
#   '  Denzel Washington',
#   ' Marton Csokas',
#   ' ChloÃƒÂ« Grace Moretz',
#   ' David Harbour',
#   384522,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   101.53,
#   'R'),
#  ('Mission: Impossible - Rogue Nation',
#   '  Tom Cruise',
#   ' Rebecca Ferguson',
#   ' Jeremy Renner',
#   ' Simon Pegg',
#   383866,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   195.04,
#   'PG'),
#  ('The Italian Job',
#   '  Donald Sutherland',
#   ' Mark Wahlberg',
#   ' Edward Norton',
#   ' Charlize Theron',
#   377067,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   106.13,
#   'R'),
#  ('The Fighter (I)',
#   '  Mark Wahlberg',
#   ' Christian Bale',
#   ' Amy Adams',
#   ' Melissa Leo',
#   376930,
#   'Action',
#   ' Biography',
#   ' Drama',
#   93.62,
#   'Not Rated'),
#  ('Speed',
#   '  Keanu Reeves',
#   ' Dennis Hopper',
#   ' Sandra Bullock',
#   ' Joe Morton',
#   376485,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   121.25,
#   'PG-13'),
#  ('Men in Black 3',
#   '  Will Smith',
#   ' Tommy Lee Jones',
#   ' Josh Brolin',
#   ' Jemaine Clement',
#   372943,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   179.02,
#   'PG-13'),
#  ('The Suicide Squad',
#   '  Margot Robbie',
#   ' Idris Elba',
#   ' John Cena',
#   ' Joel Kinnaman',
#   372805,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   55.82,
#   'PG'),
#  ('Man on Fire',
#   '  Denzel Washington',
#   ' Christopher Walken',
#   ' Dakota Fanning',
#   ' Radha Mitchell',
#   371975,
#   'Action',
#   ' Crime',
#   ' Drama',
#   77.91,
#   'Approved'),
#  ('Snowpiercer',
#   '  Chris Evans',
#   ' Jamie Bell',
#   ' Tilda Swinton',
#   ' Ed Harris',
#   371850,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   4.56,
#   'PG'),
#  ('Die Hard 2',
#   '  Bruce Willis',
#   ' William Atherton',
#   ' Bonnie Bedelia',
#   ' Reginald VelJohnson',
#   370548,
#   'Action',
#   ' Thriller',
#   'None',
#   117.54,
#   'R'),
#  ('The Lego Movie',
#   '  Chris Pratt',
#   ' Will Ferrell',
#   ' Elizabeth Banks',
#   ' Will Arnett',
#   369039,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   257.76,
#   'R'),
#  ('Terminator Salvation',
#   'None',
#   'None',
#   'None',
#   'None',
#   368922,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   125.32,
#   'R'),
#  ('Mission: Impossible III',
#   '  Tom Cruise',
#   ' Michelle Monaghan',
#   ' Ving Rhames',
#   ' Philip Seymour Hoffman',
#   366454,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   134.03,
#   'PG-13'),
#  ('Thor: Love and Thunder',
#   '  Chris Hemsworth',
#   ' Natalie Portman',
#   ' Christian Bale',
#   ' Tessa Thompson',
#   363516,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   343.26,
#   'PG-13'),
#  ('Shazam!',
#   '  Zachary Levi',
#   ' Mark Strong',
#   ' Asher Angel',
#   ' Jack Dylan Grazer',
#   363250,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   140.37,
#   'PG-13'),
#  ('Super 8',
#   '  Elle Fanning',
#   ' AJ Michalka',
#   ' Kyle Chandler',
#   ' Joel Courtney',
#   360829,
#   'Action',
#   ' Mystery',
#   ' Sci-Fi',
#   127,
#   'PG-13'),
#  ('Solo: A Star Wars Story',
#   '  Alden Ehrenreich',
#   ' Woody Harrelson',
#   ' Emilia Clarke',
#   ' Donald Glover',
#   360716,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   213.77,
#   'PG-13'),
#  ('The Gentlemen',
#   '  Matthew McConaughey',
#   ' Charlie Hunnam',
#   ' Michelle Dockery',
#   ' Jeremy Strong',
#   360399,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   36.47,
#   'R'),
#  ('Eternals',
#   '  Gemma Chan',
#   ' Richard Madden',
#   ' Angelina Jolie',
#   ' Salma Hayek',
#   358976,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   164.87,
#   'PG-13'),
#  ('Bullet Train',
#   '  Brad Pitt',
#   ' Joey King',
#   ' Aaron Taylor-Johnson',
#   ' Brian Tyree Henry',
#   358896,
#   'Action',
#   ' Comedy',
#   ' Thriller',
#   103.37,
#   'R'),
#  ('Constantine',
#   '  Keanu Reeves',
#   ' Rachel Weisz',
#   ' Djimon Hounsou',
#   ' Shia LaBeouf',
#   358235,
#   'Action',
#   ' Fantasy',
#   ' Horror',
#   75.98,
#   'PG'),
#  ('The Expendables',
#   '  Sylvester Stallone',
#   ' Jason Statham',
#   ' Jet Li',
#   ' Dolph Lundgren',
#   353039,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   103.07,
#   'PG-13'),
#  ('Seven Samurai',
#   '  ToshiroÂ´ Mifune',
#   ' Takashi Shimura',
#   ' Keiko Tsushima',
#   ' Yukiko Shimazaki',
#   352753,
#   'Action',
#   ' Drama',
#   'None',
#   0.27,
#   'Not Rated'),
#  ('Mission: Impossible II',
#   '  Tom Cruise',
#   ' Dougray Scott',
#   ' Thandiwe Newton',
#   ' Ving Rhames',
#   352707,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   215.41,
#   'R'),
#  ('Jack Reacher',
#   '  Tom Cruise',
#   ' Rosamund Pike',
#   ' Richard Jenkins',
#   ' Werner Herzog',
#   349877,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   80.07,
#   'PG-13'),
#  ('Pineapple Express',
#   '  Seth Rogen',
#   ' James Franco',
#   ' Gary Cole',
#   ' Danny McBride',
#   347736,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   87.34,
#   'R'),
#  ('How to Train Your Dragon 2',
#   '  Jay Baruchel',
#   ' Cate Blanchett',
#   ' Gerard Butler',
#   ' Craig Ferguson',
#   347484,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   177,
#   'Not Rated'),
#  ('The Rock',
#   '  Sean Connery',
#   ' Nicolas Cage',
#   ' Ed Harris',
#   ' John Spencer',
#   346907,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   134.07,
#   'R'),
#  ('TRON: Legacy',
#   '  Jeff Bridges',
#   ' Garrett Hedlund',
#   ' Olivia Wilde',
#   ' Bruce Boxleitner',
#   345360,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   172.06,
#   'Not Rated'),
#  ('Mission: Impossible - Fallout',
#   '  Tom Cruise',
#   ' Henry Cavill',
#   ' Ving Rhames',
#   ' Simon Pegg',
#   344841,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   220.16,
#   'PG-13'),
#  ('Kingsman: The Golden Circle',
#   '  Taron Egerton',
#   ' Colin Firth',
#   ' Mark Strong',
#   ' Channing Tatum',
#   343184,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   100.23,
#   'R'),
#  ('The Hunger Games: Mockingjay - Part 2',
#   '  Jennifer Lawrence',
#   ' Josh Hutcherson',
#   ' Liam Hemsworth',
#   ' Woody Harrelson',
#   343094,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   281.72,
#   'PG'),
#  ('National Treasure',
#   '  Nicolas Cage',
#   ' Diane Kruger',
#   ' Justin Bartha',
#   ' Sean Bean',
#   342871,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   173.01,
#   'PG-13'),
#  ('The Nice Guys',
#   '  Russell Crowe',
#   ' Ryan Gosling',
#   ' Angourie Rice',
#   ' Matt Bomer',
#   342428,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   36.26,
#   'PG-13'),
#  ('Shooter (I)',
#   '  Mark Wahlberg',
#   ' Michael PeÃƒÂ±a',
#   ' Rhona Mitra',
#   ' Danny Glover',
#   341986,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   47,
#   'PG'),
#  ('The Interview (II)',
#   '  James Franco',
#   ' Seth Rogen',
#   ' Randall Park',
#   ' Lizzy Caplan',
#   341338,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   6.11,
#   'PG-13'),
#  ('Pearl Harbor',
#   '  Ben Affleck',
#   ' Kate Beckinsale',
#   ' Josh Hartnett',
#   ' William Lee Scott',
#   340973,
#   'Action',
#   ' Drama',
#   ' History',
#   198.54,
#   'PG-13'),
#  ('Total Recall',
#   '  Arnold Schwarzenegger',
#   ' Sharon Stone',
#   ' Michael Ironside',
#   ' Rachel Ticotin',
#   340726,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   119.39,
#   'R'),
#  ('Real Steel',
#   '  Hugh Jackman',
#   ' Evangeline Lilly',
#   ' Dakota Goyo',
#   ' Anthony Mackie',
#   340332,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   85.47,
#   'R'),
#  ('Hellboy',
#   '  Ron Perlman',
#   ' Doug Jones',
#   ' Selma Blair',
#   ' John Hurt',
#   338371,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   59.62,
#   'R'),
#  ('Equilibrium',
#   '  Christian Bale',
#   ' Sean Bean',
#   ' Emily Watson',
#   ' Taye Diggs',
#   338349,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   1.2,
#   'PG'),
#  ('Fantastic Four (I)',
#   '  Ioan Gruffudd',
#   ' Michael Chiklis',
#   ' Chris Evans',
#   ' Jessica Alba',
#   335928,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   154.7,
#   'PG'),
#  ('The Mummy Returns',
#   '  Brendan Fraser',
#   ' Rachel Weisz',
#   ' John Hannah',
#   ' Arnold Vosloo',
#   334930,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   202.02,
#   'R'),
#  ('North by Northwest',
#   '  Cary Grant',
#   ' Eva Marie Saint',
#   ' James Mason',
#   ' Jessie Royce Landis',
#   334514,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   13.28,
#   'Approved'),
#  ('Jurassic Park III',
#   '  Sam Neill',
#   ' William H. Macy',
#   ' TÃƒÂ©a Leoni',
#   ' Alessandro Nivola',
#   330282,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   181.17,
#   'PG-13'),
#  ('Kong: Skull Island',
#   '  Tom Hiddleston',
#   ' Samuel L. Jackson',
#   ' Brie Larson',
#   ' John C. Reilly',
#   329891,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   168.05,
#   'PG-13'),
#  ('Jurassic World: Fallen Kingdom',
#   '  Chris Pratt',
#   ' Bryce Dallas Howard',
#   ' Rafe Spall',
#   ' Justice Smith',
#   327261,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   417.72,
#   'R'),
#  ('The Book of Eli',
#   '  Denzel Washington',
#   ' Mila Kunis',
#   ' Ray Stevenson',
#   ' Gary Oldman',
#   327032,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   94.84,
#   'R'),
#  ('From Dusk Till Dawn',
#   '  Harvey Keitel',
#   ' George Clooney',
#   ' Juliette Lewis',
#   ' Quentin Tarantino',
#   325268,
#   'Action',
#   ' Crime',
#   ' Horror',
#   25.75,
#   'PG-13'),
#  ('Pirates of the Caribbean: Dead Men Tell No Tales',
#   '  Johnny Depp',
#   ' Geoffrey Rush',
#   ' Javier Bardem',
#   ' Orlando Bloom',
#   324469,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   172.56,
#   'PG'),
#  ('Salt',
#   '  Angelina Jolie',
#   ' Liev Schreiber',
#   ' Chiwetel Ejiofor',
#   ' Daniel Olbrychski',
#   321431,
#   'Action',
#   ' Thriller',
#   'None',
#   118.31,
#   'PG-13'),
#  ('The Island',
#   '  Scarlett Johansson',
#   ' Ewan McGregor',
#   ' Djimon Hounsou',
#   ' Steve Buscemi',
#   321034,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   35.82,
#   'R'),
#  ('Transformers: Age of Extinction',
#   '  Mark Wahlberg',
#   ' Nicola Peltz Beckham',
#   ' Jack Reynor',
#   ' Stanley Tucci',
#   320859,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   245.44,
#   'PG-13'),
#  ('3:10 to Yuma',
#   '  Russell Crowe',
#   ' Christian Bale',
#   ' Ben Foster',
#   ' Logan Lerman',
#   320222,
#   'Action',
#   ' Crime',
#   ' Drama',
#   53.61,
#   'PG'),
#  ('Apocalypto',
#   '  Gerardo Taracena',
#   ' Raoul Max Trujillo',
#   ' Dalia HernÃƒÂ¡ndez',
#   ' Rudy Youngblood',
#   320106,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   50.87,
#   'PG'),
#  ('The Man from U.N.C.L.E.',
#   '  Henry Cavill',
#   ' Armie Hammer',
#   ' Alicia Vikander',
#   ' Elizabeth Debicki',
#   319747,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   45.45,
#   'PG-13'),
#  ('Deja Vu',
#   '  Denzel Washington',
#   ' Paula Patton',
#   ' Jim Caviezel',
#   ' Val Kilmer',
#   317751,
#   'Action',
#   ' Crime',
#   ' Sci-Fi',
#   64.04,
#   'Not Rated'),
#  ('RED',
#   '  Bruce Willis',
#   ' Helen Mirren',
#   ' Morgan Freeman',
#   ' Mary-Louise Parker',
#   315546,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   90.38,
#   'R'),
#  ('Taken 2',
#   '  Liam Neeson',
#   ' Famke Janssen',
#   ' Maggie Grace',
#   ' Leland Orser',
#   313724,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   139.85,
#   'R'),
#  ('Jumper',
#   '  Hayden Christensen',
#   ' Samuel L. Jackson',
#   ' Jamie Bell',
#   ' Rachel Bilson',
#   313690,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   80.17,
#   'R'),
#  ('Batman Returns',
#   '  Michael Keaton',
#   ' Danny DeVito',
#   ' Michelle Pfeiffer',
#   ' Christopher Walken',
#   313672,
#   'Action',
#   ' Crime',
#   ' Fantasy',
#   162.83,
#   'R'),
#  ('The Expendables 2',
#   '  Sylvester Stallone',
#   ' Liam Hemsworth',
#   ' Randy Couture',
#   ' Jean-Claude Van Damme',
#   313213,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   85.02,
#   'R'),
#  ('The Transporter',
#   '  Jason Statham',
#   ' Shu Qi',
#   ' Matt Schulze',
#   ' FranÃƒÂ§ois BerlÃƒÂ©and',
#   310802,
#   'Action',
#   ' Crime',
#   ' Thriller',
# ...
#   83130,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   ' ',
#   'TV-MA'),
#  ('Final Fantasy: The Spirits Within',
#   '  Alec Baldwin',
#   ' Steve Buscemi',
#   ' Ming-Na Wen',
#   ' Ving Rhames',
#   83011,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   32.13,
#   'R'),
#  ('Ambulance',
#   '  Jake Gyllenhaal',
#   ' Yahya Abdul-Mateen II',
#   ' Eiza GonzÃƒÂ¡lez',
#   ' Garret Dillahunt',
#   82892,
#   'Action',
#   ' Crime',
#   ' Drama',
#   22.78,
#   'PG-13'),
#  ('The Last Castle',
#   '  Robert Redford',
#   ' James Gandolfini',
#   ' Mark Ruffalo',
#   ' Steve Burton',
#   82864,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   18.21,
#   'PG-13'),
#  ('Conan the Destroyer',
#   '  Arnold Schwarzenegger',
#   ' Grace Jones',
#   ' Olivia dAbo',
#   ' Wilt Chamberlain',
#   82758,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   31.04,
#   'PG-13'),
#  ('The Long Kiss Goodnight',
#   '  Geena Davis',
#   ' Samuel L. Jackson',
#   ' Yvonne Zima',
#   ' Craig Bierko',
#   82402,
#   'Action',
#   ' Crime',
#   ' Drama',
#   33.33,
#   'R'),
#  ('Species',
#   '  Natasha Henstridge',
#   ' Michael Madsen',
#   ' Ben Kingsley',
#   ' Alfred Molina',
#   82349,
#   'Action',
#   ' Horror',
#   ' Sci-Fi',
#   60.07,
#   'R'),
#  ('Army of Thieves',
#   '  Matthias SchweighÃƒÂ¶fer',
#   ' Nathalie Emmanuel',
#   ' Ruby O. Fee',
#   ' Stuart Martin',
#   82169,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  ('Broken City',
#   '  Mark Wahlberg',
#   ' Russell Crowe',
#   ' Catherine Zeta-Jones',
#   ' Jeffrey Wright',
#   82106,
#   'Action',
#   ' Crime',
#   ' Drama',
#   19.7,
#   'PG'),
#  ('Fools Gold (I)',
#   '  Matthew McConaughey',
#   ' Kate Hudson',
#   ' Donald Sutherland',
#   ' Alexis Dziena',
#   82064,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   70.23,
#   'R'),
#  ('Super (I)',
#   '  Rainn Wilson',
#   ' Elliot Page',
#   ' Liv Tyler',
#   ' Kevin Bacon',
#   82030,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0.32,
#   'R'),
#  ('All Is Lost',
#   ' Star: Robert Redford',
#   'None',
#   'None',
#   'None',
#   82016,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   6.26,
#   'Not Rated'),
#  ('Walking Tall',
#   '  Dwayne Johnson',
#   ' Ashley Scott',
#   ' Johnny Knoxville',
#   ' Michael Bowen',
#   81857,
#   'Action',
#   ' Crime',
#   'None',
#   46.44,
#   'R'),
#  ('Star Trek: Nemesis',
#   '  Patrick Stewart',
#   ' Jonathan Frakes',
#   ' Brent Spiner',
#   ' LeVar Burton',
#   81655,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   43.25,
#   'R'),
#  ('George of the Jungle',
#   '  Brendan Fraser',
#   ' Leslie Mann',
#   ' Thomas Haden Church',
#   ' Richard Roundtree',
#   81643,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   105.26,
#   'R'),
#  ('48 Hrs.',
#   '  Nick Nolte',
#   ' Eddie Murphy',
#   ' Annette OToole',
#   ' Frank McRae',
#   81436,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   78.87,
#   'R'),
#  ('Bloodshot',
#   '  Vin Diesel',
#   ' Eiza GonzÃƒÂ¡lez',
#   ' Sam Heughan',
#   ' Toby Kebbell',
#   81104,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   12.56,
#   'PG-13'),
#  ('Deliver Us from Evil (I)',
#   '  Eric Bana',
#   ' Edgar RamÃƒÂ\xadrez',
#   ' Olivia Munn',
#   ' Chris Coy',
#   80854,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   30.58,
#   'PG'),
#  ('Machete Kills',
#   '  Danny Trejo',
#   ' Alexa PenaVega',
#   ' Mel Gibson',
#   ' Jessica Alba',
#   80664,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   8.01,
#   'R'),
#  ('Six Days Seven Nights',
#   '  Harrison Ford',
#   ' Anne Heche',
#   ' David Schwimmer',
#   ' Jacqueline Obradors',
#   80495,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   74.33,
#   'R'),
#  ('Pushpa: The Rise - Part 1',
#   '  Allu Arjun',
#   ' Fahadh Faasil',
#   ' Rashmika Mandanna',
#   ' Jagadeesh Prathap Bandari',
#   80417,
#   'Action',
#   ' Crime',
#   ' Drama',
#   '  ',
#   'PG-13'),
#  ('Assault on Precinct 13',
#   '  Ethan Hawke',
#   ' Laurence Fishburne',
#   ' Gabriel Byrne',
#   ' Maria Bello',
#   80404,
#   'Action',
#   ' Crime',
#   ' Drama',
#   19.98,
#   'R'),
#  ('Road House',
#   '  Patrick Swayze',
#   ' Kelly Lynch',
#   ' Sam Elliott',
#   ' Ben Gazzara',
#   80229,
#   'Action',
#   ' Thriller',
#   'None',
#   30.05,
#   'PG-13'),
#  ('A Wednesday',
#   '  Anupam Kher',
#   ' Naseeruddin Shah',
#   ' Veerendra Saxena',
#   ' Mahesh Kanual',
#   80205,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'UA'),
#  ('The Spy Who Dumped Me',
#   '  Justin Theroux',
#   ' Kate McKinnon',
#   ' Blanka GyÃƒÂ¶rfi-TÃƒÂ³th',
#   ' Mila Kunis',
#   80081,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   33.56,
#   'R'),
#  ('Volcano',
#   '  Tommy Lee Jones',
#   ' Anne Heche',
#   ' Gaby Hoffmann',
#   ' Don Cheadle',
#   79011,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   49.32,
#   'Not Rated'),
#  ('Seventh Son (I)',
#   '  Ben Barnes',
#   ' Julianne Moore',
#   ' Jeff Bridges',
#   ' Alicia Vikander',
#   78987,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   17.22,
#   'R'),
#  ('Master (I)',
#   '  Joseph Vijay',
#   ' Vijay Sethupathi',
#   ' Malavika Mohanan',
#   ' Arjun Das',
#   78986,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'R'),
#  ('Shaft',
#   '  Samuel L. Jackson',
#   ' Vanessa Williams',
#   ' Christian Bale',
#   ' Jeffrey Wright',
#   78758,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   70.33,
#   'R'),
#  ('Doomsday',
#   '  Rhona Mitra',
#   ' Bob Hoskins',
#   ' Alexander Siddig',
#   ' Caryn Peterson',
#   78545,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   10.96,
#   'PG-13'),
#  ('Underworld: Blood Wars',
#   '  Kate Beckinsale',
#   ' Theo James',
#   ' Tobias Menzies',
#   ' Lara Pulver',
#   78352,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   30.35,
#   'PG'),
#  ('Star Trek VI: The Undiscovered Country',
#   '  William Shatner',
#   ' Leonard Nimoy',
#   ' DeForest Kelley',
#   ' James Doohan',
#   78300,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   74.89,
#   'R'),
#  ('Oldboy',
#   '  Josh Brolin',
#   ' Elizabeth Olsen',
#   ' Samuel L. Jackson',
#   ' Sharlto Copley',
#   78216,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   2.19,
#   'R'),
#  ('Into the Blue',
#   '  Paul Walker',
#   ' Jessica Alba',
#   ' Scott Caan',
#   ' Ashley Scott',
#   77995,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   18.47,
#   'PG-13'),
#  ('Sooryavanshi',
#   '  Akshay Kumar',
#   ' Katrina Kaif',
#   ' Ajay Devgn',
#   ' Ranveer Singh',
#   77917,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'R'),
#  ('Johnny English Strikes Again',
#   '  Rowan Atkinson',
#   ' Ben Miller',
#   ' Olga Kurylenko',
#   ' Emma Thompson',
#   77685,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   4.41,
#   'PG-13'),
#  ('Escape from L.A.',
#   '  Kurt Russell',
#   ' Steve Buscemi',
#   ' Stacy Keach',
#   ' A.J. Langer',
#   77578,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   25.48,
#   'PG-13'),
#  ('Fearless',
#   '  Jet Li',
#   ' Li Sun',
#   ' Yong Dong',
#   ' Yun Qu',
#   77409,
#   'Action',
#   ' Biography',
#   ' Drama',
#   24.63,
#   'TV-MA'),
#  ('Star Trek: Insurrection',
#   '  Patrick Stewart',
#   ' Jonathan Frakes',
#   ' Brent Spiner',
#   ' LeVar Burton',
#   77360,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   70.12,
#   'PG-13'),
#  ('Outlander',
#   '  Jim Caviezel',
#   ' Sophia Myles',
#   ' Ron Perlman',
#   ' Jack Huston',
#   76996,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   0.16,
#   'PG'),
#  ('Shazam! Fury of the Gods',
#   '  Zachary Levi',
#   ' Asher Angel',
#   ' Jack Dylan Grazer',
#   ' Rachel Zegler',
#   76524,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG-13'),
#  ('Collateral Damage',
#   '  Arnold Schwarzenegger',
#   ' John Leguizamo',
#   ' Francesca Neri',
#   ' Elias Koteas',
#   76480,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   40.08,
#   'PG-13'),
#  ('Cobra',
#   '  Sylvester Stallone',
#   ' Brigitte Nielsen',
#   ' Reni Santoni',
#   ' Andrew Robinson',
#   76432,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   49.04,
#   'R'),
#  ('Ong-Bak: The Thai Warrior',
#   '  Tony Jaa',
#   ' Phetthai Vongkumlao',
#   ' Pumwaree Yodkamol',
#   ' Suchao Pongwilai',
#   76388,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   4.56,
#   'R'),
#  ('The Edge',
#   '  Anthony Hopkins',
#   ' Alec Baldwin',
#   ' Elle Macpherson',
#   ' Harold Perrineau',
#   76170,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   27.78,
#   'TV-MA'),
#  ('Outlaw King',
#   '  Chris Pine',
#   ' Stephen Dillane',
#   ' Rebecca Robin',
#   ' Billy Howle',
#   76112,
#   'Action',
#   ' Biography',
#   ' Drama',
#   ' ',
#   'R'),
#  ('Speed Racer',
#   '  Emile Hirsch',
#   ' Matthew Fox',
#   ' Christina Ricci',
#   ' Nicholas Elia',
#   76101,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   43.95,
#   'R'),
#  ('The Dirty Dozen',
#   '  Lee Marvin',
#   ' Ernest Borgnine',
#   ' Charles Bronson',
#   ' John Cassavetes',
#   76085,
#   'Action',
#   ' Adventure',
#   ' War',
#   45.3,
#   'R'),
#  ('Mercury Rising',
#   '  Bruce Willis',
#   ' Miko Hughes',
#   ' Alec Baldwin',
#   ' Chi McBride',
#   76072,
#   'Action',
#   ' Crime',
#   ' Drama',
#   32.94,
#   'R'),
#  ('The Postman',
#   '  Kevin Costner',
#   ' Will Patton',
#   ' Larenz Tate',
#   ' Olivia Williams',
#   75947,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   17.63,
#   'R'),
#  ('First Knight',
#   '  Sean Connery',
#   ' Richard Gere',
#   ' Julia Ormond',
#   ' Ben Cross',
#   75829,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   37.6,
#   'R'),
#  ('Open Range',
#   '  Kevin Costner',
#   ' Robert Duvall',
#   ' Diego Luna',
#   ' Abraham Benrubi',
#   75456,
#   'Action',
#   ' Drama',
#   ' Romance',
#   58.33,
#   'TV-MA'),
#  ('The Siege',
#   '  Denzel Washington',
#   ' Bruce Willis',
#   ' Annette Bening',
#   ' Tony Shalhoub',
#   75341,
#   'Action',
#   ' Thriller',
#   'None',
#   40.98,
#   'PG-13'),
#  ('Badlands',
#   '  Martin Sheen',
#   ' Sissy Spacek',
#   ' Warren Oates',
#   ' Ramon Bieri',
#   75304,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG'),
#  ('Sonic the Hedgehog 2',
#   '  James Marsden',
#   ' Jim Carrey',
#   ' Ben Schwartz',
#   ' Tika Sumpter',
#   74939,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   190.87,
#   'PG-13'),
#  ('Solomon Kane',
#   '  James Purefoy',
#   ' Max von Sydow',
#   ' Rachel Hurd-Wood',
#   ' Pete Postlethwaite',
#   74862,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   ' ',
#   'R'),
#  ('Mortdecai',
#   '  Johnny Depp',
#   ' Gwyneth Paltrow',
#   ' Ewan McGregor',
#   ' Olivia Munn',
#   74853,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   7.61,
#   'R'),
#  ('A Most Violent Year',
#   '  Oscar Isaac',
#   ' Jessica Chastain',
#   ' David Oyelowo',
#   ' Alessandro Nivola',
#   74833,
#   'Action',
#   ' Crime',
#   ' Drama',
#   5.74,
#   'PG-13'),
#  ('Daylight',
#   '  Sylvester Stallone',
#   ' Amy Brenneman',
#   ' Viggo Mortensen',
#   ' Dan Hedaya',
#   74734,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   33.02,
#   'PG-13'),
#  ('Triple 9',
#   '  Casey Affleck',
#   ' Chiwetel Ejiofor',
#   ' Anthony Mackie',
#   ' Aaron Paul',
#   74436,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   12.63,
#   'PG'),
#  ('Redemption (I)',
#   '  Jason Statham',
#   ' Agata Buzek',
#   ' Vicky McClure',
#   ' Benedict Wong',
#   74415,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.03,
#   'PG-13'),
#  ('Death Wish',
#   '  Bruce Willis',
#   ' Vincent DOnofrio',
#   ' Elisabeth Shue',
#   ' Camila Morrone',
#   74080,
#   'Action',
#   ' Crime',
#   ' Drama',
#   34.02,
#   'R'),
#  ('Nikita',
#   '  Anne Parillaud',
#   ' Marc Duret',
#   ' Patrick Fontana',
#   ' Alain LathiÃƒÂ¨re',
#   74049,
#   'Action',
#   ' Crime',
#   ' Drama',
#   5.02,
#   'R'),
#  ('Johnny Mnemonic',
#   '  Keanu Reeves',
#   ' Dolph Lundgren',
#   ' Dina Meyer',
#   ' Ice-T',
#   73940,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   19.08,
#   'TV-MA'),
#  ('Ninja Assassin',
#   '  Rain',
#   ' Rick Yune',
#   ' Naomie Harris',
#   ' Joon Lee',
#   73842,
#   'Action',
#   ' Thriller',
#   'None',
#   38.11,
#   'R'),
#  ('Red Heat',
#   '  Arnold Schwarzenegger',
#   ' Jim Belushi',
#   ' Peter Boyle',
#   ' Ed ORoss',
#   73327,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   34.99,
#   'R'),
#  ('Death Sentence',
#   '  Kevin Bacon',
#   ' John Goodman',
#   ' Kelly Preston',
#   ' Garrett Hedlund',
#   73245,
#   'Action',
#   ' Crime',
#   ' Drama',
#   9.53,
#   'R'),
#  ('Only the Brave',
#   '  Josh Brolin',
#   ' Miles Teller',
#   ' Jeff Bridges',
#   ' Jennifer Connelly',
#   73063,
#   'Action',
#   ' Biography',
#   ' Drama',
#   18.34,
#   'R'),
#  ('Boss Level',
#   '  Frank Grillo',
#   ' Mel Gibson',
#   ' Naomi Watts',
#   ' Michelle Yeoh',
#   72803,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG-13'),
#  ('Cold Pursuit',
#   '  Liam Neeson',
#   ' Laura Dern',
#   ' MicheÃƒÂ¡l Neeson',
#   ' Michael Eklund',
#   72467,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   32.14,
#   'R'),
#  ('Joy Ride',
#   '  Steve Zahn',
#   ' Paul Walker',
#   ' Leelee Sobieski',
#   ' Jessica Bowman',
#   72430,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   21.97,
#   'R'),
#  ('Unhinged (I)',
#   '  Russell Crowe',
#   ' Caren Pistorius',
#   ' Gabriel Bateman',
#   ' Jimmi Simpson',
#   72266,
#   'Action',
#   ' Thriller',
#   'None',
#   20.83,
#   'PG-13'),
#  ('Bullitt',
#   '  Steve McQueen',
#   ' Jacqueline Bisset',
#   ' Robert Vaughn',
#   ' Don Gordon',
#   72158,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   42.3,
#   'TV-MA'),
#  ('District B13',
#   '  Cyril Raffaelli',
#   ' David Belle',
#   ' Tony DAmario',
#   ' Bibi Naceri',
#   72053,
#   'Action',
#   ' Crime',
#   ' Sci-Fi',
#   1.2,
#   'R'),
#  ('Romeo Must Die',
#   '  Jet Li',
#   ' Aaliyah',
#   ' Isaiah Washington',
#   ' Russell Wong',
#   72039,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   55.97,
#   'R'),
#  ('The Eagle',
#   '  Channing Tatum',
#   ' Jamie Bell',
#   ' Donald Sutherland',
#   ' IstvÃƒÂ¡n GÃƒÂ¶z',
#   72009,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   19.49,
#   'PG-13'),
#  ('The Man from Nowhere',
#   '  Won Bin',
#   ' Kim Sae-ron',
#   ' Kim Tae-hoon',
#   ' Kim Hee-won',
#   71950,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.01,
#   'PG'),
#  ('Violent Night',
#   '  David Harbour',
#   ' John Leguizamo',
#   ' Beverly DAngelo',
#   ' Alex Hassell',
#   71285,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  ('Windtalkers',
#   '  Nicolas Cage',
#   ' Adam Beach',
#   ' Peter Stormare',
#   ' Noah Emmerich',
#   71266,
#   'Action',
#   ' Drama',
#   ' War',
#   40.91,
#   'R'),
#  ('Kick',
#   '  Salman Khan',
#   ' Jacqueline Fernandez',
#   ' Nawazuddin Siddiqui',
#   ' Randeep Hooda',
#   71266,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   2.46,
#   'PG-13'),
#  ('The Lego Movie 2: The Second Part',
#   '  Chris Pratt',
#   ' Elizabeth Banks',
#   ' Will Arnett',
#   ' Tiffany Haddish',
#   71069,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   105.81,
#   'PG-13'),
#  ('God Bless America',
#   '  Joel Murray',
#   ' Tara Lynne Barr',
#   ' Mackenzie Brooke Smith',
#   ' Melinda Page Hamilton',
#   71031,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0.12,
#   'TV-PG'),
#  ('The Net (I)',
#   '  Sandra Bullock',
#   ' Jeremy Northam',
#   ' Dennis Miller',
#   ' Diane Baker',
#   70800,
#   'Action',
#   ' Crime',
#   ' Drama',
#   50.73,
#   'R'),
#  ('Brawl in Cell Block 99',
#   '  Vince Vaughn',
#   ' Jennifer Carpenter',
#   ' Don Johnson',
#   ' Udo Kier',
#   70791,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  ('The Saint',
#   '  Val Kilmer',
#   ' Elisabeth Shue',
#   ' Rade Serbedzija',
#   ' Valeriy Nikolaev',
#   70506,
#   'Action',
#   ' Adventure',
#   ' Romance',
#   61.36,
#   'PG'),
#  ('21 Bridges',
#   '  Chadwick Boseman',
#   ' Sienna Miller',
#   ' J.K. Simmons',
#   ' Stephan James',
#   70352,
#   'Action',
#   ' Crime',
#   ' Drama',
#   28.54,
#   'PG-13'),
#  ('Act of Valor',
#   '  Alex Veadov',
#   ' Roselyn Sanchez',
#   ' Nestor Serrano',
#   ' Rorke Denver',
#   70351,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   70.01,
#   'R'),
#  ('Never Say Never Again',
#   '  Sean Connery',
#   ' Kim Basinger',
#   ' Klaus Maria Brandauer',
#   ' Max von Sydow',
#   70223,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   55.5,
#   'R'),
#  ('Into the Storm',
#   '  Richard Armitage',
#   ' Sarah Wayne Callies',
#   ' Matt Walsh',
#   ' Max Deacon',
#   70051,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   47.6,
#   'PG'),
#  ('Hera Pheri',
#   '  Akshay Kumar',
#   ' Suniel Shetty',
#   ' Paresh Rawal',
#   ' Tabu',
#   69404,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0,
#   'Not Rated'),
#  ('DC League of Super-Pets',
#   '  Dwayne Johnson',
#   ' Kevin Hart',
#   ' Kate McKinnon',
#   ' John Krasinski',
#   69316,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   93.66,
#   'R'),
#  ('El Mariachi',
#   '  Carlos Gallardo',
#   ' Consuelo GÃƒÂ³mez',
#   ' Jaime de Hoyos',
#   ' Peter Marquardt',
#   69267,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   2.04,
#   'R'),
#  ('The November Man',
#   '  Pierce Brosnan',
#   ' Luke Bracey',
#   ' Olga Kurylenko',
#   ' Bill Smitrovich',
#   69200,
#   'Action',
#   ' Thriller',
#   'None',
#   24.98,
#   'R'),
#  ('The Chaser',
#   '  Kim Yoon-seok',
#   ' Ha Jung-woo',
#   ' Yeong-hie Seo',
#   ' Kim Yoo-jeong',
#   69183,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('Cell 211',
#   '  Luis Tosar',
#   ' Alberto Ammann',
#   ' Antonio Resines',
#   ' Manuel MorÃƒÂ³n',
#   69164,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  ('Star Wars: The Clone Wars',
#   '  Matt Lanter',
#   ' Nika Futterman',
#   ' Tom Kane',
#   ' Ashley Eckstein',
#   69153,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   35.16,
#   'PG-13'),
#  ...]

# %% [markdown]
# 3) Display movie names with gross collections in descending order

# %%
gross_movies=cur1.execute("select Movie_Name,Gross_collection from Imdbmovie2   where Gross_collection is not ' 'and not '  ' order by Gross_collection desc")
gross_movies.fetchall()
# Out:
# [('ï»¿Movie_Name', 'Gross_collection'),
#  ('Pushpa: The Rise - Part 1', '  '),
#  ('Star Wars: Episode VII - The Force Awakens', 936.66),
#  ('Avengers: Endgame', 858.37),
#  ('Spider-Man: No Way Home', 804.75),
#  ('Avatar', 760.51),
#  ('Top Gun: Maverick', 718.73),
#  ('Black Panther', 700.06),
#  ('Avengers: Infinity War', 678.82),
#  ('Avatar: The Way of Water', 659.68),
#  ('Jurassic World', 652.27),
#  ('The Avengers', 623.28),
#  ('Star Wars: Episode VIII - The Last Jedi', 620.18),
#  ('Incredibles 2', 608.58),
#  ('The Dark Knight', 534.86),
#  ('Rogue One: A Star Wars Story', 532.18),
#  ('Star Wars: Episode IX - The Rise of Skywalker', 515.2),
#  ('Star Wars: Episode I - The Phantom Menace', 474.54),
#  ('Avengers: Age of Ultron', 459.01),
#  ('Black Panther: Wakanda Forever', 453.72),
#  ('The Dark Knight Rises', 448.14),
#  ('Captain Marvel', 426.83),
#  ('The Hunger Games: Catching Fire', 424.67),
#  ('Pirates of the Caribbean: Dead Mans Chest', 423.32),
#  ('Jurassic World: Fallen Kingdom', 417.72),
#  ('Wonder Woman', 412.56),
#  ('Doctor Strange in the Multiverse of Madness', 411.33),
#  ('Iron Man 3', 409.01),
#  ('Captain America: Civil War', 408.08),
#  ('The Hunger Games', 408.01),
#  ('Jumanji: Welcome to the Jungle', 404.52),
#  ('Spider-Man', 403.71),
#  ('Jurassic Park', 402.45),
#  ('Transformers: Revenge of the Fallen', 402.11),
#  ('Spider-Man: Far from Home', 390.53),
#  ('Guardians of the Galaxy Vol. 2', 389.81),
#  ('Star Wars: Episode III - Revenge of the Sith', 380.26),
#  ('The Lord of the Rings: The Return of the King', 377.85),
#  ('Jurassic World: Dominion', 376.85),
#  ('Spider-Man 2', 373.59),
#  ('The Batman', 369.35),
#  ('Deadpool', 363.07),
#  ('Furious 7', 353.01),
#  ('Transformers: Dark of the Moon', 352.39),
#  ('American Sniper', 350.13),
#  ('Thor: Love and Thunder', 343.26),
#  ('The Lord of the Rings: The Two Towers', 342.55),
#  ('The Hunger Games: Mockingjay - Part 1', 337.14),
#  ('Spider-Man 3', 336.53),
#  ('Aquaman', 335.06),
#  ('Spider-Man: Homecoming', 334.2),
#  ('Guardians of the Galaxy', 333.18),
#  ('Batman v Superman: Dawn of Justice', 330.36),
#  ('Suicide Squad', 325.1),
#  ('Deadpool 2', 324.59),
#  ('Star Wars: Episode IV - A New Hope', 322.74),
#  ('Transformers', 319.25),
#  ('Iron Man', 318.41),
#  ('Indiana Jones and the Kingdom of the Crystal Skull', 317.1),
#  ('Jumanji: The Next Level', 316.83),
#  ('The Lord of the Rings: The Fellowship of the Ring', 315.54),
#  ('Thor: Ragnarok', 315.06),
#  ('Iron Man 2', 312.43),
#  ('Star Wars: Episode II - Attack of the Clones', 310.68),
#  ('Pirates of the Caribbean: At Worlds End', 309.42),
#  ('Star Wars: Episode VI - Return of the Jedi', 309.13),
#  ('Independence Day', 306.17),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl', 305.41),
#  ('Skyfall', 304.36),
#  ('Harry Potter and the Half-Blood Prince', 301.96),
#  ('Inception', 292.58),
#  ('Harry Potter and the Order of the Phoenix', 292),
#  ('Man of Steel', 291.05),
#  ('Star Wars: Episode V - The Empire Strikes Back', 290.48),
#  ('The Hunger Games: Mockingjay - Part 2', 281.72),
#  ('The Matrix Reloaded', 281.49),
#  ('The Amazing Spider-Man', 262.03),
#  ('The Incredibles', 261.44),
#  ('Captain America: The Winter Soldier', 259.77),
#  ('The Lego Movie', 257.76),
#  ('Star Trek', 257.73),
#  ('I Am Legend', 256.39),
#  ('Batman', 251.19),
#  ('Men in Black', 250.69),
#  ('Indiana Jones and the Raiders of the Lost Ark', 248.16),
#  ('Transformers: Age of Extinction', 245.44),
#  ('Twister (I)', 241.72),
#  ('Pirates of the Caribbean: On Stranger Tides', 241.06),
#  ('Fast & Furious 6', 238.68),
#  ('Ghostbusters', 238.63),
#  ('Beverly Hills Cop', 234.76),
#  ('X-Men: The Last Stand', 234.36),
#  ('War of the Worlds', 234.28),
#  ('X-Men: Days of Future Past', 233.92),
#  ('Doctor Strange', 232.64),
#  ('The Lost World: Jurassic Park', 229.09),
#  ('Justice League', 229.02),
#  ('Star Trek Into Darkness', 228.78),
#  ('Hancock', 227.95),
#  ('The Bourne Ultimatum', 227.47),
#  ('Logan', 226.28),
#  ('Rush Hour 2', 226.16),
#  ('The Fate of the Furious', 226.01),
#  ('Shang-Chi and the Legend of the Ten Rings', 224.54),
#  ('Big Hero 6', 222.53),
#  ('Mission: Impossible - Fallout', 220.16),
#  ('National Treasure: Book of Secrets', 219.96),
#  ('King Kong', 218.08),
#  ('How to Train Your Dragon', 217.58),
#  ('Ant-Man and the Wasp', 216.65),
#  ('Kung Fu Panda', 215.43),
#  ('Mission: Impossible II', 215.41),
#  ('X2: X-Men United', 214.95),
#  ('Solo: A Star Wars Story', 213.77),
#  ('Venom: Let There Be Carnage', 213.55),
#  ('Venom', 213.52),
#  ('Austin Powers in Goldmember', 213.31),
#  ('300', 210.61),
#  ('Fast Five', 209.84),
#  ('Mission: Impossible - Ghost Protocol', 209.4),
#  ('Sherlock Holmes', 209.03),
#  ('Dawn of the Planet of the Apes', 208.55),
#  ('Batman Begins', 206.85),
#  ('Thor: The Dark World', 206.36),
#  ('Bad Boys for Life', 206.31),
#  ('Austin Powers: The Spy Who Shagged Me', 206.04),
#  ('Terminator 2: Judgment Day', 204.84),
#  ('The Amazing Spider-Man 2', 202.85),
#  ('World War Z', 202.36),
#  ('The Mummy Returns', 202.02),
#  ('Armageddon', 201.57),
#  ('Godzilla', 200.68),
#  ('Superman Returns', 200.08),
#  ('Spectre (I)', 200.07),
#  ('Pearl Harbor', 198.54),
#  ('Monsters vs. Aliens', 198.35),
#  ('Indiana Jones and the Last Crusade', 197.17),
#  ('Mission: Impossible - Rogue Nation', 195.04),
#  ('22 Jump Street', 191.72),
#  ('Teenage Mutant Ninja Turtles', 191.2),
#  ('Sonic the Hedgehog 2', 190.87),
#  ('Men in Black II', 190.42),
#  ('Spider-Man: Into the Spider-Verse', 190.24),
#  ('Dunkirk', 188.37),
#  ('Gladiator', 187.71),
#  ('The Croods', 187.17),
#  ('Sherlock Holmes: A Game of Shadows', 186.85),
#  ('The Day After Tomorrow', 186.74),
#  ('Mr. & Mrs. Smith', 186.34),
#  ('The Fugitive', 183.88),
#  ('Black Widow', 183.65),
#  ('The Revenant (I)', 183.64),
#  ('The Perfect Storm', 182.62),
#  ('Jurassic Park III', 181.17),
#  ('Thor', 181.03),
#  ('Mission: Impossible', 180.98),
#  ('Ant-Man', 180.2),
#  ('Planet of the Apes', 180.01),
#  ('X-Men Origins: Wolverine', 179.88),
#  ('Indiana Jones and the Temple of Doom', 179.87),
#  ('Top Gun', 179.8),
#  ('Men in Black 3', 179.02),
#  ('How to Train Your Dragon 2', 177),
#  ('Rise of the Planet of the Apes', 176.76),
#  ('Captain America: The First Avenger', 176.65),
#  ('The Karate Kid', 176.59),
#  ('The Bourne Supremacy', 176.24),
#  ('The Lego Batman Movie', 175.75),
#  ('Crocodile Dundee', 174.64),
#  ('Fast & Furious Presents: Hobbs & Shaw', 173.96),
#  ('National Treasure', 173.01),
#  ('Air Force One', 172.96),
#  ('Pirates of the Caribbean: Dead Men Tell No Tales', 172.56),
#  ('TRON: Legacy', 172.06),
#  ('The Matrix', 171.48),
#  ('John Wick: Chapter 3 - Parabellum', 171.02),
#  ('Quantum of Solace', 168.37),
#  ('Wild Hogs', 168.27),
#  ('Black Adam', 168.15),
#  ('Kong: Skull Island', 168.05),
#  ('Casino Royale', 167.45),
#  ('2012 (I)', 166.11),
#  ('Robin Hood: Prince of Thieves', 165.5),
#  ('Kung Fu Panda 2', 165.25),
#  ('Eternals', 164.87),
#  ('Clash of the Titans', 163.21),
#  ('Batman Returns', 162.83),
#  ('Jason Bourne (I)', 162.43),
#  ('Die Another Day', 160.94),
#  ('No Time to Die', 160.87),
#  ('How to Train Your Dragon: The Hidden World', 160.8),
#  ('The Heat (I)', 159.58),
#  ('1917', 159.23),
#  ('Star Trek Beyond', 158.85),
#  ('X-Men', 157.3),
#  ('X-Men: Apocalypse', 155.44),
#  ('Snow White and the Huntsman', 155.33),
#  ('The Mummy', 155.25),
#  ('San Andreas', 155.19),
#  ('Fast & Furious', 155.06),
#  ('Fantastic Four (I)', 154.7),
#  ('Mad Max: Fury Road', 154.06),
#  ('Beverly Hills Cop II', 153.67),
#  ('G.I. Joe: The Rise of Cobra', 152.27),
#  ('Divergent', 150.95),
#  ('Rambo: First Blood Part II', 150.42),
#  ('Terminator 3: Rise of the Machines', 150.37),
#  ('Sonic the Hedgehog', 148.97),
#  ('Uncharted', 148.65),
#  ('Megamind', 148.42),
#  ('Lethal Weapon 2', 147.25),
#  ('War for the Planet of the Apes', 146.88),
#  ('X-Men: First Class', 146.41),
#  ('True Lies', 146.28),
#  ('Taken (I)', 145),
#  ('I Robot', 144.8),
#  ('Lethal Weapon 3', 144.73),
#  ('The Fast and the Furious', 144.53),
#  ('Pokemon: Detective Pikachu', 144.11),
#  ('Kung Fu Panda 3', 143.53),
#  ('The Meg', 143.01),
#  ('xXx', 142.11),
#  ('The Chronicles of Narnia: Prince Caspian', 141.62),
#  ('Rush Hour', 141.15),
#  ('Deep Impact', 140.46),
#  ('Shazam!', 140.37),
#  ('Oceans Eight', 140.22),
#  ('Rush Hour 3', 140.13),
#  ('Taken 2', 139.85),
#  ('The Matrix Revolutions', 139.31),
#  ('Bad Boys II', 138.61),
#  ('21 Jump Street', 138.45),
#  ('Ready Player One', 137.69),
#  ('Ransom', 136.49),
#  ('Teenage Mutant Ninja Turtles', 135.27),
#  ('Ride Along', 134.94),
#  ('Live Free or Die Hard', 134.53),
#  ('The Incredible Hulk', 134.52),
#  ('Wanted', 134.51),
#  ('Superman', 134.22),
#  ('The Rock', 134.07),
#  ('Mission: Impossible III', 134.03),
#  ('Angels & Demons', 133.38),
#  ('The Wolverine', 132.56),
#  ('Hulk', 132.18),
#  ('Minority Report', 132.07),
#  ('Fantastic Four: Rise of the Silver Surfer', 131.92),
#  ('Lara Croft: Tomb Raider', 131.14),
#  ('Lethal Weapon 4', 130.44),
#  ('Get Smart', 130.32),
#  ('The Divergent Series: Insurgent', 130.18),
#  ('Ghostbusters', 128.34),
#  ('Kingsman: The Secret Service', 128.26),
#  ('Crouching Tiger Hidden Dragon', 128.08),
#  ('Central Intelligence', 127.44),
#  ('Bumblebee (I)', 127.2),
#  ('2 Fast 2 Furious', 127.15),
#  ('Super 8', 127),
#  ('The World Is Not Enough', 126.94),
#  ('Smokey and the Bandit', 126.74),
#  ('Lucy (I)', 126.66),
#  ('The Legend of Tarzan', 126.64),
#  ('Safe House', 126.37),
#  ('Tomorrow Never Dies', 125.33),
#  ('Terminator Salvation', 125.32),
#  ('Charlies Angels', 125.31),
#  ('Lone Survivor', 125.1),
#  ('Rango', 123.48),
#  ('G.I. Joe: Retaliation', 122.52),
#  ('Clear and Present Danger', 122.19),
#  ('The Hunt for Red October', 122.01),
#  ('The Bodyguard', 121.95),
#  ('The Bourne Identity', 121.66),
#  ('Free Guy', 121.63),
#  ('Speed', 121.25),
#  ('Van Helsing', 120.18),
#  ('The Mask', 119.94),
#  ('Total Recall', 119.39),
#  ('The Other Guys', 119.22),
#  ('The Sum of All Fears', 118.91),
#  ('Salt', 118.31),
#  ('Lightyear', 118.31),
#  ('Ford v Ferrari', 117.62),
#  ('Die Hard 2', 117.54),
#  ('Jungle Cruise', 116.99),
#  ('S.W.A.T.', 116.93),
#  ('Green Lantern', 116.6),
#  ('The Towering Inferno', 116),
#  ('Creed II', 115.72),
#  ('District 9', 115.65),
#  ('Unbroken (I)', 115.64),
#  ('The Karate Kid Part II', 115.1),
#  ('The Patriot', 113.33),
#  ('The Bourne Legacy', 113.2),
#  ('The Pacifier', 113.09),
#  ('Spy Kids', 112.72),
#  ('Ghostbusters II', 112.49),
#  ('Face/Off', 112.23),
#  ('Enemy of the State', 111.55),
#  ('The Last Samurai', 111.11),
#  ('Spy', 110.83),
#  ('Tropic Thunder', 110.52),
#  ('Godzilla: King of the Monsters', 110.5),
#  ('Creed (II)', 109.77),
#  ('Star Trek IV: The Voyage Home', 109.71),
#  ('Crocodile Dundee II', 109.31),
#  ('Black Hawk Down', 108.64),
#  ('Dune', 108.33),
#  ('Superman II', 108.19),
#  ('Baby Driver', 107.83),
#  ('Epic', 107.52),
#  ('Watchmen', 107.51),
#  ('The Angry Birds Movie', 107.51),
#  ('Captain Phillips', 107.1),
#  ('Miss Congeniality', 106.81),
#  ('GoldenEye', 106.6),
#  ('300: Rise of an Empire', 106.58),
#  ('The Italian Job', 106.13),
#  ('Every Which Way But Loose', 106),
#  ('The Lego Movie 2: The Second Part', 105.81),
#  ('The Lost City', 105.34),
#  ('Robin Hood', 105.27),
#  ('George of the Jungle', 105.26),
#  ('Journey 2: The Mysterious Island', 103.86),
#  ('Dick Tracy', 103.74),
#  ('Rise of the Guardians', 103.41),
#  ('Bullet Train', 103.37),
#  ('The Expendables', 103.07),
#  ('The Maze Runner', 102.43),
#  ('In the Line of Fire', 102.31),
#  ('The Equalizer 2', 102.08),
#  ('Pacific Rim', 101.8),
#  ('Journey to the Center of the Earth', 101.7),
#  ('Gone in 60 Seconds', 101.65),
#  ('Maverick', 101.63),
#  ('The Equalizer', 101.53),
#  ('Eraser', 101.3),
#  ('Noah', 101.2),
#  ('Con Air', 101.12),
#  ('Eagle Eye', 101.11),
#  ('Rampage', 101.03),
#  ('Collateral', 101.01),
#  ('Godzilla vs. Kong', 100.92),
#  ('Cowboys & Aliens', 100.24),
#  ('Kingsman: The Golden Circle', 100.23),
#  ('Edge of Tomorrow', 100.21),
#  ('You Dont Mess with the Zohan', 100.02),
#  ('Die Hard with a Vengeance', 100.01),
#  ('Olympus Has Fallen', 98.93),
#  ('The Green Hornet', 98.78),
#  ('Public Enemies', 97.1),
#  ('The Book of Eli', 94.84),
#  ('The Mask of Zorro', 94.1),
#  ('Master and Commander: The Far Side of the World', 93.93),
#  ('DC League of Super-Pets', 93.66),
#  ('The Fighter (I)', 93.62),
#  ('Tomorrowland', 93.44),
#  ('The Magnificent Seven', 93.43),
#  ('Elysium (I)', 93.05),
#  ('Non-Stop', 92.17),
#  ('Blade Runner 2049', 92.05),
#  ('John Wick: Chapter 2', 92.03),
#  ('Star Trek: First Contact', 92),
#  ('Kindergarten Cop', 91.46),
#  ('Crimson Tide', 91.4),
#  ('Ride Along 2', 91.22),
#  ('The Scorpion King', 91.05),
#  ('The Karate Kid', 90.82),
#  ('Prince of Persia: The Sands of Time', 90.76),
#  ('Space Cowboys', 90.46),
#  ('RED', 90.38),
#  ('Terminator Genisys', 89.76),
#  ('The Lone Ranger', 89.3),
#  ('Taken 3', 89.26),
#  ('Oblivion (I)', 89.02),
#  ('Waterworld', 88.25),
#  ('Entrapment', 87.7),
#  ('Pineapple Express', 87.34),
#  ('The Accountant', 86.26),
#  ('Fury', 85.82),
#  ('PokÃƒÂ©mon: The First Movie - Mewtwo Strikes Back', 85.74),
#  ('Alita: Battle Angel', 85.71),
#  ('Real Steel', 85.47),
#  ('Power Rangers', 85.36),
#  ('Aliens', 85.16),
#  ('The Expendables 2', 85.02),
#  ('The Poseidon Adventure', 84.56),
#  ('Birds of Prey', 84.16),
#  ('Atlantis: The Lost Empire', 84.05),
#  ('Cliffhanger', 84.05),
#  ('Wrath of the Titans', 83.67),
#  ('Battle Los Angeles', 83.55),
#  ('Immortals', 83.5),
#  ('Under Siege', 83.36),
#  ('Penguins of Madagascar', 83.35),
#  ('Patriot Games', 83.29),
#  ('Die Hard', 83.01),
#  ('Days of Thunder', 82.67),
#  ('Freddy vs. Jason', 82.62),
#  ('Lets Be Cops', 82.39),
#  ('Blade II', 82.35),
#  ('Beowulf', 82.16),
#  ('Teenage Mutant Ninja Turtles: Out of the Shadows', 82.05),
#  ('Maze Runner: The Scorch Trials', 81.7),
#  ('Unstoppable', 81.56),
#  ('Payback (I)', 81.53),
#  ('Jimmy Neutron: Boy Genius', 80.94),
#  ('Another 48 Hrs.', 80.82),
#  ('Alien vs. Predator', 80.28),
#  ('Jumper', 80.17),
#  ('Jack Reacher', 80.07),
#  ('Cloverfield', 80.05),
#  ('Men in Black: International', 80),
#  ('Knowing', 79.96),
#  ('War Horse', 79.88),
#  ('The Golden Child', 79.82),
#  ('WarGames', 79.57),
#  ('The Purge: Election Year', 79.21),
#  ('Star Trek II: The Wrath of Khan', 78.91),
#  ('48 Hrs.', 78.87),
#  ('Pixels', 78.75),
#  ('Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 78.66),
#  ('We Were Soldiers', 78.12),
#  ('Tower Heist', 78.05),
#  ('Man on Fire', 77.91),
#  ('Backdraft', 77.87),
#  ('The Adventures of Tintin', 77.59),
#  ('The A-Team', 77.22),
#  ('U-571', 77.09),
#  ('Training Day', 76.63),
#  ('Romancing the Stone', 76.57),
#  ('Star Trek III: The Search for Spock', 76.47),
#  ('Knight and Day', 76.42),
#  ('Petes Dragon', 76.23),
#  ('Constantine', 75.98),
#  ('Conspiracy Theory', 75.98),
#  ('The Jewel of the Nile', 75.97),
#  ('Hellboy II: The Golden Army', 75.75),
#  ('Star Trek: Generations', 75.67),
#  ('2 Guns', 75.61),
#  ('Zombieland', 75.59),
#  ('The Last of the Mohicans', 75.51),
#  ('The Hitmans Bodyguard', 75.47),
#  ('Star Trek VI: The Undiscovered Country', 74.89),
#  ('Ladder 49', 74.54),
#  ('Four Brothers', 74.49),
#  ('Six Days Seven Nights', 74.33),
#  ('Captain Underpants: The First Epic Movie', 73.92),
#  ('Deep Blue Sea', 73.65),
#  ('Law Abiding Citizen', 73.34),
#  ('Hollow Man', 73.21),
#  ('Zombieland: Double Tap', 73.12),
#  ('White House Down', 73.1),
#  ('John Carter', 73.08),
#  ('Everything Everywhere All at Once', 72.86),
#  ('Hercules (I)', 72.69),
#  ('Vantage Point', 72.27),
#  ('The Cannonball Run', 72.18),
#  ('The Purge: Anarchy', 71.96),
#  ('Stargate', 71.57),
#  ('The Spiderwick Chronicles', 71.2),
#  ('The Score', 71.07),
#  ('Bird on a Wire', 70.98),
#  ('Broken Arrow', 70.77),
#  ('V for Vendetta', 70.51),
#  ('Mortal Kombat', 70.45),
#  ('Shaft', 70.33),
#  ('Moonraker', 70.31),
#  ('Rocky Balboa', 70.27),
#  ('Fools Gold (I)', 70.23),
#  ('Star Trek: Insurrection', 70.12),
#  ('Kill Bill: Vol. 1', 70.1),
#  ('Blade', 70.09),
#  ('Act of Valor', 70.01),
#  ('Swordfish', 69.77),
#  ('Hot Shots!', 69.47),
#  ('Vertical Limit', 69.24),
#  ('Game Night (I)', 69.18),
#  ('Angel Has Fallen', 69.03),
#  ('Sahara', 68.67),
#  ('Blue Streak', 68.52),
#  ('Skyscraper', 68.42),
#  ('Octopussy', 67.9),
#  ('Outbreak', 67.82),
#  ('Sudden Impact', 67.64),
#  ('The Tourist (I)', 67.63),
#  ('Heat', 67.44),
#  ('The Woman King', 67.33),
#  ('Hidalgo', 67.29),
#  ('Race to Witch Mountain', 67.17),
#  ('Dantes Peak', 67.13),
#  ('The Bounty Hunter (I)', 67.06),
#  ('End of Days', 66.89),
#  ('Spies in Disguise', 66.76),
#  ('Contraband', 66.53),
#  ('Looper', 66.49),
#  ('The League of Extraordinary Gentlemen', 66.47),
#  ('Kill Bill: Vol. 2', 66.21),
#  ('Allegiant', 66.18),
#  ('X-Men: Dark Phoenix', 65.85),
#  ('Bad Boys', 65.81),
#  ('Stakeout', 65.67),
#  ('Lara Croft: Tomb Raider - The Cradle of Life', 65.66),
#  ('The Taking of Pelham 123', 65.45),
#  ('Battleship', 65.42),
#  ('Lethal Weapon', 65.21),
#  ('Jack the Giant Slayer', 65.19),
#  ('Now You See Me 2', 65.08),
#  ('Exodus: Gods and Kings', 65.01),
#  ('Flushed Away', 64.67),
#  ('Chronicle', 64.58),
#  ('Deja Vu', 64.04),
#  ('Sky High', 63.95),
#  ('Unknown (I)', 63.69),
#  ('Thunderball', 63.6),
#  ('The Fifth Element', 63.54),
#  ('Miami Vice', 63.45),
#  ('Tango & Cash', 63.41),
#  ('The Sorcerers Apprentice', 63.15),
#  ('Rising Sun', 63.1),
#  ('London Has Fallen', 62.68),
#  ('The Fast and the Furious: Tokyo Drift', 62.51),
#  ('Underworld: Evolution', 62.32),
#  ('Underworld: Awakening', 62.32),
#  ('For Your Eyes Only', 62.3),
#  ('Terminator: Dark Fate', 62.25),
#  ('Enders Game', 61.74),
#  ('Deepwater Horizon', 61.43),
#  ('The Saint', 61.36),
#  ('Friday Night Lights', 61.26),
#  ('Poseidon', 60.67),
#  ('Three Kings', 60.65),
#  ('Shanghai Knights', 60.48),
#  ('Dora and the Lost City of Gold', 60.48),
#  ('Resident Evil: Afterlife', 60.13),
#  ('Species', 60.07),
#  ('Pacific Rim: Uprising', 59.87),
#  ('Predator', 59.74),
#  ('Hellboy', 59.62),
#  ('The Last Boy Scout', 59.51),
#  ('The Lego Ninjago Movie', 59.28),
#  ('Behind Enemy Lines', 59.07),
#  ('Courage Under Fire', 59.03),
#  ('Dawn of the Dead', 59.02),
#  ('Total Recall (I)', 58.88),
#  ('Jack Reacher: Never Go Back', 58.7),
#  ('RoboCop', 58.61),
#  ('Tenet', 58.46),
#  ('Open Range', 58.33),
#  ('Tomb Raider', 58.25),
#  ('Demolition Man', 58.06),
#  ('Baywatch', 58.06),
#  ('Maze Runner: The Death Cure', 58.03),
#  ('The Chronicles of Riddick', 57.76),
#  ('Takers', 57.74),
#  ('The Specialist', 57.36),
#  ('Willow', 57.27),
#  ('The Blues Brothers', 57.23),
#  ('U.S. Marshals', 57.17),
#  ('Escape Room (I)', 57.01),
#  ('The Man in the Iron Mask (I)', 56.97),
#  ('Shanghai Noon', 56.94),
#  ('Midway', 56.85),
#  ('The Time Machine', 56.68),
#  ('Rat Race', 56.62),
#  ('A Knights Tale', 56.57),
#  ('Executive Decision', 56.57),
#  ('Once Upon a Time in Mexico', 56.36),
#  ('Dracula Untold', 56.28),
#  ('Romeo Must Die', 55.97),
#  ('The Suicide Squad', 55.82),
#  ('Hansel & Gretel: Witch Hunters', 55.7),
#  ('Legend of the Guardians: The Owls of GaHoole', 55.68),
#  ('Never Say Never Again', 55.5),
#  ('AlienÃ‚Â³', 55.47),
#  ('The Shallows', 55.12),
#  ('I Am Number Four', 55.1),
#  ('The Guardian (I)', 55.01),
#  ('The Jackal', 54.93),
#  ('Starship Troopers', 54.81),
#  ('This Means War', 54.76),
#  ('Raya and the Last Dragon', 54.72),
#  ('Source Code', 54.71),
#  ('Small Soldiers', 54.68),
#  ('Assassins Creed', 54.65),
#  ('Tag (I)', 54.55),
#  ('The Count of Monte Cristo', 54.23),
#  ('TMNT', 54.15),
#  ('The Three Musketeers', 53.9),
#  ('Paycheck', 53.79),
#  ('Rambo III', 53.72),
#  ('Hero', 53.71),
#  ('3:10 to Yuma', 53.61),
#  ('RoboCop', 53.42),
#  ('RED 2', 53.26),
#  ('13 Hours', 52.85),
#  ('The Recruit', 52.8),
#  ('Southpaw', 52.42),
#  ('Blade: Trinity', 52.41),
#  ('Star Trek V: The Final Frontier', 52.21),
#  ('The Forbidden Kingdom', 52.08),
#  ('Predators', 52),
#  ('Underworld', 51.97),
#  ('King Arthur', 51.88),
#  ('Exit Wounds', 51.76),
#  ('Atomic Blonde', 51.69),
#  ('The Grey', 51.58),
#  ('Enemy at the Gates', 51.4),
#  ('DragonHeart', 51.37),
#  ('American Made', 51.34),
#  ('Resident Evil: Apocalypse', 51.2),
#  ('The Living Daylights', 51.19),
#  ('Goldfinger', 51.08),
#  ('Apocalypto', 50.87),
#  ('The Net (I)', 50.73),
#  ('The Dark Tower', 50.7),
#  ('The Crow', 50.69),
#  ('Resident Evil: Extinction', 50.65),
#  ('Mighty Joe Young', 50.63),
#  ('Jack Ryan: Shadow Recruit', 50.58),
#  ('A View to a Kill', 50.33),
#  ('Natural Born Killers', 50.28),
#  ('Sicario: Day of the Soldado', 50.07),
#  ('Last Action Hero', 50.02),
#  ('Under Siege 2: Dark Territory', 50.02),
#  ('Absolute Power', 50.01),
#  ('Pain & Gain', 49.88),
#  ('Red Tails', 49.88),
#  ('Volcano', 49.32),
#  ('Cobra', 49.04),
#  ('Firewall', 48.75),
#  ('Gemini Man', 48.55),
#  ('The Huntsman: Winters War', 48.39),
#  ('G.I. Jane', 48.17),
#  ('Kick-Ass', 48.07),
#  ('Kubo and the Two Strings', 48.02),
#  ('Alien: Resurrection', 47.75),
#  ('The Rundown', 47.73),
#  ('Demon Slayer the Movie: Mugen Train', 47.7),
#  ('New Jack City', 47.62),
#  ('Into the Storm', 47.6),
#  ('The Kingdom', 47.54),
#  ('Hard to Kill', 47.41),
#  ('Munich', 47.4),
#  ('Kingdom of Heaven', 47.4),
#  ('Savages (I)', 47.38),
#  ('Warcraft', 47.37),
#  ('First Blood', 47.21),
#  ('Shooter (I)', 47),
#  ('Sicario', 46.89),
#  ('Red Sparrow', 46.87),
#  ('The Spy Who Loved Me', 46.8),
#  ('Firefox', 46.71),
#  ('The Rocketeer', 46.7),
#  ('Colors', 46.62),
#  ('The Legend of Zorro', 46.46),
#  ('Walking Tall', 46.44),
#  ('Its a Mad Mad Mad Mad World', 46.3),
#  ('Black Rain', 46.21),
#  ('The Enforcer', 46.2),
#  ('Gangster Squad', 46),
#  ('12 Strong', 45.82),
#  ('Underworld: Rise of the Lycans', 45.8),
#  ('RoboCop 2', 45.68),
#  ('Young Guns', 45.66),
#  ('The Great Wall (I)', 45.54),
#  ('The Man from U.N.C.L.E.', 45.45),
#  ('The Dirty Dozen', 45.3),
#  ('Here Comes the Boom', 45.29),
#  ('Den of Thieves', 44.95),
#  ('Cop Out', 44.88),
#  ('Timecop', 44.85),
#  ('Rambo: Last Blood', 44.82),
#  ('The Forever Purge', 44.54),
#  ('The Negotiator', 44.48),
#  ('Nothing to Lose', 44.46),
#  ('Young Guns II', 44.14),
#  ('Passenger 57', 44.07),
#  ('Speed Racer', 43.95),
#  ('The One', 43.91),
#  ('Diamonds Are Forever', 43.82),
#  ('Tears of the Sun', 43.73),
#  ('Need for Speed', 43.58),
#  ('Everest', 43.48),
#  ('Edge of Darkness', 43.31),
#  ('Star Trek: Nemesis', 43.25),
#  ('K-9', 43.25),
#  ('Point Break', 43.22),
#  ('Transporter 2', 43.1),
#  ('You Only Live Twice', 43.08),
#  ('Reign of Fire', 43.06),
#  ('John Wick', 43.04),
#  ('Escape from Alcatraz', 43),
#  ('Snitch (I)', 42.93),
#  ('The Devils Own', 42.87),
#  ('Rambo', 42.75),
#  ('Beverly Hills Cop III', 42.61),
#  ('Bullitt', 42.3),
#  ('Mortal Kombat', 42.2),
#  ('Riddick', 42.03),
#  ('The Angry Birds Movie 2', 41.66),
#  ('Ronin', 41.62),
#  ('The Peacemaker', 41.26),
#  ('Valerian and the City of a Thousand Planets', 41.19),
#  ('Clash of the Titans', 41.09),
#  ('Money Talks', 41.07),
#  ('End of Watch', 41),
#  ('The Siege', 40.98),
#  ('Windtalkers', 40.91),
#  ('Falling Down', 40.9),
#  ('Ghost in the Shell', 40.56),
#  ('Hanna', 40.26),
#  ('Resident Evil', 40.12),
#  ('Allied', 40.1),
#  ('Collateral Damage', 40.08),
#  ('Hitman (I)', 39.69),
#  ('Conan the Barbarian', 39.57),
#  ('30 Days of Night', 39.57),
#  ('Body of Lies', 39.39),
#  ('The Expendables 3', 39.32),
#  ('Pitch Black', 39.24),
#  ('King Arthur: Legend of the Sword', 39.18),
#  ('The Longest Day', 39.1),
#  ('Crawl (I)', 39.01),
#  ('Hot Shots! Part Deux', 38.91),
#  ('Nerve (I)', 38.58),
#  ('Surrogates', 38.58),
#  ('Midnight Run', 38.41),
#  ('The Terminator', 38.4),
#  ('Red Dawn', 38.38),
#  ('47 Ronin', 38.36),
#  ('Undercover Brother', 38.23),
#  ('The Running Man', 38.12),
#  ('Ninja Assassin', 38.11),
#  ('Showtime', 38.08),
#  ('The Brothers Grimm', 37.92),
#  ('The Dead Pool', 37.9),
#  ('Sky Captain and the World of Tomorrow', 37.76),
#  ('First Knight', 37.6),
#  ('In Time', 37.52),
#  ('Abraham Lincoln: Vampire Hunter', 37.52),
#  ('Invictus', 37.49),
#  ('The Kings Man', 37.18),
#  ('30 Minutes or Less', 37.05),
#  ('Sphere', 37.02),
#  ('16 Blocks', 36.9),
#  ('Risen', 36.87),
#  ('Kiss of the Dragon', 36.85),
#  ('Just Cause', 36.85),
#  ('The Brave One', 36.79),
#  ('The Getaway', 36.73),
#  ('Colombiana', 36.67),
#  ('The Gentlemen', 36.47),
#  ('Sucker Punch', 36.39),
#  ('National Security', 36.38),
#  ('The Commuter (I)', 36.34),
#  ('Death Race', 36.32),
#  ('Universal Soldier', 36.3),
#  ('The Sentinel', 36.28),
#  ('The Nice Guys', 36.26),
#  ('American Assassin', 36.25),
#  ('Mad Max Beyond Thunderdome', 36.2),
#  ('Mile 22', 36.11),
#  ('The Pink Panther 2', 35.92),
#  ('Dirty Harry', 35.9),
#  ('Alpha (II)', 35.85),
#  ('The Island', 35.82),
#  ('Smokin Aces', 35.66),
#  ('The American', 35.61),
#  ('Children of Men', 35.55),
#  ('No Way Out', 35.51),
#  ('Peppermint', 35.42),
#  ('Live and Let Die', 35.38),
#  ('Money Train', 35.32),
#  ('Star Wars: The Clone Wars', 35.16),
#  ('Dragon: The Bruce Lee Story', 35.11),
#  ('Commando', 35.1),
#  ('Pan', 35.09),
#  ('Drive (I)', 35.06),
#  ('Green Zone', 35.05),
#  ('The Skulls', 35.05),
#  ('Red Heat', 34.99),
#  ('Cradle 2 the Grave', 34.71),
#  ('Judge Dredd', 34.69),
#  ('Licence to Kill', 34.67),
#  ('Hostage', 34.64),
#  ('The 6th Day', 34.6),
#  ('The Foreigner (I)', 34.39),
#  ('Inferno (I)', 34.34),
#  ('Alexander', 34.3),
#  ('The Hunted', 34.24),
#  ('The Northman', 34.23),
#  ('Death Wish', 34.02),
#  ('Snakes on a Plane', 34.02),
#  ('Darkman', 33.88),
#  ('The Punisher', 33.81),
#  ('R.I.P.D.', 33.62),
#  ('Muppet Treasure Island', 33.61),
#  ('Flags of Our Fathers', 33.6),
#  ('The Spy Who Dumped Me', 33.56),
#  ('The Long Kiss Goodnight', 33.33),
#  ('Silverado', 33.2),
#  ('Daylight', 33.02),
#  ('Tron', 33),
#  ('Mercury Rising', 32.94),
#  ('Blade Runner', 32.87),
#  ('Drillbit Taylor', 32.85),
#  ('Team America: World Police', 32.79),
#  ('The 13th Warrior', 32.7),
#  ('Dont Breathe 2', 32.64),
#  ('Proof of Life', 32.6),
#  ('Hard Target', 32.59),
#  ('Rumble in the Bronx', 32.39),
#  ('Cold Pursuit', 32.14),
#  ('Final Fantasy: The Spirits Within', 32.13),
#  ('The Shadow', 32.06),
#  ('Cellular', 32),
#  ('Metro', 31.99),
#  ('Patriots Day', 31.89),
#  ('Beast (I)', 31.85),
#  ('Push', 31.81),
#  ('Lake Placid', 31.77),
#  ('1941', 31.76),
#  ('9 (I)', 31.74),
#  ('Transporter 3', 31.72),
#  ('United 93', 31.57),
#  ('Chappie', 31.57),
#  ('Scott Pilgrim vs. the World', 31.49),
#  ('A History of Violence', 31.49),
#  ('Adrift (I)', 31.45),
#  ('Beverly Hills Ninja', 31.24),
#  ('The Core', 31.19),
#  ('The Mortal Instruments: City of Bones', 31.17),
#  ('Gods of Egypt', 31.15),
#  ('Air America', 31.05),
#  ('Conan the Destroyer', 31.04),
#  ('Dune', 30.93),
#  ('Kidnap (I)', 30.72),
#  ('Dragon Ball Super: Broly', 30.71),
#  ('3 Days to Kill', 30.7),
#  ('Predator 2', 30.67),
#  ('Deliver Us from Evil (I)', 30.58),
#  ('Underworld: Blood Wars', 30.35),
#  ('Assassins', 30.31),
#  ('The Art of War', 30.21),
#  ('Blown Away', 30.16),
#  ('Bad Company', 30.16),
#  ('Daybreakers', 30.1),
#  ('Double Impact', 30.1),
#  ('Road House', 30.05),
#  ('Point of No Return', 30.04),
#  ('Rollerball', 30),
#  ('Mystery Men', 29.76),
#  ('Tora! Tora! Tora!', 29.55),
#  ('Zathura: A Space Adventure', 29.26),
#  ('Priest', 29.14),
#  ('The Mechanic', 29.12),
#  ('The Guns of Navarone', 28.9),
#  ('Kick-Ass 2', 28.8),
#  ('The Last Starfighter', 28.73),
#  ('Ready or Not (I)', 28.71),
#  ('Defiance (I)', 28.64),
#  ('28 Weeks Later', 28.64),
#  ('We Own the Night', 28.56),
#  ('21 Bridges', 28.54),
#  ('After the Sunset', 28.33),
#  ('Johnny English', 28.08),
#  ('Grosse Pointe Blank', 28.01),
#  ('Loaded Weapon 1', 27.98),
#  ('Crank', 27.83),
#  ('Logan Lucky', 27.78),
#  ('The Edge', 27.78),
#  ('The Finest Hours', 27.57),
#  ('Wrath of Man', 27.47),
#  ('Memphis Belle', 27.44),
#  ('The Last Witch Hunter', 27.37),
#  ('No Escape (I)', 27.29),
#  ('Nobody (I)', 27.27),
#  ('Brooklyns Finest', 27.15),
#  ('The Big Hit', 27.05),
#  ('Rush (I)', 26.95),
#  ('Resident Evil: The Final Chapter', 26.83),
#  ('The Host', 26.63),
#  ('Machete', 26.59),
#  ('Basic', 26.54),
#  ('Run All Night', 26.46),
#  ('Street Kings', 26.42),
#  ('Ben-Hur', 26.41),
#  ('A Walk Among the Tombstones', 26.31),
#  ('Blood Work', 26.2),
#  ('A Man Apart', 26.18),
#  ('The Worlds End', 26),
#  ('Innerspace', 25.89),
#  ('Murder at 1600', 25.83),
#  ('From Dusk Till Dawn', 25.75),
#  ('Desperado', 25.63),
#  ('Serenity', 25.51),
#  ('Escape from L.A.', 25.48),
#  ('The International (I)', 25.45),
#  ('The Transporter', 25.3),
#  ('Escape from New York', 25.24),
#  ('Fallen', 25.19),
#  ('Escape Room: Tournament of Champions', 25.19),
#  ('Escape Plan', 25.13),
#  ('Killer Elite', 25.12),
#  ('Wyatt Earp', 25.05),
#  ('Grindhouse', 25.04),
#  ('In the Heart of the Sea', 25.02),
#  ('Enter the Dragon', 25),
#  ('Thunderbolt and Lightfoot', 25),
#  ('Logans Run', 25),
#  ('The November Man', 24.98),
#  ('Never Back Down', 24.85),
#  ('From Russia with Love', 24.8),
#  ('Fearless', 24.63),
#  ('Unleashed', 24.52),
#  ('15 Minutes', 24.4),
#  ('Arlington Road', 24.36),
#  ('Lionheart', 24.08),
#  ('Virtuosity', 24.05),
#  ('The Life Aquatic with Steve Zissou', 24.01),
#  ('Around the World in 80 Days', 24.01),
#  ('From Paris with Love', 23.98),
#  ('Striking Distance', 23.8),
#  ('Hot Fuzz', 23.64),
#  ('The Losers (I)', 23.58),
#  ('Traitor', 23.53),
#  ('Reindeer Games', 23.36),
#  ('Faster', 23.24),
#  ('Pompeii (I)', 23.22),
#  ('The Iron Giant', 23.16),
#  ('Sanctum', 23.07),
#  ('Fighting', 23.04),
#  ('Transcendence (I)', 23.02),
#  ('On Her Majestys Secret Service', 22.8),
#  ('Ambulance', 22.78),
#  ('Titan A.E.', 22.75),
#  ('Babylon A.D.', 22.53),
#  ('The Warriors', 22.49),
#  ('War', 22.49),
#  ('Hitman: Agent 47', 22.47),
#  ('Stuber', 22.37),
#  ('Nowhere to Run', 22.19),
#  ('Lock Up', 22.1),
#  ('Black and Blue (I)', 22.06),
#  ('Death Wish', 22),
#  ('Joy Ride', 21.97),
#  ('Overlord', 21.7),
#  ('The Rookie', 21.63),
#  ('The Quest', 21.6),
#  ('Your Highness', 21.6),
#  ('Shaft', 21.36),
#  ('The Black Cauldron', 21.29),
#  ('Chain Reaction', 21.23),
#  ('Mechanic: Resurrection', 21.22),
#  ('Bulletproof', 21.16),
#  ('The Next Three Days', 21.15),
#  ('Tales from the Crypt: Demon Knight', 21.09),
#  ('Flight of the Phoenix', 21.01),
#  ('The Man with the Golden Gun', 20.97),
#  ('Unhinged (I)', 20.83),
#  ('Sleepless (III)', 20.78),
#  ('Free State of Jones', 20.76),
#  ('Keanu', 20.57),
#  ('Gamer', 20.49),
#  ('Brick Mansions', 20.4),
#  ('The Three Musketeers', 20.38),
#  ('Sudden Death', 20.35),
#  ('Premium Rush', 20.28),
#  ('Vampires', 20.24),
#  ('Appaloosa', 20.21),
#  ('Baahubali 2: The Conclusion', 20.19),
#  ('Homefront (I)', 20.16),
#  ('Juice', 20.15),
#  ('Assault on Precinct 13', 19.98),
#  ('Hard Rain', 19.82),
#  ('Broken City', 19.7),
#  ('Astro Boy', 19.55),
#  ('Leon: The Professional', 19.5),
#  ('The Eagle', 19.49),
#  ('Timeline', 19.48),
#  ('Johnny Mnemonic', 19.08),
#  ('Beneath the Planet of the Apes', 19),
#  ('The Replacement Killers', 18.97),
#  ('Haywire', 18.94),
#  ('Above the Law', 18.87),
#  ('Eye in the Sky', 18.7),
#  ('Casualties of War', 18.67),
#  ('The Quick and the Dead', 18.64),
#  ('Man on a Ledge', 18.62),
#  ('CHIPS', 18.6),
#  ('The Fan', 18.57),
#  ('Into the Blue', 18.47),
#  ('Only the Brave', 18.34),
#  ('The Four Feathers', 18.31),
#  ('The Last Castle', 18.21),
#  ('Next', 18.21),
#  ('Red Planet', 18),
#  ('The Postman', 17.63),
#  ('Parker', 17.62),
#  ...]

# %% [markdown]
# 4) Display the gross collection of movies with the star Arnold.

# %%
Arnold_gross=cur1.execute("select Gross_collection from Imdbmovie2 where star_1 like 'Arnold%'")
Arnold_gross.fetchall()
# Out:
# []

# %% [markdown]
# 5) Display all details of movies with comedy and action genres.

# %%
comedyandaction=cur1.execute("select * from Imdbmovie2 where Genre_1 in ('Comedy','Action')")
comedyandaction.fetchall()
# Out:
# [('The Dark Knight',
#   'Christian Bale',
#   'Heath Ledger',
#   'Aaron Eckhart',
#   'Michael Caine',
#   2717521,
#   'Action',
#   ' Crime',
#   ' Drama',
#   534.86,
#   'PG-13'),
#  ('The Lord of the Rings: The Return of the King',
#   '  Elijah Wood',
#   'Viggo Mortensen',
#   ' Ian McKellen',
#   'Orlando Bloom',
#   1886645,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   377.85,
#   'PG-13'),
#  ('Inception',
#   '  Leonardo DiCaprio',
#   'Joseph Gordon-Levitt',
#   'Elliot Page',
#   ' Ken Watanabe',
#   2412332,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   292.58,
#   'PG-13'),
#  ('The Lord of the Rings: The Fellowship of the Ring',
#   '  Elijah Wood',
#   'Ian McKellen',
#   'Orlando Bloom',
#   'Sean Bean',
#   1915355,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   315.54,
#   'PG-13'),
#  ('The Lord of the Rings: The Two Towers',
#   '  Elijah Wood',
#   ' Ian McKellen',
#   'Viggo Mortensen',
#   ' Orlando Bloom',
#   1702927,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   342.55,
#   'PG-13'),
#  ('The Matrix',
#   '  Keanu Reeves',
#   'Laurence Fishburne',
#   ' Carrie-Anne Moss',
#   ' Hugo Weaving',
#   1957307,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   171.48,
#   'R'),
#  ('Star Wars: Episode V - The Empire Strikes Back',
#   '  Mark Hamill',
#   'Harrison Ford',
#   ' Carrie Fisher',
#   'Billy Dee Williams',
#   1320777,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   290.48,
#   'PG'),
#  ('Soorarai Pottru',
#   '  Suriya',
#   ' Paresh Rawal',
#   ' Aparna Balamurali',
#   ' Urvashi',
#   119469,
#   'Action',
#   ' Drama',
#   'None',
#   0,
#   'TV-MA'),
#  ('Star Wars: Episode IV - A New Hope',
#   '  Mark Hamill',
#   ' Harrison Ford',
#   ' Carrie Fisher',
#   ' Alec Guinness',
#   1393243,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   322.74,
#   'PG'),
#  ('Terminator 2: Judgment Day',
#   '  Arnold Schwarzenegger',
#   ' Linda Hamilton',
#   ' Edward Furlong',
#   ' Robert Patrick',
#   1122770,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   204.84,
#   'R'),
#  ('Seven Samurai',
#   '  ToshiroÂ´ Mifune',
#   ' Takashi Shimura',
#   ' Keiko Tsushima',
#   ' Yukiko Shimazaki',
#   352753,
#   'Action',
#   ' Drama',
#   'None',
#   0.27,
#   'Not Rated'),
#  ('Harakiri',
#   '  Tatsuya Nakadai',
#   ' Akira Ishihama',
#   ' Shima Iwashita',
#   ' TetsurÃƒÂ´ Tanba',
#   60943,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   0,
#   'Not Rated'),
#  ('Sita Ramam',
#   '  Dulquer Salmaan',
#   ' Mrunal Thakur',
#   ' Rashmika Mandanna',
#   ' Sumanth',
#   59811,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   0,
#   'U'),
#  ('Leon: The Professional',
#   '  Jean Reno',
#   ' Gary Oldman',
#   ' Natalie Portman',
#   ' Danny Aiello',
#   1189073,
#   'Action',
#   ' Crime',
#   ' Drama',
#   19.5,
#   'R'),
#  ('Gladiator',
#   '  Russell Crowe',
#   ' Joaquin Phoenix',
#   ' Connie Nielsen',
#   ' Oliver Reed',
#   1535784,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   187.71,
#   'R'),
#  ('Avengers: Endgame',
#   '  Robert Downey Jr.',
#   ' Chris Evans',
#   ' Mark Ruffalo',
#   ' Chris Hemsworth',
#   1179423,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   858.37,
#   'PG-13'),
#  ('Indiana Jones and the Raiders of the Lost Ark',
#   '  Harrison Ford',
#   ' Karen Allen',
#   ' Paul Freeman',
#   ' John Rhys-Davies',
#   985955,
#   'Action',
#   ' Adventure',
#   'None',
#   248.16,
#   'PG'),
#  ('Avengers: Infinity War',
#   '  Robert Downey Jr.',
#   ' Chris Hemsworth',
#   ' Mark Ruffalo',
#   ' Chris Evans',
#   1122836,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   678.82,
#   'PG-13'),
#  ('Oldboy',
#   '  Choi Min-sik',
#   ' Yoo Ji-tae',
#   ' Kang Hye-jeong',
#   ' Kim Byeong-Ok',
#   596202,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   0.71,
#   'R'),
#  ('The Dark Knight Rises',
#   '  Christian Bale',
#   ' Tom Hardy',
#   ' Anne Hathaway',
#   ' Gary Oldman',
#   1741135,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   448.14,
#   'PG-13'),
#  ('Aliens',
#   '  Sigourney Weaver',
#   ' Michael Biehn',
#   ' Carrie Henn',
#   ' Paul Reiser',
#   732348,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   85.16,
#   'R'),
#  ('Kaithi',
#   '  Karthi',
#   ' Narain',
#   ' Arjun Das',
#   ' George Maryan',
#   36069,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   0,
#   'Not Rated'),
#  ('Asuran',
#   '  Dhanush',
#   ' Manju Warrier',
#   ' Prakash Raj',
#   ' Pasupathy',
#   31178,
#   'Action',
#   ' Drama',
#   'None',
#   0,
#   'Not Rated'),
#  ('Top Gun: Maverick',
#   '  Tom Cruise',
#   ' Jennifer Connelly',
#   ' Miles Teller',
#   ' Val Kilmer',
#   588695,
#   'Action',
#   ' Drama',
#   'None',
#   718.73,
#   'PG-13'),
#  ('Heat',
#   '  Al Pacino',
#   ' Robert De Niro',
#   ' Val Kilmer',
#   ' Jon Voight',
#   675813,
#   'Action',
#   ' Crime',
#   ' Drama',
#   67.44,
#   'R'),
#  ('Star Wars: Episode VI - Return of the Jedi',
#   '  Mark Hamill',
#   ' Harrison Ford',
#   ' Carrie Fisher',
#   ' Billy Dee Williams',
#   1077310,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   309.13,
#   'PG'),
#  ('North by Northwest',
#   '  Cary Grant',
#   ' Eva Marie Saint',
#   ' James Mason',
#   ' Jessie Royce Landis',
#   334514,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   13.28,
#   'Approved'),
#  ('Kantara',
#   '  Rishab Shetty',
#   ' Kishore Kumar G.',
#   ' Achyuth Kumar',
#   ' Sapthami Gowda',
#   95392,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('Dangal',
#   '  Aamir Khan',
#   ' Sakshi Tanwar',
#   ' Fatima Sana Shaikh',
#   ' Sanya Malhotra',
#   197266,
#   'Action',
#   ' Biography',
#   ' Drama',
#   12.39,
#   'Not Rated'),
#  ('K.G.F: Chapter 2',
#   '  Yash',
#   ' Sanjay Dutt',
#   ' Raveena Tandon',
#   ' Srinidhi Shetty',
#   139575,
#   'Action',
#   ' Crime',
#   ' Drama',
#   6.6,
#   'Not Rated'),
#  ('Vikram',
#   '  Kamal Haasan',
#   ' Vijay Sethupathi',
#   ' Fahadh Faasil',
#   ' Narain',
#   63797,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   0,
#   'UA'),
#  ('Raatchasan',
#   '  Vishnu Vishal',
#   ' Amala Paul',
#   ' Radha Ravi',
#   ' Sangili Murugan',
#   46924,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('Shershaah',
#   '  Sidharth Malhotra',
#   ' Kiara Advani',
#   ' Shiv Panditt',
#   ' Pranay Pachauri',
#   124760,
#   'Action',
#   ' Biography',
#   ' Drama',
#   0,
#   'TV-14'),
#  ('Guardians of the Galaxy Vol. 3',
#   '  Chris Pratt',
#   ' Chukwudi Iwuji',
#   ' Bradley Cooper',
#   ' Pom Klementieff',
#   146352,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   0,
#   'PG-13'),
#  ('Spider-Man: No Way Home',
#   '  Tom Holland',
#   ' Zendaya',
#   ' Benedict Cumberbatch',
#   ' Jacob Batalon',
#   796509,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   804.75,
#   'PG-13'),
#  ('Jurassic Park',
#   '  Sam Neill',
#   ' Laura Dern',
#   ' Jeff Goldblum',
#   ' Richard Attenborough',
#   1013596,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   402.45,
#   'PG-13'),
#  ('Indiana Jones and the Last Crusade',
#   '  Harrison Ford',
#   ' Sean Connery',
#   ' Alison Doody',
#   ' Denholm Elliott',
#   770923,
#   'Action',
#   ' Adventure',
#   'None',
#   197.17,
#   'PG-13'),
#  ('1917',
#   '  Dean-Charles Chapman',
#   ' George MacKay',
#   ' Daniel Mays',
#   ' Colin Firth',
#   620672,
#   'Action',
#   ' Drama',
#   ' War',
#   159.23,
#   'R'),
#  ('Kill Bill: Vol. 1',
#   '  Uma Thurman',
#   ' David Carradine',
#   ' Daryl Hannah',
#   ' Michael Madsen',
#   1140530,
#   'Action',
#   ' Crime',
#   ' Drama',
#   70.1,
#   'R'),
#  ('Batman Begins',
#   '  Christian Bale',
#   ' Michael Caine',
#   ' Ken Watanabe',
#   ' Liam Neeson',
#   1502882,
#   'Action',
#   ' Crime',
#   ' Drama',
#   206.85,
#   'PG-13'),
#  ('Die Hard',
#   '  Bruce Willis',
#   ' Alan Rickman',
#   ' Bonnie Bedelia',
#   ' Reginald VelJohnson',
#   901160,
#   'Action',
#   ' Thriller',
#   'None',
#   83.01,
#   'R'),
#  ('V for Vendetta',
#   '  Hugo Weaving',
#   ' Natalie Portman',
#   ' Rupert Graves',
#   ' Stephen Rea',
#   1140572,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   70.51,
#   'R'),
#  ('Ran',
#   '  Tatsuya Nakadai',
#   ' Akira Terao',
#   ' Jinpachi Nezu',
#   ' Daisuke RyÃƒÂ»',
#   129112,
#   'Action',
#   ' Drama',
#   ' War',
#   4.14,
#   'R'),
#  ('Gangs of Wasseypur',
#   '  Manoj Bajpayee',
#   ' Nawazuddin Siddiqui',
#   ' Tigmanshu Dhulia',
#   ' Richa Chadha',
#   99325,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0,
#   'Not Rated'),
#  ('Vikram Vedha',
#   '  Madhavan',
#   ' Vijay Sethupathi',
#   ' Shraddha Srinath',
#   ' Kathir',
#   47632,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('Baahubali 2: The Conclusion',
#   '  Prabhas',
#   ' Rana Daggubati',
#   ' Anushka Shetty',
#   ' Tamannaah Bhatia',
#   106669,
#   'Action',
#   ' Drama',
#   'None',
#   20.19,
#   'Not Rated'),
#  ('Yojimbo',
#   '  ToshirÃƒÂ´ Mifune',
#   ' EijirÃƒÂ´ TÃƒÂ´no',
#   ' Tatsuya Nakadai',
#   ' YÃƒÂ´ko Tsukasa',
#   125843,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   0,
#   'Not Rated'),
#  ('Uri: The Surgical Strike',
#   '  Vicky Kaushal',
#   ' Paresh Rawal',
#   ' Mohit Raina',
#   ' Yami Gautam',
#   67312,
#   'Action',
#   ' Drama',
#   ' History',
#   4.19,
#   'Not Rated'),
#  ('K.G.F: Chapter 1',
#   '  Yash',
#   ' Srinidhi Shetty',
#   ' Ramachandra Raju',
#   ' Archana Jois',
#   91560,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('Sherlock Jr.',
#   '  Buster Keaton',
#   ' Kathryn McGuire',
#   ' Joe Keaton',
#   ' Erwin Connelly',
#   52431,
#   'Action',
#   ' Comedy',
#   ' Romance',
#   0.98,
#   'Passed'),
#  ('Rangasthalam 1985',
#   '  Ram Charan',
#   ' Samantha Ruth Prabhu',
#   ' Aadhi',
#   ' Jagapathi Babu',
#   26143,
#   'Action',
#   ' Drama',
#   'None',
#   3.51,
#   'Not Rated'),
#  ('The Mountain II',
#   '  Caglar Ertugrul',
#   ' Ufuk Bayraktar',
#   ' Ahu TÃƒÂ¼rkpenÃƒÂ§e',
#   ' Murat Serezli',
#   109174,
#   'Action',
#   ' Drama',
#   ' War',
#   0,
#   'Not Rated'),
#  ('Paan Singh Tomar',
#   '  Irrfan Khan',
#   ' Mahie Gill',
#   ' Rajesh Abhay',
#   ' Hemendra Dandotiya',
#   37041,
#   'Action',
#   ' Biography',
#   ' Crime',
#   0.04,
#   'R'),
#  ('Mad Max: Fury Road',
#   '  Tom Hardy',
#   ' Charlize Theron',
#   ' Nicholas Hoult',
#   ' ZoÃƒÂ« Kravitz',
#   1029852,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   154.06,
#   'PG-13'),
#  ('Ford v Ferrari',
#   '  Matt Damon',
#   ' Christian Bale',
#   ' Jon Bernthal',
#   ' CaitrÃƒÂ\xadona Balfe',
#   418484,
#   'Action',
#   ' Biography',
#   ' Drama',
#   117.62,
#   'PG-13'),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl',
#   '  Johnny Depp',
#   ' Geoffrey Rush',
#   ' Orlando Bloom',
#   ' Keira Knightley',
#   1153318,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   305.41,
#   'R'),
#  ('Blade Runner',
#   '  Harrison Ford',
#   ' Rutger Hauer',
#   ' Sean Young',
#   ' Edward James Olmos',
#   787715,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   32.87,
#   'R'),
#  ('The Terminator',
#   '  Arnold Schwarzenegger',
#   ' Linda Hamilton',
#   ' Michael Biehn',
#   ' Paul Winfield',
#   885204,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   38.4,
#   'R'),
#  ('Logan',
#   '  Hugh Jackman',
#   ' Patrick Stewart',
#   ' Dafne Keen',
#   ' Boyd Holbrook',
#   787213,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   226.28,
#   'R'),
#  ('Lock Stock and Two Smoking Barrels',
#   '  Jason Flemyng',
#   ' Dexter Fletcher',
#   ' Nick Moran',
#   ' Jason Statham',
#   595108,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   3.9,
#   'PG'),
#  ('Warrior',
#   '  Tom Hardy',
#   ' Nick Nolte',
#   ' Joel Edgerton',
#   ' Jennifer Morrison',
#   481730,
#   'Action',
#   ' Drama',
#   ' Sport',
#   13.66,
#   'R'),
#  ('Rush (I)',
#   '  Daniel BrÃƒÂ¼hl',
#   ' Chris Hemsworth',
#   ' Olivia Wilde',
#   ' Alexandra Maria Lara',
#   490998,
#   'Action',
#   ' Biography',
#   ' Drama',
#   26.95,
#   'PG'),
#  ('Sholay',
#   '  Sanjeev Kumar',
#   ' Dharmendra',
#   ' Amitabh Bachchan',
#   ' Amjad Khan',
#   57063,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   0,
#   'Not Rated'),
#  ('Bajrangi Bhaijaan',
#   '  Salman Khan',
#   ' Harshaali Malhotra',
#   ' Nawazuddin Siddiqui',
#   ' Kareena Kapoor',
#   91904,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   8.18,
#   'Passed'),
#  ('The General',
#   '  Buster Keaton',
#   ' Marion Mack',
#   ' Glen Cavender',
#   ' Jim Farley',
#   93864,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   1.03,
#   'Not Rated'),
#  ('The Hidden Fortress',
#   '  ToshirÃƒÂ´ Mifune',
#   ' Misa Uehara',
#   ' Minoru Chiaki',
#   ' Kamatari Fujiwara',
#   40453,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('White Heat',
#   '  James Cagney',
#   ' Virginia Mayo',
#   ' Edmond OBrien',
#   ' Margaret Wycherly',
#   34278,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('A Wednesday',
#   '  Anupam Kher',
#   ' Naseeruddin Shah',
#   ' Veerendra Saxena',
#   ' Mahesh Kanual',
#   80205,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'UA'),
#  ('Major',
#   '  Adivi Sesh',
#   ' Prakash Raj',
#   ' Revathi',
#   ' Saiee Manjrekar',
#   30452,
#   'Action',
#   ' Biography',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('Sarfarosh',
#   '  Aamir Khan',
#   ' Naseeruddin Shah',
#   ' Sonali Bendre',
#   ' Mukesh Rishi',
#   26227,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   0,
#   'Not Rated'),
#  ('Hera Pheri',
#   '  Akshay Kumar',
#   ' Suniel Shetty',
#   ' Paresh Rawal',
#   ' Tabu',
#   69404,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0,
#   'Not Rated'),
#  ('Kaththi',
#   '  Joseph Vijay',
#   ' Samantha Ruth Prabhu',
#   ' Neil Nitin Mukesh',
#   ' Tota Roy Chowdhury',
#   28322,
#   'Action',
#   ' Drama',
#   'None',
#   0,
#   'Not Rated'),
#  ('Thuppakki',
#   '  Joseph Vijay',
#   ' Kajal Aggarwal',
#   ' Vidyut Jammwal',
#   ' Sathyan',
#   35909,
#   'Action',
#   ' Thriller',
#   'None',
#   0,
#   'R'),
#  ('John Wick: Chapter 4',
#   '  Keanu Reeves',
#   ' Laurence Fishburne',
#   ' George Georgiou',
#   ' Lance Reddick',
#   177823,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   0,
#   'PG-13'),
#  ('Guardians of the Galaxy',
#   '  Chris Pratt',
#   ' Vin Diesel',
#   ' Bradley Cooper',
#   ' Zoe Saldana',
#   1217116,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   333.18,
#   'PG-13'),
#  ('Dune',
#   '  TimothÃƒÂ©e Chalamet',
#   ' Rebecca Ferguson',
#   ' Zendaya',
#   ' Oscar Isaac',
#   677751,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   108.33,
#   'R'),
#  ('Blade Runner 2049',
#   '  Harrison Ford',
#   ' Ryan Gosling',
#   ' Ana de Armas',
#   ' Dave Bautista',
#   603524,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   92.05,
#   'R'),
#  ('Deadpool',
#   '  Ryan Reynolds',
#   ' Morena Baccarin',
#   ' T.J. Miller',
#   ' Ed Skrein',
#   1067514,
#   'Action',
#   ' Comedy',
#   'None',
#   363.07,
#   'PG-13'),
#  ('The Avengers',
#   '  Robert Downey Jr.',
#   ' Chris Evans',
#   ' Scarlett Johansson',
#   ' Jeremy Renner',
#   1415723,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   623.28,
#   'R'),
#  ('Zack Snyders Justice League',
#   '  Henry Cavill',
#   ' Ben Affleck',
#   ' Gal Gadot',
#   ' Amy Adams',
#   412561,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   0,
#   'PG'),
#  ('Casino Royale',
#   '  Daniel Craig',
#   ' Eva Green',
#   ' Judi Dench',
#   ' Jeffrey Wright',
#   670820,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   167.45,
#   'R'),
#  ('The Revenant (I)',
#   '  Leonardo DiCaprio',
#   ' Tom Hardy',
#   ' Will Poulter',
#   ' Domhnall Gleeson',
#   827647,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   183.64,
#   'R'),
#  ('Kill Bill: Vol. 2',
#   '  Uma Thurman',
#   ' David Carradine',
#   ' Michael Madsen',
#   ' Daryl Hannah',
#   773849,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   66.21,
#   'R'),
#  ('Ip Man',
#   '  Donnie Yen',
#   ' Simon Yam',
#   ' Siu-Wong Fan',
#   ' Ka-Tung Lam',
#   228371,
#   'Action',
#   ' Biography',
#   ' Drama',
#   0,
#   'PG-13'),
#  ('The Bourne Ultimatum',
#   '  Matt Damon',
#   ' Edgar RamÃƒÂ\xadrez',
#   ' Joan Allen',
#   ' Julia Stiles',
#   644032,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   227.47,
#   'Not Rated'),
#  ('Baahubali: The Beginning',
#   '  Prabhas',
#   ' Rana Daggubati',
#   ' Anushka Shetty',
#   ' Tamannaah Bhatia',
#   129942,
#   'Action',
#   ' Drama',
#   'None',
#   6.74,
#   'R'),
#  ('Infernal Affairs',
#   '  Andy Lau',
#   ' Tony Leung Chiu-wai',
#   ' Anthony Chau-Sang Wong',
#   ' Eric Tsang',
#   127623,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.17,
#   'PG'),
#  ('Elite Squad',
#   '  Wagner Moura',
#   ' AndrÃƒÂ© Ramiro',
#   ' Caio Junqueira',
#   ' Milhem Cortaz',
#   106710,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.01,
#   'Not Rated'),
#  ('Haider',
#   '  Shahid Kapoor',
#   ' Tabu',
#   ' Shraddha Kapoor',
#   ' Kay Kay Menon',
#   56080,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.9,
#   'Not Rated'),
#  ('Sanjuro',
#   '  ToshirÃƒÂ´ Mifune',
#   ' Tatsuya Nakadai',
#   ' Keiju Kobayashi',
#   ' YÃƒÂ»nosuke ItÃƒÂ´',
#   39432,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   0,
#   'Not Rated'),
#  ('Elite Squad 2: The Enemy Within',
#   '  Wagner Moura',
#   ' Irandhir Santos',
#   ' AndrÃƒÂ© Ramiro',
#   ' Milhem Cortaz',
#   84713,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.1,
#   'R'),
#  ('Tae Guk Gi: The Brotherhood of War',
#   '  Jang Dong-Gun',
#   ' Won Bin',
#   ' Eun-ju Lee',
#   ' Hyeong-jin Kong',
#   40367,
#   'Action',
#   ' Drama',
#   ' War',
#   1.11,
#   'Not Rated'),
#  ('Andaz Apna Apna',
#   '  Aamir Khan',
#   ' Salman Khan',
#   ' Raveena Tandon',
#   ' Karisma Kapoor',
#   54199,
#   'Action',
#   ' Comedy',
#   ' Romance',
#   0,
#   'UA'),
#  ('Karthikeya 2',
#   '  Nikhil Siddharth',
#   ' Anupama Parameswaran',
#   ' Srinivasa Reddy',
#   ' Harsha Chemudu',
#   63201,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   0,
#   'Not Rated'),
#  ('Arjun Reddy',
#   '  Vijay Deverakonda',
#   ' Shalini Pandey',
#   ' Jia Sharma',
#   ' Kanchana',
#   26282,
#   'Action',
#   ' Drama',
#   ' Romance',
#   0,
#   'Not Rated'),
#  ('1: Nenokkadine',
#   '  Mahesh Babu',
#   ' Kriti Sanon',
#   ' Nassar',
#   ' Pradeep Singh Rawat',
#   45890,
#   'Action',
#   ' Thriller',
#   'None',
#   0,
#   'PG-13'),
#  ('The Breath',
#   '  Mete Horozoglu',
#   ' Ilker Kizmaz',
#   ' Baris Bagci',
#   ' Ãƒâ€“zgÃƒÂ¼r Eren KoÃƒÂ§',
#   34384,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   0,
#   'PG-13'),
#  ('Thor: Ragnarok',
#   '  Chris Hemsworth',
#   ' Tom Hiddleston',
#   ' Cate Blanchett',
#   ' Mark Ruffalo',
#   775783,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   315.06,
#   'PG-13'),
#  ('Avatar',
#   '  Sam Worthington',
#   ' Zoe Saldana',
#   ' Sigourney Weaver',
#   ' Michelle Rodriguez',
#   1341931,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   760.51,
#   'PG-13'),
#  ('Iron Man',
#   '  Robert Downey Jr.',
#   ' Gwyneth Paltrow',
#   ' Terrence Howard',
#   ' Jeff Bridges',
#   1082141,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   318.41,
#   'PG-13'),
#  ('Star Trek',
#   '  Chris Pine',
#   ' Zachary Quinto',
#   ' Simon Pegg',
#   ' Leonard Nimoy',
#   610293,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   257.73,
#   'R'),
#  ('Edge of Tomorrow',
#   '  Tom Cruise',
#   ' Emily Blunt',
#   ' Bill Paxton',
#   ' Brendan Gleeson',
#   699063,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   100.21,
#   'PG-13'),
#  ('Children of Men',
#   '  Julianne Moore',
#   ' Clive Owen',
#   ' Chiwetel Ejiofor',
#   ' Michael Caine',
#   511555,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   35.55,
#   'R'),
#  ('X-Men: Days of Future Past',
#   '  Patrick Stewart',
#   ' Ian McKellen',
#   ' Hugh Jackman',
#   ' James McAvoy',
#   724918,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   233.92,
#   'PG-13'),
#  ('District 9',
#   '  Sharlto Copley',
#   ' David James',
#   ' Jason Cope',
#   ' Nathalie Boltt',
#   694854,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   115.65,
#   'R'),
#  ('The Bourne Identity',
#   '  Franka Potente',
#   ' Matt Damon',
#   ' Chris Cooper',
#   ' Clive Owen',
#   558713,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   121.66,
#   'PG-13'),
#  ('The Blues Brothers',
#   '  John Belushi',
#   ' Dan Aykroyd',
#   ' Cab Calloway',
#   ' John Candy',
#   205833,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   57.23,
#   'TV-MA'),
#  ('Crouching Tiger Hidden Dragon',
#   '  Chow Yun-Fat',
#   ' Michelle Yeoh',
#   ' Ziyi Zhang',
#   ' Chang Chen',
#   275624,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   128.08,
#   'R'),
#  ('A Fistful of Dollars',
#   '  Clint Eastwood',
#   ' Gian Maria VolontÃƒÂ¨',
#   ' Marianne Koch',
#   ' Wolfgang Lukschy',
#   223383,
#   'Action',
#   ' Drama',
#   ' Western',
#   14.5,
#   'R'),
#  ('The Raid 2',
#   '  Iko Uwais',
#   ' Yayan Ruhian',
#   ' Arifin Putra',
#   ' Oka Antara',
#   127078,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   2.63,
#   'PG-13'),
#  ('The Wild Bunch',
#   '  William Holden',
#   ' Ernest Borgnine',
#   ' Robert Ryan',
#   ' Edmond OBrien',
#   87399,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   12.06,
#   'R'),
#  ('Hero',
#   '  Jet Li',
#   ' Tony Leung Chiu-wai',
#   ' Maggie Cheung',
#   ' Ziyi Zhang',
#   184413,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   53.71,
#   'Not Rated'),
#  ('Letters from Iwo Jima',
#   '  Ken Watanabe',
#   ' Kazunari Ninomiya',
#   ' Tsuyoshi Ihara',
#   ' Ryo Kase',
#   166250,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   13.76,
#   'PG'),
#  ('A Taxi Driver',
#   '  Song Kang-ho',
#   ' Thomas Kretschmann',
#   ' Hae-Jin Yoo',
#   ' Ryu Jun-Yeol',
#   27381,
#   'Action',
#   ' Drama',
#   ' History',
#   1.53,
#   'Not Rated'),
#  ('The Adventures of Robin Hood',
#   '  Errol Flynn',
#   ' Olivia de Havilland',
#   ' Basil Rathbone',
#   ' Claude Rains',
#   52802,
#   'Action',
#   ' Adventure',
#   ' Romance',
#   3.98,
#   'Not Rated'),
#  ('Baby (I)',
#   '  Akshay Kumar',
#   ' Danny Denzongpa',
#   ' Rana Daggubati',
#   ' Taapsee Pannu',
#   58806,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   0,
#   'Not Rated'),
#  ('Airlift',
#   '  Akshay Kumar',
#   ' Nimrat Kaur',
#   ' Kumud Mishra',
#   ' Prakash Belawadi',
#   57845,
#   'Action',
#   ' Drama',
#   ' History',
#   0,
#   'R'),
#  ('Vishwaroopam',
#   '  Pooja Kumar',
#   ' Miles Anderson',
#   ' Kamal Haasan',
#   ' Rahul Bose',
#   40547,
#   'Action',
#   ' Thriller',
#   'None',
#   0,
#   'PG-13'),
#  ('Everything Everywhere All at Once',
#   '  Michelle Yeoh',
#   ' Stephanie Hsu',
#   ' Jamie Lee Curtis',
#   ' Ke Huy Quan',
#   448150,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   72.86,
#   'Not Rated'),
#  ('The Batman',
#   '  Robert Pattinson',
#   ' ZoÃƒÂ« Kravitz',
#   ' Jeffrey Wright',
#   ' Colin Farrell',
#   699825,
#   'Action',
#   ' Crime',
#   ' Drama',
#   369.35,
#   'R'),
#  ('RRR',
#   '  N.T. Rama Rao Jr.',
#   ' Ram Charan',
#   ' Ajay Devgn',
#   ' Alia Bhatt',
#   150199,
#   'Action',
#   ' Drama',
#   'None',
#   14.5,
#   'R'),
#  ('The Gentlemen',
#   '  Matthew McConaughey',
#   ' Charlie Hunnam',
#   ' Michelle Dockery',
#   ' Jeremy Strong',
#   360399,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   36.47,
#   'R'),
#  ('All Quiet on the Western Front',
#   '  Felix Kammerer',
#   ' Albrecht Schuch',
#   ' Aaron Hilmer',
#   ' Moritz Klaus',
#   205281,
#   'Action',
#   ' Drama',
#   ' War',
#   0,
#   'PG-13'),
#  ('Drive (I)',
#   '  Ryan Gosling',
#   ' Carey Mulligan',
#   ' Bryan Cranston',
#   ' Albert Brooks',
#   664299,
#   'Action',
#   ' Drama',
#   'None',
#   35.06,
#   'PG-13'),
#  ('Rogue One: A Star Wars Story',
#   '  Felicity Jones',
#   ' Diego Luna',
#   ' Alan Tudyk',
#   ' Donnie Yen',
#   657650,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   532.18,
#   'R'),
#  ('Star Wars: Episode VII - The Force Awakens',
#   '  Daisy Ridley',
#   ' John Boyega',
#   ' Oscar Isaac',
#   ' Domhnall Gleeson',
#   947209,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   936.66,
#   'PG-13'),
#  ('Apocalypto',
#   '  Gerardo Taracena',
#   ' Raoul Max Trujillo',
#   ' Dalia HernÃƒÂ¡ndez',
#   ' Rudy Youngblood',
#   320106,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   50.87,
#   'PG'),
#  ('Dunkirk',
#   '  Fionn Whitehead',
#   ' Barry Keoghan',
#   ' Mark Rylance',
#   ' Tom Hardy',
#   682150,
#   'Action',
#   ' Drama',
#   ' History',
#   188.37,
#   'R'),
#  ('Ghostbusters',
#   '  Bill Murray',
#   ' Dan Aykroyd',
#   ' Sigourney Weaver',
#   ' Harold Ramis',
#   425653,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   238.63,
#   'R'),
#  ('Predator',
#   '  Arnold Schwarzenegger',
#   ' Carl Weathers',
#   ' Kevin Peter Hall',
#   ' Elpidia Carrillo',
#   434375,
#   'Action',
#   ' Adventure',
#   ' Horror',
#   59.74,
#   'PG-13'),
#  ('Hot Fuzz',
#   '  Simon Pegg',
#   ' Nick Frost',
#   ' Martin Freeman',
#   ' Bill Nighy',
#   517068,
#   'Action',
#   ' Comedy',
#   ' Mystery',
#   23.64,
#   'PG-13'),
#  ('Captain America: Civil War',
#   '  Chris Evans',
#   ' Robert Downey Jr.',
#   ' Scarlett Johansson',
#   ' Sebastian Stan',
#   811441,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   408.08,
#   'PG-13'),
#  ('Taken (I)',
#   '  Liam Neeson',
#   ' Maggie Grace',
#   ' Famke Janssen',
#   ' Leland Orser',
#   614638,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   145,
#   'PG-13'),
#  ('Skyfall',
#   '  Daniel Craig',
#   ' Javier Bardem',
#   ' Naomie Harris',
#   ' Judi Dench',
#   709652,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   304.36,
#   'PG-13'),
#  ('Captain America: The Winter Soldier',
#   '  Chris Evans',
#   ' Samuel L. Jackson',
#   ' Scarlett Johansson',
#   ' Robert Redford',
#   866461,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   259.77,
#   'PG'),
#  ('The Fugitive',
#   '  Harrison Ford',
#   ' Tommy Lee Jones',
#   ' Sela Ward',
#   ' Julianne Moore',
#   304568,
#   'Action',
#   ' Crime',
#   ' Drama',
#   183.88,
#   'PG-13'),
#  ('Captain Phillips',
#   '  Tom Hanks',
#   ' Barkhad Abdi',
#   ' Barkhad Abdirahman',
#   ' Catherine Keener',
#   473214,
#   'Action',
#   ' Biography',
#   ' Crime',
#   107.1,
#   'R'),
#  ('I Saw the Devil',
#   '  Lee Byung-hun',
#   ' Choi Min-sik',
#   ' Jeon Gook-hwan',
#   ' Ho-jin Chun',
#   137088,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.13,
#   'PG-13'),
#  ('The Last Samurai',
#   '  Tom Cruise',
#   ' Ken Watanabe',
#   ' Billy Connolly',
#   ' William Atherton',
#   452033,
#   'Action',
#   ' Drama',
#   'None',
#   111.11,
#   'PG-13'),
#  ('Serenity',
#   '  Nathan Fillion',
#   ' Gina Torres',
#   ' Chiwetel Ejiofor',
#   ' Alan Tudyk',
#   300284,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   25.51,
#   'R'),
#  ('Thirteen Lives',
#   '  Viggo Mortensen',
#   ' Colin Farrell',
#   ' Joel Edgerton',
#   ' Tom Bateman',
#   60640,
#   'Action',
#   ' Adventure',
#   ' Biography',
#   0,
#   'PG'),
#  ('The Fighter (I)',
#   '  Mark Wahlberg',
#   ' Christian Bale',
#   ' Amy Adams',
#   ' Melissa Leo',
#   376930,
#   'Action',
#   ' Biography',
#   ' Drama',
#   93.62,
#   'Not Rated'),
#  ('The Chaser',
#   '  Kim Yoon-seok',
#   ' Ha Jung-woo',
#   ' Yeong-hie Seo',
#   ' Kim Yoo-jeong',
#   69183,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  ('Aguirre the Wrath of God',
#   '  Klaus Kinski',
#   ' Ruy Guerra',
#   ' Helena Rojo',
#   ' Del Negro',
#   59107,
#   'Action',
#   ' Adventure',
#   ' Biography',
#   0,
#   'PG'),
#  ('The Killer',
#   '  Chow Yun-Fat',
#   ' Danny Lee',
#   ' Sally Yeh',
#   ' Kong Chu',
#   49583,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  ('Knockin on Heavens Door',
#   '  Til Schweiger',
#   ' Jan Josef Liefers',
#   ' Thierry van Werveke',
#   ' Moritz Bleibtreu',
#   32078,
#   'Action',
#   ' Crime',
#   ' Comedy',
#   0,
#   'PG-13'),
#  ('Minnal Murali',
#   '  Tovino Thomas',
#   ' Guru Somasundaram',
#   ' Aju Varghese',
#   ' Baiju',
#   31064,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'R'),
#  ('Avatar: The Way of Water',
#   '  Sam Worthington',
#   ' Zoe Saldana',
#   ' Sigourney Weaver',
#   ' Stephen Lang',
#   384846,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   659.68,
#   'PG-13'),
#  ('Kingsman: The Secret Service',
#   '  Colin Firth',
#   ' Taron Egerton',
#   ' Samuel L. Jackson',
#   ' Michael Caine',
#   686315,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   128.26,
#   'PG-13'),
#  ('Star Trek Into Darkness',
#   '  Chris Pine',
#   ' Zachary Quinto',
#   ' Zoe Saldana',
#   ' Benedict Cumberbatch',
#   489293,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   228.78,
#   'R'),
#  ('Mission: Impossible - Fallout',
#   '  Tom Cruise',
#   ' Henry Cavill',
#   ' Ving Rhames',
#   ' Simon Pegg',
#   344841,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   220.16,
#   'PG-13'),
#  ('Black Hawk Down',
#   '  Josh Hartnett',
#   ' Ewan McGregor',
#   ' Tom Sizemore',
#   ' Eric Bana',
#   407147,
#   'Action',
#   ' Drama',
#   ' History',
#   108.64,
#   'R'),
#  ('The Count of Monte Cristo',
#   '  Jim Caviezel',
#   ' Guy Pearce',
#   ' Christopher Adamson',
#   ' JB Blanc',
#   142602,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   54.23,
#   'R'),
#  ('3:10 to Yuma',
#   '  Russell Crowe',
#   ' Christian Bale',
#   ' Ben Foster',
#   ' Logan Lerman',
#   320222,
#   'Action',
#   ' Crime',
#   ' Drama',
#   53.61,
#   'PG'),
#  ('The Last of the Mohicans',
#   '  Daniel Day-Lewis',
#   ' Madeleine Stowe',
#   ' Russell Means',
#   ' Eric Schweig',
#   177524,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   75.51,
#   'PG-13'),
#  ('X-Men: First Class',
#   '  James McAvoy',
#   ' Michael Fassbender',
#   ' Jennifer Lawrence',
#   ' Kevin Bacon',
#   704696,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   146.41,
#   'Approved'),
#  ('Training Day',
#   '  Denzel Washington',
#   ' Ethan Hawke',
#   ' Scott Glenn',
#   ' Tom Berenger',
#   450131,
#   'Action',
#   ' Crime',
#   ' Drama',
#   76.63,
#   'R'),
#  ('The Dirty Dozen',
#   '  Lee Marvin',
#   ' Ernest Borgnine',
#   ' Charles Bronson',
#   ' John Cassavetes',
#   76085,
#   'Action',
#   ' Adventure',
#   ' War',
#   45.3,
#   'R'),
#  ('Man on Fire',
#   '  Denzel Washington',
#   ' Christopher Walken',
#   ' Dakota Fanning',
#   ' Radha Mitchell',
#   371975,
#   'Action',
#   ' Crime',
#   ' Drama',
#   77.91,
#   'Approved'),
#  ('First Blood',
#   '  Sylvester Stallone',
#   ' Brian Dennehy',
#   ' Richard Crenna',
#   ' Bill McKinney',
#   262244,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   47.21,
#   'R'),
#  ('The Magnificent Seven',
#   '  Yul Brynner',
#   ' Steve McQueen',
#   ' Charles Bronson',
#   ' Eli Wallach',
#   98239,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   4.91,
#   'R'),
#  ('Kung Fu Hustle',
#   '  Stephen Chow',
#   ' Wah Yuen',
#   ' Qiu Yuen',
#   ' Siu-Lung Leung',
#   144456,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   17.11,
#   'PG'),
#  ('The Boondock Saints',
#   '  Willem Dafoe',
#   ' Sean Patrick Flanery',
#   ' Norman Reedus',
#   ' David Della Rocco',
#   243402,
#   'Action',
#   ' Thriller',
#   'None',
#   0.03,
#   'G'),
#  ('Goldfinger',
#   '  Sean Connery',
#   ' Gert FrÃƒÂ¶be',
#   ' Honor Blackman',
#   ' Shirley Eaton',
#   195641,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   51.08,
#   'R'),
#  ('The Longest Day',
#   '  John Wayne',
#   ' Robert Ryan',
#   ' Richard Burton',
#   ' Henry Fonda',
#   57435,
#   'Action',
#   ' Drama',
#   ' History',
#   39.1,
#   'PG'),
#  ('Dirty Harry',
#   '  Clint Eastwood',
#   ' Andrew Robinson',
#   ' Harry Guardino',
#   ' Reni Santoni',
#   161710,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   35.9,
#   'PG-13'),
#  ('Star Trek II: The Wrath of Khan',
#   '  William Shatner',
#   ' Leonard Nimoy',
#   ' DeForest Kelley',
#   ' James Doohan',
#   125206,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   78.91,
#   'R'),
#  ('The Bourne Supremacy',
#   '  Matt Damon',
#   ' Franka Potente',
#   ' Joan Allen',
#   ' Brian Cox',
#   473471,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   176.24,
#   'R'),
#  ('Bonnie and Clyde',
#   '  Warren Beatty',
#   ' Faye Dunaway',
#   ' Michael J. Pollard',
#   ' Gene Hackman',
#   116465,
#   'Action',
#   ' Biography',
#   ' Crime',
#   ' ',
#   'PG'),
#  ('The French Connection',
#   '  Gene Hackman',
#   ' Roy Scheider',
#   ' Fernando Rey',
#   ' Tony Lo Bianco',
#   127590,
#   'Action',
#   ' Crime',
#   ' Drama',
#   15.63,
#   'R'),
#  ('Badlands',
#   '  Martin Sheen',
#   ' Sissy Spacek',
#   ' Warren Oates',
#   ' Ramon Bieri',
#   75304,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG'),
#  ('Run Lola Run',
#   '  Franka Potente',
#   ' Moritz Bleibtreu',
#   ' Herbert Knaup',
#   ' Nina Petri',
#   202327,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   7.27,
#   'Not Rated'),
#  ('Ponniyin Selvan: Part I',
#   '  Vikram',
#   ' Aishwarya Rai Bachchan',
#   ' Jayam Ravi',
#   ' Karthi',
#   33612,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  ('Key Largo',
#   '  Humphrey Bogart',
#   ' Edward G. Robinson',
#   ' Lauren Bacall',
#   ' Lionel Barrymore',
#   42546,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  ('The Man from Nowhere',
#   '  Won Bin',
#   ' Kim Sae-ron',
#   ' Kim Tae-hoon',
#   ' Kim Hee-won',
#   71950,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.01,
#   'PG'),
#  ('Hard Boiled',
#   '  Chow Yun-Fat',
#   ' Tony Leung Chiu-wai',
#   ' Teresa Mo',
#   ' Philip Chan',
#   52121,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'PG'),
#  ('Scarface',
#   '  Paul Muni',
#   ' Ann Dvorak',
#   ' Karen Morley',
#   ' Osgood Perkins',
#   29086,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  ('Joint Security Area',
#   '  Lee Yeong-ae',
#   ' Lee Byung-hun',
#   ' Song Kang-ho',
#   ' Kim Tae-woo',
#   32178,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   ' ',
#   'Not Rated'),
#  ('Eega',
#   '  Sudeep',
#   ' Nani',
#   ' Samantha Ruth Prabhu',
#   ' Hamsa Nandini',
#   25943,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  ('Udta Punjab',
#   '  Shahid Kapoor',
#   ' Alia Bhatt',
#   ' Kareena Kapoor',
#   ' Diljit Dosanjh',
#   31396,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  ('Raazi',
#   '  Alia Bhatt',
#   ' Vicky Kaushal',
#   ' Rajit Kapoor',
#   ' Shishir Sharma',
#   32273,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  ('Guy Ritchies The Covenant',
#   '  Jake Gyllenhaal',
#   ' Dar Salim',
#   ' Sean Sagar',
#   ' Jason Wong',
#   38663,
#   'Action',
#   ' Thriller',
#   ' War',
#   ' ',
#   'PG-13'),
#  ('Guardians of the Galaxy Vol. 2',
#   '  Chris Pratt',
#   ' Zoe Saldana',
#   ' Dave Bautista',
#   ' Vin Diesel',
#   714414,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   389.81,
#   'R'),
#  ('The Fifth Element',
#   '  Bruce Willis',
#   ' Milla Jovovich',
#   ' Gary Oldman',
#   ' Ian Holm',
#   485970,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   63.54,
#   'R'),
#  ('Sicario',
#   '  Emily Blunt',
#   ' Josh Brolin',
#   ' Benicio Del Toro',
#   ' Jon Bernthal',
#   446130,
#   'Action',
#   ' Crime',
#   ' Drama',
#   46.89,
#   'R'),
#  ('300',
#   '  Gerard Butler',
#   ' Lena Headey',
#   ' David Wenham',
#   ' Dominic West',
#   836319,
#   'Action',
#   ' Drama',
#   'None',
#   210.61,
#   'PG-13'),
#  ('Baby Driver',
#   '  Ansel Elgort',
#   ' Jon Bernthal',
#   ' Jon Hamm',
#   ' Eiza GonzÃƒÂ¡lez',
#   566453,
#   'Action',
#   ' Crime',
#   ' Drama',
#   107.83,
#   'R'),
#  ('Star Wars: Episode III - Revenge of the Sith',
#   '  Hayden Christensen',
#   ' Natalie Portman',
#   ' Ewan McGregor',
#   ' Samuel L. Jackson',
#   811691,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   380.26,
#   'R'),
#  ('Deadpool 2',
#   '  Ryan Reynolds',
#   ' Josh Brolin',
#   ' Morena Baccarin',
#   ' Julian Dennison',
#   605012,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   324.59,
#   'PG'),
#  ('Watchmen',
#   '  Jackie Earle Haley',
#   ' Patrick Wilson',
#   ' Carla Gugino',
#   ' Malin Akerman',
#   562747,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   107.51,
#   'PG'),
#  ('Harry Potter and the Half-Blood Prince',
#   '  Daniel Radcliffe',
#   ' Emma Watson',
#   ' Rupert Grint',
#   ' Michael Gambon',
#   564019,
#   'Action',
#   ' Adventure',
#   ' Family',
#   301.96,
#   'R'),
#  ('RoboCop',
#   '  Peter Weller',
#   ' Nancy Allen',
#   ' Dan OHerlihy',
#   ' Ronny Cox',
#   267411,
#   'Action',
#   ' Crime',
#   ' Sci-Fi',
#   53.42,
#   'R'),
#  ('Train to Busan',
#   '  Gong Yoo',
#   ' Jung Yu-mi',
#   ' Ma Dong-seok',
#   ' Su-an Kim',
#   234527,
#   'Action',
#   ' Horror',
#   ' Thriller',
#   2.13,
#   'PG-13'),
#  ('The Warriors',
#   '  Michael Beck',
#   ' James Remar',
#   ' Dorsey Wright',
#   ' Brian Tyler',
#   106035,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   22.49,
#   'PG'),
#  ('Creed (II)',
#   '  Michael B. Jordan',
#   ' Sylvester Stallone',
#   ' Tessa Thompson',
#   ' Phylicia Rashad',
#   296575,
#   'Action',
#   ' Drama',
#   ' Sport',
#   109.77,
#   'R'),
#  ('The Road Warrior',
#   '  Mel Gibson',
#   ' Bruce Spence',
#   ' Michael Preston',
#   ' Max Phipps',
#   186089,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   12.47,
#   'R'),
#  ('Kick-Ass',
#   '  Aaron Taylor-Johnson',
#   ' Nicolas Cage',
#   ' ChloÃƒÂ« Grace Moretz',
#   ' Garrett M. Brown',
#   575103,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   48.07,
#   'R'),
#  ('Falling Down',
#   '  Michael Douglas',
#   ' Robert Duvall',
#   ' Barbara Hershey',
#   ' Rachel Ticotin',
#   196844,
#   'Action',
#   ' Crime',
#   ' Drama',
#   40.9,
#   'PG-13'),
#  ('Zombieland',
#   '  Jesse Eisenberg',
#   ' Emma Stone',
#   ' Woody Harrelson',
#   ' Abigail Breslin',
#   595210,
#   'Action',
#   ' Comedy',
#   ' Horror',
#   75.59,
#   'PG-13'),
#  ('Minority Report',
#   '  Tom Cruise',
#   ' Colin Farrell',
#   ' Samantha Morton',
#   ' Max von Sydow',
#   565154,
#   'Action',
#   ' Crime',
#   ' Mystery',
#   132.07,
#   'PG-13'),
#  ('Sherlock Holmes',
#   '  Robert Downey Jr.',
#   ' Jude Law',
#   ' Rachel McAdams',
#   ' Mark Strong',
#   648103,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   209.03,
#   'R'),
#  ('Rise of the Planet of the Apes',
#   '  James Franco',
#   ' Andy Serkis',
#   ' Freida Pinto',
#   ' Karin Konoval',
#   540181,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   176.76,
#   'PG-13'),
#  ('The Raid: Redemption',
#   '  Iko Uwais',
#   ' Ananda George',
#   ' Ray Sahetapy',
#   ' Donny Alamsyah',
#   210125,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   4.11,
#   'M'),
#  ('Dawn of the Planet of the Apes',
#   '  Gary Oldman',
#   ' Keri Russell',
#   ' Andy Serkis',
#   ' Kodi Smit-McPhee',
#   451621,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   208.55,
#   'R'),
#  ('Where Eagles Dare',
#   '  Richard Burton',
#   ' Clint Eastwood',
#   ' Mary Ure',
#   ' Patrick Wymark',
#   60486,
#   'Action',
#   ' Adventure',
#   ' War',
#   ' ',
#   'R'),
#  ('End of Watch',
#   '  Jake Gyllenhaal',
#   ' Michael PeÃƒÂ±a',
#   ' Anna Kendrick',
#   ' America Ferrera',
#   256703,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   41,
#   'Not Rated'),
#  ('Lethal Weapon',
#   '  Mel Gibson',
#   ' Danny Glover',
#   ' Gary Busey',
#   ' Mitchell Ryan',
#   266294,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   65.21,
#   'R'),
#  ('Battle Royale',
#   '  Tatsuya Fujiwara',
#   ' Aki Maeda',
#   ' TarÃƒÂ´ Yamamoto',
#   ' Chiaki Kuriyama',
#   188311,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  ('Enter the Dragon',
#   '  Bruce Lee',
#   ' John Saxon',
#   ' Jim Kelly',
#   ' Ahna Capri',
#   107696,
#   'Action',
#   ' Crime',
#   ' Drama',
#   25,
#   'PG-13'),
#  ('Die Hard with a Vengeance',
#   '  Bruce Willis',
#   ' Jeremy Irons',
#   ' Samuel L. Jackson',
#   ' Graham Greene',
#   395889,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   100.01,
#   'R'),
#  ('Star Trek: First Contact',
#   '  Patrick Stewart',
#   ' Jonathan Frakes',
#   ' Brent Spiner',
#   ' LeVar Burton',
#   128791,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   92,
#   'PG-13'),
#  ('Hotel Mumbai',
#   '  Dev Patel',
#   ' Armie Hammer',
#   ' Nazanin Boniadi',
#   ' Anupam Kher',
#   66992,
#   'Action',
#   ' Drama',
#   ' History',
#   9.65,
#   'PG'),
#  ('Only the Brave',
#   '  Josh Brolin',
#   ' Miles Teller',
#   ' Jeff Bridges',
#   ' Jennifer Connelly',
#   73063,
#   'Action',
#   ' Biography',
#   ' Drama',
#   18.34,
#   'R'),
#  ('Escape from Alcatraz',
#   '  Clint Eastwood',
#   ' Patrick McGoohan',
#   ' Roberts Blossom',
#   ' Jack Thibeau',
#   141730,
#   'Action',
#   ' Biography',
#   ' Crime',
#   43,
#   'R'),
#  ('United 93',
#   '  David Alan Basche',
#   ' Olivia Thirlby',
#   ' Liza ColÃƒÂ³n-Zayas',
#   ' J.J. Johnson',
#   108396,
#   'Action',
#   ' Drama',
#   ' History',
#   31.57,
#   'R'),
#  ('The Taking of Pelham One Two Three',
#   '  Walter Matthau',
#   ' Robert Shaw',
#   ' Martin Balsam',
#   ' Hector Elizondo',
#   32922,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   2.49,
#   'PG-13'),
#  ('Fearless',
#   '  Jet Li',
#   ' Li Sun',
#   ' Yong Dong',
#   ' Yun Qu',
#   77409,
#   'Action',
#   ' Biography',
#   ' Drama',
#   24.63,
#   'TV-MA'),
#  ('Pushpa: The Rise - Part 1',
#   '  Allu Arjun',
#   ' Fahadh Faasil',
#   ' Rashmika Mandanna',
#   ' Jagadeesh Prathap Bandari',
#   80417,
#   'Action',
#   ' Crime',
#   ' Drama',
#   '  ',
#   'PG-13'),
#  ('Ludo',
#   '  Pankaj Tripathi',
#   ' Abhishek Bachchan',
#   ' Rajkummar Rao',
#   ' Fatima Sana Shaikh',
#   41207,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'A'),
#  ('Cell 211',
#   '  Luis Tosar',
#   ' Alberto Ammann',
#   ' Antonio Resines',
#   ' Manuel MorÃƒÂ³n',
#   69164,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  ('Mortal World',
#   '  Ahmet MÃƒÂ¼mtaz Taylan',
#   ' Alper Kul',
#   ' Sarp Apak',
#   ' Irem Sak',
#   28153,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'R'),
#  ('Its a Mad Mad Mad Mad World',
#   '  Spencer Tracy',
#   ' Milton Berle',
#   ' Ethel Merman',
#   ' Mickey Rooney',
#   43812,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   46.3,
#   'PG-13'),
#  ('Indiana Jones and the Temple of Doom',
#   '  Harrison Ford',
#   ' Kate Capshaw',
#   ' Ke Huy Quan',
#   ' Amrish Puri',
#   503406,
#   'Action',
#   ' Adventure',
#   'None',
#   179.87,
#   'PG-13'),
#  ('Lone Survivor',
#   '  Mark Wahlberg',
#   ' Taylor Kitsch',
#   ' Emile Hirsch',
#   ' Ben Foster',
#   295369,
#   'Action',
#   ' Biography',
#   ' Drama',
#   125.1,
#   'PG-13'),
#  ('Batman',
#   '  Michael Keaton',
#   ' Jack Nicholson',
#   ' Kim Basinger',
#   ' Robert Wuhl',
#   387228,
#   'Action',
#   ' Adventure',
#   'None',
#   251.19,
#   'R'),
#  ('Scott Pilgrim vs. the World',
#   '  Michael Cera',
#   ' Mary Elizabeth Winstead',
#   ' Kieran Culkin',
#   ' Anna Kendrick',
#   441598,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   31.49,
#   'PG-13'),
#  ('Harry Potter and the Order of the Phoenix',
#   '  Daniel Radcliffe',
#   ' Emma Watson',
#   ' Rupert Grint',
#   ' Brendan Gleeson',
#   600982,
#   'Action',
#   ' Adventure',
#   ' Family',
#   292,
#   'R'),
#  ('Fury',
#   '  Brad Pitt',
#   ' Shia LaBeouf',
#   ' Logan Lerman',
#   ' Michael PeÃƒÂ±a',
#   512217,
#   'Action',
#   ' Drama',
#   ' War',
#   85.82,
#   'R'),
#  ('The Hunger Games: Catching Fire',
#   '  Jennifer Lawrence',
#   ' Josh Hutcherson',
#   ' Liam Hemsworth',
#   ' Philip Seymour Hoffman',
#   683641,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   424.67,
#   'R'),
#  ('Upgrade',
#   '  Logan Marshall-Green',
#   ' Melanie Vallejo',
#   ' Steve Danielsen',
#   ' Abby Craden',
#   192971,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   11.98,
#   'PG-13'),
#  ('The Crow',
#   '  Brandon Lee',
#   ' Michael Wincott',
#   ' Rochelle Davis',
#   ' Ernie Hudson',
#   190335,
#   'Action',
#   ' Crime',
#   ' Drama',
#   50.69,
#   'PG-13'),
#  ('Total Recall',
#   '  Arnold Schwarzenegger',
#   ' Sharon Stone',
#   ' Michael Ironside',
#   ' Rachel Ticotin',
#   340726,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   119.39,
#   'R'),
#  ('Doctor Strange',
#   '  Benedict Cumberbatch',
#   ' Chiwetel Ejiofor',
#   ' Rachel McAdams',
#   ' Benedict Wong',
#   765484,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   232.64,
#   'R'),
#  ('Master and Commander: The Far Side of the World',
#   '  Russell Crowe',
#   ' Paul Bettany',
#   ' Billy Boyd',
#   ' James DArcy',
#   228610,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   93.93,
#   'Not Rated'),
#  ('Collateral',
#   '  Tom Cruise',
#   ' Jamie Foxx',
#   ' Jada Pinkett Smith',
#   ' Mark Ruffalo',
#   415928,
#   'Action',
#   ' Crime',
#   ' Drama',
#   101.01,
#   'PG-13'),
#  ('Enemy at the Gates',
#   '  Jude Law',
#   ' Ed Harris',
#   ' Joseph Fiennes',
#   ' Rachel Weisz',
#   268921,
#   'Action',
#   ' Drama',
#   ' War',
#   51.4,
#   'R'),
#  ('Riders of Justice',
#   '  Mads Mikkelsen',
#   ' Nikolaj Lie Kaas',
#   ' Andrea Heick Gadeberg',
#   ' Lars Brygmann',
#   55023,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'PG'),
#  ('Source Code',
#   '  Jake Gyllenhaal',
#   ' Michelle Monaghan',
#   ' Vera Farmiga',
#   ' Jeffrey Wright',
#   530897,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   54.71,
#   'R'),
#  ('Munich',
#   '  Eric Bana',
#   ' Daniel Craig',
#   ' Marie-JosÃƒÂ©e Croze',
#   ' CiarÃƒÂ¡n Hinds',
#   232071,
#   'Action',
#   ' Drama',
#   ' History',
#   47.4,
#   'R'),
#  ('The Hunt for Red October',
#   '  Sean Connery',
#   ' Alec Baldwin',
#   ' Scott Glenn',
#   ' Sam Neill',
#   206709,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   122.01,
#   'Not Rated'),
#  ('Grindhouse',
#   '  Kurt Russell',
#   ' Rose McGowan',
#   ' Danny Trejo',
#   ' ZoÃƒÂ« Bell',
#   187475,
#   'Action',
#   ' Horror',
#   ' Thriller',
#   25.04,
#   'G'),
#  ('Midnight Run',
#   '  Robert De Niro',
#   ' Charles Grodin',
#   ' Yaphet Kotto',
#   ' John Ashton',
#   89429,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   38.41,
#   'R'),
#  ('The Guns of Navarone',
#   '  David Niven',
#   ' Gregory Peck',
#   ' Anthony Quinn',
#   ' Anthony Quayle',
#   53175,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   28.9,
#   'PG-13'),
#  ('Tora! Tora! Tora!',
#   '  Martin Balsam',
#   ' SÃƒÂ´ Yamamura',
#   ' Jason Robards',
#   ' Joseph Cotten',
#   35690,
#   'Action',
#   ' Drama',
#   ' History',
#   29.55,
#   'R'),
#  ('Headhunters',
#   '  Aksel Hennie',
#   ' SynnÃƒÂ¸ve Macody Lund',
#   ' Nikolaj Coster-Waldau',
#   ' Julie R. ÃƒËœlgaard',
#   104335,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   1.2,
#   'R'),
#  ('Police Story',
#   '  Jackie Chan',
#   ' Maggie Cheung',
#   ' Brigitte Lin',
#   ' Yuen Chor',
#   39050,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0.11,
#   'Not Rated'),
#  ('Ip Man 2',
#   '  Donnie Yen',
#   ' Xiaoming Huang',
#   ' Sammo Kam-Bo Hung',
#   ' Lynn Xiong',
#   108088,
#   'Action',
#   ' Biography',
#   ' Drama',
#   0.21,
#   'PG-13'),
#  ('13 Assassins',
#   '  KÃƒÂ´ji Yakusho',
#   ' Takayuki Yamada',
#   ' YÃƒÂ»suke Iseya',
#   ' Ikki Sawamura',
#   66926,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   0.8,
#   'Not Rated'),
#  ('New World',
#   '  Lee Jung-jae',
#   ' Choi Min-sik',
#   ' Hwang Jung-min',
#   ' Park Sung-woong',
#   25009,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.46,
#   'R'),
#  ('House of Flying Daggers',
#   '  Ziyi Zhang',
#   ' Takeshi Kaneshiro',
#   ' Andy Lau',
#   ' Dandan Song',
#   114297,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   11.05,
#   'Not Rated'),
#  ('A Bittersweet Life',
#   '  Lee Byung-hun',
#   ' Shin Min-a',
#   ' Yeong-cheol Kim',
#   ' Hwang Jung-min',
#   41474,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  ('The Legend of Drunken Master',
#   '  Jackie Chan',
#   ' Ho-Sung Pak',
#   ' Lung Ti',
#   ' Anita Mui',
#   47461,
#   'Action',
#   ' Comedy',
#   'None',
#   11.55,
#   'R'),
#  ('Tanhaji: The Unsung Warrior',
#   '  Ajay Devgn',
#   ' Saif Ali Khan',
#   ' Sharad Kelkar',
#   ' Kajol',
#   34214,
#   'Action',
#   ' Biography',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  ('The Blind Swordsman: Zatoichi',
#   '  Takeshi Kitano',
#   ' Tadanobu Asano',
#   ' Yui Natsukawa',
#   ' Michiyo Yasuda',
#   50530,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0.85,
#   'Not Rated'),
#  ('Mesrine: Killer Instinct',
#   '  Vincent Cassel',
#   ' CÃƒÂ©cile de France',
#   ' GÃƒÂ©rard Depardieu',
#   ' Gilles Lellouche',
#   34552,
#   'Action',
#   ' Biography',
#   ' Crime',
#   0.55,
#   'Not Rated'),
#  ('Jodhaa Akbar',
#   '  Hrithik Roshan',
#   ' Aishwarya Rai Bachchan',
#   ' Sonu Sood',
#   ' Poonam Sinha',
#   33611,
#   'Action',
#   ' Drama',
#   ' History',
#   3.44,
#   'R'),
#  ('Delhi Belly',
#   '  Imran Khan',
#   ' Vir Das',
#   ' Kunaal Roy Kapur',
#   ' Shenaz Treasury',
#   30953,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   1.53,
#   'R'),
#  ('Mersal',
#   '  Joseph Vijay',
#   ' Nithya Menen',
#   ' S.J. Suryah',
#   ' Samantha Ruth Prabhu',
#   36201,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'R'),
#  ('To Strike',
#   '  Shaan Shahid',
#   ' Hamza Ali Abbasi',
#   ' Shamoon Abbasi',
#   ' Ayesha Khan',
#   29927,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  ('John Wick',
#   '  Keanu Reeves',
#   ' Michael Nyqvist',
#   ' Alfie Allen',
#   ' Willem Dafoe',
#   693733,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   43.04,
#   'PG-13'),
#  ('John Wick: Chapter 3 - Parabellum',
#   '  Keanu Reeves',
#   ' Halle Berry',
#   ' Ian McShane',
#   ' Laurence Fishburne',
#   390068,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   171.02,
#   'R'),
#  ('John Wick: Chapter 2',
#   '  Keanu Reeves',
#   ' Riccardo Scamarcio',
#   ' Ian McShane',
#   ' Ruby Rose',
#   476647,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   92.03,
#   'PG-13'),
#  ('Shang-Chi and the Legend of the Ten Rings',
#   '  Simu Liu',
#   ' Awkwafina',
#   ' Tony Leung Chiu-wai',
#   ' Ben Kingsley',
#   402309,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   224.54,
#   'PG-13'),
#  ('Spider-Man: Homecoming',
#   '  Tom Holland',
#   ' Michael Keaton',
#   ' Robert Downey Jr.',
#   ' Marisa Tomei',
#   679799,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   334.2,
#   'PG-13'),
#  ('Nobody (I)',
#   '  Bob Odenkirk',
#   ' Aleksey Serebryakov',
#   ' Connie Nielsen',
#   ' Christopher Lloyd',
#   285860,
#   'Action',
#   ' Crime',
#   ' Drama',
#   27.27,
#   'PG-13'),
#  ('Spider-Man',
#   '  Tobey Maguire',
#   ' Kirsten Dunst',
#   ' Willem Dafoe',
#   ' James Franco',
#   838102,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   403.71,
#   'R'),
#  ('Ready Player One',
#   '  Tye Sheridan',
#   ' Olivia Cooke',
#   ' Ben Mendelsohn',
#   ' Lena Waithe',
#   453860,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   137.69,
#   'PG-13'),
#  ('Mission: Impossible - Rogue Nation',
#   '  Tom Cruise',
#   ' Rebecca Ferguson',
#   ' Jeremy Renner',
#   ' Simon Pegg',
#   383866,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   195.04,
#   'PG'),
#  ('Mission: Impossible - Ghost Protocol',
#   '  Tom Cruise',
#   ' Jeremy Renner',
#   ' Simon Pegg',
#   ' Paula Patton',
#   501423,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   209.4,
#   'PG-13'),
#  ('The Last Duel',
#   '  Matt Damon',
#   ' Adam Driver',
#   ' Jodie Comer',
#   ' Harriet Walter',
#   165559,
#   'Action',
#   ' Drama',
#   ' History',
#   10.85,
#   'PG-13'),
#  ('Wonder Woman',
#   '  Gal Gadot',
#   ' Chris Pine',
#   ' Robin Wright',
#   ' Lucy Davis',
#   674284,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   412.56,
#   'R'),
#  ('Superman',
#   '  Christopher Reeve',
#   ' Margot Kidder',
#   ' Gene Hackman',
#   ' Marlon Brando',
#   180583,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   134.22,
#   'R'),
#  ('Spider-Man: Far from Home',
#   '  Tom Holland',
#   ' Samuel L. Jackson',
#   ' Jake Gyllenhaal',
#   ' Marisa Tomei',
#   515676,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   390.53,
#   'R'),
#  ('Spider-Man 2',
#   '  Tobey Maguire',
#   ' Kirsten Dunst',
#   ' Alfred Molina',
#   ' James Franco',
#   672203,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   373.59,
#   'R'),
#  ('The Rock',
#   '  Sean Connery',
#   ' Nicolas Cage',
#   ' Ed Harris',
#   ' John Spencer',
#   346907,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   134.07,
#   'R'),
#  ('Predestination (I)',
#   '  Ethan Hawke',
#   ' Sarah Snook',
#   ' Noah Taylor',
#   ' Madeleine West',
#   291165,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   0.07,
#   'PG-13'),
#  ('Looper',
#   '  Joseph Gordon-Levitt',
#   ' Bruce Willis',
#   ' Emily Blunt',
#   ' Paul Dano',
#   586887,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   66.49,
#   'PG-13'),
#  ('A History of Violence',
#   '  Viggo Mortensen',
#   ' Maria Bello',
#   ' Ed Harris',
#   ' William Hurt',
#   244637,
#   'Action',
#   ' Crime',
#   ' Drama',
#   31.49,
#   'PG'),
#  ('Law Abiding Citizen',
#   '  Gerard Butler',
#   ' Jamie Foxx',
#   ' Leslie Bibb',
#   ' Colm Meaney',
#   306524,
#   'Action',
#   ' Crime',
#   ' Drama',
#   73.34,
#   'PG-13'),
#  ('X2: X-Men United',
#   '  Patrick Stewart',
#   ' Hugh Jackman',
#   ' Halle Berry',
#   ' Ian McKellen',
#   560786,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   214.95,
#   'M/PG'),
#  ('War for the Planet of the Apes',
#   '  Andy Serkis',
#   ' Woody Harrelson',
#   ' Steve Zahn',
#   ' Karin Konoval',
#   266611,
#   'Action',
#   ' Adventure',
# ...
#   ' Brendan Gleeson',
#   ' Chris Messina',
#   58557,
#   'Action',
#   ' Crime',
#   ' Drama',
#   10.38,
#   'R'),
#  ('Darkman',
#   '  Liam Neeson',
#   ' Frances McDormand',
#   ' Colin Friels',
#   ' Larry Drake',
#   67131,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   33.88,
#   'R'),
#  ('Kill List',
#   '  Neil Maskell',
#   ' MyAnna Buring',
#   ' Harry Simpson',
#   ' Michael Smiley',
#   42776,
#   'Action',
#   ' Crime',
#   ' Horror',
#   0.03,
#   'PG'),
#  ('Act of Valor',
#   '  Alex Veadov',
#   ' Roselyn Sanchez',
#   ' Nestor Serrano',
#   ' Rorke Denver',
#   70351,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   70.01,
#   'R'),
#  ('The Siege',
#   '  Denzel Washington',
#   ' Bruce Willis',
#   ' Annette Bening',
#   ' Tony Shalhoub',
#   75341,
#   'Action',
#   ' Thriller',
#   'None',
#   40.98,
#   'PG-13'),
#  ('Lets Be Cops',
#   '  Jake Johnson',
#   ' Damon Wayans Jr.',
#   ' Rob Riggle',
#   ' Nina Dobrev',
#   137116,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   82.39,
#   'R'),
#  ('Daybreakers',
#   '  Ethan Hawke',
#   ' Willem Dafoe',
#   ' Sam Neill',
#   ' Harriet Minto-Day',
#   131647,
#   'Action',
#   ' Horror',
#   ' Sci-Fi',
#   30.1,
#   'R'),
#  ('The Omega Man',
#   '  Charlton Heston',
#   ' Anthony Zerbe',
#   ' Rosalind Cash',
#   ' Paul Koslo',
#   32780,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   8.72,
#   'R'),
#  ('Shaft',
#   '  Samuel L. Jackson',
#   ' Jessie T. Usher',
#   ' Richard Roundtree',
#   ' Regina Hall',
#   56020,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   21.36,
#   'R'),
#  ('Snitch (I)',
#   '  Dwayne Johnson',
#   ' Susan Sarandon',
#   ' Jon Bernthal',
#   ' Rafi Gavron',
#   90368,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   42.93,
#   'R'),
#  ('Contraband',
#   '  Mark Wahlberg',
#   ' Giovanni Ribisi',
#   ' Kate Beckinsale',
#   ' Robert Wahlberg',
#   124634,
#   'Action',
#   ' Crime',
#   ' Drama',
#   66.53,
#   'R'),
#  ('The Prophecy',
#   '  Christopher Walken',
#   ' Elias Koteas',
#   ' Virginia Madsen',
#   ' Eric Stoltz',
#   32169,
#   'Action',
#   ' Crime',
#   ' Drama',
#   16.12,
#   'R'),
#  ('The Rover',
#   '  Guy Pearce',
#   ' Robert Pattinson',
#   ' Scoot McNairy',
#   ' David Field',
#   49778,
#   'Action',
#   ' Crime',
#   ' Drama',
#   1.11,
#   'R'),
#  ('Blood Father',
#   '  Mel Gibson',
#   ' Erin Moriarty',
#   ' Diego Luna',
#   ' Michael Parks',
#   65965,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  ('Just Cause',
#   '  Sean Connery',
#   ' Laurence Fishburne',
#   ' Kate Capshaw',
#   ' Blair Underwood',
#   28245,
#   'Action',
#   ' Crime',
#   ' Drama',
#   36.85,
#   'R'),
#  ('Black Death',
#   '  Eddie Redmayne',
#   ' Sean Bean',
#   ' Carice van Houten',
#   ' Kimberley Nixon',
#   49676,
#   'Action',
#   ' Drama',
#   ' History',
#   0.02,
#   'R'),
#  ('Dead Man Down',
#   '  Colin Farrell',
#   ' Noomi Rapace',
#   ' Dominic Cooper',
#   ' Terrence Howard',
#   69094,
#   'Action',
#   ' Crime',
#   ' Drama',
#   10.88,
#   'R'),
#  ('Lock Up',
#   '  Sylvester Stallone',
#   ' Donald Sutherland',
#   ' John Amos',
#   ' Sonny Landham',
#   44680,
#   'Action',
#   ' Crime',
#   ' Drama',
#   22.1,
#   'PG-13'),
#  ('Last Man Standing',
#   '  Bruce Willis',
#   ' Bruce Dern',
#   ' William Sanderson',
#   ' Christopher Walken',
#   59505,
#   'Action',
#   ' Crime',
#   ' Drama',
#   17.6,
#   'R'),
#  ('Black and Blue (I)',
#   '  Naomie Harris',
#   ' Tyrese Gibson',
#   ' Frank Grillo',
#   ' Mike Colter',
#   25207,
#   'Action',
#   ' Thriller',
#   'None',
#   22.06,
#   'R'),
#  ('Basic',
#   '  John Travolta',
#   ' Samuel L. Jackson',
#   ' Connie Nielsen',
#   ' Tim Daly',
#   64501,
#   'Action',
#   ' Crime',
#   ' Drama',
#   26.54,
#   'R'),
#  ('Son of a Gun',
#   '  Ewan McGregor',
#   ' Brenton Thwaites',
#   ' Alicia Vikander',
#   ' Brendan Kerkvliet',
#   28845,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'R'),
#  ('From Paris with Love',
#   '  John Travolta',
#   ' Jonathan Rhys Meyers',
#   ' Kasia Smutniak',
#   ' Richard Durden',
#   119346,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   23.98,
#   'R'),
#  ('Blood Work',
#   '  Clint Eastwood',
#   ' Jeff Daniels',
#   ' Anjelica Huston',
#   ' Wanda De Jesus',
#   46351,
#   'Action',
#   ' Crime',
#   ' Drama',
#   26.2,
#   'R'),
#  ('How I Live Now',
#   '  Saoirse Ronan',
#   ' Tom Holland',
#   ' George MacKay',
#   ' Harley Bird',
#   31213,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   0.06,
#   'Not Rated'),
#  ('Ned Kelly',
#   '  Heath Ledger',
#   ' Orlando Bloom',
#   ' Geoffrey Rush',
#   ' Naomi Watts',
#   27565,
#   'Action',
#   ' Adventure',
#   ' Biography',
#   0.07,
#   'PG-13'),
#  ('Night Watch',
#   '  Konstantin Khabenskiy',
#   ' Vladimir Menshov',
#   ' Mariya Poroshina',
#   ' Valeriy Zolotukhin',
#   54670,
#   'Action',
#   ' Fantasy',
#   ' Horror',
#   1.49,
#   'R'),
#  ('Day Watch',
#   '  Konstantin Khabenskiy',
#   ' Mariya Poroshina',
#   ' Vladimir Menshov',
#   ' Galina Tyunina',
#   34900,
#   'Action',
#   ' Fantasy',
#   ' Horror',
#   0.45,
#   'PG-13'),
#  ('Redirected',
#   '  Vinnie Jones',
#   ' Scot Williams',
#   ' Gil Darnell',
#   ' Oliver Jackson',
#   34322,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  ('Fast X',
#   '  Vin Diesel',
#   ' Michelle Rodriguez',
#   ' Jason Statham',
#   ' Jordana Brewster',
#   30775,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  ('Operation Fortune: Ruse de Guerre',
#   '  Jason Statham',
#   ' Aubrey Plaza',
#   ' Cary Elwes',
#   ' Hugh Grant',
#   55109,
#   'Action',
#   ' Comedy',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  ('King Arthur',
#   '  Clive Owen',
#   ' Stephen Dillane',
#   ' Keira Knightley',
#   ' Ioan Gruffudd',
#   171716,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   51.88,
#   'R'),
#  ('Black Adam',
#   '  Dwayne Johnson',
#   ' Aldis Hodge',
#   ' Pierce Brosnan',
#   ' Noah Centineo',
#   246159,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   168.15,
#   'PG-13'),
#  ('Eternals',
#   '  Gemma Chan',
#   ' Richard Madden',
#   ' Angelina Jolie',
#   ' Salma Hayek',
#   358976,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   164.87,
#   'PG-13'),
#  ('Dune',
#   '  Kyle MacLachlan',
#   ' Virginia Madsen',
#   ' Francesca Annis',
#   ' Leonardo Cimino',
#   165723,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   30.93,
#   'PG-13'),
#  ('Uncharted',
#   '  Tom Holland',
#   ' Mark Wahlberg',
#   ' Antonio Banderas',
#   ' Sophia Ali',
#   227887,
#   'Action',
#   ' Adventure',
#   'None',
#   148.65,
#   'PG-13'),
#  ('The Kings Man',
#   '  Ralph Fiennes',
#   ' Gemma Arterton',
#   ' Rhys Ifans',
#   ' Harris Dickinson',
#   157898,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   37.18,
#   'PG'),
#  ('Spider-Man 3',
#   '  Tobey Maguire',
#   ' Kirsten Dunst',
#   ' Topher Grace',
#   ' Thomas Haden Church',
#   607525,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   336.53,
#   'PG-13'),
#  ('Red Notice',
#   '  Dwayne Johnson',
#   ' Ryan Reynolds',
#   ' Gal Gadot',
#   ' Ritu Arya',
#   290777,
#   'Action',
#   ' Comedy',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  ('Godzilla vs. Kong',
#   '  Alexander SkarsgÃƒÂ¥rd',
#   ' Millie Bobby Brown',
#   ' Rebecca Hall',
#   ' Brian Tyree Henry',
#   219751,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   100.92,
#   'R'),
#  ('Central Intelligence',
#   '  Dwayne Johnson',
#   ' Kevin Hart',
#   ' Danielle Nicolet',
#   ' Amy Ryan',
#   200176,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   127.44,
#   'TV-MA'),
#  ('Sky High',
#   '  Kurt Russell',
#   ' Kelly Preston',
#   ' Michael Angarano',
#   ' Danielle Panabaker',
#   90767,
#   'Action',
#   ' Comedy',
#   ' Family',
#   63.95,
#   'PG-13'),
#  ('Terminator Genisys',
#   '  Arnold Schwarzenegger',
#   ' Jason Clarke',
#   ' Emilia Clarke',
#   ' Jai Courtney',
#   284397,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   89.76,
#   'PG-13'),
#  ('Oceans Eight',
#   '  Sandra Bullock',
#   ' Cate Blanchett',
#   ' Anne Hathaway',
#   ' Mindy Kaling',
#   229216,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   140.22,
#   'R'),
#  ('The Last Stand',
#   '  Arnold Schwarzenegger',
#   ' Forest Whitaker',
#   ' Johnny Knoxville',
#   ' Rodrigo Santoro',
#   142327,
#   'Action',
#   ' Thriller',
#   ' Western',
#   12.05,
#   'PG-13'),
#  ('Polar (I)',
#   '  Mads Mikkelsen',
#   ' Vanessa Hudgens',
#   ' Katheryn Winnick',
#   ' Fei Ren',
#   94190,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'R'),
#  ('Tomb Raider',
#   '  Alicia Vikander',
#   ' Dominic West',
#   ' Walton Goggins',
#   ' Daniel Wu',
#   219623,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   58.25,
#   'PG-13'),
#  ('White House Down',
#   '  Channing Tatum',
#   ' Jamie Foxx',
#   ' Maggie Gyllenhaal',
#   ' Jason Clarke',
#   228450,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   73.1,
#   'PG-13'),
#  ('Terminator 3: Rise of the Machines',
#   '  Arnold Schwarzenegger',
#   ' Nick Stahl',
#   ' Kristanna Loken',
#   ' Claire Danes',
#   407694,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   150.37,
#   'PG'),
#  ('Ghost in the Shell',
#   '  Scarlett Johansson',
#   ' Pilou AsbÃƒÂ¦k',
#   ' Takeshi Kitano',
#   ' Juliette Binoche',
#   220614,
#   'Action',
#   ' Crime',
#   ' Drama',
#   40.56,
#   'PG-13'),
#  ('The Bodyguard',
#   '  Kevin Costner',
#   ' Whitney Houston',
#   ' Gary Kemp',
#   ' Bill Cobbs',
#   141173,
#   'Action',
#   ' Drama',
#   ' Music',
#   121.95,
#   'PG-13'),
#  ('Knight and Day',
#   '  Tom Cruise',
#   ' Cameron Diaz',
#   ' Peter Sarsgaard',
#   ' Jordi MollÃƒÂ\xa0',
#   202447,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   76.42,
#   'R'),
#  ('Waterworld',
#   '  Kevin Costner',
#   ' Jeanne Tripplehorn',
#   ' Dennis Hopper',
#   ' Tina Majorino',
#   202222,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   88.25,
#   'PG'),
#  ('A View to a Kill',
#   '  Roger Moore',
#   ' Christopher Walken',
#   ' Tanya Roberts',
#   ' Grace Jones',
#   101108,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   50.33,
#   'R'),
#  ('Miss Congeniality',
#   '  Sandra Bullock',
#   ' Michael Caine',
#   ' Benjamin Bratt',
#   ' Candice Bergen',
#   218804,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   106.81,
#   'TV-MA'),
#  ('The Shallows',
#   '  Blake Lively',
#   ' Ãƒâ€œscar Jaenada',
#   ' Angelo Josue Lozano Corzo',
#   ' Joseph Salas',
#   137769,
#   'Action',
#   ' Drama',
#   ' Horror',
#   55.12,
#   'PG-13'),
#  ('Criminal',
#   '  Kevin Costner',
#   ' Ryan Reynolds',
#   ' Gal Gadot',
#   ' Gary Oldman',
#   68167,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   14.27,
#   'PG-13'),
#  ('Every Which Way But Loose',
#   '  Clint Eastwood',
#   ' Sondra Locke',
#   ' Geoffrey Lewis',
#   ' Beverly DAngelo',
#   28733,
#   'Action',
#   ' Comedy',
#   'None',
#   106,
#   'PG-13'),
#  ('The American',
#   '  George Clooney',
#   ' Paolo Bonacelli',
#   ' Violante Placido',
#   ' Irina BjÃƒÂ¶rklund',
#   99905,
#   'Action',
#   ' Crime',
#   ' Drama',
#   35.61,
#   'R'),
#  ('Run Hide Fight',
#   '  Isabel May',
#   ' Radha Mitchell',
#   ' Thomas Jane',
#   ' Eli Brown',
#   25327,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  ('Red Dawn',
#   '  Patrick Swayze',
#   ' C. Thomas Howell',
#   ' Lea Thompson',
#   ' Charlie Sheen',
#   60128,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   38.38,
#   'R'),
#  ('My Spy',
#   '  Dave Bautista',
#   ' Chloe Coleman',
#   ' Parisa Fitz-Henley',
#   ' Kristen Schaal',
#   32416,
#   'Action',
#   ' Comedy',
#   'None',
#   ' ',
#   'TV-MA'),
#  ('Maze Runner: The Scorch Trials',
#   '  Dylan OBrien',
#   ' Kaya Scodelario',
#   ' Thomas Brodie-Sangster',
#   ' Giancarlo Esposito',
#   260849,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   81.7,
#   'PG-13'),
#  ('Once Upon a Time in Mexico',
#   '  Antonio Banderas',
#   ' Salma Hayek',
#   ' Johnny Depp',
#   ' Willem Dafoe',
#   165858,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   56.36,
#   'PG-13'),
#  ('Scouts Guide to the Zombie Apocalypse',
#   '  Tye Sheridan',
#   ' Logan Miller',
#   ' Joey Morgan',
#   ' Sarah Dumont',
#   52527,
#   'Action',
#   ' Comedy',
#   ' Horror',
#   3.64,
#   'R'),
#  ('Death Wish',
#   '  Bruce Willis',
#   ' Vincent DOnofrio',
#   ' Elisabeth Shue',
#   ' Camila Morrone',
#   74080,
#   'Action',
#   ' Crime',
#   ' Drama',
#   34.02,
#   'R'),
#  ('Bright (I)',
#   '  Will Smith',
#   ' Joel Edgerton',
#   ' Noomi Rapace',
#   ' Edgar RamÃƒÂ\xadrez',
#   194878,
#   'Action',
#   ' Fantasy',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  ('Spectral',
#   '  James Badge Dale',
#   ' Emily Mortimer',
#   ' Bruce Greenwood',
#   ' Max Martini',
#   61689,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   ' ',
#   'R'),
#  ('Ninja Assassin',
#   '  Rain',
#   ' Rick Yune',
#   ' Naomie Harris',
#   ' Joon Lee',
#   73842,
#   'Action',
#   ' Thriller',
#   'None',
#   38.11,
#   'R'),
#  ('The Take',
#   '  Idris Elba',
#   ' Richard Madden',
#   ' Charlotte Le Bon',
#   ' Kelly Reilly',
#   46979,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.04,
#   'R'),
#  ('The Commuter (I)',
#   '  Liam Neeson',
#   ' Vera Farmiga',
#   ' Patrick Wilson',
#   ' Jonathan Banks',
#   119590,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   36.34,
#   'PG'),
#  ('Sand Castle',
#   '  Nicholas Hoult',
#   ' Logan Marshall-Green',
#   ' Henry Cavill',
#   ' Glen Powell',
#   25262,
#   'Action',
#   ' Drama',
#   ' War',
#   ' ',
#   'R'),
#  ('Predator 2',
#   '  Danny Glover',
#   ' Gary Busey',
#   ' Kevin Peter Hall',
#   ' RubÃƒÂ©n Blades',
#   174565,
#   'Action',
#   ' Horror',
#   ' Sci-Fi',
#   30.67,
#   'R'),
#  ('Triple 9',
#   '  Casey Affleck',
#   ' Chiwetel Ejiofor',
#   ' Anthony Mackie',
#   ' Aaron Paul',
#   74436,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   12.63,
#   'PG'),
#  ('The Collector (I)',
#   '  Josh Stewart',
#   ' Andrea Roth',
#   ' Juan FernÃƒÂ¡ndez',
#   ' William Prael',
#   68417,
#   'Action',
#   ' Horror',
#   ' Thriller',
#   7.71,
#   'PG-13'),
#  ('Unlocked (I)',
#   '  Noomi Rapace',
#   ' Orlando Bloom',
#   ' Toni Collette',
#   ' John Malkovich',
#   37024,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG'),
#  ('Guns Akimbo',
#   '  Daniel Radcliffe',
#   ' Samara Weaving',
#   ' Ned Dennehy',
#   ' Natasha Liu Bordizzo',
#   64719,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'TV-MA'),
#  ('Surrogates',
#   '  Bruce Willis',
#   ' Radha Mitchell',
#   ' Ving Rhames',
#   ' Rosamund Pike',
#   177695,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   38.58,
#   'PG-13'),
#  ('The Dead Pool',
#   '  Clint Eastwood',
#   ' Liam Neeson',
#   ' Patricia Clarkson',
#   ' Evan C. Kim',
#   47343,
#   'Action',
#   ' Crime',
#   ' Mystery',
#   37.9,
#   'R'),
#  ('#Alive',
#   '  Yoo Ah-in',
#   ' Park Shin-Hye',
#   ' Jeon Bae-soo',
#   ' Hyun-Wook Lee',
#   43435,
#   'Action',
#   ' Drama',
#   ' Horror',
#   ' ',
#   'PG-13'),
#  ('Transporter 2',
#   '  Jason Statham',
#   ' Amber Valletta',
#   ' Kate Nauta',
#   ' Alessandro Gassmann',
#   208248,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   43.1,
#   'PG-13'),
#  ('Entrapment',
#   '  Sean Connery',
#   ' Catherine Zeta-Jones',
#   ' Ving Rhames',
#   ' Will Patton',
#   120204,
#   'Action',
#   ' Crime',
#   ' Romance',
#   87.7,
#   'PG-13'),
#  ('Revolver',
#   '  Jason Statham',
#   ' Ray Liotta',
#   ' AndrÃƒÂ© 3000',
#   ' Vincent Pastore',
#   99064,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.08,
#   'R'),
#  ('Free Fire',
#   '  Sharlto Copley',
#   ' Brie Larson',
#   ' Armie Hammer',
#   ' Cillian Murphy',
#   48248,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   1.8,
#   'R'),
#  ('Paycheck',
#   '  Ben Affleck',
#   ' Aaron Eckhart',
#   ' Uma Thurman',
#   ' Michael C. Hall',
#   110852,
#   'Action',
#   ' Mystery',
#   ' Sci-Fi',
#   53.79,
#   'PG'),
#  ('This Means War',
#   'None',
#   'None',
#   'None',
#   'None',
#   190371,
#   'Action',
#   ' Comedy',
#   ' Romance',
#   54.76,
#   'R'),
#  ('Blue Streak',
#   '  Martin Lawrence',
#   ' Luke Wilson',
#   ' Peter Greene',
#   ' Dave Chappelle',
#   85947,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   68.52,
#   'PG-13'),
#  ('Centurion',
#   '  Michael Fassbender',
#   ' Dominic West',
#   ' Olga Kurylenko',
#   ' Andreas Wisniewski',
#   84438,
#   'Action',
#   ' Drama',
#   ' History',
#   0.12,
#   'R'),
#  ('Assassins',
#   '  Sylvester Stallone',
#   ' Antonio Banderas',
#   ' Julianne Moore',
#   ' Anatoli Davydov',
#   85782,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   30.31,
#   'R'),
#  ('Johnny English Reborn',
#   '  Rowan Atkinson',
#   ' Rosamund Pike',
#   ' Dominic West',
#   ' Roger Barclay',
#   135354,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   8.31,
#   'G'),
#  ('Mr. Right (I)',
#   '  Anna Kendrick',
#   ' Sam Rockwell',
#   ' Tim Roth',
#   ' James Ransone',
#   58103,
#   'Action',
#   ' Comedy',
#   ' Romance',
#   0.03,
#   'R'),
#  ('Risen',
#   '  Joseph Fiennes',
#   ' Tom Felton',
#   ' Peter Firth',
#   ' Cliff Curtis',
#   29547,
#   'Action',
#   ' Drama',
#   ' History',
#   36.87,
#   'R'),
#  ('Underworld: Awakening',
#   '  Kate Beckinsale',
#   ' Michael Ealy',
#   ' India Eisley',
#   ' Stephen Rea',
#   157764,
#   'Action',
#   ' Fantasy',
#   ' Horror',
#   62.32,
#   'R'),
#  ('Repo Men',
#   '  Jude Law',
#   ' Forest Whitaker',
#   ' Alice Braga',
#   ' Liev Schreiber',
#   108790,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   13.79,
#   'R'),
#  ('Escape from the Planet of the Apes',
#   '  Roddy McDowall',
#   ' Kim Hunter',
#   ' Bradford Dillman',
#   ' Natalie Trundy',
#   36951,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   12.3,
#   'TV-MA'),
#  ('Assault on Precinct 13',
#   '  Ethan Hawke',
#   ' Laurence Fishburne',
#   ' Gabriel Byrne',
#   ' Maria Bello',
#   80404,
#   'Action',
#   ' Crime',
#   ' Drama',
#   19.98,
#   'R'),
#  ...]

# %% [markdown]
# # SUBQUERIES IN SQL

# %% [markdown]
# Make subquery :
#
# 1) Display all details from both tables where movie names are the same.
#
# 2) Display all movie names, Director, ratings, and gross collection where the genre is action.
#
# 3) Display all details from both tables with the highest gross collection.
#
# 4) Display all details from both tables with the highest ratings
#
# 5) Display all details from both tables with the lowest gross collection and lowest ratings

# %% [markdown]
# # CREATING DATABASE

# %%
d=sqlite3.connect('bothmovies.db')
c=d.cursor()

# %% [markdown]
# # CREATING TABLE 1

# %%
c.execute('create table table1(Sno Int primary key,Movie_Name text,Director_1 text,Director_2 text,Duration_in_mins Int,year Int,ratings_out_of10 Int,Metascore Int)')

# %%
with open("c:\Users\dell\Downloads\movie1.csv",'r')as file:
    total_movies=0
    for i in file:
        c.execute("insert into table1 values(?,?,?,?,?,?,?,?)",i.split(","))
        d.commit()
        total_movies+=1
print("records inserted", total_movies)
# Out:
# records inserted 1552

# %% [markdown]
# # CREATING TABLE 2

# %%
c.execute('create table table2(Movie_Name text,star_1 text,star_2 text,star_3 text,star_4 text,votes Int,Genre_1 text,Genre_2 text,Genre_3 text,Grosscollection Int,Certification text,foreign key(Movie_Name)references no1(Movie_Name) )')

# %%
with open("c:\Users\dell\Downloads\movie2.csv",'r',errors='ignore')as file:
    contents=csv.reader(file)
    total_movies=0
    for i in contents:
        c.execute("insert into table2 values(?,?,?,?,?,?,?,?,?,?,?)",i)
        d.commit()
        total_movies+=1
print("records inserted", total_movies)
# Out:
# records inserted 1552

# %% [markdown]
# # SUBQUERYING

# %% [markdown]
# 1) Display all details from both tables where movie names are the same.

# %%
details=c.execute("select * from table1 INNER JOIN table2 ON table1.Movie_Name=table2.Movie_Name")
details.fetchall()
# Out:
# [(1,
#   'The Dark Knight',
#   'Christopher Nolan ',
#   'None',
#   152,
#   2008,
#   9,
#   84,
#   'The Dark Knight',
#   'Christian Bale',
#   'Heath Ledger',
#   'Aaron Eckhart',
#   'Michael Caine',
#   2717521,
#   'Action',
#   ' Crime',
#   ' Drama',
#   534.86,
#   'PG-13'),
#  (2,
#   'The Lord of the Rings: The Return of the King',
#   'Peter Jackson ',
#   'None',
#   201,
#   2003,
#   9,
#   94,
#   'The Lord of the Rings: The Return of the King',
#   '  Elijah Wood',
#   'Viggo Mortensen',
#   ' Ian McKellen',
#   'Orlando Bloom',
#   1886645,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   377.85,
#   'PG-13'),
#  (3,
#   'Inception',
#   'Christopher Nolan ',
#   'None',
#   148,
#   2010,
#   8.8,
#   74,
#   'Inception',
#   '  Leonardo DiCaprio',
#   'Joseph Gordon-Levitt',
#   'Elliot Page',
#   ' Ken Watanabe',
#   2412332,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   292.58,
#   'PG-13'),
#  (4,
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Peter Jackson ',
#   'None',
#   178,
#   2001,
#   8.8,
#   92,
#   'The Lord of the Rings: The Fellowship of the Ring',
#   '  Elijah Wood',
#   'Ian McKellen',
#   'Orlando Bloom',
#   'Sean Bean',
#   1915355,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   315.54,
#   'PG-13'),
#  (5,
#   'The Lord of the Rings: The Two Towers',
#   'Peter Jackson ',
#   'None',
#   179,
#   2002,
#   8.8,
#   87,
#   'The Lord of the Rings: The Two Towers',
#   '  Elijah Wood',
#   ' Ian McKellen',
#   'Viggo Mortensen',
#   ' Orlando Bloom',
#   1702927,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   342.55,
#   'PG-13'),
#  (6,
#   'The Matrix',
#   'Lana Wachowski',
#   'Lilly Wachowski',
#   136,
#   1999,
#   8.7,
#   73,
#   'The Matrix',
#   '  Keanu Reeves',
#   'Laurence Fishburne',
#   ' Carrie-Anne Moss',
#   ' Hugo Weaving',
#   1957307,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   171.48,
#   'R'),
#  (7,
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Irvin Kershner ',
#   'None',
#   124,
#   1980,
#   8.7,
#   82,
#   'Star Wars: Episode V - The Empire Strikes Back',
#   '  Mark Hamill',
#   'Harrison Ford',
#   ' Carrie Fisher',
#   'Billy Dee Williams',
#   1320777,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   290.48,
#   'PG'),
#  (8,
#   'Soorarai Pottru',
#   'Sudha Kongara ',
#   'None',
#   153,
#   2020,
#   8.7,
#   90,
#   'Soorarai Pottru',
#   '  Suriya',
#   ' Paresh Rawal',
#   ' Aparna Balamurali',
#   ' Urvashi',
#   119469,
#   'Action',
#   ' Drama',
#   'None',
#   0,
#   'TV-MA'),
#  (9,
#   'Star Wars: Episode IV - A New Hope',
#   'George Lucas ',
#   'None',
#   121,
#   1977,
#   8.6,
#   75,
#   'Star Wars: Episode IV - A New Hope',
#   '  Mark Hamill',
#   ' Harrison Ford',
#   ' Carrie Fisher',
#   ' Alec Guinness',
#   1393243,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   322.74,
#   'PG'),
#  (10,
#   'Terminator 2: Judgment Day',
#   'James Cameron ',
#   'None',
#   137,
#   1991,
#   8.6,
#   98,
#   'Terminator 2: Judgment Day',
#   '  Arnold Schwarzenegger',
#   ' Linda Hamilton',
#   ' Edward Furlong',
#   ' Robert Patrick',
#   1122770,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   204.84,
#   'R'),
#  (11,
#   'Seven Samurai',
#   'Akira Kurosawa ',
#   'None',
#   207,
#   1954,
#   8.6,
#   85,
#   'Seven Samurai',
#   '  ToshiroÂ´ Mifune',
#   ' Takashi Shimura',
#   ' Keiko Tsushima',
#   ' Yukiko Shimazaki',
#   352753,
#   'Action',
#   ' Drama',
#   'None',
#   0.27,
#   'Not Rated'),
#  (12,
#   'Harakiri',
#   'Masaki Kobayashi ',
#   'None',
#   133,
#   1962,
#   8.6,
#   64,
#   'Harakiri',
#   '  Tatsuya Nakadai',
#   ' Akira Ishihama',
#   ' Shima Iwashita',
#   ' TetsurÃƒÂ´ Tanba',
#   60943,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   0,
#   'Not Rated'),
#  (13,
#   'Sita Ramam',
#   'Hanu Raghavapudi ',
#   'None',
#   163,
#   2022,
#   8.6,
#   67,
#   'Sita Ramam',
#   '  Dulquer Salmaan',
#   ' Mrunal Thakur',
#   ' Rashmika Mandanna',
#   ' Sumanth',
#   59811,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   0,
#   'U'),
#  (15,
#   'Gladiator',
#   'Ridley Scott ',
#   'None',
#   155,
#   2000,
#   8.5,
#   78,
#   'Gladiator',
#   '  Russell Crowe',
#   ' Joaquin Phoenix',
#   ' Connie Nielsen',
#   ' Oliver Reed',
#   1535784,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   187.71,
#   'R'),
#  (16,
#   'Spider-Man: Into the Spider-Verse',
#   'Bob Persichetti',
#   'Peter Ramsay',
#   117,
#   2018,
#   8.4,
#   85,
#   'Spider-Man: Into the Spider-Verse',
#   '  Shameik Moore',
#   ' Jake Johnson',
#   ' Hailee Steinfeld',
#   ' Mahershala Ali',
#   564456,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   190.24,
#   'PG'),
#  (17,
#   'Avengers: Endgame',
#   'Anthony Russo',
#   'Joe Russo',
#   181,
#   2019,
#   8.4,
#   68,
#   'Avengers: Endgame',
#   '  Robert Downey Jr.',
#   ' Chris Evans',
#   ' Mark Ruffalo',
#   ' Chris Hemsworth',
#   1179423,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   858.37,
#   'PG-13'),
#  (18,
#   'Indiana Jones and the Raiders of the Lost Ark',
#   'Steven Spielberg ',
#   'None',
#   115,
#   1981,
#   8.4,
#   77,
#   'Indiana Jones and the Raiders of the Lost Ark',
#   '  Harrison Ford',
#   ' Karen Allen',
#   ' Paul Freeman',
#   ' John Rhys-Davies',
#   985955,
#   'Action',
#   ' Adventure',
#   'None',
#   248.16,
#   'PG'),
#  (19,
#   'Avengers: Infinity War',
#   'Anthony Russo',
#   'Joe Russo',
#   149,
#   2018,
#   8.4,
#   78,
#   'Avengers: Infinity War',
#   '  Robert Downey Jr.',
#   ' Chris Hemsworth',
#   ' Mark Ruffalo',
#   ' Chris Evans',
#   1122836,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   678.82,
#   'PG-13'),
#  (20,
#   'Oldboy',
#   'Park Chan-wook ',
#   'None',
#   101,
#   2003,
#   8.4,
#   84,
#   'Oldboy',
#   '  Choi Min-sik',
#   ' Yoo Ji-tae',
#   ' Kang Hye-jeong',
#   ' Kim Byeong-Ok',
#   596202,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   0.71,
#   'R'),
#  (20,
#   'Oldboy',
#   'Park Chan-wook ',
#   'None',
#   101,
#   2003,
#   8.4,
#   84,
#   'Oldboy',
#   '  Josh Brolin',
#   ' Elizabeth Olsen',
#   ' Samuel L. Jackson',
#   ' Sharlto Copley',
#   78216,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   2.19,
#   'R'),
#  (21,
#   'The Dark Knight Rises',
#   'Christopher Nolan ',
#   'None',
#   164,
#   2012,
#   8.4,
#   78,
#   'The Dark Knight Rises',
#   '  Christian Bale',
#   ' Tom Hardy',
#   ' Anne Hathaway',
#   ' Gary Oldman',
#   1741135,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   448.14,
#   'PG-13'),
#  (22,
#   'Aliens',
#   'James Cameron ',
#   'None',
#   137,
#   1986,
#   8.4,
#   76,
#   'Aliens',
#   '  Sigourney Weaver',
#   ' Michael Biehn',
#   ' Carrie Henn',
#   ' Paul Reiser',
#   732348,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   85.16,
#   'R'),
#  (23,
#   'Kaithi',
#   'Lokesh Kanagaraj ',
#   'None',
#   145,
#   2019,
#   8.4,
#   58,
#   'Kaithi',
#   '  Karthi',
#   ' Narain',
#   ' Arjun Das',
#   ' George Maryan',
#   36069,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   0,
#   'Not Rated'),
#  (24,
#   'Asuran',
#   'Vetrimaaran ',
#   'None',
#   141,
#   2019,
#   8.4,
#   76,
#   'Asuran',
#   '  Dhanush',
#   ' Manju Warrier',
#   ' Prakash Raj',
#   ' Pasupathy',
#   31178,
#   'Action',
#   ' Drama',
#   'None',
#   0,
#   'Not Rated'),
#  (25,
#   'Top Gun: Maverick',
#   'Joseph Kosinski ',
#   'None',
#   130,
#   2022,
#   8.3,
#   98,
#   'Top Gun: Maverick',
#   '  Tom Cruise',
#   ' Jennifer Connelly',
#   ' Miles Teller',
#   ' Val Kilmer',
#   588695,
#   'Action',
#   ' Drama',
#   'None',
#   718.73,
#   'PG-13'),
#  (26,
#   'Heat',
#   'Michael Mann ',
#   'None',
#   170,
#   1995,
#   8.3,
#   64,
#   'Heat',
#   '  Al Pacino',
#   ' Robert De Niro',
#   ' Val Kilmer',
#   ' Jon Voight',
#   675813,
#   'Action',
#   ' Crime',
#   ' Drama',
#   67.44,
#   'R'),
#  (27,
#   'Star Wars: Episode VI - Return of the Jedi',
#   'Richard Marquand ',
#   'None',
#   131,
#   1983,
#   8.3,
#   71,
#   'Star Wars: Episode VI - Return of the Jedi',
#   '  Mark Hamill',
#   ' Harrison Ford',
#   ' Carrie Fisher',
#   ' Billy Dee Williams',
#   1077310,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   309.13,
#   'PG'),
#  (28,
#   'Princess Mononoke',
#   'Hayao Miyazaki ',
#   'None',
#   134,
#   1997,
#   8.3,
#   68,
#   'Princess Mononoke',
#   '  YÃƒÂ´ji Matsuda',
#   ' Yuriko Ishida',
#   ' YÃƒÂ»ko Tanaka',
#   ' Billy Crudup',
#   406641,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   2.38,
#   'PG-13'),
#  (29,
#   'North by Northwest',
#   'Alfred Hitchcock ',
#   'None',
#   136,
#   1959,
#   8.3,
#   65,
#   'North by Northwest',
#   '  Cary Grant',
#   ' Eva Marie Saint',
#   ' James Mason',
#   ' Jessie Royce Landis',
#   334514,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   13.28,
#   'Approved'),
#  (30,
#   'Kantara',
#   'Rishab Shetty ',
#   'None',
#   148,
#   2022,
#   8.3,
#   78,
#   'Kantara',
#   '  Rishab Shetty',
#   ' Kishore Kumar G.',
#   ' Achyuth Kumar',
#   ' Sapthami Gowda',
#   95392,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (31,
#   'Dangal',
#   'Nitesh Tiwari ',
#   'None',
#   161,
#   2016,
#   8.3,
#   69,
#   'Dangal',
#   '  Aamir Khan',
#   ' Sakshi Tanwar',
#   ' Fatima Sana Shaikh',
#   ' Sanya Malhotra',
#   197266,
#   'Action',
#   ' Biography',
#   ' Drama',
#   12.39,
#   'Not Rated'),
#  (32,
#   'K.G.F: Chapter 2',
#   'Prashanth Neel ',
#   'None',
#   168,
#   2022,
#   8.3,
#   70,
#   'K.G.F: Chapter 2',
#   '  Yash',
#   ' Sanjay Dutt',
#   ' Raveena Tandon',
#   ' Srinidhi Shetty',
#   139575,
#   'Action',
#   ' Crime',
#   ' Drama',
#   6.6,
#   'Not Rated'),
#  (33,
#   'Vikram',
#   'Lokesh Kanagaraj ',
#   'None',
#   175,
#   2022,
#   8.3,
#   72,
#   'Vikram',
#   '  Kamal Haasan',
#   ' Vijay Sethupathi',
#   ' Fahadh Faasil',
#   ' Narain',
#   63797,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   0,
#   'UA'),
#  (34,
#   'Raatchasan',
#   'Ram Kumar ',
#   'None',
#   170,
#   2018,
#   8.3,
#   62,
#   'Raatchasan',
#   '  Vishnu Vishal',
#   ' Amala Paul',
#   ' Radha Ravi',
#   ' Sangili Murugan',
#   46924,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (35,
#   'Shershaah',
#   'Vishnuvardhan ',
#   'None',
#   135,
#   2021,
#   8.3,
#   72,
#   'Shershaah',
#   '  Sidharth Malhotra',
#   ' Kiara Advani',
#   ' Shiv Panditt',
#   ' Pranay Pachauri',
#   124760,
#   'Action',
#   ' Biography',
#   ' Drama',
#   0,
#   'TV-14'),
#  (36,
#   'Guardians of the Galaxy Vol. 3',
#   'James Gunn ',
#   'None',
#   150,
#   2023,
#   8.2,
#   97,
#   'Guardians of the Galaxy Vol. 3',
#   '  Chris Pratt',
#   ' Chukwudi Iwuji',
#   ' Bradley Cooper',
#   ' Pom Klementieff',
#   146352,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   0,
#   'PG-13'),
#  (37,
#   'Spider-Man: No Way Home',
#   'Jon Watts ',
#   'None',
#   148,
#   2021,
#   8.2,
#   89,
#   'Spider-Man: No Way Home',
#   '  Tom Holland',
#   ' Zendaya',
#   ' Benedict Cumberbatch',
#   ' Jacob Batalon',
#   796509,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   804.75,
#   'PG-13'),
#  (38,
#   'Jurassic Park',
#   'Steven Spielberg ',
#   'None',
#   127,
#   1993,
#   8.2,
#   93,
#   'Jurassic Park',
#   '  Sam Neill',
#   ' Laura Dern',
#   ' Jeff Goldblum',
#   ' Richard Attenborough',
#   1013596,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   402.45,
#   'PG-13'),
#  (39,
#   'Indiana Jones and the Last Crusade',
#   'Steven Spielberg ',
#   'None',
#   127,
#   1989,
#   8.2,
#   90,
#   'Indiana Jones and the Last Crusade',
#   '  Harrison Ford',
#   ' Sean Connery',
#   ' Alison Doody',
#   ' Denholm Elliott',
#   770923,
#   'Action',
#   ' Adventure',
#   'None',
#   197.17,
#   'PG-13'),
#  (40,
#   '1917',
#   'Sam Mendes ',
#   'None',
#   119,
#   2019,
#   8.2,
#   81,
#   '1917',
#   '  Dean-Charles Chapman',
#   ' George MacKay',
#   ' Daniel Mays',
#   ' Colin Firth',
#   620672,
#   'Action',
#   ' Drama',
#   ' War',
#   159.23,
#   'R'),
#  (41,
#   'Kill Bill: Vol. 1',
#   'Quentin Tarantino ',
#   'None',
#   111,
#   2003,
#   8.2,
#   63,
#   'Kill Bill: Vol. 1',
#   '  Uma Thurman',
#   ' David Carradine',
#   ' Daryl Hannah',
#   ' Michael Madsen',
#   1140530,
#   'Action',
#   ' Crime',
#   ' Drama',
#   70.1,
#   'R'),
#  (42,
#   'Batman Begins',
#   'Christopher Nolan ',
#   'None',
#   140,
#   2005,
#   8.2,
#   84,
#   'Batman Begins',
#   '  Christian Bale',
#   ' Michael Caine',
#   ' Ken Watanabe',
#   ' Liam Neeson',
#   1502882,
#   'Action',
#   ' Crime',
#   ' Drama',
#   206.85,
#   'PG-13'),
#  (43,
#   'Die Hard',
#   'John McTiernan ',
#   'None',
#   132,
#   1988,
#   8.2,
#   84,
#   'Die Hard',
#   '  Bruce Willis',
#   ' Alan Rickman',
#   ' Bonnie Bedelia',
#   ' Reginald VelJohnson',
#   901160,
#   'Action',
#   ' Thriller',
#   'None',
#   83.01,
#   'R'),
#  (44,
#   'V for Vendetta',
#   'James McTeigue ',
#   'None',
#   132,
#   2005,
#   8.2,
#   77,
#   'V for Vendetta',
#   '  Hugo Weaving',
#   ' Natalie Portman',
#   ' Rupert Graves',
#   ' Stephen Rea',
#   1140572,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   70.51,
#   'R'),
#  (45,
#   'Demon Slayer the Movie: Mugen Train',
#   'Haruo Sotozaki ',
#   'None',
#   117,
#   2020,
#   8.2,
#   66,
#   'Demon Slayer the Movie: Mugen Train',
#   '  Natsuki Hanae',
#   ' Akari KitÃƒÂ´',
#   ' Yoshitsugu Matsuoka',
#   ' Hiro Shimono',
#   64313,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   47.7,
#   'R'),
#  (46,
#   'Ran',
#   'Akira Kurosawa ',
#   'None',
#   162,
#   1985,
#   8.2,
#   75,
#   'Ran',
#   '  Tatsuya Nakadai',
#   ' Akira Terao',
#   ' Jinpachi Nezu',
#   ' Daisuke RyÃƒÂ»',
#   129112,
#   'Action',
#   ' Drama',
#   ' War',
#   4.14,
#   'R'),
#  (47,
#   'Gangs of Wasseypur',
#   'Anurag Kashyap ',
#   'None',
#   321,
#   2012,
#   8.2,
#   71,
#   'Gangs of Wasseypur',
#   '  Manoj Bajpayee',
#   ' Nawazuddin Siddiqui',
#   ' Tigmanshu Dhulia',
#   ' Richa Chadha',
#   99325,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0,
#   'Not Rated'),
#  (48,
#   'Vikram Vedha',
#   'Gayatri',
#   'Pushkar',
#   147,
#   2017,
#   8.2,
#   74,
#   'Vikram Vedha',
#   '  Madhavan',
#   ' Vijay Sethupathi',
#   ' Shraddha Srinath',
#   ' Kathir',
#   47632,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (49,
#   'Baahubali 2: The Conclusion',
#   'S.S. Rajamouli ',
#   'None',
#   167,
#   2017,
#   8.2,
#   85,
#   'Baahubali 2: The Conclusion',
#   '  Prabhas',
#   ' Rana Daggubati',
#   ' Anushka Shetty',
#   ' Tamannaah Bhatia',
#   106669,
#   'Action',
#   ' Drama',
#   'None',
#   20.19,
#   'Not Rated'),
#  (50,
#   'Yojimbo',
#   'Akira Kurosawa ',
#   'None',
#   110,
#   1961,
#   8.2,
#   89,
#   'Yojimbo',
#   '  ToshirÃƒÂ´ Mifune',
#   ' EijirÃƒÂ´ TÃƒÂ´no',
#   ' Tatsuya Nakadai',
#   ' YÃƒÂ´ko Tsukasa',
#   125843,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   0,
#   'Not Rated'),
#  (51,
#   'Uri: The Surgical Strike',
#   'Aditya Dhar ',
#   'None',
#   138,
#   2019,
#   8.2,
#   78,
#   'Uri: The Surgical Strike',
#   '  Vicky Kaushal',
#   ' Paresh Rawal',
#   ' Mohit Raina',
#   ' Yami Gautam',
#   67312,
#   'Action',
#   ' Drama',
#   ' History',
#   4.19,
#   'Not Rated'),
#  (52,
#   'K.G.F: Chapter 1',
#   'Prashanth Neel ',
#   'None',
#   156,
#   2018,
#   8.2,
#   76,
#   'K.G.F: Chapter 1',
#   '  Yash',
#   ' Srinidhi Shetty',
#   ' Ramachandra Raju',
#   ' Archana Jois',
#   91560,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (53,
#   'Sherlock Jr.',
#   'Buster Keaton ',
#   'None',
#   45,
#   1924,
#   8.2,
#   74,
#   'Sherlock Jr.',
#   '  Buster Keaton',
#   ' Kathryn McGuire',
#   ' Joe Keaton',
#   ' Erwin Connelly',
#   52431,
#   'Action',
#   ' Comedy',
#   ' Romance',
#   0.98,
#   'Passed'),
#  (54,
#   'Rangasthalam 1985',
#   'Sukumar ',
#   'None',
#   170,
#   2018,
#   8.2,
#   81,
#   'Rangasthalam 1985',
#   '  Ram Charan',
#   ' Samantha Ruth Prabhu',
#   ' Aadhi',
#   ' Jagapathi Babu',
#   26143,
#   'Action',
#   ' Drama',
#   'None',
#   3.51,
#   'Not Rated'),
#  (55,
#   'The Mountain II',
#   'Alper Caglar ',
#   'None',
#   135,
#   2016,
#   8.2,
#   65,
#   'The Mountain II',
#   '  Caglar Ertugrul',
#   ' Ufuk Bayraktar',
#   ' Ahu TÃƒÂ¼rkpenÃƒÂ§e',
#   ' Murat Serezli',
#   109174,
#   'Action',
#   ' Drama',
#   ' War',
#   0,
#   'Not Rated'),
#  (56,
#   'Paan Singh Tomar',
#   'Tigmanshu Dhulia ',
#   'None',
#   135,
#   2012,
#   8.2,
#   69,
#   'Paan Singh Tomar',
#   '  Irrfan Khan',
#   ' Mahie Gill',
#   ' Rajesh Abhay',
#   ' Hemendra Dandotiya',
#   37041,
#   'Action',
#   ' Biography',
#   ' Crime',
#   0.04,
#   'R'),
#  (57,
#   'Mad Max: Fury Road',
#   'George Miller ',
#   'None',
#   120,
#   2015,
#   8.1,
#   54,
#   'Mad Max: Fury Road',
#   '  Tom Hardy',
#   ' Charlize Theron',
#   ' Nicholas Hoult',
#   ' ZoÃƒÂ« Kravitz',
#   1029852,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   154.06,
#   'PG-13'),
#  (58,
#   'Ford v Ferrari',
#   'James Mangold ',
#   'None',
#   152,
#   2019,
#   8.1,
#   90,
#   'Ford v Ferrari',
#   '  Matt Damon',
#   ' Christian Bale',
#   ' Jon Bernthal',
#   ' CaitrÃƒÂ\xadona Balfe',
#   418484,
#   'Action',
#   ' Biography',
#   ' Drama',
#   117.62,
#   'PG-13'),
#  (59,
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Gore Verbinski ',
#   'None',
#   143,
#   2003,
#   8.1,
#   80,
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   '  Johnny Depp',
#   ' Geoffrey Rush',
#   ' Orlando Bloom',
#   ' Keira Knightley',
#   1153318,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   305.41,
#   'R'),
#  (60,
#   'Blade Runner',
#   'Ridley Scott ',
#   'None',
#   117,
#   1982,
#   8.1,
#   76,
#   'Blade Runner',
#   '  Harrison Ford',
#   ' Rutger Hauer',
#   ' Sean Young',
#   ' Edward James Olmos',
#   787715,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   32.87,
#   'R'),
#  (61,
#   'The Terminator',
#   'James Cameron ',
#   'None',
#   107,
#   1984,
#   8.1,
#   67,
#   'The Terminator',
#   '  Arnold Schwarzenegger',
#   ' Linda Hamilton',
#   ' Michael Biehn',
#   ' Paul Winfield',
#   885204,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   38.4,
#   'R'),
#  (62,
#   'Logan',
#   'James Mangold ',
#   'None',
#   137,
#   2017,
#   8.1,
#   83,
#   'Logan',
#   '  Hugh Jackman',
#   ' Patrick Stewart',
#   ' Dafne Keen',
#   ' Boyd Holbrook',
#   787213,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   226.28,
#   'R'),
#  (63,
#   'Lock Stock and Two Smoking Barrels',
#   'Guy Ritchie ',
#   'None',
#   107,
#   1998,
#   8.1,
#   59,
#   'Lock Stock and Two Smoking Barrels',
#   '  Jason Flemyng',
#   ' Dexter Fletcher',
#   ' Nick Moran',
#   ' Jason Statham',
#   595108,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   3.9,
#   'PG'),
#  (64,
#   'How to Train Your Dragon',
#   'Dean DeBlois',
#   'Chris Sanders',
#   98,
#   2010,
#   8.1,
#   85,
#   'How to Train Your Dragon',
#   '  Jay Baruchel',
#   ' Gerard Butler',
#   ' Christopher Mintz-Plasse',
#   ' Craig Ferguson',
#   761030,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   217.58,
#   'PG-13'),
#  (65,
#   'Warrior',
#   'Gavin OConnor ',
#   'None',
#   140,
#   2011,
#   8.1,
#   75,
#   'Warrior',
#   '  Tom Hardy',
#   ' Nick Nolte',
#   ' Joel Edgerton',
#   ' Jennifer Morrison',
#   481730,
#   'Action',
#   ' Drama',
#   ' Sport',
#   13.66,
#   'R'),
#  (66,
#   'Rush (I)',
#   'Ron Howard ',
#   'None',
#   123,
#   2013,
#   8.1,
#   87,
#   'Rush (I)',
#   '  Daniel BrÃƒÂ¼hl',
#   ' Chris Hemsworth',
#   ' Olivia Wilde',
#   ' Alexandra Maria Lara',
#   490998,
#   'Action',
#   ' Biography',
#   ' Drama',
#   26.95,
#   'PG'),
#  (67,
#   'The Iron Giant',
#   'Brad Bird ',
#   'None',
#   86,
#   1999,
#   8.1,
#   33,
#   'The Iron Giant',
#   '  Eli Marienthal',
#   ' Harry Connick Jr.',
#   ' Jennifer Aniston',
#   ' Vin Diesel',
#   208963,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   23.16,
#   'TV-MA'),
#  (68,
#   'Neon Genesis Evangelion: The End of Evangelion',
#   'Hideaki Anno',
#   'Kazuya Tsurumaki ',
#   87,
#   1997,
#   8.1,
#   71,
#   'Neon Genesis Evangelion: The End of Evangelion',
#   '  Megumi Ogata',
#   ' Megumi Hayashibara',
#   ' YÃƒÂ»ko Miyamura',
#   ' Kotono Mitsuishi',
#   58525,
#   'Animation',
#   ' Action',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (69,
#   'Sholay',
#   'Ramesh Sippy ',
#   'None',
#   162,
#   1975,
#   8.1,
#   64,
#   'Sholay',
#   '  Sanjeev Kumar',
#   ' Dharmendra',
#   ' Amitabh Bachchan',
#   ' Amjad Khan',
#   57063,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   0,
#   'Not Rated'),
#  (70,
#   'Bajrangi Bhaijaan',
#   'Kabir Khan',
#   'Mehmet Tutkun',
#   163,
#   2015,
#   8.1,
#   74,
#   'Bajrangi Bhaijaan',
#   '  Salman Khan',
#   ' Harshaali Malhotra',
#   ' Nawazuddin Siddiqui',
#   ' Kareena Kapoor',
#   91904,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   8.18,
#   'Passed'),
#  (71,
#   'The General',
#   ' Clyde Bruckman',
#   'Buster Keaton ',
#   67,
#   1926,
#   8.1,
#   83,
#   'The General',
#   '  Buster Keaton',
#   ' Marion Mack',
#   ' Glen Cavender',
#   ' Jim Farley',
#   93864,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   1.03,
#   'Not Rated'),
#  (72,
#   'The Hidden Fortress',
#   'Akira Kurosawa ',
#   'None',
#   126,
#   1958,
#   8.1,
#   79,
#   'The Hidden Fortress',
#   '  ToshirÃƒÂ´ Mifune',
#   ' Misa Uehara',
#   ' Minoru Chiaki',
#   ' Kamatari Fujiwara',
#   40453,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (73,
#   'White Heat',
#   'Raoul Walsh ',
#   'None',
#   114,
#   1949,
#   8.1,
#   82,
#   'White Heat',
#   '  James Cagney',
#   ' Virginia Mayo',
#   ' Edmond OBrien',
#   ' Margaret Wycherly',
#   34278,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (74,
#   'A Wednesday',
#   'Neeraj Pandey ',
#   'None',
#   104,
#   2008,
#   8.1,
#   71,
#   'A Wednesday',
#   '  Anupam Kher',
#   ' Naseeruddin Shah',
#   ' Veerendra Saxena',
#   ' Mahesh Kanual',
#   80205,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'UA'),
#  (75,
#   'Major',
#   'Sashi Kiran Tikka ',
#   'None',
#   150,
#   2022,
#   8.1,
#   84,
#   'Major',
#   '  Adivi Sesh',
#   ' Prakash Raj',
#   ' Revathi',
#   ' Saiee Manjrekar',
#   30452,
#   'Action',
#   ' Biography',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (76,
#   'Sarfarosh',
#   'John Mathew Matthan ',
#   'None',
#   174,
#   1999,
#   8.1,
#   75,
#   'Sarfarosh',
#   '  Aamir Khan',
#   ' Naseeruddin Shah',
#   ' Sonali Bendre',
#   ' Mukesh Rishi',
#   26227,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   0,
#   'Not Rated'),
#  (77,
#   'Hera Pheri',
#   'Priyadarshan ',
#   'None',
#   156,
#   2000,
#   8.1,
#   81,
#   'Hera Pheri',
#   '  Akshay Kumar',
#   ' Suniel Shetty',
#   ' Paresh Rawal',
#   ' Tabu',
#   69404,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   0,
#   'Not Rated'),
#  (78,
#   'Kaththi',
#   'A.R. Murugadoss ',
#   'None',
#   166,
#   2014,
#   8.1,
#   68,
#   'Kaththi',
#   '  Joseph Vijay',
#   ' Samantha Ruth Prabhu',
#   ' Neil Nitin Mukesh',
#   ' Tota Roy Chowdhury',
#   28322,
#   'Action',
#   ' Drama',
#   'None',
#   0,
#   'Not Rated'),
#  (79,
#   'Thuppakki',
#   'A.R. Murugadoss ',
#   'None',
#   165,
#   2012,
#   8.1,
#   60,
#   'Thuppakki',
#   '  Joseph Vijay',
#   ' Kajal Aggarwal',
#   ' Vidyut Jammwal',
#   ' Sathyan',
#   35909,
#   'Action',
#   ' Thriller',
#   'None',
#   0,
#   'R'),
#  (80,
#   'John Wick: Chapter 4',
#   'Chad Stahelski ',
#   'None',
#   169,
#   2023,
#   8,
#   94,
#   'John Wick: Chapter 4',
#   '  Keanu Reeves',
#   ' Laurence Fishburne',
#   ' George Georgiou',
#   ' Lance Reddick',
#   177823,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   0,
#   'PG-13'),
#  (81,
#   'Guardians of the Galaxy',
#   'James Gunn ',
#   'None',
#   121,
#   2014,
#   8,
#   76,
#   'Guardians of the Galaxy',
#   '  Chris Pratt',
#   ' Vin Diesel',
#   ' Bradley Cooper',
#   ' Zoe Saldana',
#   1217116,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   333.18,
#   'PG-13'),
#  (82,
#   'Dune',
#   'Denis Villeneuve ',
#   'None',
#   155,
#   2021,
#   8,
#   65,
#   'Dune',
#   '  Kyle MacLachlan',
#   ' Virginia Madsen',
#   ' Francesca Annis',
#   ' Leonardo Cimino',
#   165723,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   30.93,
#   'PG-13'),
#  (82,
#   'Dune',
#   'Denis Villeneuve ',
#   'None',
#   155,
#   2021,
#   8,
#   65,
#   'Dune',
#   '  TimothÃƒÂ©e Chalamet',
#   ' Rebecca Ferguson',
#   ' Zendaya',
#   ' Oscar Isaac',
#   677751,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   108.33,
#   'R'),
#  (83,
#   'Blade Runner 2049',
#   'Denis Villeneuve ',
#   'None',
#   164,
#   2017,
#   8,
#   71,
#   'Blade Runner 2049',
#   '  Harrison Ford',
#   ' Ryan Gosling',
#   ' Ana de Armas',
#   ' Dave Bautista',
#   603524,
#   'Action',
#   ' Drama',
#   ' Mystery',
#   92.05,
#   'R'),
#  (84,
#   'Deadpool',
#   'Tim Miller ',
#   'None',
#   108,
#   2016,
#   8,
#   98,
#   'Deadpool',
#   '  Ryan Reynolds',
#   ' Morena Baccarin',
#   ' T.J. Miller',
#   ' Ed Skrein',
#   1067514,
#   'Action',
#   ' Comedy',
#   'None',
#   363.07,
#   'PG-13'),
#  (85,
#   'The Avengers',
#   'Joss Whedon ',
#   'None',
#   143,
#   2012,
#   8,
#   85,
#   'The Avengers',
#   '  Robert Downey Jr.',
#   ' Chris Evans',
#   ' Scarlett Johansson',
#   ' Jeremy Renner',
#   1415723,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   623.28,
#   'R'),
#  (86,
#   'Zack Snyders Justice League',
#   'Zack Snyder ',
#   'None',
#   242,
#   2021,
#   8,
#   89,
#   'Zack Snyders Justice League',
#   '  Henry Cavill',
#   ' Ben Affleck',
#   ' Gal Gadot',
#   ' Amy Adams',
#   412561,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   0,
#   'PG'),
#  (87,
#   'The Incredibles',
#   'Brad Bird ',
#   'None',
#   115,
#   2004,
#   8,
#   69,
#   'The Incredibles',
#   '  Craig T. Nelson',
#   ' Samuel L. Jackson',
#   ' Holly Hunter',
#   ' Jason Lee',
#   761142,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   261.44,
#   'PG-13'),
#  (88,
#   'Casino Royale',
#   'Martin Campbell ',
#   'None',
#   144,
#   2006,
#   8,
#   97,
#   'Casino Royale',
#   '  Daniel Craig',
#   ' Eva Green',
#   ' Judi Dench',
#   ' Jeffrey Wright',
#   670820,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   167.45,
#   'R'),
#  (89,
#   'The Revenant (I)',
#   'Alejandro G. IÃ±Ã¡rritu  ',
#   'None',
#   156,
#   2015,
#   8,
#   81,
#   'The Revenant (I)',
#   '  Leonardo DiCaprio',
#   ' Tom Hardy',
#   ' Will Poulter',
#   ' Domhnall Gleeson',
#   827647,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   183.64,
#   'R'),
#  (90,
#   'Akira',
#   ' Katsuhiro Ã”tomo',
#   'None',
#   124,
#   1988,
#   8,
#   72,
#   'Akira',
#   '  Mitsuo Iwata',
#   ' Nozomu Sasaki',
#   ' Mami Koyama',
#   ' TesshÃƒÂ´ Genda',
#   193573,
#   'Animation',
#   ' Action',
#   ' Drama',
#   0.55,
#   'R'),
#  (91,
#   'Kill Bill: Vol. 2',
#   'Quentin Tarantino ',
#   'None',
#   137,
#   2004,
#   8,
#   83,
#   'Kill Bill: Vol. 2',
#   '  Uma Thurman',
#   ' David Carradine',
#   ' Michael Madsen',
#   ' Daryl Hannah',
#   773849,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   66.21,
#   'R'),
#  (92,
#   'Ip Man',
#   'Wilson Yip ',
#   'None',
#   106,
#   2008,
#   8,
#   51,
#   'Ip Man',
#   '  Donnie Yen',
#   ' Simon Yam',
#   ' Siu-Wong Fan',
#   ' Ka-Tung Lam',
#   228371,
#   'Action',
#   ' Biography',
#   ' Drama',
#   0,
#   'PG-13'),
#  (93,
#   'The Bourne Ultimatum',
#   'Paul Greengrass ',
#   'None',
#   115,
#   2007,
#   8,
#   76,
#   'The Bourne Ultimatum',
#   '  Matt Damon',
#   ' Edgar RamÃƒÂ\xadrez',
#   ' Joan Allen',
#   ' Julia Stiles',
#   644032,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   227.47,
#   'Not Rated'),
#  (94,
#   'Baahubali: The Beginning',
#   'S.S. Rajamouli ',
#   'None',
#   159,
#   2015,
#   8,
#   78,
#   'Baahubali: The Beginning',
#   '  Prabhas',
#   ' Rana Daggubati',
#   ' Anushka Shetty',
#   ' Tamannaah Bhatia',
#   129942,
#   'Action',
#   ' Drama',
#   'None',
#   6.74,
#   'R'),
#  (95,
#   'Infernal Affairs',
#   'Andrew Lau',
#   'Alan Mak ',
#   101,
#   2002,
#   8,
#   65,
#   'Infernal Affairs',
#   '  Andy Lau',
#   ' Tony Leung Chiu-wai',
#   ' Anthony Chau-Sang Wong',
#   ' Eric Tsang',
#   127623,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.17,
#   'PG'),
#  (96,
#   'Wolfwalkers',
#   'Tomm Moore',
#   'Ross Stewart ',
#   103,
#   2020,
#   8,
#   80,
#   'Wolfwalkers',
#   '  Honor Kneafsey',
#   ' Eva Whittaker',
#   ' Sean Bean',
#   ' Simon McBurney',
#   35142,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   0,
#   'R'),
#  (97,
#   'Elite Squad',
#   ' JosÃ© Padilha ',
#   'None',
#   115,
#   2007,
#   8,
#   68,
#   'Elite Squad',
#   '  Wagner Moura',
#   ' AndrÃƒÂ© Ramiro',
#   ' Caio Junqueira',
#   ' Milhem Cortaz',
#   106710,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.01,
#   'Not Rated'),
#  (98,
#   'Haider',
#   'Vishal Bhardwaj ',
#   'None',
#   160,
#   2014,
#   8,
#   94,
#   'Haider',
#   '  Shahid Kapoor',
#   ' Tabu',
#   ' Shraddha Kapoor',
#   ' Kay Kay Menon',
#   56080,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.9,
#   'Not Rated'),
#  (99,
#   'Sanjuro',
#   'Akira Kurosawa ',
#   'None',
#   96,
#   1962,
#   8,
#   71,
#   'Sanjuro',
#   '  ToshirÃƒÂ´ Mifune',
#   ' Tatsuya Nakadai',
#   ' Keiju Kobayashi',
#   ' YÃƒÂ»nosuke ItÃƒÂ´',
#   39432,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   0,
#   'Not Rated'),
#  (100,
#   'Elite Squad 2: The Enemy Within',
#   ' JosÃ© Padilha ',
#   'None',
#   115,
#   2010,
#   8,
#   47,
#   'Elite Squad 2: The Enemy Within',
#   '  Wagner Moura',
#   ' Irandhir Santos',
#   ' AndrÃƒÂ© Ramiro',
#   ' Milhem Cortaz',
#   84713,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.1,
#   'R'),
#  (101,
#   'Tae Guk Gi: The Brotherhood of War',
#   'Je-kyu Kang ',
#   'None',
#   140,
#   2004,
#   8,
#   81,
#   'Tae Guk Gi: The Brotherhood of War',
#   '  Jang Dong-Gun',
#   ' Won Bin',
#   ' Eun-ju Lee',
#   ' Hyeong-jin Kong',
#   40367,
#   'Action',
#   ' Drama',
#   ' War',
#   1.11,
#   'Not Rated'),
#  (102,
#   'Andaz Apna Apna',
#   'Rajkumar Santoshi ',
#   'None',
#   160,
#   1994,
#   8,
#   75,
#   'Andaz Apna Apna',
#   '  Aamir Khan',
#   ' Salman Khan',
#   ' Raveena Tandon',
#   ' Karisma Kapoor',
#   54199,
#   'Action',
#   ' Comedy',
#   ' Romance',
#   0,
#   'UA'),
#  (103,
#   'Karthikeya 2',
#   'Chandoo Mondeti ',
#   'None',
#   150,
#   2022,
#   8,
#   51,
#   'Karthikeya 2',
#   '  Nikhil Siddharth',
#   ' Anupama Parameswaran',
#   ' Srinivasa Reddy',
#   ' Harsha Chemudu',
#   63201,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   0,
#   'Not Rated'),
#  (104,
#   'Arjun Reddy',
#   'Sandeep Reddy Vanga ',
#   'None',
#   182,
#   2017,
#   8,
#   81,
#   'Arjun Reddy',
#   '  Vijay Deverakonda',
#   ' Shalini Pandey',
#   ' Jia Sharma',
#   ' Kanchana',
#   26282,
#   'Action',
#   ' Drama',
#   ' Romance',
#   0,
#   'Not Rated'),
#  (105,
#   '1: Nenokkadine',
#   'Sukumar ',
#   'None',
#   170,
#   2014,
#   8,
#   70,
#   '1: Nenokkadine',
#   '  Mahesh Babu',
#   ' Kriti Sanon',
#   ' Nassar',
#   ' Pradeep Singh Rawat',
#   45890,
#   'Action',
#   ' Thriller',
#   'None',
#   0,
#   'PG-13'),
#  (106,
#   'The Breath',
#   'Levent Semerci ',
#   'None',
#   128,
#   2009,
#   8,
#   87,
#   'The Breath',
#   '  Mete Horozoglu',
#   ' Ilker Kizmaz',
#   ' Baris Bagci',
#   ' Ãƒâ€“zgÃƒÂ¼r Eren KoÃƒÂ§',
#   34384,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   0,
#   'PG-13'),
#  (107,
#   'Thor: Ragnarok',
#   'Taika Waititi ',
#   'None',
#   130,
#   2017,
#   7.9,
#   74,
#   'Thor: Ragnarok',
#   '  Chris Hemsworth',
#   ' Tom Hiddleston',
#   ' Cate Blanchett',
#   ' Mark Ruffalo',
#   775783,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   315.06,
#   'PG-13'),
#  (108,
#   'Avatar',
#   'James Cameron ',
#   'None',
#   162,
#   2009,
#   7.9,
#   82,
#   'Avatar',
#   '  Sam Worthington',
#   ' Zoe Saldana',
#   ' Sigourney Weaver',
#   ' Michelle Rodriguez',
#   1341931,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   760.51,
#   'PG-13'),
#  (109,
#   'Iron Man',
#   'Jon Favreau ',
#   'None',
#   126,
#   2008,
#   7.9,
#   67,
#   'Iron Man',
#   '  Robert Downey Jr.',
#   ' Gwyneth Paltrow',
#   ' Terrence Howard',
#   ' Jeff Bridges',
#   1082141,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   318.41,
#   'PG-13'),
#  (110,
#   'Star Trek',
#   'J.J. Abrams ',
#   'None',
#   127,
#   2009,
#   7.9,
#   55,
#   'Star Trek',
#   '  Chris Pine',
#   ' Zachary Quinto',
#   ' Simon Pegg',
#   ' Leonard Nimoy',
#   610293,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   257.73,
#   'R'),
#  (111,
#   'Edge of Tomorrow',
#   'Doug Liman ',
#   'None',
#   113,
#   2014,
#   7.9,
#   74,
#   'Edge of Tomorrow',
#   '  Tom Cruise',
#   ' Emily Blunt',
#   ' Bill Paxton',
#   ' Brendan Gleeson',
#   699063,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   100.21,
#   'PG-13'),
#  (112,
#   'Children of Men',
#   'Alfonso CuarÃ³n',
#   'None',
#   109,
#   2006,
#   7.9,
#   66,
#   'Children of Men',
#   '  Julianne Moore',
#   ' Clive Owen',
#   ' Chiwetel Ejiofor',
#   ' Michael Caine',
#   511555,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   35.55,
#   'R'),
#  (113,
#   'X-Men: Days of Future Past',
#   'Bryan Singer ',
#   'None',
#   132,
#   2014,
#   7.9,
#   79,
#   'X-Men: Days of Future Past',
#   '  Patrick Stewart',
#   ' Ian McKellen',
#   ' Hugh Jackman',
#   ' James McAvoy',
#   724918,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   233.92,
#   'PG-13'),
#  (114,
#   'District 9',
#   'Neill Blomkamp ',
#   'None',
#   112,
#   2009,
#   7.9,
#   77,
#   'District 9',
#   '  Sharlto Copley',
#   ' David James',
#   ' Jason Cope',
#   ' Nathalie Boltt',
#   694854,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   115.65,
#   'R'),
#  (115,
#   'The Bourne Identity',
#   'Doug Liman ',
#   'None',
#   119,
#   2002,
#   7.9,
#   64,
#   'The Bourne Identity',
#   '  Franka Potente',
#   ' Matt Damon',
#   ' Chris Cooper',
#   ' Clive Owen',
#   558713,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   121.66,
#   'PG-13'),
#  (116,
#   'The Blues Brothers',
#   'John Landis ',
#   'None',
#   133,
#   1980,
#   7.9,
#   65,
#   'The Blues Brothers',
#   '  John Belushi',
#   ' Dan Aykroyd',
#   ' Cab Calloway',
#   ' John Candy',
#   205833,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   57.23,
#   'TV-MA'),
#  (117,
#   'Crouching Tiger Hidden Dragon',
#   'Ang Lee ',
#   'None',
#   120,
#   2000,
#   7.9,
#   82,
#   'Crouching Tiger Hidden Dragon',
#   '  Chow Yun-Fat',
#   ' Michelle Yeoh',
#   ' Ziyi Zhang',
#   ' Chang Chen',
#   275624,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   128.08,
#   'R'),
#  (118,
#   'Ghost in the Shell',
#   'Mamoru Oshii ',
#   'None',
#   83,
#   1995,
#   7.9,
#   61,
#   'Ghost in the Shell',
#   '  Atsuko Tanaka',
#   ' Iemasa Kayumi',
#   ' Akio Ãƒâ€tsuka',
#   ' KÃƒÂ´ichi Yamadera',
#   148421,
#   'Animation',
#   ' Action',
#   ' Crime',
#   0.52,
#   'R'),
#  (118,
#   'Ghost in the Shell',
#   'Mamoru Oshii ',
#   'None',
#   83,
#   1995,
#   7.9,
#   61,
#   'Ghost in the Shell',
#   '  Scarlett Johansson',
#   ' Pilou AsbÃƒÂ¦k',
#   ' Takeshi Kitano',
#   ' Juliette Binoche',
#   220614,
#   'Action',
#   ' Crime',
#   ' Drama',
#   40.56,
#   'PG-13'),
#  (119,
#   'A Fistful of Dollars',
#   'Sergio Leone ',
#   'None',
#   99,
#   1964,
#   7.9,
#   67,
#   'A Fistful of Dollars',
#   '  Clint Eastwood',
#   ' Gian Maria VolontÃƒÂ¨',
#   ' Marianne Koch',
#   ' Wolfgang Lukschy',
#   223383,
#   'Action',
#   ' Drama',
#   ' Western',
#   14.5,
#   'R'),
#  (120,
#   'The Raid 2',
#   'Gareth Evans ',
#   'None',
#   150,
#   2014,
#   7.9,
#   60,
#   'The Raid 2',
#   '  Iko Uwais',
#   ' Yayan Ruhian',
#   ' Arifin Putra',
#   ' Oka Antara',
#   127078,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   2.63,
#   'PG-13'),
#  (121,
#   'The Wild Bunch',
#   'Sam Peckinpah ',
#   'None',
#   135,
#   1969,
#   7.9,
#   72,
#   'The Wild Bunch',
#   '  William Holden',
#   ' Ernest Borgnine',
#   ' Robert Ryan',
#   ' Edmond OBrien',
#   87399,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   12.06,
#   'R'),
#  (122,
#   'Hero',
#   'Yimou Zhang ',
#   'None',
#   120,
#   2002,
#   7.9,
#   86,
#   'Hero',
#   '  Jet Li',
#   ' Tony Leung Chiu-wai',
#   ' Maggie Cheung',
#   ' Ziyi Zhang',
#   184413,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   53.71,
#   'Not Rated'),
#  (123,
#   'Letters from Iwo Jima',
#   'Clint Eastwood ',
#   'None',
#   141,
#   2006,
#   7.9,
#   74,
#   'Letters from Iwo Jima',
#   '  Ken Watanabe',
#   ' Kazunari Ninomiya',
#   ' Tsuyoshi Ihara',
#   ' Ryo Kase',
#   166250,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   13.76,
#   'PG'),
#  (124,
#   'A Taxi Driver',
#   'Hun Jang ',
#   'None',
#   137,
#   2017,
#   7.9,
#   61,
#   'A Taxi Driver',
#   '  Song Kang-ho',
#   ' Thomas Kretschmann',
#   ' Hae-Jin Yoo',
#   ' Ryu Jun-Yeol',
#   27381,
#   'Action',
#   ' Drama',
#   ' History',
#   1.53,
#   'Not Rated'),
#  (125,
#   'The Adventures of Robin Hood',
#   ' Michael Curtiz',
#   'William Keighley ',
#   102,
#   1938,
#   7.9,
#   76,
#   'The Adventures of Robin Hood',
#   '  Errol Flynn',
#   ' Olivia de Havilland',
#   ' Basil Rathbone',
#   ' Claude Rains',
#   52802,
#   'Action',
#   ' Adventure',
#   ' Romance',
#   3.98,
#   'Not Rated'),
#  (126,
#   'Baby (I)',
#   'Neeraj Pandey ',
#   'None',
#   159,
#   2015,
#   7.9,
#   76,
#   'Baby (I)',
#   '  Akshay Kumar',
#   ' Danny Denzongpa',
#   ' Rana Daggubati',
#   ' Taapsee Pannu',
#   58806,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   0,
#   'Not Rated'),
#  (127,
#   'Airlift',
#   'Raja Menon ',
#   'None',
#   130,
#   2016,
#   7.9,
#   83,
#   'Airlift',
#   '  Akshay Kumar',
#   ' Nimrat Kaur',
#   ' Kumud Mishra',
#   ' Prakash Belawadi',
#   57845,
#   'Action',
#   ' Drama',
#   ' History',
#   0,
#   'R'),
#  (128,
#   'Vishwaroopam',
#   'Kamal Haasan ',
#   'None',
#   148,
#   2013,
#   7.9,
#   65,
#   'Vishwaroopam',
#   '  Pooja Kumar',
#   ' Miles Anderson',
#   ' Kamal Haasan',
#   ' Rahul Bose',
#   40547,
#   'Action',
#   ' Thriller',
#   'None',
#   0,
#   'PG-13'),
#  (129,
#   'Everything Everywhere All at Once',
#   'Daniel Kwan',
#   ' Daniel Scheinert ',
#   139,
#   2022,
#   7.8,
#   69,
#   'Everything Everywhere All at Once',
#   '  Michelle Yeoh',
#   ' Stephanie Hsu',
#   ' Jamie Lee Curtis',
#   ' Ke Huy Quan',
#   448150,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   72.86,
#   'Not Rated'),
#  (130,
#   'The Batman',
#   'Matt Reeves ',
#   'None',
#   176,
#   2022,
#   7.8,
#   73,
#   'The Batman',
#   '  Robert Pattinson',
#   ' ZoÃƒÂ« Kravitz',
#   ' Jeffrey Wright',
#   ' Colin Farrell',
#   699825,
#   'Action',
#   ' Crime',
#   ' Drama',
#   369.35,
#   'R'),
#  (131,
#   'RRR',
#   'S.S. Rajamouli ',
#   'None',
#   187,
#   2022,
#   7.8,
#   47,
#   'RRR',
#   '  N.T. Rama Rao Jr.',
#   ' Ram Charan',
#   ' Ajay Devgn',
#   ' Alia Bhatt',
#   150199,
#   'Action',
#   ' Drama',
#   'None',
#   14.5,
#   'R'),
#  (132,
#   'The Gentlemen',
#   'Guy Ritchie ',
#   'None',
#   113,
#   2019,
#   7.8,
#   61,
#   'The Gentlemen',
#   '  Matthew McConaughey',
#   ' Charlie Hunnam',
#   ' Michelle Dockery',
#   ' Jeremy Strong',
#   360399,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   36.47,
#   'R'),
#  (133,
#   'All Quiet on the Western Front',
#   'Edward Berger ',
#   'None',
#   148,
#   2022,
#   7.8,
#   74,
#   'All Quiet on the Western Front',
#   '  Felix Kammerer',
#   ' Albrecht Schuch',
#   ' Aaron Hilmer',
#   ' Moritz Klaus',
#   205281,
#   'Action',
#   ' Drama',
#   ' War',
#   0,
#   'PG-13'),
#  (134,
#   'Drive (I)',
#   'Nicolas Winding Refn ',
#   'None',
#   100,
#   2011,
#   7.8,
#   78,
#   'Drive (I)',
#   '  Ryan Gosling',
#   ' Carey Mulligan',
#   ' Bryan Cranston',
#   ' Albert Brooks',
#   664299,
#   'Action',
#   ' Drama',
#   'None',
#   35.06,
#   'PG-13'),
#  (135,
#   'Rogue One: A Star Wars Story',
#   'Gareth Edwards ',
#   'None',
#   133,
#   2016,
#   7.8,
#   44,
#   'Rogue One: A Star Wars Story',
#   '  Felicity Jones',
#   ' Diego Luna',
#   ' Alan Tudyk',
#   ' Donnie Yen',
#   657650,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   532.18,
#   'R'),
#  (136,
#   'Star Wars: Episode VII - The Force Awakens',
#   'J.J. Abrams ',
#   'None',
#   138,
#   2015,
#   7.8,
#   87,
#   'Star Wars: Episode VII - The Force Awakens',
#   '  Daisy Ridley',
#   ' John Boyega',
#   ' Oscar Isaac',
#   ' Domhnall Gleeson',
#   947209,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   936.66,
#   'PG-13'),
#  (137,
#   'Apocalypto',
#   'Mel Gibson ',
#   'None',
#   139,
#   2006,
#   7.8,
#   75,
#   'Apocalypto',
#   '  Gerardo Taracena',
#   ' Raoul Max Trujillo',
#   ' Dalia HernÃƒÂ¡ndez',
#   ' Rudy Youngblood',
#   320106,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   50.87,
#   'PG'),
#  (138,
#   'Dunkirk',
#   'Christopher Nolan ',
#   'None',
#   106,
#   2017,
#   7.8,
#   87,
#   'Dunkirk',
#   '  Fionn Whitehead',
#   ' Barry Keoghan',
#   ' Mark Rylance',
#   ' Tom Hardy',
#   682150,
#   'Action',
#   ' Drama',
#   ' History',
#   188.37,
#   'R'),
#  (139,
#   'Ghostbusters',
#   'Ivan Reitman ',
#   'None',
#   105,
#   1984,
#   7.8,
#   68,
#   'Ghostbusters',
#   '  Bill Murray',
#   ' Dan Aykroyd',
#   ' Sigourney Weaver',
#   ' Harold Ramis',
#   425653,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   238.63,
#   'R'),
#  (139,
#   'Ghostbusters',
#   'Ivan Reitman ',
#   'None',
#   105,
#   1984,
#   7.8,
#   68,
#   'Ghostbusters',
#   '  Melissa McCarthy',
#   ' Kristen Wiig',
#   ' Kate McKinnon',
#   ' Leslie Jones',
#   236932,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   128.34,
#   'PG-13'),
#  (140,
#   'Predator',
#   'John McTiernan ',
#   'None',
#   107,
#   1987,
#   7.8,
#   73,
#   'Predator',
#   '  Arnold Schwarzenegger',
#   ' Carl Weathers',
#   ' Kevin Peter Hall',
#   ' Elpidia Carrillo',
#   434375,
#   'Action',
#   ' Adventure',
#   ' Horror',
#   59.74,
#   'PG-13'),
#  (141,
#   'Hot Fuzz',
#   'Edgar Wright ',
#   'None',
#   121,
#   2007,
#   7.8,
#   86,
#   'Hot Fuzz',
#   '  Simon Pegg',
#   ' Nick Frost',
#   ' Martin Freeman',
#   ' Bill Nighy',
#   517068,
#   'Action',
#   ' Comedy',
#   ' Mystery',
#   23.64,
#   'PG-13'),
#  (142,
#   'Captain America: Civil War',
#   ' Anthony Russo',
#   ' Joe Russo ',
#   147,
#   2016,
#   7.8,
#   94,
#   'Captain America: Civil War',
#   '  Chris Evans',
#   ' Robert Downey Jr.',
#   ' Scarlett Johansson',
#   ' Sebastian Stan',
#   811441,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   408.08,
#   'PG-13'),
#  (143,
#   'Taken (I)',
#   'Pierre Morel ',
#   'None',
#   90,
#   2008,
#   7.8,
#   93,
#   'Taken (I)',
#   '  Liam Neeson',
#   ' Maggie Grace',
#   ' Famke Janssen',
#   ' Leland Orser',
#   614638,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   145,
#   'PG-13'),
#  (144,
#   'Skyfall',
#   'Sam Mendes ',
#   'None',
#   143,
#   2012,
#   7.8,
#   77,
#   'Skyfall',
#   '  Daniel Craig',
#   ' Javier Bardem',
#   ' Naomie Harris',
#   ' Judi Dench',
#   709652,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   304.36,
#   'PG-13'),
#  (145,
#   'Captain America: The Winter Soldier',
#   'Anthony Russo',
#   ' Joe Russo ',
#   136,
#   2014,
#   7.8,
#   84,
#   'Captain America: The Winter Soldier',
#   '  Chris Evans',
#   ' Samuel L. Jackson',
#   ' Scarlett Johansson',
#   ' Robert Redford',
#   866461,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   259.77,
#   'PG'),
#  (146,
#   'The Fugitive',
#   'Andrew Davis ',
#   'None',
#   130,
#   1993,
#   7.8,
#   90,
#   'The Fugitive',
#   '  Harrison Ford',
#   ' Tommy Lee Jones',
#   ' Sela Ward',
#   ' Julianne Moore',
#   304568,
#   'Action',
#   ' Crime',
#   ' Drama',
#   183.88,
#   'PG-13'),
#  (147,
#   'Big Hero 6',
#   'Don Hall',
#   'Chris Williams ',
#   102,
#   2014,
#   7.8,
#   59,
#   'Big Hero 6',
#   '  Ryan Potter',
#   ' Scott Adsit',
#   ' Jamie Chung',
#   ' T.J. Miller',
#   476426,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   222.53,
#   'Not Rated'),
#  (148,
#   'Captain Phillips',
#   'Paul Greengrass ',
#   'None',
#   134,
#   2013,
#   7.8,
#   58,
#   'Captain Phillips',
#   '  Tom Hanks',
#   ' Barkhad Abdi',
#   ' Barkhad Abdirahman',
#   ' Catherine Keener',
#   473214,
#   'Action',
#   ' Biography',
#   ' Crime',
#   107.1,
#   'R'),
#  (149,
#   'I Saw the Devil',
#   'Jee-woon Kim ',
#   'None',
#   144,
#   2010,
#   7.8,
#   63,
#   'I Saw the Devil',
#   '  Lee Byung-hun',
#   ' Choi Min-sik',
#   ' Jeon Gook-hwan',
#   ' Ho-jin Chun',
#   137088,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0.13,
#   'PG-13'),
#  (150,
#   'The Last Samurai',
#   'Edward Zwick ',
#   'None',
#   154,
#   2003,
#   7.8,
#   67,
#   'The Last Samurai',
#   '  Tom Cruise',
#   ' Ken Watanabe',
#   ' Billy Connolly',
#   ' William Atherton',
#   452033,
#   'Action',
#   ' Drama',
#   'None',
#   111.11,
#   'PG-13'),
#  (151,
#   'Serenity',
#   'Joss Whedon ',
#   'None',
#   119,
#   2005,
#   7.8,
#   52,
#   'Serenity',
#   '  Nathan Fillion',
#   ' Gina Torres',
#   ' Chiwetel Ejiofor',
#   ' Alan Tudyk',
#   300284,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   25.51,
#   'R'),
#  (152,
#   'Thirteen Lives',
#   'Ron Howard ',
#   'None',
#   147,
#   2022,
#   7.8,
#   82,
#   'Thirteen Lives',
#   '  Viggo Mortensen',
#   ' Colin Farrell',
#   ' Joel Edgerton',
#   ' Tom Bateman',
#   60640,
#   'Action',
#   ' Adventure',
#   ' Biography',
#   0,
#   'PG'),
#  (153,
#   'The Fighter (I)',
#   'David O. Russell ',
#   'None',
#   116,
#   2010,
#   7.8,
#   52,
#   'The Fighter (I)',
#   '  Mark Wahlberg',
#   ' Christian Bale',
#   ' Amy Adams',
#   ' Melissa Leo',
#   376930,
#   'Action',
#   ' Biography',
#   ' Drama',
#   93.62,
#   'Not Rated'),
#  (154,
#   'How to Train Your Dragon 2',
#   'Dean DeBlois ',
#   'None',
#   102,
#   2014,
#   7.8,
#   86,
#   'How to Train Your Dragon 2',
#   '  Jay Baruchel',
#   ' Cate Blanchett',
#   ' Gerard Butler',
#   ' Craig Ferguson',
#   347484,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   177,
#   'Not Rated'),
#  (155,
#   'The Chaser',
#   'Na Hong-jin ',
#   'None',
#   125,
#   2008,
#   7.8,
#   68,
#   'The Chaser',
#   '  Kim Yoon-seok',
#   ' Ha Jung-woo',
#   ' Yeong-hie Seo',
#   ' Kim Yoo-jeong',
#   69183,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'Not Rated'),
#  (156,
#   'Aguirre the Wrath of God',
#   'Werner Herzog ',
#   'None',
#   95,
#   1972,
#   7.8,
#   66,
#   'Aguirre the Wrath of God',
#   '  Klaus Kinski',
#   ' Ruy Guerra',
#   ' Helena Rojo',
#   ' Del Negro',
#   59107,
#   'Action',
#   ' Adventure',
#   ' Biography',
#   0,
#   'PG'),
#  (157,
#   'Ninja Scroll',
#   'Yoshiaki Kawajiri ',
#   'None',
#   94,
#   1993,
#   7.8,
#   56,
#   'Ninja Scroll',
#   '  KÃƒÂ´ichi Yamadera',
#   ' Emi Shinohara',
#   ' Takeshi Aono',
#   ' Osamu Saka',
#   38856,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   ' ',
#   'R'),
#  (158,
#   'Batman: Mask of the Phantasm',
#   ' Bruce Timm',
#   'Dan Riba',
#   76,
#   1993,
#   7.8,
#   78,
#   'Batman: Mask of the Phantasm',
#   '  Kevin Conroy',
#   ' Dana Delany',
#   ' Hart Bochner',
#   ' Stacy Keach',
#   53489,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   5.62,
#   'TV-14'),
#  (159,
#   'The Killer',
#   'John Woo ',
#   'None',
#   111,
#   1989,
#   7.8,
#   74,
#   'The Killer',
#   '  Chow Yun-Fat',
#   ' Danny Lee',
#   ' Sally Yeh',
#   ' Kong Chu',
#   49583,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  (160,
#   'Cowboy Bebop: The Movie',
#   ' Yoshiyuki Takei',
#   ' Hiroyuki Okiura',
#   115,
#   2001,
#   7.8,
#   70,
#   'Cowboy Bebop: The Movie',
#   '  Beau Billingslea',
#   ' Melissa Fahn',
#   ' Nicholas Guest',
#   ' KÃƒÂ´ichi Yamadera',
#   50654,
#   'Animation',
#   ' Action',
#   ' Crime',
#   1,
#   'TV-14'),
#  (161,
#   'Knockin on Heavens Door',
#   'Thomas Jahn ',
#   'None',
#   87,
#   1997,
#   7.8,
#   73,
#   'Knockin on Heavens Door',
#   '  Til Schweiger',
#   ' Jan Josef Liefers',
#   ' Thierry van Werveke',
#   ' Moritz Bleibtreu',
#   32078,
#   'Action',
#   ' Crime',
#   ' Comedy',
#   0,
#   'PG-13'),
#  (162,
#   'Minnal Murali',
#   'Basil Joseph ',
#   'None',
#   158,
#   2021,
#   7.8,
#   65,
#   'Minnal Murali',
#   '  Tovino Thomas',
#   ' Guru Somasundaram',
#   ' Aju Varghese',
#   ' Baiju',
#   31064,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'R'),
#  (163,
#   'Avatar: The Way of Water',
#   'James Cameron ',
#   'None',
#   192,
#   2022,
#   7.7,
#   82,
#   'Avatar: The Way of Water',
#   '  Sam Worthington',
#   ' Zoe Saldana',
#   ' Sigourney Weaver',
#   ' Stephen Lang',
#   384846,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   659.68,
#   'PG-13'),
#  (164,
#   'Kingsman: The Secret Service',
#   'Matthew Vaughn ',
#   'None',
#   129,
#   2014,
#   7.7,
#   80,
#   'Kingsman: The Secret Service',
#   '  Colin Firth',
#   ' Taron Egerton',
#   ' Samuel L. Jackson',
#   ' Michael Caine',
#   686315,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   128.26,
#   'PG-13'),
#  (165,
#   'Star Trek Into Darkness',
#   'J.J. Abrams ',
#   'None',
#   132,
#   2013,
#   7.7,
#   77,
#   'Star Trek Into Darkness',
#   '  Chris Pine',
#   ' Zachary Quinto',
#   ' Zoe Saldana',
#   ' Benedict Cumberbatch',
#   489293,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   228.78,
#   'R'),
#  (166,
#   'Mission: Impossible - Fallout',
#   'Christopher McQuarrie ',
#   'None',
#   147,
#   2018,
#   7.7,
#   66,
#   'Mission: Impossible - Fallout',
#   '  Tom Cruise',
#   ' Henry Cavill',
#   ' Ving Rhames',
#   ' Simon Pegg',
#   344841,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   220.16,
#   'PG-13'),
#  (167,
#   'Black Hawk Down',
#   'Ridley Scott ',
#   'None',
#   144,
#   2001,
#   7.7,
#   56,
#   'Black Hawk Down',
#   '  Josh Hartnett',
#   ' Ewan McGregor',
#   ' Tom Sizemore',
#   ' Eric Bana',
#   407147,
#   'Action',
#   ' Drama',
#   ' History',
#   108.64,
#   'R'),
#  (168,
#   'The Count of Monte Cristo',
#   'Kevin Reynolds ',
#   'None',
#   131,
#   2002,
#   7.7,
#   73,
#   'The Count of Monte Cristo',
#   '  Jim Caviezel',
#   ' Guy Pearce',
#   ' Christopher Adamson',
#   ' JB Blanc',
#   142602,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   54.23,
#   'R'),
#  (169,
#   '3:10 to Yuma',
#   'James Mangold ',
#   'None',
#   122,
#   2007,
#   7.7,
#   80,
#   '3:10 to Yuma',
#   '  Russell Crowe',
#   ' Christian Bale',
#   ' Ben Foster',
#   ' Logan Lerman',
#   320222,
#   'Action',
#   ' Crime',
#   ' Drama',
#   53.61,
#   'PG'),
#  (170,
#   'The Last of the Mohicans',
#   'Michael Mann ',
#   'None',
#   112,
#   1992,
#   7.7,
#   57,
#   'The Last of the Mohicans',
#   '  Daniel Day-Lewis',
#   ' Madeleine Stowe',
#   ' Russell Means',
#   ' Eric Schweig',
#   177524,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   75.51,
#   'PG-13'),
#  (171,
#   'The Lego Movie',
#   ' Phil Lord',
#   'Christopher Miller ',
#   100,
#   2014,
#   7.7,
#   68,
#   'The Lego Movie',
#   '  Chris Pratt',
#   ' Will Ferrell',
#   ' Elizabeth Banks',
#   ' Will Arnett',
#   369039,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   257.76,
#   'R'),
#  (172,
#   'X-Men: First Class',
#   'Matthew Vaughn ',
#   'None',
#   131,
#   2011,
#   7.7,
#   73,
#   'X-Men: First Class',
#   '  James McAvoy',
#   ' Michael Fassbender',
#   ' Jennifer Lawrence',
#   ' Kevin Bacon',
#   704696,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   146.41,
#   'Approved'),
#  (173,
#   'Training Day',
#   'Antoine Fuqua ',
#   'None',
#   122,
#   2001,
#   7.7,
#   79,
#   'Training Day',
#   '  Denzel Washington',
#   ' Ethan Hawke',
#   ' Scott Glenn',
#   ' Tom Berenger',
#   450131,
#   'Action',
#   ' Crime',
#   ' Drama',
#   76.63,
#   'R'),
#  (174,
#   'The Dirty Dozen',
#   'Robert Aldrich ',
#   'None',
#   150,
#   1967,
#   7.7,
#   63,
#   'The Dirty Dozen',
#   '  Lee Marvin',
#   ' Ernest Borgnine',
#   ' Charles Bronson',
#   ' John Cassavetes',
#   76085,
#   'Action',
#   ' Adventure',
#   ' War',
#   45.3,
#   'R'),
#  (175,
#   'Man on Fire',
#   'Tony Scott ',
#   'None',
#   146,
#   2004,
#   7.7,
#   68,
#   'Man on Fire',
#   '  Denzel Washington',
#   ' Christopher Walken',
#   ' Dakota Fanning',
#   ' Radha Mitchell',
#   371975,
#   'Action',
#   ' Crime',
#   ' Drama',
#   77.91,
#   'Approved'),
#  (176,
#   'First Blood',
#   'Ted Kotcheff ',
#   'None',
#   93,
#   1982,
#   7.7,
#   68,
#   'First Blood',
#   '  Sylvester Stallone',
#   ' Brian Dennehy',
#   ' Richard Crenna',
#   ' Bill McKinney',
#   262244,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   47.21,
#   'R'),
#  (177,
#   'The Magnificent Seven',
#   'John Sturges ',
#   'None',
#   128,
#   1960,
#   7.7,
#   81,
#   'The Magnificent Seven',
#   '  Denzel Washington',
#   ' Chris Pratt',
#   ' Ethan Hawke',
#   ' Vincent DOnofrio',
#   219169,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   93.43,
#   'PG-13'),
#  (177,
#   'The Magnificent Seven',
#   'John Sturges ',
#   'None',
#   128,
#   1960,
#   7.7,
#   81,
#   'The Magnificent Seven',
#   '  Yul Brynner',
#   ' Steve McQueen',
#   ' Charles Bronson',
#   ' Eli Wallach',
#   98239,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   4.91,
#   'R'),
#  (178,
#   'Kung Fu Hustle',
#   'Stephen Chow ',
#   'None',
#   99,
#   2004,
#   7.7,
#   83,
#   'Kung Fu Hustle',
#   '  Stephen Chow',
#   ' Wah Yuen',
#   ' Qiu Yuen',
#   ' Siu-Lung Leung',
#   144456,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   17.11,
#   'PG'),
#  (179,
#   'The Boondock Saints',
#   'Troy Duffy ',
#   'None',
#   108,
#   1999,
#   7.7,
#   58,
#   'The Boondock Saints',
#   '  Willem Dafoe',
#   ' Sean Patrick Flanery',
#   ' Norman Reedus',
#   ' David Della Rocco',
#   243402,
#   'Action',
#   ' Thriller',
#   'None',
#   0.03,
#   'G'),
#  (180,
#   'Goldfinger',
#   'Guy Hamilton ',
#   'None',
#   110,
#   1964,
#   7.7,
#   71,
#   'Goldfinger',
#   '  Sean Connery',
#   ' Gert FrÃƒÂ¶be',
#   ' Honor Blackman',
#   ' Shirley Eaton',
#   195641,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   51.08,
#   'R'),
#  (181,
#   'The Longest Day',
#   ' Ken Annakin',
#   'Andrew Marton',
#   178,
#   1962,
#   7.7,
#   62,
#   'The Longest Day',
#   '  John Wayne',
#   ' Robert Ryan',
#   ' Richard Burton',
#   ' Henry Fonda',
#   57435,
#   'Action',
#   ' Drama',
#   ' History',
#   39.1,
#   'PG'),
# ...
#  (923,
#   'The Sum of All Fears',
#   'Phil Alden Robinson ',
#   'None',
#   124,
#   2002,
#   6.4,
#   29,
#   'The Sum of All Fears',
#   '  Ben Affleck',
#   ' Morgan Freeman',
#   ' Ian Mongrain',
#   ' Russell Bobbitt',
#   120272,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   118.91,
#   'R'),
#  (924,
#   'Angel Has Fallen',
#   'Ric Roman Waugh ',
#   'None',
#   121,
#   2019,
#   6.4,
#   43,
#   'Angel Has Fallen',
#   '  Gerard Butler',
#   ' Frederick Schmidt',
#   ' Danny Huston',
#   ' Rocci Boy Williams',
#   103088,
#   'Action',
#   ' Thriller',
#   'None',
#   69.03,
#   'R'),
#  (925,
#   'Army of Thieves',
#   'Matthias SchweighÃ¶fer ',
#   'None',
#   127,
#   2021,
#   6.4,
#   46,
#   'Army of Thieves',
#   '  Matthias SchweighÃƒÂ¶fer',
#   ' Nathalie Emmanuel',
#   ' Ruby O. Fee',
#   ' Stuart Martin',
#   82169,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (926,
#   'Revenge (II)',
#   'Coralie Fargeat ',
#   'None',
#   108,
#   2017,
#   6.4,
#   42,
#   'Revenge (II)',
#   '  Matilda Anna Ingrid Lutz',
#   ' Kevin Janssens',
#   ' Vincent Colombe',
#   ' Guillaume BouchÃƒÂ¨de',
#   45676,
#   'Action',
#   ' Drama',
#   ' Horror',
#   0.1,
#   'PG-13'),
#  (928,
#   'The Expendables',
#   'Sylvester Stallone ',
#   'None',
#   103,
#   2010,
#   6.4,
#   45,
#   'The Expendables',
#   '  Sylvester Stallone',
#   ' Jason Statham',
#   ' Jet Li',
#   ' Dolph Lundgren',
#   353039,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   103.07,
#   'PG-13'),
#  (929,
#   'Predators',
#   'NimrÃ³d Antal ',
#   'None',
#   107,
#   2010,
#   6.4,
#   46,
#   'Predators',
#   '  Adrien Brody',
#   ' Laurence Fishburne',
#   ' Topher Grace',
#   ' Alice Braga',
#   236893,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   52,
#   'PG-13'),
#  (930,
#   'Need for Speed',
#   'Scott Waugh ',
#   'None',
#   132,
#   2014,
#   6.4,
#   59,
#   'Need for Speed',
#   '  Aaron Paul',
#   ' Dominic Cooper',
#   ' Imogen Poots',
#   ' Kid Cudi',
#   174283,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   43.58,
#   'PG-13'),
#  (931,
#   'Hancock',
#   'Peter Berg ',
#   'None',
#   92,
#   2008,
#   6.4,
#   56,
#   'Hancock',
#   '  Will Smith',
#   ' Charlize Theron',
#   ' Jason Bateman',
#   ' Jae Head',
#   494952,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   227.95,
#   'PG-13'),
#  (932,
#   'The Three Musketeers',
#   'Stephen Herek ',
#   'None',
#   105,
#   1993,
#   6.4,
#   54,
#   'The Three Musketeers',
#   '  Charlie Sheen',
#   ' Kiefer Sutherland',
#   ' Chris ODonnell',
#   ' Oliver Platt',
#   56945,
#   'Action',
#   ' Adventure',
#   ' Romance',
#   53.9,
#   'R'),
#  (932,
#   'The Three Musketeers',
#   'Stephen Herek ',
#   'None',
#   105,
#   1993,
#   6.4,
#   54,
#   'The Three Musketeers',
#   '  Logan Lerman',
#   ' Matthew Macfadyen',
#   ' Ray Stevenson',
#   ' Milla Jovovich',
#   109837,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   20.38,
#   'PG-13'),
#  (933,
#   'Now You See Me 2',
#   'Jon M. Chu ',
#   'None',
#   129,
#   2016,
#   6.4,
#   25,
#   'Now You See Me 2',
#   '  Jesse Eisenberg',
#   ' Mark Ruffalo',
#   ' Woody Harrelson',
#   ' Dave Franco',
#   303122,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   65.08,
#   'R'),
#  (934,
#   'The World Is Not Enough',
#   'Michael Apted ',
#   'None',
#   128,
#   1999,
#   6.4,
#   63,
#   'The World Is Not Enough',
#   '  Pierce Brosnan',
#   ' Sophie Marceau',
#   ' Robert Carlyle',
#   ' Denise Richards',
#   204863,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   126.94,
#   'R'),
#  (935,
#   'Colombiana',
#   'Olivier Megaton ',
#   'None',
#   108,
#   2011,
#   6.4,
#   43,
#   'Colombiana',
#   '  Zoe Saldana',
#   ' Michael Vartan',
#   ' Callum Blue',
#   ' Jordi MollÃƒÂ\xa0',
#   104073,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   36.67,
#   'R'),
#  (936,
#   'Salt',
#   'Phillip Noyce ',
#   'None',
#   100,
#   2010,
#   6.4,
#   31,
#   'Salt',
#   '  Angelina Jolie',
#   ' Liev Schreiber',
#   ' Chiwetel Ejiofor',
#   ' Daniel Olbrychski',
#   321431,
#   'Action',
#   ' Thriller',
#   'None',
#   118.31,
#   'PG-13'),
#  (937,
#   'Savages (I)',
#   'Oliver Stone ',
#   'None',
#   131,
#   2012,
#   6.4,
#   46,
#   'Savages (I)',
#   '  Aaron Taylor-Johnson',
#   ' Taylor Kitsch',
#   ' Blake Lively',
#   ' Benicio Del Toro',
#   132296,
#   'Action',
#   ' Crime',
#   ' Drama',
#   47.38,
#   'PG'),
#  (938,
#   'Pain & Gain',
#   'Michael Bay ',
#   'None',
#   129,
#   2013,
#   6.4,
#   62,
#   'Pain & Gain',
#   '  Mark Wahlberg',
#   ' Dwayne Johnson',
#   ' Anthony Mackie',
#   ' Tony Shalhoub',
#   222505,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   49.88,
#   'R'),
#  (939,
#   'Faster',
#   'George Tillman Jr. ',
#   'None',
#   98,
#   2010,
#   6.4,
#   46,
#   'Faster',
#   '  Dwayne Johnson',
#   ' Billy Bob Thornton',
#   ' Maggie Grace',
#   ' Mauricio Lopez',
#   109851,
#   'Action',
#   ' Crime',
#   ' Drama',
#   23.24,
#   'PG-13'),
#  (940,
#   'The Vault',
#   ' Jaume BalaguerÃ³',
#   'None',
#   118,
#   2021,
#   6.4,
#   52,
#   'The Vault',
#   '  Freddie Highmore',
#   ' Astrid BergÃƒÂ¨s-Frisbey',
#   ' Sam Riley',
#   ' Liam Cunningham',
#   28033,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (941,
#   'Rat Race',
#   'Jerry Zucker ',
#   'None',
#   112,
#   2001,
#   6.4,
#   51,
#   'Rat Race',
#   '  Breckin Meyer',
#   ' Amy Smart',
#   ' Whoopi Goldberg',
#   ' Vince Vieluf',
#   119422,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   56.62,
#   'PG'),
#  (942,
#   'Monsters vs. Aliens',
#   ' Rob Letterman',
#   'Conrad Vernon ',
#   94,
#   2009,
#   6.4,
#   39,
#   'Monsters vs. Aliens',
#   '  Reese Witherspoon',
#   ' Rainn Wilson',
#   ' Stephen Colbert',
#   ' Seth Rogen',
#   168926,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   198.35,
#   'R'),
#  (943,
#   'Tango & Cash',
#   ' Andrey Konchalovskiy',
#   'Albert Magnoli',
#   104,
#   1989,
#   6.4,
#   32,
#   'Tango & Cash',
#   '  Sylvester Stallone',
#   ' Kurt Russell',
#   ' Teri Hatcher',
#   ' Jack Palance',
#   109513,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   63.41,
#   'R'),
#  (944,
#   'Star Trek: Nemesis',
#   'Stuart Baird ',
#   'None',
#   116,
#   2002,
#   6.4,
#   69,
#   'Star Trek: Nemesis',
#   '  Patrick Stewart',
#   ' Jonathan Frakes',
#   ' Brent Spiner',
#   ' LeVar Burton',
#   81655,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   43.25,
#   'R'),
#  (945,
#   'The Lone Ranger',
#   'Gore Verbinski ',
#   'None',
#   150,
#   2013,
#   6.4,
#   54,
#   'The Lone Ranger',
#   '  Johnny Depp',
#   ' Armie Hammer',
#   ' William Fichtner',
#   ' Tom Wilkinson',
#   239201,
#   'Action',
#   ' Adventure',
#   ' Western',
#   89.3,
#   'PG'),
#  (946,
#   'Here Comes the Boom',
#   'Frank Coraci ',
#   'None',
#   105,
#   2012,
#   6.4,
#   23,
#   'Here Comes the Boom',
#   '  Kevin James',
#   ' Salma Hayek',
#   ' Henry Winkler',
#   ' Greg Germann',
#   93442,
#   'Action',
#   ' Comedy',
#   ' Sport',
#   45.29,
#   'R'),
#  (947,
#   'The Taking of Pelham 123',
#   'Tony Scott ',
#   'None',
#   106,
#   2009,
#   6.4,
#   45,
#   'The Taking of Pelham 123',
#   '  Denzel Washington',
#   ' John Travolta',
#   ' Luis GuzmÃƒÂ¡n',
#   ' Victor Gojcaj',
#   202233,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   65.45,
#   'R'),
#  (948,
#   'Kickboxer',
#   ' Mark DiSalle',
#   ' David Worth ',
#   97,
#   1989,
#   6.4,
#   58,
#   'Kickboxer',
#   '  Jean-Claude Van Damme',
#   ' Dennis Alexio',
#   ' Dennis Chan',
#   ' Michel Qissi',
#   57969,
#   'Action',
#   ' Sport',
#   ' Thriller',
#   14.7,
#   'PG'),
#  (949,
#   'The Purge: Anarchy',
#   'James DeMonaco ',
#   'None',
#   103,
#   2014,
#   6.4,
#   31,
#   'The Purge: Anarchy',
#   '  Frank Grillo',
#   ' Carmen Ejogo',
#   ' Zach Gilford',
#   ' Kiele Sanchez',
#   156664,
#   'Action',
#   ' Horror',
#   ' Sci-Fi',
#   71.96,
#   'PG-13'),
#  (950,
#   'Star Trek: Insurrection',
#   'Jonathan Frakes ',
#   'None',
#   103,
#   1998,
#   6.4,
#   48,
#   'Star Trek: Insurrection',
#   '  Patrick Stewart',
#   ' Jonathan Frakes',
#   ' Brent Spiner',
#   ' LeVar Burton',
#   77360,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   70.12,
#   'PG-13'),
#  (951,
#   'The Jackal',
#   'Michael Caton-Jones ',
#   'None',
#   124,
#   1997,
#   6.4,
#   71,
#   'The Jackal',
#   '  Bruce Willis',
#   ' Richard Gere',
#   ' Sidney Poitier',
#   ' Diane Venora',
#   120550,
#   'Action',
#   ' Crime',
#   ' Drama',
#   54.93,
#   'R'),
#  (952,
#   'Chaos (II)',
#   'Tony Giglio ',
#   'None',
#   106,
#   2005,
#   6.4,
#   57,
#   'Chaos (II)',
#   '  Jason Statham',
#   ' Ryan Phillippe',
#   ' Wesley Snipes',
#   ' Henry Czerny',
#   56176,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (953,
#   'The Angry Birds Movie 2',
#   ' Thurop Van Orman ',
#   'John Rice',
#   97,
#   2019,
#   6.4,
#   65,
#   'The Angry Birds Movie 2',
#   '  Jason Sudeikis',
#   ' Josh Gad',
#   ' Leslie Jones',
#   ' Bill Hader',
#   32069,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   41.66,
#   'R'),
#  (954,
#   'DragonHeart',
#   'Rob Cohen ',
#   'None',
#   103,
#   1996,
#   6.4,
#   61,
#   'DragonHeart',
#   '  Dennis Quaid',
#   ' Sean Connery',
#   ' Dina Meyer',
#   ' Pete Postlethwaite',
#   99574,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   51.37,
#   'Not Rated'),
#  (955,
#   'Behind Enemy Lines',
#   'John Moore ',
#   'None',
#   106,
#   2001,
#   6.4,
#   54,
#   'Behind Enemy Lines',
#   '  Gene Hackman',
#   ' Owen Wilson',
#   ' Gabriel Macht',
#   ' Charles Malik Whitfield',
#   108887,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   59.07,
#   'R'),
#  (956,
#   'Killer Elite',
#   'Gary McKendry ',
#   'None',
#   116,
#   2011,
#   6.4,
#   44,
#   'Killer Elite',
#   '  Jason Statham',
#   ' Clive Owen',
#   ' Robert De Niro',
#   ' Dominic Purcell',
#   132908,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   25.12,
#   'R'),
#  (957,
#   'Live by Night',
#   'Ben Affleck ',
#   'None',
#   129,
#   2016,
#   6.4,
#   49,
#   'Live by Night',
#   '  Ben Affleck',
#   ' Elle Fanning',
#   ' Brendan Gleeson',
#   ' Chris Messina',
#   58557,
#   'Action',
#   ' Crime',
#   ' Drama',
#   10.38,
#   'R'),
#  (958,
#   'Darkman',
#   'Sam Raimi ',
#   'None',
#   96,
#   1990,
#   6.4,
#   42,
#   'Darkman',
#   '  Liam Neeson',
#   ' Frances McDormand',
#   ' Colin Friels',
#   ' Larry Drake',
#   67131,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   33.88,
#   'R'),
#  (959,
#   'Kill List',
#   'Ben Wheatley ',
#   'None',
#   95,
#   2011,
#   6.4,
#   62,
#   'Kill List',
#   '  Neil Maskell',
#   ' MyAnna Buring',
#   ' Harry Simpson',
#   ' Michael Smiley',
#   42776,
#   'Action',
#   ' Crime',
#   ' Horror',
#   0.03,
#   'PG'),
#  (960,
#   'Act of Valor',
#   ' Mike McCoy',
#   ' Scott Waugh ',
#   110,
#   2012,
#   6.4,
#   61,
#   'Act of Valor',
#   '  Alex Veadov',
#   ' Roselyn Sanchez',
#   ' Nestor Serrano',
#   ' Rorke Denver',
#   70351,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   70.01,
#   'R'),
#  (961,
#   'The Siege',
#   'Edward Zwick ',
#   'None',
#   116,
#   1998,
#   6.4,
#   40,
#   'The Siege',
#   '  Denzel Washington',
#   ' Bruce Willis',
#   ' Annette Bening',
#   ' Tony Shalhoub',
#   75341,
#   'Action',
#   ' Thriller',
#   'None',
#   40.98,
#   'PG-13'),
#  (962,
#   'Lets Be Cops',
#   'Luke Greenfield ',
#   'None',
#   104,
#   2014,
#   6.4,
#   41,
#   'Lets Be Cops',
#   '  Jake Johnson',
#   ' Damon Wayans Jr.',
#   ' Rob Riggle',
#   ' Nina Dobrev',
#   137116,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   82.39,
#   'R'),
#  (963,
#   'Daybreakers',
#   ' Michael Spierig',
#   'Peter Spierig ',
#   98,
#   2009,
#   6.4,
#   44,
#   'Daybreakers',
#   '  Ethan Hawke',
#   ' Willem Dafoe',
#   ' Sam Neill',
#   ' Harriet Minto-Day',
#   131647,
#   'Action',
#   ' Horror',
#   ' Sci-Fi',
#   30.1,
#   'R'),
#  (964,
#   'The Omega Man',
#   'Boris Sagal ',
#   'None',
#   98,
#   1971,
#   6.4,
#   48,
#   'The Omega Man',
#   '  Charlton Heston',
#   ' Anthony Zerbe',
#   ' Rosalind Cash',
#   ' Paul Koslo',
#   32780,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   8.72,
#   'R'),
#  (965,
#   'Shaft',
#   'Tim Story ',
#   'None',
#   111,
#   2019,
#   6.4,
#   35,
#   'Shaft',
#   '  Samuel L. Jackson',
#   ' Jessie T. Usher',
#   ' Richard Roundtree',
#   ' Regina Hall',
#   56020,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   21.36,
#   'R'),
#  (965,
#   'Shaft',
#   'Tim Story ',
#   'None',
#   111,
#   2019,
#   6.4,
#   35,
#   'Shaft',
#   '  Samuel L. Jackson',
#   ' Vanessa Williams',
#   ' Christian Bale',
#   ' Jeffrey Wright',
#   78758,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   70.33,
#   'R'),
#  (966,
#   'Snitch (I)',
#   'Ric Roman Waugh ',
#   'None',
#   112,
#   2013,
#   6.4,
#   43,
#   'Snitch (I)',
#   '  Dwayne Johnson',
#   ' Susan Sarandon',
#   ' Jon Bernthal',
#   ' Rafi Gavron',
#   90368,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   42.93,
#   'R'),
#  (967,
#   'Contraband',
#   'Baltasar KormÃ¡kur',
#   'None',
#   109,
#   2012,
#   6.4,
#   45,
#   'Contraband',
#   '  Mark Wahlberg',
#   ' Giovanni Ribisi',
#   ' Kate Beckinsale',
#   ' Robert Wahlberg',
#   124634,
#   'Action',
#   ' Crime',
#   ' Drama',
#   66.53,
#   'R'),
#  (968,
#   'The Prophecy',
#   'Gregory Widen ',
#   'None',
#   98,
#   1995,
#   6.4,
#   47,
#   'The Prophecy',
#   '  Christopher Walken',
#   ' Elias Koteas',
#   ' Virginia Madsen',
#   ' Eric Stoltz',
#   32169,
#   'Action',
#   ' Crime',
#   ' Drama',
#   16.12,
#   'R'),
#  (969,
#   'The Rover',
#   'David MichÃ´d',
#   'None',
#   103,
#   2014,
#   6.4,
#   39,
#   'The Rover',
#   '  Guy Pearce',
#   ' Robert Pattinson',
#   ' Scoot McNairy',
#   ' David Field',
#   49778,
#   'Action',
#   ' Crime',
#   ' Drama',
#   1.11,
#   'R'),
#  (970,
#   'Blood Father',
#   'Jean-FranÃ§ois Richet ',
#   'None',
#   88,
#   2016,
#   6.4,
#   63,
#   'Blood Father',
#   '  Mel Gibson',
#   ' Erin Moriarty',
#   ' Diego Luna',
#   ' Michael Parks',
#   65965,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (971,
#   'Just Cause',
#   'Arne Glimcher ',
#   'None',
#   102,
#   1995,
#   6.4,
#   40,
#   'Just Cause',
#   '  Sean Connery',
#   ' Laurence Fishburne',
#   ' Kate Capshaw',
#   ' Blair Underwood',
#   28245,
#   'Action',
#   ' Crime',
#   ' Drama',
#   36.85,
#   'R'),
#  (972,
#   'Black Death',
#   'Christopher Smith ',
#   'None',
#   102,
#   2010,
#   6.4,
#   68,
#   'Black Death',
#   '  Eddie Redmayne',
#   ' Sean Bean',
#   ' Carice van Houten',
#   ' Kimberley Nixon',
#   49676,
#   'Action',
#   ' Drama',
#   ' History',
#   0.02,
#   'R'),
#  (973,
#   'Batman: The Killing Joke',
#   'Sam Liu ',
#   'None',
#   76,
#   2016,
#   6.4,
#   42,
#   'Batman: The Killing Joke',
#   '  Kevin Conroy',
#   ' Mark Hamill',
#   ' Tara Strong',
#   ' Ray Wise',
#   59194,
#   'Animation',
#   ' Action',
#   ' Crime',
#   3.78,
#   'R'),
#  (974,
#   'Dead Man Down',
#   'Niels Arden Oplev ',
#   'None',
#   118,
#   2013,
#   6.4,
#   42,
#   'Dead Man Down',
#   '  Colin Farrell',
#   ' Noomi Rapace',
#   ' Dominic Cooper',
#   ' Terrence Howard',
#   69094,
#   'Action',
#   ' Crime',
#   ' Drama',
#   10.88,
#   'R'),
#  (975,
#   'Lock Up',
#   'John Flynn ',
#   'None',
#   109,
#   1989,
#   6.4,
#   40,
#   'Lock Up',
#   '  Sylvester Stallone',
#   ' Donald Sutherland',
#   ' John Amos',
#   ' Sonny Landham',
#   44680,
#   'Action',
#   ' Crime',
#   ' Drama',
#   22.1,
#   'PG-13'),
#  (976,
#   'Last Man Standing',
#   'Walter Hill ',
#   'None',
#   101,
#   1996,
#   6.4,
#   44,
#   'Last Man Standing',
#   '  Bruce Willis',
#   ' Bruce Dern',
#   ' William Sanderson',
#   ' Christopher Walken',
#   59505,
#   'Action',
#   ' Crime',
#   ' Drama',
#   17.6,
#   'R'),
#  (977,
#   'Black and Blue (I)',
#   'Deon Taylor ',
#   'None',
#   108,
#   2019,
#   6.4,
#   48,
#   'Black and Blue (I)',
#   '  Naomie Harris',
#   ' Tyrese Gibson',
#   ' Frank Grillo',
#   ' Mike Colter',
#   25207,
#   'Action',
#   ' Thriller',
#   'None',
#   22.06,
#   'R'),
#  (978,
#   'Basic',
#   'John McTiernan ',
#   'None',
#   98,
#   2003,
#   6.4,
#   44,
#   'Basic',
#   '  John Travolta',
#   ' Samuel L. Jackson',
#   ' Connie Nielsen',
#   ' Tim Daly',
#   64501,
#   'Action',
#   ' Crime',
#   ' Drama',
#   26.54,
#   'R'),
#  (979,
#   'Son of a Gun',
#   'Julius Avery ',
#   'None',
#   108,
#   2014,
#   6.4,
#   28,
#   'Son of a Gun',
#   '  Ewan McGregor',
#   ' Brenton Thwaites',
#   ' Alicia Vikander',
#   ' Brendan Kerkvliet',
#   28845,
#   'Action',
#   ' Crime',
#   ' Drama',
#   0,
#   'R'),
#  (980,
#   'Final Fantasy: The Spirits Within',
#   ' Hironobu Sakaguchi',
#   'Motonori Sakakibara ',
#   106,
#   2001,
#   6.4,
#   50,
#   'Final Fantasy: The Spirits Within',
#   '  Alec Baldwin',
#   ' Steve Buscemi',
#   ' Ming-Na Wen',
#   ' Ving Rhames',
#   83011,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   32.13,
#   'R'),
#  (981,
#   'From Paris with Love',
#   'Pierre Morel ',
#   'None',
#   92,
#   2010,
#   6.4,
#   46,
#   'From Paris with Love',
#   '  John Travolta',
#   ' Jonathan Rhys Meyers',
#   ' Kasia Smutniak',
#   ' Richard Durden',
#   119346,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   23.98,
#   'R'),
#  (982,
#   'Blood Work',
#   'Clint Eastwood ',
#   'None',
#   110,
#   2002,
#   6.4,
#   49,
#   'Blood Work',
#   '  Clint Eastwood',
#   ' Jeff Daniels',
#   ' Anjelica Huston',
#   ' Wanda De Jesus',
#   46351,
#   'Action',
#   ' Crime',
#   ' Drama',
#   26.2,
#   'R'),
#  (983,
#   'How I Live Now',
#   'Kevin Macdonald ',
#   'None',
#   101,
#   2013,
#   6.4,
#   42,
#   'How I Live Now',
#   '  Saoirse Ronan',
#   ' Tom Holland',
#   ' George MacKay',
#   ' Harley Bird',
#   31213,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   0.06,
#   'Not Rated'),
#  (984,
#   'Ned Kelly',
#   'Gregor Jordan ',
#   'None',
#   110,
#   2003,
#   6.4,
#   28,
#   'Ned Kelly',
#   '  Heath Ledger',
#   ' Orlando Bloom',
#   ' Geoffrey Rush',
#   ' Naomi Watts',
#   27565,
#   'Action',
#   ' Adventure',
#   ' Biography',
#   0.07,
#   'PG-13'),
#  ...]

# %% [markdown]
# 2) Display all movie names, Director, ratings, and gross collection where the genre is action.

# %%
six_in_one=c.execute("select table1.Movie_Name,table1.Director_1,table1.Director_2,table1.ratings_out_of10,table2.Grosscollection,table2.Genre_1 from table1 INNER JOIN table2 ON table1.Movie_Name=table2.Movie_Name where Genre_1 ='Action'")
six_in_one.fetchall()
# Out:
# [('The Dark Knight', 'Christopher Nolan ', 'None', 9, 534.86, 'Action'),
#  ('The Lord of the Rings: The Return of the King',
#   'Peter Jackson ',
#   'None',
#   9,
#   377.85,
#   'Action'),
#  ('Inception', 'Christopher Nolan ', 'None', 8.8, 292.58, 'Action'),
#  ('The Lord of the Rings: The Fellowship of the Ring',
#   'Peter Jackson ',
#   'None',
#   8.8,
#   315.54,
#   'Action'),
#  ('The Lord of the Rings: The Two Towers',
#   'Peter Jackson ',
#   'None',
#   8.8,
#   342.55,
#   'Action'),
#  ('The Matrix', 'Lana Wachowski', 'Lilly Wachowski', 8.7, 171.48, 'Action'),
#  ('Star Wars: Episode V - The Empire Strikes Back',
#   'Irvin Kershner ',
#   'None',
#   8.7,
#   290.48,
#   'Action'),
#  ('Soorarai Pottru', 'Sudha Kongara ', 'None', 8.7, 0, 'Action'),
#  ('Star Wars: Episode IV - A New Hope',
#   'George Lucas ',
#   'None',
#   8.6,
#   322.74,
#   'Action'),
#  ('Terminator 2: Judgment Day',
#   'James Cameron ',
#   'None',
#   8.6,
#   204.84,
#   'Action'),
#  ('Seven Samurai', 'Akira Kurosawa ', 'None', 8.6, 0.27, 'Action'),
#  ('Harakiri', 'Masaki Kobayashi ', 'None', 8.6, 0, 'Action'),
#  ('Sita Ramam', 'Hanu Raghavapudi ', 'None', 8.6, 0, 'Action'),
#  ('Gladiator', 'Ridley Scott ', 'None', 8.5, 187.71, 'Action'),
#  ('Avengers: Endgame', 'Anthony Russo', 'Joe Russo', 8.4, 858.37, 'Action'),
#  ('Indiana Jones and the Raiders of the Lost Ark',
#   'Steven Spielberg ',
#   'None',
#   8.4,
#   248.16,
#   'Action'),
#  ('Avengers: Infinity War',
#   'Anthony Russo',
#   'Joe Russo',
#   8.4,
#   678.82,
#   'Action'),
#  ('Oldboy', 'Park Chan-wook ', 'None', 8.4, 0.71, 'Action'),
#  ('Oldboy', 'Spike Lee ', 'None', 5.8, 0.71, 'Action'),
#  ('The Dark Knight Rises',
#   'Christopher Nolan ',
#   'None',
#   8.4,
#   448.14,
#   'Action'),
#  ('Aliens', 'James Cameron ', 'None', 8.4, 85.16, 'Action'),
#  ('Kaithi', 'Lokesh Kanagaraj ', 'None', 8.4, 0, 'Action'),
#  ('Asuran', 'Vetrimaaran ', 'None', 8.4, 0, 'Action'),
#  ('Top Gun: Maverick', 'Joseph Kosinski ', 'None', 8.3, 718.73, 'Action'),
#  ('Heat', 'Michael Mann ', 'None', 8.3, 67.44, 'Action'),
#  ('Star Wars: Episode VI - Return of the Jedi',
#   'Richard Marquand ',
#   'None',
#   8.3,
#   309.13,
#   'Action'),
#  ('North by Northwest', 'Alfred Hitchcock ', 'None', 8.3, 13.28, 'Action'),
#  ('Kantara', 'Rishab Shetty ', 'None', 8.3, 0, 'Action'),
#  ('Dangal', 'Nitesh Tiwari ', 'None', 8.3, 12.39, 'Action'),
#  ('K.G.F: Chapter 2', 'Prashanth Neel ', 'None', 8.3, 6.6, 'Action'),
#  ('Vikram', 'Lokesh Kanagaraj ', 'None', 8.3, 0, 'Action'),
#  ('Raatchasan', 'Ram Kumar ', 'None', 8.3, 0, 'Action'),
#  ('Shershaah', 'Vishnuvardhan ', 'None', 8.3, 0, 'Action'),
#  ('Guardians of the Galaxy Vol. 3', 'James Gunn ', 'None', 8.2, 0, 'Action'),
#  ('Spider-Man: No Way Home', 'Jon Watts ', 'None', 8.2, 804.75, 'Action'),
#  ('Jurassic Park', 'Steven Spielberg ', 'None', 8.2, 402.45, 'Action'),
#  ('Indiana Jones and the Last Crusade',
#   'Steven Spielberg ',
#   'None',
#   8.2,
#   197.17,
#   'Action'),
#  ('1917', 'Sam Mendes ', 'None', 8.2, 159.23, 'Action'),
#  ('Kill Bill: Vol. 1', 'Quentin Tarantino ', 'None', 8.2, 70.1, 'Action'),
#  ('Batman Begins', 'Christopher Nolan ', 'None', 8.2, 206.85, 'Action'),
#  ('Die Hard', 'John McTiernan ', 'None', 8.2, 83.01, 'Action'),
#  ('V for Vendetta', 'James McTeigue ', 'None', 8.2, 70.51, 'Action'),
#  ('Ran', 'Akira Kurosawa ', 'None', 8.2, 4.14, 'Action'),
#  ('Gangs of Wasseypur', 'Anurag Kashyap ', 'None', 8.2, 0, 'Action'),
#  ('Vikram Vedha', 'Gayatri', 'Pushkar', 8.2, 0, 'Action'),
#  ('Baahubali 2: The Conclusion',
#   'S.S. Rajamouli ',
#   'None',
#   8.2,
#   20.19,
#   'Action'),
#  ('Yojimbo', 'Akira Kurosawa ', 'None', 8.2, 0, 'Action'),
#  ('Uri: The Surgical Strike', 'Aditya Dhar ', 'None', 8.2, 4.19, 'Action'),
#  ('K.G.F: Chapter 1', 'Prashanth Neel ', 'None', 8.2, 0, 'Action'),
#  ('Sherlock Jr.', 'Buster Keaton ', 'None', 8.2, 0.98, 'Action'),
#  ('Rangasthalam 1985', 'Sukumar ', 'None', 8.2, 3.51, 'Action'),
#  ('The Mountain II', 'Alper Caglar ', 'None', 8.2, 0, 'Action'),
#  ('Paan Singh Tomar', 'Tigmanshu Dhulia ', 'None', 8.2, 0.04, 'Action'),
#  ('Mad Max: Fury Road', 'George Miller ', 'None', 8.1, 154.06, 'Action'),
#  ('Ford v Ferrari', 'James Mangold ', 'None', 8.1, 117.62, 'Action'),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Gore Verbinski ',
#   'None',
#   8.1,
#   305.41,
#   'Action'),
#  ('Blade Runner', 'Ridley Scott ', 'None', 8.1, 32.87, 'Action'),
#  ('The Terminator', 'James Cameron ', 'None', 8.1, 38.4, 'Action'),
#  ('Logan', 'James Mangold ', 'None', 8.1, 226.28, 'Action'),
#  ('Lock Stock and Two Smoking Barrels',
#   'Guy Ritchie ',
#   'None',
#   8.1,
#   3.9,
#   'Action'),
#  ('Warrior', 'Gavin OConnor ', 'None', 8.1, 13.66, 'Action'),
#  ('Rush (I)', 'Ron Howard ', 'None', 8.1, 26.95, 'Action'),
#  ('Sholay', 'Ramesh Sippy ', 'None', 8.1, 0, 'Action'),
#  ('Bajrangi Bhaijaan', 'Kabir Khan', 'Mehmet Tutkun', 8.1, 8.18, 'Action'),
#  ('The General', ' Clyde Bruckman', 'Buster Keaton ', 8.1, 1.03, 'Action'),
#  ('The Hidden Fortress', 'Akira Kurosawa ', 'None', 8.1, 0, 'Action'),
#  ('White Heat', 'Raoul Walsh ', 'None', 8.1, 0, 'Action'),
#  ('A Wednesday', 'Neeraj Pandey ', 'None', 8.1, 0, 'Action'),
#  ('Major', 'Sashi Kiran Tikka ', 'None', 8.1, 0, 'Action'),
#  ('Sarfarosh', 'John Mathew Matthan ', 'None', 8.1, 0, 'Action'),
#  ('Hera Pheri', 'Priyadarshan ', 'None', 8.1, 0, 'Action'),
#  ('Kaththi', 'A.R. Murugadoss ', 'None', 8.1, 0, 'Action'),
#  ('Thuppakki', 'A.R. Murugadoss ', 'None', 8.1, 0, 'Action'),
#  ('John Wick: Chapter 4', 'Chad Stahelski ', 'None', 8, 0, 'Action'),
#  ('Guardians of the Galaxy', 'James Gunn ', 'None', 8, 333.18, 'Action'),
#  ('Dune', 'David Lynch ', 'None', 6.3, 108.33, 'Action'),
#  ('Dune', 'Denis Villeneuve ', 'None', 8, 108.33, 'Action'),
#  ('Blade Runner 2049', 'Denis Villeneuve ', 'None', 8, 92.05, 'Action'),
#  ('Deadpool', 'Tim Miller ', 'None', 8, 363.07, 'Action'),
#  ('The Avengers', 'Joss Whedon ', 'None', 8, 623.28, 'Action'),
#  ('Zack Snyders Justice League', 'Zack Snyder ', 'None', 8, 0, 'Action'),
#  ('Casino Royale', 'Martin Campbell ', 'None', 8, 167.45, 'Action'),
#  ('The Revenant (I)',
#   'Alejandro G. IÃ±Ã¡rritu  ',
#   'None',
#   8,
#   183.64,
#   'Action'),
#  ('Kill Bill: Vol. 2', 'Quentin Tarantino ', 'None', 8, 66.21, 'Action'),
#  ('Ip Man', 'Wilson Yip ', 'None', 8, 0, 'Action'),
#  ('The Bourne Ultimatum', 'Paul Greengrass ', 'None', 8, 227.47, 'Action'),
#  ('Baahubali: The Beginning', 'S.S. Rajamouli ', 'None', 8, 6.74, 'Action'),
#  ('Infernal Affairs', 'Andrew Lau', 'Alan Mak ', 8, 0.17, 'Action'),
#  ('Elite Squad', ' JosÃ© Padilha ', 'None', 8, 0.01, 'Action'),
#  ('Haider', 'Vishal Bhardwaj ', 'None', 8, 0.9, 'Action'),
#  ('Sanjuro', 'Akira Kurosawa ', 'None', 8, 0, 'Action'),
#  ('Elite Squad 2: The Enemy Within',
#   ' JosÃ© Padilha ',
#   'None',
#   8,
#   0.1,
#   'Action'),
#  ('Tae Guk Gi: The Brotherhood of War',
#   'Je-kyu Kang ',
#   'None',
#   8,
#   1.11,
#   'Action'),
#  ('Andaz Apna Apna', 'Rajkumar Santoshi ', 'None', 8, 0, 'Action'),
#  ('Karthikeya 2', 'Chandoo Mondeti ', 'None', 8, 0, 'Action'),
#  ('Arjun Reddy', 'Sandeep Reddy Vanga ', 'None', 8, 0, 'Action'),
#  ('1: Nenokkadine', 'Sukumar ', 'None', 8, 0, 'Action'),
#  ('The Breath', 'Levent Semerci ', 'None', 8, 0, 'Action'),
#  ('Thor: Ragnarok', 'Taika Waititi ', 'None', 7.9, 315.06, 'Action'),
#  ('Avatar', 'James Cameron ', 'None', 7.9, 760.51, 'Action'),
#  ('Iron Man', 'Jon Favreau ', 'None', 7.9, 318.41, 'Action'),
#  ('Star Trek', 'J.J. Abrams ', 'None', 7.9, 257.73, 'Action'),
#  ('Edge of Tomorrow', 'Doug Liman ', 'None', 7.9, 100.21, 'Action'),
#  ('Children of Men', 'Alfonso CuarÃ³n', 'None', 7.9, 35.55, 'Action'),
#  ('X-Men: Days of Future Past',
#   'Bryan Singer ',
#   'None',
#   7.9,
#   233.92,
#   'Action'),
#  ('District 9', 'Neill Blomkamp ', 'None', 7.9, 115.65, 'Action'),
#  ('The Bourne Identity', 'Doug Liman ', 'None', 7.9, 121.66, 'Action'),
#  ('The Blues Brothers', 'John Landis ', 'None', 7.9, 57.23, 'Action'),
#  ('Crouching Tiger Hidden Dragon', 'Ang Lee ', 'None', 7.9, 128.08, 'Action'),
#  ('A Fistful of Dollars', 'Sergio Leone ', 'None', 7.9, 14.5, 'Action'),
#  ('The Raid 2', 'Gareth Evans ', 'None', 7.9, 2.63, 'Action'),
#  ('The Wild Bunch', 'Sam Peckinpah ', 'None', 7.9, 12.06, 'Action'),
#  ('Hero', 'Yimou Zhang ', 'None', 7.9, 53.71, 'Action'),
#  ('Letters from Iwo Jima', 'Clint Eastwood ', 'None', 7.9, 13.76, 'Action'),
#  ('A Taxi Driver', 'Hun Jang ', 'None', 7.9, 1.53, 'Action'),
#  ('The Adventures of Robin Hood',
#   ' Michael Curtiz',
#   'William Keighley ',
#   7.9,
#   3.98,
#   'Action'),
#  ('Baby (I)', 'Neeraj Pandey ', 'None', 7.9, 0, 'Action'),
#  ('Airlift', 'Raja Menon ', 'None', 7.9, 0, 'Action'),
#  ('Vishwaroopam', 'Kamal Haasan ', 'None', 7.9, 0, 'Action'),
#  ('Everything Everywhere All at Once',
#   'Daniel Kwan',
#   ' Daniel Scheinert ',
#   7.8,
#   72.86,
#   'Action'),
#  ('The Batman', 'Matt Reeves ', 'None', 7.8, 369.35, 'Action'),
#  ('RRR', 'S.S. Rajamouli ', 'None', 7.8, 14.5, 'Action'),
#  ('The Gentlemen', 'Guy Ritchie ', 'None', 7.8, 36.47, 'Action'),
#  ('All Quiet on the Western Front',
#   'Edward Berger ',
#   'None',
#   7.8,
#   0,
#   'Action'),
#  ('Drive (I)', 'Nicolas Winding Refn ', 'None', 7.8, 35.06, 'Action'),
#  ('Rogue One: A Star Wars Story',
#   'Gareth Edwards ',
#   'None',
#   7.8,
#   532.18,
#   'Action'),
#  ('Star Wars: Episode VII - The Force Awakens',
#   'J.J. Abrams ',
#   'None',
#   7.8,
#   936.66,
#   'Action'),
#  ('Apocalypto', 'Mel Gibson ', 'None', 7.8, 50.87, 'Action'),
#  ('Dunkirk', 'Christopher Nolan ', 'None', 7.8, 188.37, 'Action'),
#  ('Ghostbusters', 'Ivan Reitman ', 'None', 7.8, 238.63, 'Action'),
#  ('Ghostbusters', 'Paul Feig ', 'None', 6.8, 238.63, 'Action'),
#  ('Predator', 'John McTiernan ', 'None', 7.8, 59.74, 'Action'),
#  ('Hot Fuzz', 'Edgar Wright ', 'None', 7.8, 23.64, 'Action'),
#  ('Captain America: Civil War',
#   ' Anthony Russo',
#   ' Joe Russo ',
#   7.8,
#   408.08,
#   'Action'),
#  ('Taken (I)', 'Pierre Morel ', 'None', 7.8, 145, 'Action'),
#  ('Skyfall', 'Sam Mendes ', 'None', 7.8, 304.36, 'Action'),
#  ('Captain America: The Winter Soldier',
#   'Anthony Russo',
#   ' Joe Russo ',
#   7.8,
#   259.77,
#   'Action'),
#  ('The Fugitive', 'Andrew Davis ', 'None', 7.8, 183.88, 'Action'),
#  ('Captain Phillips', 'Paul Greengrass ', 'None', 7.8, 107.1, 'Action'),
#  ('I Saw the Devil', 'Jee-woon Kim ', 'None', 7.8, 0.13, 'Action'),
#  ('The Last Samurai', 'Edward Zwick ', 'None', 7.8, 111.11, 'Action'),
#  ('Serenity', 'Joss Whedon ', 'None', 7.8, 25.51, 'Action'),
#  ('Thirteen Lives', 'Ron Howard ', 'None', 7.8, 0, 'Action'),
#  ('The Fighter (I)', 'David O. Russell ', 'None', 7.8, 93.62, 'Action'),
#  ('The Chaser', 'Na Hong-jin ', 'None', 7.8, 0, 'Action'),
#  ('Aguirre the Wrath of God', 'Werner Herzog ', 'None', 7.8, 0, 'Action'),
#  ('The Killer', 'John Woo ', 'None', 7.8, ' ', 'Action'),
#  ('Knockin on Heavens Door', 'Thomas Jahn ', 'None', 7.8, 0, 'Action'),
#  ('Minnal Murali', 'Basil Joseph ', 'None', 7.8, ' ', 'Action'),
#  ('Avatar: The Way of Water', 'James Cameron ', 'None', 7.7, 659.68, 'Action'),
#  ('Kingsman: The Secret Service',
#   'Matthew Vaughn ',
#   'None',
#   7.7,
#   128.26,
#   'Action'),
#  ('Star Trek Into Darkness', 'J.J. Abrams ', 'None', 7.7, 228.78, 'Action'),
#  ('Mission: Impossible - Fallout',
#   'Christopher McQuarrie ',
#   'None',
#   7.7,
#   220.16,
#   'Action'),
#  ('Black Hawk Down', 'Ridley Scott ', 'None', 7.7, 108.64, 'Action'),
#  ('The Count of Monte Cristo',
#   'Kevin Reynolds ',
#   'None',
#   7.7,
#   54.23,
#   'Action'),
#  ('3:10 to Yuma', 'James Mangold ', 'None', 7.7, 53.61, 'Action'),
#  ('The Last of the Mohicans', 'Michael Mann ', 'None', 7.7, 75.51, 'Action'),
#  ('X-Men: First Class', 'Matthew Vaughn ', 'None', 7.7, 146.41, 'Action'),
#  ('Training Day', 'Antoine Fuqua ', 'None', 7.7, 76.63, 'Action'),
#  ('The Dirty Dozen', 'Robert Aldrich ', 'None', 7.7, 45.3, 'Action'),
#  ('Man on Fire', 'Tony Scott ', 'None', 7.7, 77.91, 'Action'),
#  ('First Blood', 'Ted Kotcheff ', 'None', 7.7, 47.21, 'Action'),
#  ('The Magnificent Seven', 'Antoine Fuqua ', 'None', 6.8, 4.91, 'Action'),
#  ('The Magnificent Seven', 'John Sturges ', 'None', 7.7, 4.91, 'Action'),
#  ('Kung Fu Hustle', 'Stephen Chow ', 'None', 7.7, 17.11, 'Action'),
#  ('The Boondock Saints', 'Troy Duffy ', 'None', 7.7, 0.03, 'Action'),
#  ('Goldfinger', 'Guy Hamilton ', 'None', 7.7, 51.08, 'Action'),
#  ('The Longest Day', ' Ken Annakin', 'Andrew Marton', 7.7, 39.1, 'Action'),
#  ('Dirty Harry', 'Don Siegel', 'Clint Eastwood ', 7.7, 35.9, 'Action'),
#  ('Star Trek II: The Wrath of Khan',
#   'Nicholas Meyer ',
#   'None',
#   7.7,
#   78.91,
#   'Action'),
#  ('The Bourne Supremacy', 'Paul Greengrass ', 'None', 7.7, 176.24, 'Action'),
#  ('Bonnie and Clyde', 'Arthur Penn ', 'None', 7.7, ' ', 'Action'),
#  ('The French Connection', 'William Friedkin ', 'None', 7.7, 15.63, 'Action'),
#  ('Badlands', 'Terrence Malick ', 'None', 7.7, ' ', 'Action'),
#  ('Run Lola Run', 'Tom Tykwer ', 'None', 7.7, 7.27, 'Action'),
#  ('Ponniyin Selvan: Part I', 'Mani Ratnam ', 'None', 7.7, ' ', 'Action'),
#  ('Key Largo', 'John Huston ', 'None', 7.7, ' ', 'Action'),
#  ('The Man from Nowhere', 'Jeong-beom Lee ', 'None', 7.7, 0.01, 'Action'),
#  ('Hard Boiled', 'John Woo ', 'None', 7.7, ' ', 'Action'),
#  ('Scarface', 'Howard Hawks ', 'Richard Rosson', 7.7, ' ', 'Action'),
#  ('Joint Security Area', 'Park Chan-wook ', 'None', 7.7, ' ', 'Action'),
#  ('Eega', 'S.S. Rajamouli ', 'None', 7.7, ' ', 'Action'),
#  ('Udta Punjab', 'Abhishek Chaubey ', 'None', 7.7, ' ', 'Action'),
#  ('Raazi', 'Meghna Gulzar ', 'None', 7.7, ' ', 'Action'),
#  ('Guy Ritchies The Covenant', 'Guy Ritchie ', 'None', 7.6, ' ', 'Action'),
#  ('Guardians of the Galaxy Vol. 2',
#   'James Gunn ',
#   'None',
#   7.6,
#   389.81,
#   'Action'),
#  ('The Fifth Element', 'Luc Besson ', 'None', 7.6, 63.54, 'Action'),
#  ('Sicario', 'Denis Villeneuve ', 'None', 7.6, 46.89, 'Action'),
#  ('300', 'Zack Snyder ', 'None', 7.6, 210.61, 'Action'),
#  ('Baby Driver', 'Edgar Wright ', 'None', 7.6, 107.83, 'Action'),
#  ('Star Wars: Episode III - Revenge of the Sith',
#   'George Lucas ',
#   'None',
#   7.6,
#   380.26,
#   'Action'),
#  ('Deadpool 2', 'David Leitch ', 'None', 7.6, 324.59, 'Action'),
#  ('Watchmen', 'Zack Snyder ', 'None', 7.6, 107.51, 'Action'),
#  ('Harry Potter and the Half-Blood Prince',
#   'David Yates ',
#   'None',
#   7.6,
#   301.96,
#   'Action'),
#  ('RoboCop', 'JosÃ© Padilha', 'None', 6.1, 53.42, 'Action'),
#  ('RoboCop', 'Paul Verhoeven ', 'None', 7.6, 53.42, 'Action'),
#  ('Train to Busan', 'Sang-ho Yeon ', 'None', 7.6, 2.13, 'Action'),
#  ('The Warriors', 'Walter Hill ', 'None', 7.6, 22.49, 'Action'),
#  ('Creed (II)', 'Ryan Coogler ', 'None', 7.6, 109.77, 'Action'),
#  ('The Road Warrior', 'George Miller ', 'None', 7.6, 12.47, 'Action'),
#  ('Kick-Ass', 'Matthew Vaughn ', 'None', 7.6, 48.07, 'Action'),
#  ('Falling Down', 'Joel Schumacher ', 'None', 7.6, 40.9, 'Action'),
#  ('Zombieland', 'Ruben Fleischer ', 'None', 7.6, 75.59, 'Action'),
#  ('Minority Report', 'Steven Spielberg ', 'None', 7.6, 132.07, 'Action'),
#  ('Sherlock Holmes', 'Guy Ritchie ', 'None', 7.6, 209.03, 'Action'),
#  ('Rise of the Planet of the Apes',
#   'Rupert Wyatt ',
#   'None',
#   7.6,
#   176.76,
#   'Action'),
#  ('The Raid: Redemption', 'Gareth Evans ', 'None', 7.6, 4.11, 'Action'),
#  ('Dawn of the Planet of the Apes',
#   'Matt Reeves ',
#   'None',
#   7.6,
#   208.55,
#   'Action'),
#  ('Where Eagles Dare', 'Brian G. Hutton ', 'None', 7.6, ' ', 'Action'),
#  ('End of Watch', 'David Ayer ', 'None', 7.6, 41, 'Action'),
#  ('Lethal Weapon', 'Richard Donner ', 'None', 7.6, 65.21, 'Action'),
#  ('Battle Royale', 'Kinji Fukasaku ', 'None', 7.6, ' ', 'Action'),
#  ('Enter the Dragon', 'Robert Clouse ', 'None', 7.6, 25, 'Action'),
#  ('Die Hard with a Vengeance',
#   'John McTiernan ',
#   'None',
#   7.6,
#   100.01,
#   'Action'),
#  ('Star Trek: First Contact', 'Jonathan Frakes ', 'None', 7.6, 92, 'Action'),
#  ('Hotel Mumbai', 'Anthony Maras ', 'None', 7.6, 9.65, 'Action'),
#  ('Only the Brave', 'Joseph Kosinski ', 'None', 7.6, 18.34, 'Action'),
#  ('Escape from Alcatraz', 'Don Siegel ', 'None', 7.6, 43, 'Action'),
#  ('United 93', 'Paul Greengrass ', 'None', 7.6, 31.57, 'Action'),
#  ('The Taking of Pelham One Two Three',
#   'Joseph Sargent ',
#   'None',
#   7.6,
#   2.49,
#   'Action'),
#  ('Fearless', 'Ronny Yu ', 'None', 7.6, 24.63, 'Action'),
#  ('Pushpa: The Rise - Part 1', 'Sukumar ', 'None', 7.6, '  ', 'Action'),
#  ('Ludo', 'Anurag Basu ', 'None', 7.6, ' ', 'Action'),
#  ('Cell 211', 'Daniel MonzÃ³n ', 'None', 7.6, ' ', 'Action'),
#  ('Mortal World', 'Ali Atay ', 'None', 7.6, ' ', 'Action'),
#  ('Its a Mad Mad Mad Mad World',
#   'Stanley Kramer ',
#   'None',
#   7.5,
#   46.3,
#   'Action'),
#  ('Indiana Jones and the Temple of Doom',
#   'Steven Spielberg ',
#   'None',
#   7.5,
#   179.87,
#   'Action'),
#  ('Lone Survivor', 'Peter Berg ', 'None', 7.5, 125.1, 'Action'),
#  ('Batman', 'Tim Burton ', 'None', 7.5, 251.19, 'Action'),
#  ('Scott Pilgrim vs. the World',
#   'Edgar Wright ',
#   'None',
#   7.5,
#   31.49,
#   'Action'),
#  ('Harry Potter and the Order of the Phoenix',
#   'David Yates ',
#   'None',
#   7.5,
#   292,
#   'Action'),
#  ('Fury', 'David Ayer ', 'None', 7.5, 85.82, 'Action'),
#  ('The Hunger Games: Catching Fire',
#   'Francis Lawrence ',
#   'None',
#   7.5,
#   424.67,
#   'Action'),
#  ('Upgrade', 'Leigh Whannell ', 'None', 7.5, 11.98, 'Action'),
#  ('The Crow', 'Alex Proyas ', 'None', 7.5, 50.69, 'Action'),
#  ('Total Recall', 'Paul Verhoeven ', 'None', 7.5, 119.39, 'Action'),
#  ('Doctor Strange', 'Scott Derrickson ', 'None', 7.5, 232.64, 'Action'),
#  ('Master and Commander: The Far Side of the World',
#   'Peter Weir ',
#   'None',
#   7.5,
#   93.93,
#   'Action'),
#  ('Collateral', 'Michael Mann ', 'None', 7.5, 101.01, 'Action'),
#  ('Enemy at the Gates', 'Jean-Jacques Annaud ', 'None', 7.5, 51.4, 'Action'),
#  ('Riders of Justice', 'Anders Thomas Jensen ', 'None', 7.5, ' ', 'Action'),
#  ('Source Code', 'Duncan Jones ', 'None', 7.5, 54.71, 'Action'),
#  ('Munich', 'Steven Spielberg ', 'None', 7.5, 47.4, 'Action'),
#  ('The Hunt for Red October',
#   'John McTiernan ',
#   'None',
#   7.5,
#   122.01,
#   'Action'),
#  ('Grindhouse', ' Robert Rodriguez', 'Eli Roth', 7.5, 25.04, 'Action'),
#  ('Midnight Run', 'Martin Brest ', 'None', 7.5, 38.41, 'Action'),
#  ('The Guns of Navarone', 'J. Lee Thompson ', 'None', 7.5, 28.9, 'Action'),
#  ('Tora! Tora! Tora!',
#   ' Richard Fleischer',
#   'Akira Kurosawa ',
#   7.5,
#   29.55,
#   'Action'),
#  ('Headhunters', 'Morten Tyldum ', 'None', 7.5, 1.2, 'Action'),
#  ('Police Story', 'Jackie Chan', ' Chi-Hwa Chen ', 7.5, 0.11, 'Action'),
#  ('Ip Man 2', 'Wilson Yip ', 'None', 7.5, 0.21, 'Action'),
#  ('13 Assassins', 'Takashi Miike ', 'None', 7.5, 0.8, 'Action'),
#  ('New World', 'Park Hoon-jung ', 'None', 7.5, 0.46, 'Action'),
#  ('House of Flying Daggers', 'Yimou Zhang ', 'None', 7.5, 11.05, 'Action'),
#  ('A Bittersweet Life', 'Jee-woon Kim ', 'None', 7.5, ' ', 'Action'),
#  ('The Legend of Drunken Master',
#   'Chia-Liang Liu',
#   'Jackie Chan',
#   7.5,
#   11.55,
#   'Action'),
#  ('Tanhaji: The Unsung Warrior', 'Om Raut ', 'None', 7.5, ' ', 'Action'),
#  ('The Blind Swordsman: Zatoichi',
#   'Takeshi Kitano ',
#   'None',
#   7.5,
#   0.85,
#   'Action'),
#  ('Mesrine: Killer Instinct',
#   'Jean-FranÃ§ois Richet ',
#   'None',
#   7.5,
#   0.55,
#   'Action'),
#  ('Jodhaa Akbar', 'Ashutosh Gowariker ', 'None', 7.5, 3.44, 'Action'),
#  ('Delhi Belly', 'Abhinay Deo', 'Akshat Verma ', 7.5, 1.53, 'Action'),
#  ('Mersal', 'Atlee ', 'None', 7.5, ' ', 'Action'),
#  ('To Strike', 'Bilal Lashari ', 'None', 7.5, ' ', 'Action'),
#  ('John Wick', 'Chad Stahelski', 'David Leitch ', 7.4, 43.04, 'Action'),
#  ('John Wick: Chapter 3 - Parabellum',
#   'Chad Stahelski ',
#   'None',
#   7.4,
#   171.02,
#   'Action'),
#  ('John Wick: Chapter 2', 'Chad Stahelski ', 'None', 7.4, 92.03, 'Action'),
#  ('Shang-Chi and the Legend of the Ten Rings',
#   'Destin Daniel Cretton ',
#   'None',
#   7.4,
#   224.54,
#   'Action'),
#  ('Spider-Man: Homecoming', 'Jon Watts ', 'None', 7.4, 334.2, 'Action'),
#  ('Nobody (I)', 'Ilya Naishuller ', 'None', 7.4, 27.27, 'Action'),
#  ('Spider-Man', 'Sam Raimi ', 'None', 7.4, 403.71, 'Action'),
#  ('Ready Player One', 'Steven Spielberg ', 'None', 7.4, 137.69, 'Action'),
#  ('Mission: Impossible - Rogue Nation',
#   'Christopher McQuarrie ',
#   'None',
#   7.4,
#   195.04,
#   'Action'),
#  ('Mission: Impossible - Ghost Protocol',
#   'Brad Bird ',
#   'None',
#   7.4,
#   209.4,
#   'Action'),
#  ('The Last Duel', 'Ridley Scott ', 'None', 7.4, 10.85, 'Action'),
#  ('Wonder Woman', 'Patty Jenkins ', 'None', 7.4, 412.56, 'Action'),
#  ('Superman', 'Richard Donner ', 'None', 7.4, 134.22, 'Action'),
#  ('Spider-Man: Far from Home', 'Jon Watts ', 'None', 7.4, 390.53, 'Action'),
#  ('Spider-Man 2', 'Sam Raimi ', 'None', 7.4, 373.59, 'Action'),
#  ('The Rock', 'Michael Bay ', 'None', 7.4, 134.07, 'Action'),
#  ('Predestination (I)',
#   ' Michael Spierig',
#   'Peter Spierig ',
#   7.4,
#   0.07,
#   'Action'),
#  ('Looper', 'Rian Johnson ', 'None', 7.4, 66.49, 'Action'),
#  ('A History of Violence', 'David Cronenberg ', 'None', 7.4, 31.49, 'Action'),
#  ('Law Abiding Citizen', 'F. Gary Gray ', 'None', 7.4, 73.34, 'Action'),
#  ('X2: X-Men United', 'Bryan Singer ', 'None', 7.4, 214.95, 'Action'),
#  ('War for the Planet of the Apes',
#   'Matt Reeves ',
#   'None',
#   7.4,
#   146.88,
#   'Action'),
#  ('Sherlock Holmes: A Game of Shadows',
#   'Guy Ritchie ',
#   'None',
#   7.4,
#   186.85,
#   'Action'),
#  ('Bullitt', 'Peter Yates ', 'None', 7.4, 42.3, 'Action'),
#  ('From Russia with Love', 'Terence Young ', 'None', 7.4, 24.8, 'Action'),
#  ('Open Range', 'Kevin Costner ', 'None', 7.4, 58.33, 'Action'),
#  ('Thief', 'Michael Mann ', 'None', 7.4, 11.49, 'Action'),
#  ('Mission Majnu', 'Shantanu Bagchi ', 'None', 7.4, ' ', 'Action'),
#  ('Black Dynamite', 'Scott Sanders ', 'None', 7.4, 0.23, 'Action'),
#  ('Rurouni Kenshin Part I: Origins',
#   'Keishi Otomo ',
#   'None',
#   7.4,
#   ' ',
#   'Action'),
#  ('Drunken Master', 'Woo-Ping Yuen ', 'None', 7.4, ' ', 'Action'),
#  ('Mesrine: Public Enemy No. 1',
#   'Jean-FranÃ§ois Richet ',
#   'None',
#   7.4,
#   0.28,
#   'Action'),
#  ('Dungeons & Dragons: Honor Among Thieves',
#   ' John Francis Daley',
#   'Jonathan Goldstein ',
#   7.3,
#   ' ',
#   'Action'),
#  ('Bullet Train', 'David Leitch ', 'None', 7.3, 103.37, 'Action'),
#  ('Fast Five', 'Justin Lin ', 'None', 7.3, 209.84, 'Action'),
#  ('Tenet', 'Christopher Nolan ', 'None', 7.3, 58.46, 'Action'),
#  ('Ant-Man', 'Peyton Reed ', 'None', 7.3, 180.2, 'Action'),
#  ('Starship Troopers', 'Paul Verhoeven ', 'None', 7.3, 54.81, 'Action'),
#  ('No Time to Die', 'Cary Joji Fukunaga ', 'None', 7.3, 160.87, 'Action'),
#  ('True Lies', 'James Cameron ', 'None', 7.3, 146.28, 'Action'),
#  ('Men in Black', 'Barry Sonnenfeld ', 'None', 7.3, 250.69, 'Action'),
#  ('The Accountant', 'Gavin OConnor ', 'None', 7.3, 86.26, 'Action'),
#  ('The Nice Guys', 'Shane Black ', 'None', 7.3, 36.26, 'Action'),
#  ('Dawn of the Dead', 'Zack Snyder ', 'None', 7.3, 59.02, 'Action'),
#  ('Black Panther', 'Ryan Coogler ', 'None', 7.3, 700.06, 'Action'),
#  ('Speed', 'Jan de Bont ', 'None', 7.3, 121.25, 'Action'),
#  ('Avengers: Age of Ultron', 'Joss Whedon ', 'None', 7.3, 459.01, 'Action'),
#  ('Beverly Hills Cop', 'Martin Brest ', 'None', 7.3, 234.76, 'Action'),
#  ('Face/Off', 'John Woo ', 'None', 7.3, 112.23, 'Action'),
#  ('X-Men', 'Bryan Singer ', 'None', 7.3, 157.3, 'Action'),
#  ('13 Hours', 'Michael Bay ', 'None', 7.3, 52.85, 'Action'),
#  ('Alita: Battle Angel', 'Robert Rodriguez ', 'None', 7.3, 85.71, 'Action'),
#  ('American Sniper', 'Clint Eastwood ', 'None', 7.3, 350.13, 'Action'),
#  ('The Karate Kid', 'Harald Zwart ', 'None', 6.2, 90.82, 'Action'),
#  ('The Karate Kid', 'John G. Avildsen ', 'None', 7.3, 90.82, 'Action'),
#  ('El Camino: A Breaking Bad Movie',
#   'Vince Gilligan ',
#   'None',
#   7.3,
#   ' ',
#   'Action'),
#  ('Pirates of the Caribbean: Dead Mans Chest',
#   'Gore Verbinski ',
#   'None',
#   7.3,
#   423.32,
#   'Action'),
#  ('Equilibrium', 'Kurt Wimmer ', 'None', 7.3, 1.2, 'Action'),
#  ('Patriots Day', 'Peter Berg ', 'None', 7.3, 31.89, 'Action'),
#  ('Southpaw', 'Antoine Fuqua ', 'None', 7.3, 52.42, 'Action'),
#  ('Layer Cake', 'Matthew Vaughn ', 'None', 7.3, 2.34, 'Action'),
#  ('Eye in the Sky', 'Gavin Hood ', 'None', 7.3, 18.7, 'Action'),
#  ('Enemy of the State', 'Tony Scott ', 'None', 7.3, 111.55, 'Action'),
#  ('Okja', 'Bong Joon Ho ', 'None', 7.3, ' ', 'Action'),
#  ('To Live and Die in L.A.',
#   'William Friedkin ',
#   'None',
#   7.3,
#   17.31,
#   'Action'),
#  ('The Next Three Days', 'Paul Haggis ', 'None', 7.3, 21.15, 'Action'),
#  ('The Negotiator', 'F. Gary Gray ', 'None', 7.3, 44.48, 'Action'),
#  ('Invictus', 'Clint Eastwood ', 'None', 7.3, 37.49, 'Action'),
#  ('Nikita', 'Luc Besson ', 'None', 7.3, 5.02, 'Action'),
#  ('Star Trek IV: The Voyage Home',
#   'Leonard Nimoy ',
#   'None',
#   7.3,
#   109.71,
#   'Action'),
#  ('Crimson Tide', 'Tony Scott ', 'None', 7.3, 91.4, 'Action'),
#  ('Grosse Pointe Blank', 'George Armitage ', 'None', 7.3, 28.01, 'Action'),
#  ('Running Scared', 'Wayne Kramer ', 'None', 7.3, 6.86, 'Action'),
#  ('Shaolin Soccer', 'Stephen Chow ', 'None', 7.3, 0.49, 'Action'),
#  ('Assault on Precinct 13',
#   'Jean-FranÃ§ois RichetÂ\xa0',
#   'None',
#   6.3,
#   ' ',
#   'Action'),
#  ('Assault on Precinct 13', 'John Carpenter ', 'None', 7.3, ' ', 'Action'),
#  ('Jason and the Argonauts', 'Don Chaffey ', 'None', 7.3, 4.58, 'Action'),
#  ('The Getaway', 'Sam Peckinpah ', 'None', 7.3, 36.73, 'Action'),
#  ('Red Cliff', 'John Woo ', 'None', 7.3, 0.63, 'Action'),
#  ('Bacurau',
#   'Juliano Dornelles',
#   'Kleber MendonÃ§a Filho',
#   7.3,
#   ' ',
#   'Action'),
#  ('Get Carter', 'Mike Hodges ', 'None', 7.3, 0.39, 'Action'),
#  ('Ghajini', 'A.R. Murugadoss ', 'None', 7.3, 2.43, 'Action'),
#  ('Max Manus: Man of War',
#   'Joachim RÃ¸nning',
#   'Espen Sandberg ',
#   7.3,
#   ' ',
#   'Action'),
#  ('The Baader Meinhof Complex', 'Uli Edel ', 'None', 7.3, 0.48, 'Action'),
#  ('Master (I)', 'Lokesh Kanagaraj ', 'None', 7.3, ' ', 'Action'),
#  ('The Suicide Squad', 'James Gunn ', 'None', 7.2, 55.82, 'Action'),
#  ('The Hunger Games', 'Gary Ross ', 'None', 7.2, 408.01, 'Action'),
#  ('From Dusk Till Dawn', 'Robert Rodriguez ', 'None', 7.2, 25.75, 'Action'),
#  ('The Equalizer', 'Antoine Fuqua ', 'None', 7.2, 101.53, 'Action'),
#  ('Willow', 'Ron Howard ', 'None', 7.2, 57.27, 'Action'),
#  ('Point Break', 'Kathryn Bigelow ', 'None', 7.2, 43.22, 'Action'),
#  ('The Man from U.N.C.L.E.', 'Guy Ritchie ', 'None', 7.2, 45.45, 'Action'),
#  ('Kingdom of Heaven', 'Ridley Scott ', 'None', 7.2, 47.4, 'Action'),
#  ('21 Jump Street',
#   ' Phil Lord',
#   'Christopher Miller ',
#   7.2,
#   138.45,
#   'Action'),
#  ('Natural Born Killers', 'Oliver Stone ', 'None', 7.2, 50.28, 'Action'),
#  ('GoldenEye', 'Martin Campbell ', 'None', 7.2, 106.6, 'Action'),
#  ('Unbroken (I)', 'Angelina Jolie ', 'None', 7.2, 115.64, 'Action'),
#  ('The Matrix Reloaded',
#   ' Lana Wachowski',
#   'Lilly Wachowski ',
#   7.2,
#   281.49,
#   'Action'),
#  ('They Live', 'John Carpenter ', 'None', 7.2, 13.01, 'Action'),
#  ('King Kong', 'Peter Jackson ', 'None', 7.2, 218.08, 'Action'),
#  ('The Patriot', 'Roland Emmerich ', 'None', 7.2, 113.33, 'Action'),
#  ('I Am Legend', 'Francis Lawrence ', 'None', 7.2, 256.39, 'Action'),
#  ('The Life Aquatic with Steve Zissou',
#   'Wes Anderson ',
#   'None',
#   7.2,
#   24.01,
#   'Action'),
#  ('Big Trouble in Little China',
#   'John Carpenter ',
#   'None',
#   7.2,
#   11.1,
#   'Action'),
#  ('RocknRolla', 'Guy Ritchie ', 'None', 7.2, 5.69, 'Action'),
#  ('Old Henry', 'Potsy Ponciroli ', 'None', 7.2, ' ', 'Action'),
#  ('Dr. No', 'Terence Young ', 'None', 7.2, 16.07, 'Action'),
#  ('Friday Night Lights', 'Peter Berg ', 'None', 7.2, 61.26, 'Action'),
#  ('Team America: World Police', 'Trey Parker ', 'None', 7.2, 32.79, 'Action'),
#  ('Ronin', 'John Frankenheimer ', 'None', 7.2, 41.62, 'Action'),
#  ('Batman v Superman: Dawn of Justice (Ultimate Edition)',
#   'Zack Snyder ',
#   'None',
#   7.2,
#   ' ',
#   'Action'),
#  ('Runaway Train', 'Andrey Konchalovskiy ', 'None', 7.2, 7.94, 'Action'),
#  ('Star Trek VI: The Undiscovered Country',
#   'Nicholas Meyer ',
#   'None',
#   7.2,
#   74.89,
#   'Action'),
#  ('The Italian Job', 'F. Gary Gray ', 'None', 7, ' ', 'Action'),
#  ('The Italian Job', 'Peter Collinson ', 'None', 7.2, ' ', 'Action'),
#  ('Anthropoid', 'Sean Ellis ', 'None', 7.2, 2.96, 'Action'),
#  ('War Horse', 'Steven Spielberg ', 'None', 7.2, 79.88, 'Action'),
#  ('Magnum Force', 'Ted Post ', 'None', 7.2, 4.56, 'Action'),
#  ('In the Line of Fire', 'Wolfgang Petersen ', 'None', 7.2, 102.31, 'Action'),
#  ('Silverado', 'Lawrence Kasdan ', 'None', 7.2, 33.2, 'Action'),
#  ('The Way of the Dragon', 'Bruce Lee ', 'None', 7.2, 4.06, 'Action'),
#  ('Vanishing Point', 'Richard C. Sarafian ', 'None', 7.2, ' ', 'Action'),
#  ('Lethal Weapon 2', 'Richard Donner ', 'None', 7.2, 147.25, 'Action'),
#  ('Arlington Road', 'Mark Pellington ', 'None', 7.2, 24.36, 'Action'),
#  ('Kon-Tiki', 'Joachim RÃ¸nning', ' Espen Sandberg ', 7.2, 1.52, 'Action'),
#  ('The Hitcher', 'Robert Harmon ', 'None', 7.2, 5.84, 'Action'),
#  ('Django', 'Sergio Corbucci ', 'None', 7.2, 0.03, 'Action'),
#  ('The Siege of Jadotville', 'Richie Smyth ', 'None', 7.2, ' ', 'Action'),
#  ('71', 'Yann Demange ', 'None', 7.2, 1.27, 'Action'),
#  ('Bajirao Mastani', 'Sanjay Leela Bhansali ', 'None', 7.2, 6.56, 'Action'),
#  ('Fist of Fury', 'Wei Lo ', 'None', 7.2, 1.29, 'Action'),
#  ('Harry Brown', 'Daniel Barber ', 'None', 7.2, 1.82, 'Action'),
#  ('The Good the Bad the Weird', 'Jee-woon Kim ', 'None', 7.2, 0.13, 'Action'),
#  ('Marshland', 'Alberto RodrÃ\xadguez', 'None', 7.2, ' ', 'Action'),
#  ('Mongol: The Rise of Genghis Khan',
#   'Sergei Bodrov ',
#   'None',
#   7.2,
#   5.7,
#   'Action'),
#  ('Holiday: A Soldier is Never Off Duty',
#   'A.R. Murugadoss ',
#   'None',
#   7.2,
#   0.71,
#   'Action'),
#  ('Furious 7', 'James Wan ', 'None', 7.1, 353.01, 'Action'),
#  ('The Mummy', 'Stephen Sommers ', 'None', 7.1, 155.25, 'Action'),
#  ('Mission: Impossible', 'Brian De Palma ', 'None', 7.1, 180.98, 'Action'),
#  ('Free Guy', 'Shawn Levy ', 'None', 7.1, 121.63, 'Action'),
#  ('Wrath of Man', 'Guy Ritchie ', 'None', 7.1, 27.47, 'Action'),
#  ('Tropic Thunder', 'Ben Stiller ', 'None', 7.1, 110.52, 'Action'),
#  ('Prey (I)', 'Dan Trachtenberg ', 'None', 7.1, ' ', 'Action'),
#  ('Man of Steel', 'Zack Snyder ', 'None', 7.1, 291.05, 'Action'),
#  ('Everest', 'Baltasar KormÃ¡kur', 'None', 7.1, 43.48, 'Action'),
#  ('Blade', 'Stephen Norrington ', 'None', 7.1, 70.09, 'Action'),
#  ('Shooter (I)', 'Antoine Fuqua ', 'None', 7.1, 47, 'Action'),
#  ('Batman Returns', 'Tim Burton ', 'None', 7.1, 162.83, 'Action'),
#  ('Highlander', 'Russell Mulcahy ', 'None', 7.1, 5.9, 'Action'),
#  ('Iron Man 3', 'Shane Black ', 'None', 7.1, 409.01, 'Action'),
#  ('WarGames', 'John Badham ', 'None', 7.1, 79.57, 'Action'),
#  ('Dredd', 'Pete Travis ', 'None', 7.1, 13.41, 'Action'),
#  ('Snowpiercer', 'Bong Joon Ho ', 'None', 7.1, 4.56, 'Action'),
#  ('Pirates of the Caribbean: At Worlds End',
#   'Gore Verbinski ',
#   'None',
#   7.1,
#   309.42,
#   'Action'),
#  ('American Made', 'Doug Liman ', 'None', 7.1, 51.34, 'Action'),
#  ('Creed II', 'Steven Caple Jr. ', 'None', 7.1, 115.72, 'Action'),
#  ('Desperado', 'Robert Rodriguez ', 'None', 7.1, 25.63, 'Action'),
#  ('I Robot', 'Alex Proyas ', 'None', 7.1, 144.8, 'Action'),
#  ('Escape from New York', 'John Carpenter ', 'None', 7.1, 25.24, 'Action'),
#  ('We Were Soldiers', 'Randall Wallace ', 'None', 7.1, 78.12, 'Action'),
#  ('Live Free or Die Hard', 'Len Wiseman ', 'None', 7.1, 134.53, 'Action'),
#  ('Allied', 'Robert Zemeckis ', 'None', 7.1, 40.1, 'Action'),
#  ('The Poseidon Adventure', 'Ronald Neame ', 'None', 7.1, 84.56, 'Action'),
#  ('Planet Terror', 'Robert Rodriguez ', 'None', 7.1, ' ', 'Action'),
#  ('Casualties of War', 'Brian De Palma ', 'None', 7.1, 18.67, 'Action'),
#  ('No Way Out', 'Roger Donaldson ', 'None', 7.1, 35.51, 'Action'),
#  ('Rocky Balboa', 'Sylvester Stallone ', 'None', 7.1, 70.27, 'Action'),
#  ('Deepwater Horizon', 'Peter Berg ', 'None', 7.1, 61.43, 'Action'),
#  ('Deja Vu', 'Tony Scott ', 'None', 7.1, 64.04, 'Action'),
#  ('Defiance (I)', 'Edward Zwick ', 'None', 7.1, 28.64, 'Action'),
#  ('Three Kings', 'David O. Russell ', 'None', 7.1, 60.65, 'Action'),
#  ('Die Hard 2', 'Renny Harlin ', 'None', 7.1, 117.54, 'Action'),
#  ('Brawl in Cell Block 99', 'S. Craig Zahler ', 'None', 7.1, ' ', 'Action'),
#  ('Payback (I)', 'Brian Helgeland ', 'None', 7.1, 81.53, 'Action'),
#  ('Flags of Our Fathers', 'Clint Eastwood ', 'None', 7.1, 33.6, 'Action'),
#  ('Ong-Bak: The Thai Warrior',
#   'Prachya Pinkaew ',
#   'None',
#   7.1,
#   4.56,
#   'Action'),
#  ('Megan Leavey', 'Gabriela Cowperthwaite ', 'None', 7.1, 13.41, 'Action'),
#  ('District B13', 'Pierre Morel ', 'None', 7.1, 1.2, 'Action'),
#  ('Mosul (I)', 'Matthew Michael Carnahan ', 'None', 7.1, ' ', 'Action'),
#  ('The Girl Who Played with Fire',
#   'Daniel Alfredson ',
#   'None',
#   7.1,
#   9.08,
#   'Action'),
#  ('God Bless America', 'Bobcat Goldthwait ', 'None', 7.1, 0.12, 'Action'),
#  ('In Order of Disappearance',
#   'Hans Petter Moland ',
#   'None',
#   7.1,
#   0.05,
#   'Action'),
#  ('Kaabil', 'Sanjay Gupta ', 'None', 7.1, ' ', 'Action'),
#  ('JCVD', 'Mabrouk El Mechri ', 'None', 7.1, 0.47, 'Action'),
#  ('Don (I)', 'Farhan Akhtar ', 'None', 7.1, 0.8, 'Action'),
#  ('Micmacs', 'Jean-Pierre Jeunet ', 'None', 7.1, 1.26, 'Action'),
#  ('Koi... Mil Gaya', 'Rakesh Roshan ', 'None', 7.1, 0.68, 'Action'),
#  ('Fanaa', 'Kunal Kohli ', 'None', 7.1, 2.1, 'Action'),
#  ('Marighella', 'Wagner Moura ', 'None', 7.1, ' ', 'Action'),
#  ('Enthiran', 'S. Shankar ', 'None', 7.1, 4.37, 'Action'),
#  ('Gabbar Is Back', 'Radha Krishna Jagarlamudi ', 'None', 7.1, ' ', 'Action'),
#  ('Sisu', 'Jalmari Helander ', 'None', 7, ' ', 'Action'),
#  ('Thor', 'Kenneth Branagh ', 'None', 7, 181.03, 'Action'),
#  ('Fast & Furious 6', 'Justin Lin ', 'None', 7, 238.68, 'Action'),
#  ('Shazam!', 'David F. Sandberg ', 'None', 7, 140.37, 'Action'),
#  ('The Unbearable Weight of Massive Talent',
#   'Tom Gormican ',
#   'None',
#   7,
#   ' ',
#   'Action'),
#  ('Transformers', 'Michael Bay ', 'None', 7, 319.25, 'Action'),
#  ('The Northman', 'Robert Eggers ', 'None', 7, 34.23, 'Action'),
#  ('Ant-Man and the Wasp', 'Peyton Reed ', 'None', 7, 216.65, 'Action'),
#  ('Independence Day', 'Roland Emmerich ', 'None', 7, 306.17, 'Action'),
#  ('Jack Reacher', 'Christopher McQuarrie ', 'None', 7, 80.07, 'Action'),
#  ('World War Z', 'Marc Forster ', 'None', 7, 202.36, 'Action'),
#  ('Death Proof', 'Quentin Tarantino ', 'None', 7, ' ', 'Action'),
#  ('Super 8', 'J.J. Abrams ', 'None', 7, 127, 'Action'),
#  ('Constantine', 'Francis Lawrence ', 'None', 7, 75.98, 'Action'),
#  ('Star Trek Beyond', 'Justin Lin ', 'None', 7, 158.85, 'Action'),
#  ('Cloverfield', 'Matt Reeves ', 'None', 7, 80.05, 'Action'),
#  ('Rush Hour', 'Brett Ratner ', 'None', 7, 141.15, 'Action'),
#  ('The Italian Job', 'F. Gary Gray ', 'None', 7, 106.13, 'Action'),
#  ('The Italian Job', 'Peter Collinson ', 'None', 7.2, 106.13, 'Action'),
#  ('Smokey and the Bandit', 'Hal Needham ', 'None', 7, 126.74, 'Action'),
#  ('Oblivion (I)', 'Joseph Kosinski ', 'None', 7, 89.02, 'Action'),
#  ('Pitch Black', 'David Twohy ', 'None', 7, 39.24, 'Action'),
#  ('Stargate', 'Roland Emmerich ', 'None', 7, 71.57, 'Action'),
#  ('Sicario: Day of the Soldado',
#   'Stefano Sollima ',
#   'None',
#   7,
#   50.07,
#   'Action'),
#  ('Greyhound', 'Aaron Schneider ', 'None', 7, ' ', 'Action'),
#  ('Brotherhood of the Wolf', 'Christophe Gans ', 'None', 7, 11.26, 'Action'),
#  ('Den of Thieves', 'Christian Gudegast ', 'None', 7, 44.95, 'Action'),
#  ('RED', 'Robert Schwentke ', 'None', 7, 90.38, 'Action'),
#  ('Underworld', 'Len Wiseman ', 'None', 7, 51.97, 'Action'),
#  ('Spy', 'Paul Feig ', 'None', 7, 110.83, 'Action'),
#  ('Real Steel', 'Shawn Levy ', 'None', 7, 85.47, 'Action'),
#  ('Logan Lucky', 'Steven Soderbergh ', 'None', 7, 27.78, 'Action'),
#  ('22 Jump Street', ' Phil Lord', 'Christopher Miller ', 7, 191.72, 'Action'),
#  ('Bronson', 'Nicolas Winding Refn ', 'None', 7, 0.1, 'Action'),
#  ('Public Enemies', 'Michael Mann ', 'None', 7, 97.1, 'Action'),
#  ('The Last Boy Scout', 'Tony Scott ', 'None', 7, 59.51, 'Action'),
#  ('Chronicle', 'Josh Trank ', 'None', 7, 64.58, 'Action'),
#  ('A Most Violent Year', 'J.C. Chandor ', 'None', 7, 5.74, 'Action'),
#  ('Body of Lies', 'Ridley Scott ', 'None', 7, 39.39, 'Action'),
#  ('Rambo', 'Sylvester Stallone ', 'None', 7, 42.75, 'Action'),
#  ('Fallen', 'Gregory Hoblit ', 'None', 7, 25.19, 'Action'),
#  ('Hellboy II: The Golden Army',
#   'Guillermo del Toro ',
#   'None',
#   7,
#   75.75,
#   'Action'),
#  ('The Foreigner (I)', 'Martin Campbell ', 'None', 7, 34.39, 'Action'),
#  ('The Towering Inferno', 'John Guillermin ', 'None', 7, 116, 'Action'),
#  ('Ip Man 4: The Finale', 'Wilson Yip ', 'None', 7, 3.96, 'Action'),
#  ('The Kingdom', 'Peter Berg ', 'None', 7, 47.54, 'Action'),
#  ('Filth (I)', 'Jon S. Baird ', 'None', 7, 0.03, 'Action'),
#  ('The Spy Who Loved Me', 'Lewis Gilbert ', 'None', 7, 46.8, 'Action'),
#  ('Spy Game', 'Tony Scott ', 'None', 7, 0.03, 'Action'),
#  ('Maverick', 'Richard Donner ', 'None', 7, 101.63, 'Action'),
#  ('Ichi the Killer', 'Takashi Miike ', 'None', 7, 0.02, 'Action'),
#  ('Thunderbolt and Lightfoot', 'Michael Cimino ', 'None', 7, 25, 'Action'),
#  ('Juice', 'Ernest R. Dickerson ', 'None', 7, 20.15, 'Action'),
#  ('The War of the Worlds', 'Byron Haskin ', 'None', 7, 4.36, 'Action'),
#  ('Son of Rambow', 'Garth Jennings ', 'None', 7, 1.78, 'Action'),
#  ('An Action Hero', 'Anirudh Iyer ', 'None', 7, ' ', 'Action'),
#  ('Taxi (I)', 'GÃ©rard PirÃ¨s', 'None', 7, 0.27, 'Action'),
#  ('Unleashed', 'Louis Leterrier ', 'None', 7, 24.52, 'Action'),
#  ('Ip Man 3', 'Wilson Yip ', 'None', 7, 2.68, 'Action'),
#  ('Dragon: The Bruce Lee Story', 'Rob Cohen ', 'None', 7, 35.11, 'Action'),
#  ('The Protector', 'Prachya Pinkaew ', 'None', 7, 11.91, 'Action'),
#  ('Curse of the Golden Flower', 'Yimou Zhang ', 'None', 7, 6.57, 'Action'),
#  ('Don 2', 'Farhan Akhtar ', 'None', 7, 3.68, 'Action'),
#  ('Sultan', 'Ali Abbas Zafar ', 'None', 7, 6.2, 'Action'),
#  ('Kabir Singh', 'Sandeep Reddy Vanga ', 'None', 7, ' ', 'Action'),
#  ('Main Hoon Na', 'Farah Khan ', 'None', 7, 1.72, 'Action'),
#  ('The Legend', ' Jerry', 'Joseph D. Sami ', 7, ' ', 'Action'),
#  ('Vikrant Rona', 'Anup Bhandari ', 'None', 7, ' ', 'Action'),
#  ('The Warlords', ' Peter Ho-Sun Chan', 'Wai-Man Yip ', 7, 0.13, 'Action'),
#  ('The Legend Is Born: Ip Man', 'Herman Yau ', 'None', 7, ' ', 'Action'),
#  ('Top Gun', 'Tony Scott ', 'None', 6.9, 179.8, 'Action'),
#  ('The Last Kingdom: Seven Kings Must Die',
#   'Edward Bazalgette ',
#   'None',
#   6.9,
#   ' ',
#   'Action'),
#  ('Conan the Barbarian', 'John Milius ', 'None', 6.9, 39.57, 'Action'),
#  ('Doctor Strange in the Multiverse of Madness',
#   'Sam Raimi ',
#   'None',
#   6.9,
#   411.33,
#   'Action'),
#  ('Clash of the Titans', 'Desmond Davis ', 'None', 6.9, 41.09, 'Action'),
#  ('Clash of the Titans', 'Louis Leterrier ', 'None', 5.8, 41.09, 'Action'),
#  ('Game Night (I)',
#   ' John Francis Daley ',
#   'Jonathan Goldstein',
#   6.9,
#   69.18,
#   'Action'),
#  ('Jumanji: Welcome to the Jungle',
#   'Jake Kasdan ',
#   'None',
#   6.9,
#   404.52,
#   'Action'),
#  ('Captain America: The First Avenger',
#   'Joe Johnston ',
#   'None',
#   6.9,
#   176.65,
#   'Action'),
#  ('The Mask', 'Chuck Russell ', 'None', 6.9, 119.94, 'Action'),
#  ('Mission: Impossible III', 'J.J. Abrams ', 'None', 6.9, 134.03, 'Action'),
#  ('Solo: A Star Wars Story', 'Ron Howard ', 'None', 6.9, 213.77, 'Action'),
#  ('Thunderball', 'Terence Young ', 'None', 6.9, 63.6, 'Action'),
#  ('The Amazing Spider-Man', 'Marc Webb ', 'None', 6.9, 262.03, 'Action'),
#  ('Jurassic World', 'Colin Trevorrow ', 'None', 6.9, 652.27, 'Action'),
#  ('Star Wars: Episode VIII - The Last Jedi',
#   'Rian Johnson ',
#   'None',
#   6.9,
#   620.18,
#   'Action'),
#  ('A Knights Tale', 'Brian Helgeland ', 'None', 6.9, 56.57, 'Action'),
#  ('Con Air', 'Simon West ', 'None', 6.9, 101.12, 'Action'),
#  ('X-Men: Apocalypse', 'Bryan Singer ', 'None', 6.9, 155.44, 'Action'),
#  ('Pacific Rim', 'Guillermo del Toro ', 'None', 6.9, 101.8, 'Action'),
#  ('Iron Man 2', 'Jon Favreau ', 'None', 6.9, 312.43, 'Action'),
#  ('Romancing the Stone', 'Robert Zemeckis ', 'None', 6.9, 76.57, 'Action'),
#  ('National Treasure', 'Jon Turteltaub ', 'None', 6.9, 173.01, 'Action'),
#  ('Robin Hood: Prince of Thieves',
#   'Kevin Reynolds ',
#   'None',
#   6.9,
#   165.5,
#   'Action'),
#  ('The Hitmans Bodyguard', 'Patrick Hughes ', 'None', 6.9, 75.47, 'Action'),
#  ('Dragged Across Concrete', 'S. Craig Zahler ', 'None', 6.9, ' ', 'Action'),
#  ('Love and Monsters', 'Michael Matthews ', 'None', 6.9, 1.07, 'Action'),
#  ('28 Weeks Later', 'Juan Carlos Fresnadillo ', 'None', 6.9, 28.64, 'Action'),
#  ('Outlaw King', 'David Mackenzie ', 'None', 6.9, ' ', 'Action'),
#  ('The Worlds End', 'Edgar Wright ', 'None', 6.9, 26, 'Action'),
#  ('Pineapple Express', 'David Gordon Green ', 'None', 6.9, 87.34, 'Action'),
#  ('In the Heart of the Sea', 'Ron Howard ', 'None', 6.9, 25.02, 'Action'),
#  ('Crank', ' Mark Neveldine', 'Brian Taylor ', 6.9, 27.83, 'Action'),
#  ('48 Hrs.', 'Walter Hill ', 'None', 6.9, 78.87, 'Action'),
#  ('Clear and Present Danger', 'Phillip Noyce ', 'None', 6.9, 122.19, 'Action'),
#  ('Death Wish', 'Eli Roth ', 'None', 6.3, 22, 'Action'),
#  ('Death Wish', 'Michael Winner ', 'None', 6.9, 22, 'Action'),
#  ('The Edge', 'Lee Tamahori ', 'None', 6.9, 27.78, 'Action'),
#  ('Non-Stop', 'Jaume Collet-Serra ', 'None', 6.9, 92.17, 'Action'),
#  ('The Last Castle', 'Rod Lurie ', 'None', 6.9, 18.21, 'Action'),
#  ('The Guardian (I)', 'Andrew Davis ', 'None', 6.9, 55.01, 'Action'),
#  ('Westworld', 'Michael Crichton ', 'None', 6.9, 16.06, 'Action'),
#  ('The Night Comes for Us', 'Timo Tjahjanto ', 'None', 6.9, ' ', 'Action'),
#  ('Repo Man', 'Alex Cox ', 'None', 6.9, 3.57, 'Action'),
#  ('The Monster Squad', 'Fred Dekker ', 'None', 6.9, 3.77, 'Action'),
#  ('Free State of Jones', 'Gary Ross ', 'None', 6.9, 20.76, 'Action'),
#  ('Get the Gringo', 'Adrian Grunberg ', 'None', 6.9, ' ', 'Action'),
#  ('Muppet Treasure Island',
#   ' Brian Henson',
#   'David Lane ',
#   6.9,
#   33.61,
#   'Action'),
#  ('All Is Lost', 'J.C. Chandor ', 'None', 6.9, 6.26, 'Action'),
#  ('Memphis Belle', 'Michael Caton-Jones ', 'None', 6.9, 27.44, 'Action'),
#  ('Slow West', 'John Maclean ', 'None', 6.9, 0.23, 'Action'),
#  ('The Big Boss', ' Wei Lo', 'Chia-Hsiang Wu ', 6.9, 0.04, 'Action'),
#  ('New Police Story', 'Benny Chan ', 'None', 6.9, ' ', 'Action'),
#  ('Agneepath', 'Karan Malhotra ', 'None', 6.9, 1.98, 'Action'),
#  ('Alan Partridge', 'Declan Lowney ', 'None', 6.9, 0.15, 'Action'),
#  ('Traitor', 'Jeffrey Nachmanoff ', 'None', 6.9, 23.53, 'Action'),
#  ('Fan (I)', 'Maneesh Sharma ', 'None', 6.9, 1.36, 'Action'),
#  ('The Fast and the Furious', 'Rob Cohen ', 'None', 6.8, 144.53, 'Action'),
#  ('The Woman King', 'Gina Prince-Bythewood ', 'None', 6.8, 67.33, 'Action'),
#  ('The Magnificent Seven', 'Antoine Fuqua ', 'None', 6.8, 93.43, 'Action'),
#  ('The Magnificent Seven', 'John Sturges ', 'None', 7.7, 93.43, 'Action'),
#  ('Aquaman', 'James Wan ', 'None', 6.8, 335.06, 'Action'),
#  ('Ready or Not (I)',
#   ' Matt Bettinelli-Olpin',
#   'Tyler Gillett ',
#   6.8,
#   28.71,
#   'Action'),
#  ('Thor: The Dark World', 'Alan Taylor ', 'None', 6.8, 206.36, 'Action'),
#  ('Mad Max', 'George Miller ', 'None', 6.8, 8.75, 'Action'),
#  ('Captain Marvel', ' Anna Boden ', 'Ryan Fleck', 6.8, 426.83, 'Action'),
#  ('Men in Black 3', 'Barry Sonnenfeld ', 'None', 6.8, 179.02, 'Action'),
#  ('The Maze Runner', 'Wes Ball ', 'None', 6.8, 102.43, 'Action'),
#  ('The Book of Eli', ' Albert Hughes ', 'Allen Hughes', 6.8, 94.84, 'Action'),
#  ('TRON: Legacy', 'Joseph Kosinski ', 'None', 6.8, 172.06, 'Action'),
#  ('What Happened to Monday', 'Tommy Wirkola ', 'None', 6.8, ' ', 'Action'),
#  ('Spectre (I)', 'Sam Mendes ', 'None', 6.8, 200.07, 'Action'),
#  ('Boss Level', 'Joe Carnahan ', 'None', 6.8, ' ', 'Action'),
#  ('Bad Boys', 'Michael Bay ', 'None', 6.8, 65.81, 'Action'),
#  ('Kisi Ka Bhai Kisi Ki Jaan', 'Farhad Samji ', 'None', 6.8, ' ', 'Action'),
#  ('The Long Kiss Goodnight', 'Renny Harlin ', 'None', 6.8, 33.33, 'Action'),
#  ('The Island', 'Michael Bay ', 'None', 6.8, 35.82, 'Action'),
#  ('News of the World', 'Paul Greengrass ', 'None', 6.8, ' ', 'Action'),
#  ('The Transporter', ' Louis Leterrier', 'Corey Yuen ', 6.8, 25.3, 'Action'),
#  ('Hellboy', 'Guillermo del Toro ', 'None', 6.8, 59.62, 'Action'),
#  ('The Outpost', 'Rod Lurie ', 'None', 6.8, ' ', 'Action'),
#  ('Chappie', 'Neill Blomkamp ', 'None', 6.8, 31.57, 'Action'),
#  ('Ghostbusters', 'Ivan Reitman ', 'None', 7.8, 128.34, 'Action'),
#  ('Ghostbusters', 'Paul Feig ', 'None', 6.8, 128.34, 'Action'),
#  ('Bloodsport', 'Newt Arnold ', 'None', 6.8, 11.81, 'Action'),
#  ('Young Guns', 'Christopher Cain ', 'None', 6.8, 45.66, 'Action'),
#  ('The Mask of Zorro', 'Martin Campbell ', 'None', 6.8, 94.1, 'Action'),
#  ('Logans Run', 'Michael Anderson ', 'None', 6.8, 25, 'Action'),
#  ('Hanna', 'Joe Wright ', 'None', 6.8, 40.26, 'Action'),
#  ('Patriot Games', 'Phillip Noyce ', 'None', 6.8, 83.29, 'Action'),
#  ('Superman II', ' Richard Lester', 'Richard Donner ', 6.8, 108.19, 'Action'),
#  ('Unstoppable', 'Tony Scott ', 'None', 6.8, 81.56, 'Action'),
#  ('You Only Live Twice', 'Lewis Gilbert ', 'None', 6.8, 43.08, 'Action'),
#  ('Street Kings', 'David Ayer ', 'None', 6.8, 26.42, 'Action'),
#  ('The Score', 'Frank Oz ', 'None', 6.8, 71.07, 'Action'),
#  ('Shin Godzilla', ' Hideaki Anno', 'Shinji Higuchi ', 6.8, 1.92, 'Action'),
#  ('Four Brothers', 'John Singleton ', 'None', 6.8, 74.49, 'Action'),
#  ('Innerspace', 'Joe Dante ', 'None', 6.8, 25.89, 'Action'),
#  ('Dog Soldiers', 'Neil Marshall ', 'None', 6.8, ' ', 'Action'),
#  ('Three Steps Above Heaven',
#   ' Fernando GonzÃ¡lez Molina',
#   'None',
#   6.8,
#   ' ',
#   'Action'),
#  ('Unknown (I)', 'Jaume Collet-Serra ', 'None', 6.8, 63.69, 'Action'),
#  ('El Mariachi', 'Robert Rodriguez ', 'None', 6.8, 2.04, 'Action'),
#  ('Enemy Mine', 'Wolfgang Petersen ', 'None', 6.8, 4.27, 'Action'),
#  ('Tristan + Isolde', 'Kevin Reynolds ', 'None', 6.8, 14.73, 'Action'),
#  ('Harsh Times', 'David Ayer ', 'None', 6.8, 3.34, 'Action'),
#  ('Green Zone', 'Paul Greengrass ', 'None', 6.8, 35.05, 'Action'),
#  ('We Own the Night', 'James Gray ', 'None', 6.8, 28.56, 'Action'),
#  ('Who Am I?', ' Benny Chan', 'Jackie Chan ', 6.8, ' ', 'Action'),
#  ('Dead Snow 2: Red vs. Dead', 'Tommy Wirkola ', 'None', 6.8, ' ', 'Action'),
#  ('Black Panther: Wakanda Forever',
#   'Ryan Coogler ',
#   'None',
#   6.7,
#   453.72,
#   'Action'),
#  ('Extraction', 'Sam Hargrave ', 'None', 6.7, ' ', 'Action'),
#  ('Kingsman: The Golden Circle',
#   'Matthew Vaughn ',
#   'None',
#   6.7,
#   100.23,
#   'Action'),
#  ('Black Widow', 'Cate Shortland ', 'None', 6.7, 183.65, 'Action'),
#  ('Jumanji: The Next Level', 'Jake Kasdan ', 'None', 6.7, 316.83, 'Action'),
#  ('Violent Night', 'Tommy Wirkola ', 'None', 6.7, ' ', 'Action'),
#  ('In Time', 'Andrew Niccol ', 'None', 6.7, 37.52, 'Action'),
#  ('Safe House', 'Daniel Espinosa ', 'None', 6.7, 126.37, 'Action'),
#  ('The Running Man', 'Paul Michael Glaser ', 'None', 6.7, 38.12, 'Action'),
#  ('Road House', 'Rowdy Herrington ', 'None', 6.7, 30.05, 'Action'),
#  ('The Adam Project', 'Shawn Levy ', 'None', 6.7, ' ', 'Action'),
#  ('Bumblebee (I)', 'Travis Knight ', 'None', 6.7, 127.2, 'Action'),
#  ('No Escape (I)', 'John Erick Dowdle ', 'None', 6.7, 27.29, 'Action'),
#  ('Warcraft', 'Duncan Jones ', 'None', 6.7, 47.37, 'Action'),
#  ('Armageddon', 'Michael Bay ', 'None', 6.7, 201.57, 'Action'),
#  ('The Equalizer 2', 'Antoine Fuqua ', 'None', 6.7, 102.08, 'Action'),
#  ('The Wolverine', 'James Mangold ', 'None', 6.7, 132.56, 'Action'),
#  ('Commando', 'Mark L. Lester ', 'None', 6.7, 35.1, 'Action'),
#  ('Midway', 'Roland Emmerich ', 'None', 6.7, 56.85, 'Action'),
#  ('The A-Team', 'Joe Carnahan ', 'None', 6.7, 77.22, 'Action'),
#  ('King Arthur: Legend of the Sword',
#   'Guy Ritchie ',
#   'None',
#   6.7,
#   39.18,
#   'Action'),
#  ('Atomic Blonde', 'David Leitch ', 'None', 6.7, 51.69, 'Action'),
#  ('Backdraft', 'Ron Howard ', 'None', 6.7, 77.87, 'Action'),
#  ('Wanted', 'Timur Bekmambetov ', 'None', 6.7, 134.51, 'Action'),
#  ('Enola Holmes 2', 'Harry Bradbeer ', 'None', 6.7, ' ', 'Action'),
#  ('Super (I)', 'James Gunn ', 'None', 6.7, 0.32, 'Action'),
#  ('Teenage Mutant Ninja Turtles',
#   'Jonathan Liebesman ',
#   'None',
#   5.8,
#   135.27,
#   'Action'),
#  ('Teenage Mutant Ninja Turtles',
#   'Steve Barron ',
#   'None',
#   6.7,
#   135.27,
#   'Action'),
#  ('Zombieland: Double Tap', 'Ruben Fleischer ', 'None', 6.7, 73.12, 'Action'),
#  ('Blade II', 'Guillermo del Toro ', 'None', 6.7, 82.35, 'Action'),
#  ('Tron', 'Steven Lisberger ', 'None', 6.7, 33, 'Action'),
#  ('Demolition Man', 'Marco Brambilla ', 'None', 6.7, 58.06, 'Action'),
#  ('The Matrix Revolutions',
#   'Lana Wachowski',
#   ' Lilly Wachowski ',
#   6.7,
#   139.31,
#   'Action'),
#  ('Escape Plan', 'Mikael HÃ¥fstrÃ¶m', 'None', 6.7, 25.13, 'Action'),
#  ('2 Guns', 'Baltasar KormÃ¡kur', 'None', 6.7, 75.61, 'Action'),
#  ('Angels & Demons', 'Ron Howard ', 'None', 6.7, 133.38, 'Action'),
# ...
#  ('New Jack City', 'Mario Van Peebles ', 'None', 6.6, 47.62, 'Action'),
#  ('21 Bridges', 'Brian Kirk ', 'None', 6.6, 28.54, 'Action'),
#  ('Outland', 'Peter Hyams ', 'None', 6.6, 17.37, 'Action'),
#  ('The Final Countdown', 'Don Taylor ', 'None', 6.6, 16.65, 'Action'),
#  ('Courage Under Fire', 'Edward Zwick ', 'None', 6.6, 59.03, 'Action'),
#  ('The Wave', 'Roar Uthaug ', 'None', 6.6, 0.18, 'Action'),
#  ('Man on a Ledge', 'Asger Leth ', 'None', 6.6, 18.62, 'Action'),
#  ('Alpha (II)', 'Albert Hughes ', 'None', 6.6, 35.85, 'Action'),
#  ('Lethal Weapon 4', 'Richard Donner ', 'None', 6.6, 130.44, 'Action'),
#  ('The Recruit', 'Roger Donaldson ', 'None', 6.6, 52.8, 'Action'),
#  ('Edge of Darkness', 'Martin Campbell ', 'None', 6.6, 43.31, 'Action'),
#  ('The Way of the Gun', 'Christopher McQuarrie ', 'None', 6.6, 6.06, 'Action'),
#  ('Vantage Point', 'Pete Travis ', 'None', 6.6, 72.27, 'Action'),
#  ('16 Blocks', 'Richard Donner ', 'None', 6.6, 36.9, 'Action'),
#  ('Raees', 'Rahul Dholakia ', 'None', 6.6, 3.26, 'Action'),
#  ('Seraphim Falls', 'David Von Ancken ', 'None', 6.6, 0.42, 'Action'),
#  ('22 Bullets', 'Richard Berry ', 'None', 6.6, ' ', 'Action'),
#  ('Wasabi', 'GÃ©rard Krawczyk ', 'None', 6.6, 0.08, 'Action'),
#  ('Wanted (I)', 'Prabhu Deva ', 'None', 6.6, ' ', 'Action'),
#  ('Fast & Furious', 'Justin Lin ', 'None', 6.5, 155.06, 'Action'),
#  ('Plane', ' Jean-FranÃ§ois Richet', 'None', 6.5, ' ', 'Action'),
#  ('Fast & Furious Presents: Hobbs & Shaw',
#   'David Leitch ',
#   'None',
#   6.5,
#   173.96,
#   'Action'),
#  ('The Gray Man', ' Anthony Russo', 'Joe Russo ', 6.5, ' ', 'Action'),
#  ('Star Wars: Episode I - The Phantom Menace',
#   'George Lucas ',
#   'None',
#   6.5,
#   474.54,
#   'Action'),
#  ('Star Wars: Episode IX - The Rise of Skywalker',
#   'J.J. Abrams ',
#   'None',
#   6.5,
#   515.2,
#   'Action'),
#  ('The Hunt (II)', 'Craig Zobel ', 'None', 6.5, 5.81, 'Action'),
#  ('The Tomorrow War', 'Chris McKay ', 'None', 6.5, ' ', 'Action'),
#  ('Pirates of the Caribbean: Dead Men Tell No Tales',
#   'Joachim RÃ¸nning',
#   'Espen Sandberg',
#   6.5,
#   172.56,
#   'Action'),
#  ('Homefront (I)', 'Gary Fleder ', 'None', 6.5, 20.16, 'Action'),
#  ('Pokemon: Detective Pikachu',
#   'Rob Letterman ',
#   'None',
#   6.5,
#   144.11,
#   'Action'),
#  ('Sonic the Hedgehog 2', 'Jeff Fowler ', 'None', 6.5, 190.87, 'Action'),
#  ('Tag (I)', 'Jeff Tomsic ', 'None', 6.5, 54.55, 'Action'),
#  ('Sonic the Hedgehog', 'Jeff Fowler ', 'None', 6.5, 148.97, 'Action'),
#  ('The Lost World: Jurassic Park',
#   'Steven Spielberg ',
#   'None',
#   6.5,
#   229.09,
#   'Action'),
#  ('Olympus Has Fallen', 'Antoine Fuqua ', 'None', 6.5, 98.93, 'Action'),
#  ('Gone in 60 Seconds', 'Dominic Sena ', 'None', 6.5, 101.65, 'Action'),
#  ('Bad Boys for Life',
#   ' Adil El Arbi',
#   'Bilall Fallah ',
#   6.5,
#   206.31,
#   'Action'),
#  ('The Hunger Games: Mockingjay - Part 2',
#   'Francis Lawrence ',
#   'None',
#   6.5,
#   281.72,
#   'Action'),
#  ('X-Men Origins: Wolverine', 'Gavin Hood ', 'None', 6.5, 179.88, 'Action'),
#  ('War of the Worlds', 'Steven Spielberg ', 'None', 6.5, 234.28, 'Action'),
#  ('Mandy (I)', 'Panos Cosmatos ', 'None', 6.5, 1.21, 'Action'),
#  ('Swordfish', 'Dominic Sena ', 'None', 6.5, 69.77, 'Action'),
#  ('Flash Gordon', 'Mike Hodges ', 'None', 6.5, ' ', 'Action'),
#  ('12 Strong', 'Nicolai Fuglsig ', 'None', 6.5, 45.82, 'Action'),
#  ('The Mechanic', 'Simon West ', 'None', 6.5, 29.12, 'Action'),
#  ('The Quick and the Dead', 'Sam Raimi ', 'None', 6.5, 18.64, 'Action'),
#  ('Mr. & Mrs. Smith', 'Doug Liman ', 'None', 6.5, 186.34, 'Action'),
#  ('The Chronicles of Narnia: Prince Caspian',
#   'Andrew Adamson ',
#   'None',
#   6.5,
#   141.62,
#   'Action'),
#  ('Cliffhanger', 'Renny Harlin ', 'None', 6.5, 84.05, 'Action'),
#  ('Beverly Hills Cop II', 'Tony Scott ', 'None', 6.5, 153.67, 'Action'),
#  ('The Spiderwick Chronicles', 'Mark Waters ', 'None', 6.5, 71.2, 'Action'),
#  ('Sin City: A Dame to Kill For',
#   ' Frank Miller ',
#   'Robert Rodriguez',
#   6.5,
#   13.76,
#   'Action'),
#  ('Tomorrow Never Dies', 'Roger Spottiswoode ', 'None', 6.5, 125.33, 'Action'),
#  ('Kick-Ass 2', 'Jeff Wadlow ', 'None', 6.5, 28.8, 'Action'),
#  ('Terminator Salvation', 'McG ', 'None', 6.5, 125.32, 'Action'),
#  ('Rambo: First Blood Part II',
#   'George P. Cosmatos ',
#   'None',
#   6.5,
#   150.42,
#   'Action'),
#  ('The Forbidden Kingdom', 'Rob Minkoff ', 'None', 6.5, 52.08, 'Action'),
#  ('Air Force One', 'Wolfgang Petersen ', 'None', 6.5, 172.96, 'Action'),
#  ('The Man in the Iron Mask (I)',
#   'Randall Wallace ',
#   'None',
#   6.5,
#   56.97,
#   'Action'),
#  ('A Walk Among the Tombstones', 'Scott Frank ', 'None', 6.5, 26.31, 'Action'),
#  ('The Interview (II)', ' Evan Goldberg', 'Seth Rogen ', 6.5, 6.11, 'Action'),
#  ('The Perfect Storm', 'Wolfgang Petersen ', 'None', 6.5, 182.62, 'Action'),
#  ('Under Siege', 'Andrew Davis ', 'None', 6.5, 83.36, 'Action'),
#  ('Never Back Down', 'Jeff Wadlow ', 'None', 6.5, 24.85, 'Action'),
#  ('Space Cowboys', 'Clint Eastwood ', 'None', 6.5, 90.46, 'Action'),
#  ('Nerve (I)', ' Henry Joost', 'Ariel Schulman ', 6.5, 38.58, 'Action'),
#  ('The Rocketeer', 'Joe Johnston ', 'None', 6.5, 46.7, 'Action'),
#  ('Peppermint', 'Pierre Morel ', 'None', 6.5, 35.42, 'Action'),
#  ('Octopussy', 'John Glen ', 'None', 6.5, 67.9, 'Action'),
#  ('Diamonds Are Forever', 'Guy Hamilton ', 'None', 6.5, 43.82, 'Action'),
#  ('Get Smart', 'Peter Segal ', 'None', 6.5, 130.32, 'Action'),
#  ('Safe (I)', 'Boaz Yakin ', 'None', 6.5, 17.14, 'Action'),
#  ('U.S. Marshals', 'Stuart Baird ', 'None', 6.5, 57.17, 'Action'),
#  ('National Treasure: Book of Secrets',
#   'Jon Turteltaub ',
#   'None',
#   6.5,
#   219.96,
#   'Action'),
#  ('Underworld: Rise of the Lycans',
#   'Patrick Tatopoulos ',
#   'None',
#   6.5,
#   45.8,
#   'Action'),
#  ('Batman: The Movie', 'Leslie H. Martinson ', 'None', 6.5, ' ', 'Action'),
#  ('Executive Decision', 'Stuart Baird ', 'None', 6.5, 56.57, 'Action'),
#  ('Young Guns II', 'Geoff Murphy ', 'None', 6.5, 44.14, 'Action'),
#  ('Self/less', 'Tarsem Singh ', 'None', 6.5, 12.28, 'Action'),
#  ('The International (I)', 'Tom Tykwer ', 'None', 6.5, 25.45, 'Action'),
#  ('Cellular', 'David R. Ellis ', 'None', 6.5, 32, 'Action'),
#  ('Premium Rush', 'David Koepp ', 'None', 6.5, 20.28, 'Action'),
#  ('The Grandmaster', 'Kar-Wai Wong ', 'None', 6.5, 6.59, 'Action'),
#  ('Space Sweepers', 'Sung-hee Jo ', 'None', 6.5, ' ', 'Action'),
#  ('Hostage', 'Florent-Emilio Siri ', 'None', 6.5, 34.64, 'Action'),
#  ('Flyboys', 'Tony Bill ', 'None', 6.5, 13.08, 'Action'),
#  ('Heist', 'David Mamet ', 'None', 6.5, 0.05, 'Action'),
#  ('The Four Feathers', 'Shekhar Kapur ', 'None', 6.5, 18.31, 'Action'),
#  ('Ladder 49', 'Jay Russell ', 'None', 6.5, 74.54, 'Action'),
#  ('War', 'Philip G. Atwell ', 'None', 6.2, ' ', 'Action'),
#  ('War', 'Siddharth Anand ', 'None', 6.5, ' ', 'Action'),
#  ('Spartan', 'David Mamet ', 'None', 6.5, 4.43, 'Action'),
#  ('District 13: Ultimatum',
#   'Patrick Alessandrin ',
#   'None',
#   6.5,
#   0.04,
#   'Action'),
#  ('Dhoom 2', 'Sanjay Gadhvi ', 'None', 6.5, 2.64, 'Action'),
#  ('Taxi 2', 'GÃ©rard Krawczyk', 'None', 6.5, 0.73, 'Action'),
#  ('Conquest 1453', 'Faruk Aksoy ', 'None', 6.5, 0.07, 'Action'),
#  ('Valerian and the City of a Thousand Planets',
#   'Luc Besson ',
#   'None',
#   6.4,
#   41.19,
#   'Action'),
#  ('Twister (I)', 'Jan de Bont ', 'None', 6.4, 241.72, 'Action'),
#  ('Escape Room (I)', 'Adam Robitel ', 'None', 6.4, 57.01, 'Action'),
#  ('The Punisher', 'Jonathan Hensleigh ', 'None', 6.4, 33.81, 'Action'),
#  ('Lucy (I)', 'Luc Besson ', 'None', 6.4, 126.66, 'Action'),
#  ('Last Action Hero', 'John McTiernan ', 'None', 6.4, 50.02, 'Action'),
#  ('The Day After Tomorrow', 'Roland Emmerich ', 'None', 6.4, 186.74, 'Action'),
#  ('Batman v Superman: Dawn of Justice',
#   'Zack Snyder ',
#   'None',
#   6.4,
#   330.36,
#   'Action'),
#  ('Triple Frontier', 'J.C. Chandor ', 'None', 6.4, ' ', 'Action'),
#  ('Greenland', 'Ric Roman Waugh ', 'None', 6.4, ' ', 'Action'),
#  ('Godzilla', 'Gareth Edwards ', 'None', 6.4, 200.68, 'Action'),
#  ('Tomorrowland', 'Brad Bird ', 'None', 6.4, 93.44, 'Action'),
#  ('Riddick', 'David Twohy ', 'None', 6.4, 42.03, 'Action'),
#  ('Death Race', 'Paul W.S. Anderson ', 'None', 6.4, 36.32, 'Action'),
#  ('The Mummy Returns', 'Stephen Sommers ', 'None', 6.4, 202.02, 'Action'),
#  ('The Sum of All Fears',
#   'Phil Alden Robinson ',
#   'None',
#   6.4,
#   118.91,
#   'Action'),
#  ('Angel Has Fallen', 'Ric Roman Waugh ', 'None', 6.4, 69.03, 'Action'),
#  ('Army of Thieves', 'Matthias SchweighÃ¶fer ', 'None', 6.4, ' ', 'Action'),
#  ('Revenge (II)', 'Coralie Fargeat ', 'None', 6.4, 0.1, 'Action'),
#  ('The Expendables', 'Sylvester Stallone ', 'None', 6.4, 103.07, 'Action'),
#  ('Predators', 'NimrÃ³d Antal ', 'None', 6.4, 52, 'Action'),
#  ('Need for Speed', 'Scott Waugh ', 'None', 6.4, 43.58, 'Action'),
#  ('Hancock', 'Peter Berg ', 'None', 6.4, 227.95, 'Action'),
#  ('The Three Musketeers', 'Paul W.S. Anderson ', 'None', 5.7, 53.9, 'Action'),
#  ('The Three Musketeers', 'Stephen Herek ', 'None', 6.4, 53.9, 'Action'),
#  ('Now You See Me 2', 'Jon M. Chu ', 'None', 6.4, 65.08, 'Action'),
#  ('The World Is Not Enough', 'Michael Apted ', 'None', 6.4, 126.94, 'Action'),
#  ('Colombiana', 'Olivier Megaton ', 'None', 6.4, 36.67, 'Action'),
#  ('Salt', 'Phillip Noyce ', 'None', 6.4, 118.31, 'Action'),
#  ('Savages (I)', 'Oliver Stone ', 'None', 6.4, 47.38, 'Action'),
#  ('Pain & Gain', 'Michael Bay ', 'None', 6.4, 49.88, 'Action'),
#  ('Faster', 'George Tillman Jr. ', 'None', 6.4, 23.24, 'Action'),
#  ('The Vault', ' Jaume BalaguerÃ³', 'None', 6.4, ' ', 'Action'),
#  ('Rat Race', 'Jerry Zucker ', 'None', 6.4, 56.62, 'Action'),
#  ('Tango & Cash',
#   ' Andrey Konchalovskiy',
#   'Albert Magnoli',
#   6.4,
#   63.41,
#   'Action'),
#  ('Star Trek: Nemesis', 'Stuart Baird ', 'None', 6.4, 43.25, 'Action'),
#  ('The Lone Ranger', 'Gore Verbinski ', 'None', 6.4, 89.3, 'Action'),
#  ('Here Comes the Boom', 'Frank Coraci ', 'None', 6.4, 45.29, 'Action'),
#  ('The Taking of Pelham 123', 'Tony Scott ', 'None', 6.4, 65.45, 'Action'),
#  ('Kickboxer', ' Mark DiSalle', ' David Worth ', 6.4, 14.7, 'Action'),
#  ('The Purge: Anarchy', 'James DeMonaco ', 'None', 6.4, 71.96, 'Action'),
#  ('Star Trek: Insurrection', 'Jonathan Frakes ', 'None', 6.4, 70.12, 'Action'),
#  ('The Jackal', 'Michael Caton-Jones ', 'None', 6.4, 54.93, 'Action'),
#  ('Chaos (II)', 'Tony Giglio ', 'None', 6.4, ' ', 'Action'),
#  ('DragonHeart', 'Rob Cohen ', 'None', 6.4, 51.37, 'Action'),
#  ('Behind Enemy Lines', 'John Moore ', 'None', 6.4, 59.07, 'Action'),
#  ('Killer Elite', 'Gary McKendry ', 'None', 6.4, 25.12, 'Action'),
#  ('Live by Night', 'Ben Affleck ', 'None', 6.4, 10.38, 'Action'),
#  ('Darkman', 'Sam Raimi ', 'None', 6.4, 33.88, 'Action'),
#  ('Kill List', 'Ben Wheatley ', 'None', 6.4, 0.03, 'Action'),
#  ('Act of Valor', ' Mike McCoy', ' Scott Waugh ', 6.4, 70.01, 'Action'),
#  ('The Siege', 'Edward Zwick ', 'None', 6.4, 40.98, 'Action'),
#  ('Lets Be Cops', 'Luke Greenfield ', 'None', 6.4, 82.39, 'Action'),
#  ('Daybreakers', ' Michael Spierig', 'Peter Spierig ', 6.4, 30.1, 'Action'),
#  ('The Omega Man', 'Boris Sagal ', 'None', 6.4, 8.72, 'Action'),
#  ('Shaft', 'John Singleton ', 'None', 6, 21.36, 'Action'),
#  ('Shaft', 'Tim Story ', 'None', 6.4, 21.36, 'Action'),
#  ('Snitch (I)', 'Ric Roman Waugh ', 'None', 6.4, 42.93, 'Action'),
#  ('Contraband', 'Baltasar KormÃ¡kur', 'None', 6.4, 66.53, 'Action'),
#  ('The Prophecy', 'Gregory Widen ', 'None', 6.4, 16.12, 'Action'),
#  ('The Rover', 'David MichÃ´d', 'None', 6.4, 1.11, 'Action'),
#  ('Blood Father', 'Jean-FranÃ§ois Richet ', 'None', 6.4, ' ', 'Action'),
#  ('Just Cause', 'Arne Glimcher ', 'None', 6.4, 36.85, 'Action'),
#  ('Black Death', 'Christopher Smith ', 'None', 6.4, 0.02, 'Action'),
#  ('Dead Man Down', 'Niels Arden Oplev ', 'None', 6.4, 10.88, 'Action'),
#  ('Lock Up', 'John Flynn ', 'None', 6.4, 22.1, 'Action'),
#  ('Last Man Standing', 'Walter Hill ', 'None', 6.4, 17.6, 'Action'),
#  ('Black and Blue (I)', 'Deon Taylor ', 'None', 6.4, 22.06, 'Action'),
#  ('Basic', 'John McTiernan ', 'None', 6.4, 26.54, 'Action'),
#  ('Son of a Gun', 'Julius Avery ', 'None', 6.4, 0, 'Action'),
#  ('From Paris with Love', 'Pierre Morel ', 'None', 6.4, 23.98, 'Action'),
#  ('Blood Work', 'Clint Eastwood ', 'None', 6.4, 26.2, 'Action'),
#  ('How I Live Now', 'Kevin Macdonald ', 'None', 6.4, 0.06, 'Action'),
#  ('Ned Kelly', 'Gregor Jordan ', 'None', 6.4, 0.07, 'Action'),
#  ('Night Watch', 'Timur Bekmambetov ', 'None', 6.4, 1.49, 'Action'),
#  ('Day Watch', 'Timur Bekmambetov ', 'None', 6.4, 0.45, 'Action'),
#  ('Redirected', 'Emilis Velyvis ', 'None', 6.4, ' ', 'Action'),
#  ('Fast X', 'Louis Leterrier ', 'None', 6.3, ' ', 'Action'),
#  ('Operation Fortune: Ruse de Guerre',
#   'Guy Ritchie ',
#   'None',
#   6.3,
#   ' ',
#   'Action'),
#  ('King Arthur', 'Antoine Fuqua ', 'None', 6.3, 51.88, 'Action'),
#  ('Black Adam', 'Jaume Collet-Serra ', 'None', 6.3, 168.15, 'Action'),
#  ('Eternals', 'ChloÃ© Zhao', 'None', 6.3, 164.87, 'Action'),
#  ('Dune', 'David Lynch ', 'None', 6.3, 30.93, 'Action'),
#  ('Dune', 'Denis Villeneuve ', 'None', 8, 30.93, 'Action'),
#  ('Uncharted', 'Ruben Fleischer ', 'None', 6.3, 148.65, 'Action'),
#  ('The Kings Man', 'Matthew Vaughn ', 'None', 6.3, 37.18, 'Action'),
#  ('Spider-Man 3', 'Sam Raimi ', 'None', 6.3, 336.53, 'Action'),
#  ('Red Notice', 'Rawson Marshall Thurber ', 'None', 6.3, ' ', 'Action'),
#  ('Godzilla vs. Kong', 'Adam Wingard ', 'None', 6.3, 100.92, 'Action'),
#  ('Central Intelligence',
#   'Rawson Marshall Thurber ',
#   'None',
#   6.3,
#   127.44,
#   'Action'),
#  ('Sky High', 'Mike Mitchell ', 'None', 6.3, 63.95, 'Action'),
#  ('Terminator Genisys', 'Alan Taylor ', 'None', 6.3, 89.76, 'Action'),
#  ('Oceans Eight', 'Gary Ross ', 'None', 6.3, 140.22, 'Action'),
#  ('The Last Stand', 'Jee-woon Kim ', 'None', 6.3, 12.05, 'Action'),
#  ('Polar (I)', ' Jonas Ã…kerlund ', 'None', 6.3, ' ', 'Action'),
#  ('Tomb Raider', 'Roar Uthaug ', 'None', 6.3, 58.25, 'Action'),
#  ('White House Down', 'Roland Emmerich ', 'None', 6.3, 73.1, 'Action'),
#  ('Terminator 3: Rise of the Machines',
#   'Jonathan Mostow ',
#   'None',
#   6.3,
#   150.37,
#   'Action'),
#  ('Ghost in the Shell', 'Mamoru Oshii ', 'None', 7.9, 40.56, 'Action'),
#  ('Ghost in the Shell', 'Rupert Sanders ', 'None', 6.3, 40.56, 'Action'),
#  ('The Bodyguard', 'Mick Jackson ', 'None', 6.3, 121.95, 'Action'),
#  ('Knight and Day', 'James Mangold ', 'None', 6.3, 76.42, 'Action'),
#  ('Waterworld', 'Kevin Reynolds ', 'None', 6.3, 88.25, 'Action'),
#  ('A View to a Kill', 'John Glen ', 'None', 6.3, 50.33, 'Action'),
#  ('Miss Congeniality', 'Donald Petrie ', 'None', 6.3, 106.81, 'Action'),
#  ('The Shallows', 'Jaume Collet-Serra ', 'None', 6.3, 55.12, 'Action'),
#  ('Criminal', 'Ariel Vromen ', 'None', 6.3, 14.27, 'Action'),
#  ('Every Which Way But Loose', 'James Fargo ', 'None', 6.3, 106, 'Action'),
#  ('The American', 'Anton Corbijn ', 'None', 6.3, 35.61, 'Action'),
#  ('Run Hide Fight', 'Kyle Rankin ', 'None', 6.3, ' ', 'Action'),
#  ('Red Dawn', 'John Milius ', 'None', 6.3, 38.38, 'Action'),
#  ('My Spy', 'Peter Segal ', 'None', 6.3, ' ', 'Action'),
#  ('Maze Runner: The Scorch Trials', 'Wes Ball ', 'None', 6.3, 81.7, 'Action'),
#  ('Once Upon a Time in Mexico',
#   'Robert Rodriguez ',
#   'None',
#   6.3,
#   56.36,
#   'Action'),
#  ('Scouts Guide to the Zombie Apocalypse',
#   'Christopher Landon ',
#   'None',
#   6.3,
#   3.64,
#   'Action'),
#  ('Death Wish', 'Eli Roth ', 'None', 6.3, 34.02, 'Action'),
#  ('Death Wish', 'Michael Winner ', 'None', 6.9, 34.02, 'Action'),
#  ('Bright (I)', 'David Ayer ', 'None', 6.3, ' ', 'Action'),
#  ('Spectral', 'Nic Mathieu ', 'None', 6.3, ' ', 'Action'),
#  ('Ninja Assassin', 'James McTeigue ', 'None', 6.3, 38.11, 'Action'),
#  ('The Take', 'James Watkins ', 'None', 6.3, 0.04, 'Action'),
#  ('The Commuter (I)', 'Jaume Collet-Serra ', 'None', 6.3, 36.34, 'Action'),
#  ('Sand Castle', 'Fernando Coimbra ', 'None', 6.3, ' ', 'Action'),
#  ('Predator 2', 'Stephen Hopkins ', 'None', 6.3, 30.67, 'Action'),
#  ('Triple 9', 'John Hillcoat ', 'None', 6.3, 12.63, 'Action'),
#  ('The Collector (I)', 'Marcus Dunstan ', 'None', 6.3, 7.71, 'Action'),
#  ('Unlocked (I)', 'Michael Apted ', 'None', 6.3, ' ', 'Action'),
#  ('Guns Akimbo', 'Jason Howden ', 'None', 6.3, ' ', 'Action'),
#  ('Surrogates', 'Jonathan Mostow ', 'None', 6.3, 38.58, 'Action'),
#  ...]

# %% [markdown]
# 3) Display all details from both tables with the highest gross collection.

# %%
high_gross=c.execute("select * from table1 INNER JOIN table2 ON table1.Movie_Name=table2.Movie_Name order by Grosscollection desc ")
high_gross.fetchall()
# Out:
# [(239,
#   'Pushpa: The Rise - Part 1',
#   'Sukumar ',
#   'None',
#   179,
#   2021,
#   7.6,
#   83,
#   'Pushpa: The Rise - Part 1',
#   '  Allu Arjun',
#   ' Fahadh Faasil',
#   ' Rashmika Mandanna',
#   ' Jagadeesh Prathap Bandari',
#   80417,
#   'Action',
#   ' Crime',
#   ' Drama',
#   '  ',
#   'PG-13'),
#  (157,
#   'Ninja Scroll',
#   'Yoshiaki Kawajiri ',
#   'None',
#   94,
#   1993,
#   7.8,
#   56,
#   'Ninja Scroll',
#   '  KÃƒÂ´ichi Yamadera',
#   ' Emi Shinohara',
#   ' Takeshi Aono',
#   ' Osamu Saka',
#   38856,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   ' ',
#   'R'),
#  (159,
#   'The Killer',
#   'John Woo ',
#   'None',
#   111,
#   1989,
#   7.8,
#   74,
#   'The Killer',
#   '  Chow Yun-Fat',
#   ' Danny Lee',
#   ' Sally Yeh',
#   ' Kong Chu',
#   49583,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  (162,
#   'Minnal Murali',
#   'Basil Joseph ',
#   'None',
#   158,
#   2021,
#   7.8,
#   65,
#   'Minnal Murali',
#   '  Tovino Thomas',
#   ' Guru Somasundaram',
#   ' Aju Varghese',
#   ' Baiju',
#   31064,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'R'),
#  (185,
#   'Bonnie and Clyde',
#   'Arthur Penn ',
#   'None',
#   111,
#   1967,
#   7.7,
#   68,
#   'Bonnie and Clyde',
#   '  Warren Beatty',
#   ' Faye Dunaway',
#   ' Michael J. Pollard',
#   ' Gene Hackman',
#   116465,
#   'Action',
#   ' Biography',
#   ' Crime',
#   ' ',
#   'PG'),
#  (187,
#   'Badlands',
#   'Terrence Malick ',
#   'None',
#   94,
#   1973,
#   7.7,
#   70,
#   'Badlands',
#   '  Martin Sheen',
#   ' Sissy Spacek',
#   ' Warren Oates',
#   ' Ramon Bieri',
#   75304,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG'),
#  (190,
#   'Ponniyin Selvan: Part I',
#   'Mani Ratnam ',
#   'None',
#   167,
#   2022,
#   7.7,
#   65,
#   'Ponniyin Selvan: Part I',
#   '  Vikram',
#   ' Aishwarya Rai Bachchan',
#   ' Jayam Ravi',
#   ' Karthi',
#   33612,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  (191,
#   'Key Largo',
#   'John Huston ',
#   'None',
#   100,
#   1948,
#   7.7,
#   59,
#   'Key Largo',
#   '  Humphrey Bogart',
#   ' Edward G. Robinson',
#   ' Lauren Bacall',
#   ' Lionel Barrymore',
#   42546,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (193,
#   'Hard Boiled',
#   'John Woo ',
#   'None',
#   128,
#   1992,
#   7.7,
#   60,
#   'Hard Boiled',
#   '  Chow Yun-Fat',
#   ' Tony Leung Chiu-wai',
#   ' Teresa Mo',
#   ' Philip Chan',
#   52121,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'PG'),
#  (194,
#   'Scarface',
#   'Howard Hawks ',
#   'Richard Rosson',
#   93,
#   1932,
#   7.7,
#   69,
#   'Scarface',
#   '  Paul Muni',
#   ' Ann Dvorak',
#   ' Karen Morley',
#   ' Osgood Perkins',
#   29086,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  (196,
#   'Joint Security Area',
#   'Park Chan-wook ',
#   'None',
#   110,
#   2000,
#   7.7,
#   71,
#   'Joint Security Area',
#   '  Lee Yeong-ae',
#   ' Lee Byung-hun',
#   ' Song Kang-ho',
#   ' Kim Tae-woo',
#   32178,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   ' ',
#   'Not Rated'),
#  (197,
#   'Eega',
#   'S.S. Rajamouli ',
#   'None',
#   145,
#   2012,
#   7.7,
#   64,
#   'Eega',
#   '  Sudeep',
#   ' Nani',
#   ' Samantha Ruth Prabhu',
#   ' Hamsa Nandini',
#   25943,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  (198,
#   'Udta Punjab',
#   'Abhishek Chaubey ',
#   'None',
#   148,
#   2016,
#   7.7,
#   76,
#   'Udta Punjab',
#   '  Shahid Kapoor',
#   ' Alia Bhatt',
#   ' Kareena Kapoor',
#   ' Diljit Dosanjh',
#   31396,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (199,
#   'Raazi',
#   'Meghna Gulzar ',
#   'None',
#   138,
#   2018,
#   7.7,
#   67,
#   'Raazi',
#   '  Alia Bhatt',
#   ' Vicky Kaushal',
#   ' Rajit Kapoor',
#   ' Shishir Sharma',
#   32273,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (200,
#   'Guy Ritchies The Covenant',
#   'Guy Ritchie ',
#   'None',
#   123,
#   2023,
#   7.6,
#   71,
#   'Guy Ritchies The Covenant',
#   '  Jake Gyllenhaal',
#   ' Dar Salim',
#   ' Sean Sagar',
#   ' Jason Wong',
#   38663,
#   'Action',
#   ' Thriller',
#   ' War',
#   ' ',
#   'PG-13'),
#  (225,
#   'Where Eagles Dare',
#   'Brian G. Hutton ',
#   'None',
#   158,
#   1968,
#   7.6,
#   68,
#   'Where Eagles Dare',
#   '  Richard Burton',
#   ' Clint Eastwood',
#   ' Mary Ure',
#   ' Patrick Wymark',
#   60486,
#   'Action',
#   ' Adventure',
#   ' War',
#   ' ',
#   'R'),
#  (228,
#   'Battle Royale',
#   'Kinji Fukasaku ',
#   'None',
#   114,
#   2000,
#   7.6,
#   71,
#   'Battle Royale',
#   '  Tatsuya Fujiwara',
#   ' Aki Maeda',
#   ' TarÃƒÂ´ Yamamoto',
#   ' Chiaki Kuriyama',
#   188311,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  (240,
#   'Ludo',
#   'Anurag Basu ',
#   'None',
#   149,
#   2020,
#   7.6,
#   58,
#   'Ludo',
#   '  Pankaj Tripathi',
#   ' Abhishek Bachchan',
#   ' Rajkummar Rao',
#   ' Fatima Sana Shaikh',
#   41207,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'A'),
#  (242,
#   'Cell 211',
#   'Daniel MonzÃ³n ',
#   'None',
#   113,
#   2009,
#   7.6,
#   84,
#   'Cell 211',
#   '  Luis Tosar',
#   ' Alberto Ammann',
#   ' Antonio Resines',
#   ' Manuel MorÃƒÂ³n',
#   69164,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (243,
#   'Lupin III: The Castle of Cagliostro',
#   'Hayao Miyazaki ',
#   'None',
#   102,
#   1979,
#   7.6,
#   82,
#   'Lupin III: The Castle of Cagliostro',
#   '  Yasuo Yamada',
#   ' Eiko Masuyama',
#   ' Kiyoshi Kobayashi',
#   ' Makio Inoue',
#   31778,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   ' ',
#   'G'),
#  (245,
#   'Mortal World',
#   'Ali Atay ',
#   'None',
#   107,
#   2018,
#   7.6,
#   68,
#   'Mortal World',
#   '  Ahmet MÃƒÂ¼mtaz Taylan',
#   ' Alper Kul',
#   ' Sarp Apak',
#   ' Irem Sak',
#   28153,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'R'),
#  (261,
#   'Riders of Justice',
#   'Anders Thomas Jensen ',
#   'None',
#   116,
#   2020,
#   7.5,
#   64,
#   'Riders of Justice',
#   '  Mads Mikkelsen',
#   ' Nikolaj Lie Kaas',
#   ' Andrea Heick Gadeberg',
#   ' Lars Brygmann',
#   55023,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'PG'),
#  (275,
#   'A Bittersweet Life',
#   'Jee-woon Kim ',
#   'None',
#   119,
#   2005,
#   7.5,
#   48,
#   'A Bittersweet Life',
#   '  Lee Byung-hun',
#   ' Shin Min-a',
#   ' Yeong-cheol Kim',
#   ' Hwang Jung-min',
#   41474,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (277,
#   'Tanhaji: The Unsung Warrior',
#   'Om Raut ',
#   'None',
#   135,
#   2020,
#   7.5,
#   72,
#   'Tanhaji: The Unsung Warrior',
#   '  Ajay Devgn',
#   ' Saif Ali Khan',
#   ' Sharad Kelkar',
#   ' Kajol',
#   34214,
#   'Action',
#   ' Biography',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  (282,
#   'Mersal',
#   'Atlee ',
#   'None',
#   172,
#   2017,
#   7.5,
#   75,
#   'Mersal',
#   '  Joseph Vijay',
#   ' Nithya Menen',
#   ' S.J. Suryah',
#   ' Samantha Ruth Prabhu',
#   36201,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'R'),
#  (283,
#   'To Strike',
#   'Bilal Lashari ',
#   'None',
#   130,
#   2013,
#   7.5,
#   33,
#   'To Strike',
#   '  Shaan Shahid',
#   ' Hamza Ali Abbasi',
#   ' Shamoon Abbasi',
#   ' Ayesha Khan',
#   29927,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (312,
#   'Mission Majnu',
#   'Shantanu Bagchi ',
#   'None',
#   129,
#   2023,
#   7.4,
#   48,
#   'Mission Majnu',
#   '  Sidharth Malhotra',
#   ' Rashmika Mandanna',
#   ' Parmeet Sethi',
#   ' Zakir Hussain',
#   41582,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'PG'),
#  (314,
#   'Rurouni Kenshin Part I: Origins',
#   'Keishi Otomo ',
#   'None',
#   134,
#   2012,
#   7.4,
#   47,
#   'Rurouni Kenshin Part I: Origins',
#   '  Takeru Satoh',
#   ' Emi Takei',
#   ' YÃƒÂ» Aoi',
#   ' Munetaka Aoki',
#   27613,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (315,
#   'Drunken Master',
#   'Woo-Ping Yuen ',
#   'None',
#   111,
#   1978,
#   7.4,
#   59,
#   'Drunken Master',
#   '  Jackie Chan',
#   ' Siu-Tin Yuen',
#   ' Jeong-lee Hwang',
#   ' Dean Shek',
#   41928,
#   'Action',
#   ' Comedy',
#   'None',
#   ' ',
#   'R'),
#  (318,
#   'Dungeons & Dragons: Honor Among Thieves',
#   ' John Francis Daley',
#   'Jonathan Goldstein ',
#   134,
#   2023,
#   7.3,
#   69,
#   'Dungeons & Dragons: Honor Among Thieves',
#   '  Chris Pine',
#   ' Michelle Rodriguez',
#   ' RegÃƒÂ©-Jean Page',
#   ' Justice Smith',
#   113201,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG-13'),
#  (340,
#   'El Camino: A Breaking Bad Movie',
#   'Vince Gilligan ',
#   'None',
#   122,
#   2019,
#   7.3,
#   70,
#   'El Camino: A Breaking Bad Movie',
#   '  Aaron Paul',
#   ' Jonathan Banks',
#   ' Matt Jones',
#   ' Charles Baker',
#   267115,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (352,
#   'Okja',
#   'Bong Joon Ho ',
#   'None',
#   120,
#   2017,
#   7.3,
#   62,
#   'Okja',
#   '  Tilda Swinton',
#   ' Paul Dano',
#   ' Seo-hyun Ahn',
#   ' Jake Gyllenhaal',
#   126574,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (363,
#   'Assault on Precinct 13',
#   'John Carpenter ',
#   'None',
#   91,
#   1976,
#   7.3,
#   59,
#   'Assault on Precinct 13',
#   '  Austin Stoker',
#   ' Darwin Joston',
#   ' Laurie Zimmer',
#   ' Martin West',
#   52831,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'Not Rated'),
#  (367,
#   'Bacurau',
#   'Juliano Dornelles',
#   'Kleber MendonÃ§a Filho',
#   131,
#   2019,
#   7.3,
#   71,
#   'Bacurau',
#   '  BÃƒÂ¡rbara Colen',
#   ' Thomas Aquino',
#   ' Silvero Pereira',
#   ' Thardelly Lima',
#   28983,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  (370,
#   'Max Manus: Man of War',
#   'Joachim RÃ¸nning',
#   'Espen Sandberg ',
#   118,
#   2008,
#   7.3,
#   47,
#   'Max Manus: Man of War',
#   '  Aksel Hennie',
#   ' Agnes Kittelsen',
#   ' Nicolai Cleve Broch',
#   ' Ken Duken',
#   28938,
#   'Action',
#   ' Biography',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (372,
#   'Master (I)',
#   'Lokesh Kanagaraj ',
#   'None',
#   178,
#   2021,
#   7.3,
#   68,
#   'Master (I)',
#   '  Joseph Vijay',
#   ' Vijay Sethupathi',
#   ' Malavika Mohanan',
#   ' Arjun Das',
#   78986,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'R'),
#  (395,
#   'Old Henry',
#   'Potsy Ponciroli ',
#   'None',
#   99,
#   2021,
#   7.2,
#   58,
#   'Old Henry',
#   '  Tim Blake Nelson',
#   ' Scott Haze',
#   ' Gavin Lewis',
#   ' Trace Adkins',
#   30103,
#   'Action',
#   ' Drama',
#   ' Western',
#   ' ',
#   'R'),
#  (401,
#   'Batman v Superman: Dawn of Justice (Ultimate Edition)',
#   'Zack Snyder ',
#   'None',
#   182,
#   2016,
#   7.2,
#   69,
#   'Batman v Superman: Dawn of Justice (Ultimate Edition)',
#   '  Amy Adams',
#   ' Ben Affleck',
#   ' Henry Cavill',
#   ' Jesse Eisenberg',
#   66518,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   ' ',
#   'R'),
#  (404,
#   'The Italian Job',
#   'Peter Collinson ',
#   'None',
#   99,
#   1969,
#   7.2,
#   71,
#   'The Italian Job',
#   '  Michael Caine',
#   ' NoÃƒÂ«l Coward',
#   ' Benny Hill',
#   ' Raf Vallone',
#   48345,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'R'),
#  (412,
#   'Vanishing Point',
#   'Richard C. Sarafian ',
#   'None',
#   99,
#   1971,
#   7.2,
#   61,
#   'Vanishing Point',
#   '  Barry Newman',
#   ' Cleavon Little',
#   ' Charlotte Rampling',
#   ' Dean Jagger',
#   29537,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (418,
#   'The Witcher: Nightmare of the Wolf',
#   'Kwang Il Han ',
#   'None',
#   83,
#   2021,
#   7.2,
#   59,
#   'The Witcher: Nightmare of the Wolf',
#   '  Theo James',
#   ' Mary McDonnell',
#   ' Lara Pulver',
#   ' Graham McTavish',
#   47141,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   ' ',
#   'Not Rated'),
#  (420,
#   'The Siege of Jadotville',
#   'Richie Smyth ',
#   'None',
#   108,
#   2016,
#   7.2,
#   63,
#   'The Siege of Jadotville',
#   '  Richard Lukunku',
#   ' Danny Sapani',
#   ' Andrew Stock',
#   ' Mark Strong',
#   41890,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'R'),
#  (426,
#   'Marshland',
#   'Alberto RodrÃ\xadguez',
#   'None',
#   105,
#   2014,
#   7.2,
#   68,
#   'Marshland',
#   '  Javier GutiÃƒÂ©rrez',
#   ' RaÃƒÂºl ArÃƒÂ©valo',
#   ' MarÃƒÂ\xada Varod',
#   ' Perico Cervantes',
#   35037,
#   'Action',
#   ' Crime',
#   ' Mystery',
#   ' ',
#   'PG-13'),
#  (427,
#   'Final Fantasy VII: Advent Children',
#   ' Tetsuya Nomura',
#   'Takeshi Nozue ',
#   101,
#   2005,
#   7.2,
#   50,
#   'Final Fantasy VII: Advent Children',
#   '  Takahiro Sakurai',
#   ' Ayumi Ito',
#   ' ShÃƒÂ´tarÃƒÂ´ Morikubo',
#   ' Maaya Sakamoto',
#   57213,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   ' ',
#   'PG-13'),
#  (436,
#   'Prey (I)',
#   'Dan Trachtenberg ',
#   'None',
#   100,
#   2022,
#   7.1,
#   42,
#   'Prey (I)',
#   '  Amber Midthunder',
#   ' Dakota Beavers',
#   ' Dane DiLiegro',
#   ' Stormee Kipp',
#   206932,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  (459,
#   'Planet Terror',
#   'Robert Rodriguez ',
#   'None',
#   105,
#   2007,
#   7.1,
#   55,
#   'Planet Terror',
#   '  Rose McGowan',
#   ' Freddy RodrÃƒÂ\xadguez',
#   ' Josh Brolin',
#   ' Marley Shelton',
#   216748,
#   'Action',
#   ' Comedy',
#   ' Horror',
#   ' ',
#   'PG-13'),
#  (468,
#   'Brawl in Cell Block 99',
#   'S. Craig Zahler ',
#   'None',
#   132,
#   2017,
#   7.1,
#   70,
#   'Brawl in Cell Block 99',
#   '  Vince Vaughn',
#   ' Jennifer Carpenter',
#   ' Don Johnson',
#   ' Udo Kier',
#   70791,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (474,
#   'Mosul (I)',
#   'Matthew Michael Carnahan ',
#   'None',
#   101,
#   2019,
#   7.1,
#   60,
#   'Mosul (I)',
#   '  Waleed Elgadi',
#   ' Suhail Dabbach',
#   ' Adam Bessa',
#   ' Ishaq Elias',
#   28471,
#   'Action',
#   ' Drama',
#   ' War',
#   ' ',
#   'Not Rated'),
#  (478,
#   'Kaabil',
#   'Sanjay Gupta ',
#   'None',
#   139,
#   2017,
#   7.1,
#   66,
#   'Kaabil',
#   '  Hrithik Roshan',
#   ' Yami Gautam',
#   ' Ronit Roy',
#   ' Rohit Roy',
#   28005,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (485,
#   'Marighella',
#   'Wagner Moura ',
#   'None',
#   155,
#   2019,
#   7.1,
#   84,
#   'Marighella',
#   '  Seu Jorge',
#   ' Bruno Gagliasso',
#   ' Luiz Carlos Vasconcelos',
#   ' Humberto CarrÃƒÂ£o',
#   55582,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'PG-13'),
#  (487,
#   'Gabbar Is Back',
#   'Radha Krishna Jagarlamudi ',
#   'None',
#   128,
#   2015,
#   7.1,
#   52,
#   'Gabbar Is Back',
#   '  Akshay Kumar',
#   ' Shruti Haasan',
#   ' Kareena Kapoor',
#   ' Suman',
#   25770,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (488,
#   'Sisu',
#   'Jalmari Helander ',
#   'None',
#   91,
#   2022,
#   7,
#   52,
#   'Sisu',
#   '  Jorma Tommila',
#   ' Aksel Hennie',
#   ' Jack Doolan',
#   ' Mimosa Willamo',
#   26050,
#   'Action',
#   ' War',
#   'None',
#   ' ',
#   'PG-13'),
#  (492,
#   'The Unbearable Weight of Massive Talent',
#   'Tom Gormican ',
#   'None',
#   107,
#   2022,
#   7,
#   40,
#   'The Unbearable Weight of Massive Talent',
#   '  Nicolas Cage',
#   ' Pedro Pascal',
#   ' Tiffany Haddish',
#   ' Sharon Horgan',
#   123633,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (499,
#   'Death Proof',
#   'Quentin Tarantino ',
#   'None',
#   127,
#   2007,
#   7,
#   59,
#   'Death Proof',
#   '  Kurt Russell',
#   ' ZoÃƒÂ« Bell',
#   ' Rosario Dawson',
#   ' Vanessa Ferlito',
#   300794,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (505,
#   'The Italian Job',
#   'F. Gary Gray ',
#   'None',
#   111,
#   2003,
#   7,
#   74,
#   'The Italian Job',
#   '  Michael Caine',
#   ' NoÃƒÂ«l Coward',
#   ' Benny Hill',
#   ' Raf Vallone',
#   48345,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'R'),
#  (511,
#   'Greyhound',
#   'Aaron Schneider ',
#   'None',
#   91,
#   2020,
#   7,
#   77,
#   'Greyhound',
#   '  Tom Hanks',
#   ' Elisabeth Shue',
#   ' Stephen Graham',
#   ' Matt Helm',
#   103302,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'R'),
#  (524,
#   'Chip n Dale: Rescue Rangers',
#   'Akiva Schaffer ',
#   'None',
#   97,
#   2022,
#   7,
#   58,
#   'Chip n Dale: Rescue Rangers',
#   '  Andy Samberg',
#   ' John Mulaney',
#   ' KiKi Layne',
#   ' Will Arnett',
#   43611,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   ' ',
#   'PG-13'),
#  (544,
#   'An Action Hero',
#   'Anirudh Iyer ',
#   'None',
#   130,
#   2022,
#   7,
#   72,
#   'An Action Hero',
#   '  Ayushmann Khurrana',
#   ' Jaideep Ahlawat',
#   ' Neeraj Madhav',
#   ' Gautam Joglekar',
#   29325,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'R'),
#  (553,
#   'Kabir Singh',
#   'Sandeep Reddy Vanga ',
#   'None',
#   173,
#   2019,
#   7,
#   64,
#   'Kabir Singh',
#   '  Shahid Kapoor',
#   ' Kiara Advani',
#   ' Nikita Dutta',
#   ' Soham Majumdar',
#   35819,
#   'Action',
#   ' Drama',
#   ' Romance',
#   ' ',
#   'Not Rated'),
#  (555,
#   'The Legend',
#   ' Jerry',
#   'Joseph D. Sami ',
#   161,
#   2022,
#   7,
#   69,
#   'The Legend',
#   '  Saravanan Arul',
#   ' Geethika',
#   ' Mayilsamy',
#   ' Nassar',
#   29203,
#   'Action',
#   ' Drama',
#   ' Romance',
#   ' ',
#   'TV-MA'),
#  (556,
#   'Vikrant Rona',
#   'Anup Bhandari ',
#   'None',
#   148,
#   2022,
#   7,
#   61,
#   'Vikrant Rona',
#   '  Sudeep',
#   ' Nirup Bhandari',
#   ' Neetha Ashok',
#   ' Jacqueline Fernandez',
#   27929,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (558,
#   'The Legend Is Born: Ip Man',
#   'Herman Yau ',
#   'None',
#   100,
#   2010,
#   7,
#   71,
#   'The Legend Is Born: Ip Man',
#   '  Yu-Hang To',
#   ' Yi Huang',
#   ' Biao Yuen',
#   ' Siu-Wong Fan',
#   32524,
#   'Action',
#   ' Biography',
#   ' Drama',
#   ' ',
#   'PG'),
#  (560,
#   'The Last Kingdom: Seven Kings Must Die',
#   'Edward Bazalgette ',
#   'None',
#   111,
#   2023,
#   6.9,
#   49,
#   'The Last Kingdom: Seven Kings Must Die',
#   '  Mark Rowley',
#   ' Pekka Strang',
#   ' Zoltan Andrasi',
#   ' Ingrid GarcÃƒÂ\xada Jonsson',
#   25871,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'PG-13'),
#  (584,
#   'Dragged Across Concrete',
#   'S. Craig Zahler ',
#   'None',
#   159,
#   2018,
#   6.9,
#   32,
#   'Dragged Across Concrete',
#   '  Mel Gibson',
#   ' Vince Vaughn',
#   ' Tory Kittles',
#   ' Michael Jai White',
#   50999,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (587,
#   'Outlaw King',
#   'David Mackenzie ',
#   'None',
#   121,
#   2018,
#   6.9,
#   61,
#   'Outlaw King',
#   '  Chris Pine',
#   ' Stephen Dillane',
#   ' Rebecca Robin',
#   ' Billy Howle',
#   76112,
#   'Action',
#   ' Biography',
#   ' Drama',
#   ' ',
#   'R'),
#  (600,
#   'The Night Comes for Us',
#   'Timo Tjahjanto ',
#   'None',
#   121,
#   2018,
#   6.9,
#   58,
#   'The Night Comes for Us',
#   '  Iko Uwais',
#   ' Joe Taslim',
#   ' Julie Estelle',
#   ' Hannah Al Rashid',
#   27689,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'R'),
#  (605,
#   'Get the Gringo',
#   'Adrian Grunberg ',
#   'None',
#   96,
#   2012,
#   6.9,
#   48,
#   'Get the Gringo',
#   '  Mel Gibson',
#   ' Kevin Balmore',
#   ' Daniel GimÃƒÂ©nez Cacho',
#   ' JesÃƒÂºs Ochoa',
#   109783,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   ' ',
#   'R'),
#  (611,
#   'New Police Story',
#   'Benny Chan ',
#   'None',
#   123,
#   2004,
#   6.9,
#   55,
#   'New Police Story',
#   '  Jackie Chan',
#   ' Nicholas Tse',
#   ' Charlie Yeung',
#   ' Daniel Wu',
#   28042,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (628,
#   'What Happened to Monday',
#   'Tommy Wirkola ',
#   'None',
#   123,
#   2017,
#   6.8,
#   66,
#   'What Happened to Monday',
#   '  Noomi Rapace',
#   ' Glenn Close',
#   ' Willem Dafoe',
#   ' Marwan Kenzari',
#   128209,
#   'Action',
#   ' Crime',
#   ' Fantasy',
#   ' ',
#   'R'),
#  (630,
#   'Boss Level',
#   'Joe Carnahan ',
#   'None',
#   100,
#   2020,
#   6.8,
#   40,
#   'Boss Level',
#   '  Frank Grillo',
#   ' Mel Gibson',
#   ' Naomi Watts',
#   ' Michelle Yeoh',
#   72803,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG-13'),
#  (632,
#   'Kisi Ka Bhai Kisi Ki Jaan',
#   'Farhad Samji ',
#   'None',
#   145,
#   2023,
#   6.8,
#   58,
#   'Kisi Ka Bhai Kisi Ki Jaan',
#   '  Salman Khan',
#   ' Pooja Hegde',
#   ' Venkatesh Daggubati',
#   ' Aamir Naik',
#   36114,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (635,
#   'News of the World',
#   'Paul Greengrass ',
#   'None',
#   118,
#   2020,
#   6.8,
#   55,
#   'News of the World',
#   '  Tom Hanks',
#   ' Helena Zengel',
#   ' Tom Astor',
#   ' Travis Johnson',
#   91215,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (638,
#   'The Outpost',
#   'Rod Lurie ',
#   'None',
#   123,
#   2019,
#   6.8,
#   43,
#   'The Outpost',
#   '  Scott Eastwood',
#   ' Caleb Landry Jones',
#   ' Orlando Bloom',
#   ' Jack Kesy',
#   37100,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'PG-13'),
#  (656,
#   'Dog Soldiers',
#   'Neil Marshall ',
#   'None',
#   105,
#   2002,
#   6.8,
#   70,
#   'Dog Soldiers',
#   '  Sean Pertwee',
#   ' Kevin McKidd',
#   ' Emma Cleasby',
#   ' Liam Cunningham',
#   62861,
#   'Action',
#   ' Horror',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (657,
#   'Three Steps Above Heaven',
#   ' Fernando GonzÃ¡lez Molina',
#   'None',
#   118,
#   2010,
#   6.8,
#   61,
#   'Three Steps Above Heaven',
#   '  Mario Casas',
#   ' MarÃƒÂ\xada Valverde',
#   ' ÃƒÂlvaro Cervantes',
#   ' Marina Salas',
#   27317,
#   'Action',
#   ' Drama',
#   ' Romance',
#   ' ',
#   'R'),
#  (665,
#   'Who Am I?',
#   ' Benny Chan',
#   'Jackie Chan ',
#   108,
#   1998,
#   6.8,
#   64,
#   'Who Am I?',
#   '  Jackie Chan',
#   ' Michelle Ferre',
#   ' Mirai Yamamoto',
#   ' Ron Smerczak',
#   41473,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG-13'),
#  (666,
#   'Dead Snow 2: Red vs. Dead',
#   'Tommy Wirkola ',
#   'None',
#   100,
#   2014,
#   6.8,
#   43,
#   'Dead Snow 2: Red vs. Dead',
#   '  Geir Vegar Hoel',
#   ' ÃƒËœrjan Gamst',
#   ' Martin Starr',
#   ' Jocelyn DeBoer',
#   25766,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   ' ',
#   'PG-13'),
#  (668,
#   'Extraction',
#   'Sam Hargrave ',
#   'None',
#   116,
#   2020,
#   6.7,
#   50,
#   'Extraction',
#   '  Chris Hemsworth',
#   ' Bryon Lerum',
#   ' Ryder Lerum',
#   ' Rudhraksh Jaiswal',
#   214533,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (672,
#   'Violent Night',
#   'Tommy Wirkola ',
#   'None',
#   112,
#   2022,
#   6.7,
#   53,
#   'Violent Night',
#   '  David Harbour',
#   ' John Leguizamo',
#   ' Beverly DAngelo',
#   ' Alex Hassell',
#   71285,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (677,
#   'The Adam Project',
#   'Shawn Levy ',
#   'None',
#   106,
#   2022,
#   6.7,
#   42,
#   'The Adam Project',
#   '  Ryan Reynolds',
#   ' Walker Scobell',
#   ' Mark Ruffalo',
#   ' Jennifer Garner',
#   213852,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'R'),
#  (691,
#   'Enola Holmes 2',
#   'Harry Bradbeer ',
#   'None',
#   129,
#   2022,
#   6.7,
#   56,
#   'Enola Holmes 2',
#   '  Millie Bobby Brown',
#   ' Henry Cavill',
#   ' David Thewlis',
#   ' Louis Partridge',
#   86799,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'PG'),
#  (710,
#   'Jungle (I)',
#   'Greg McLean ',
#   'None',
#   115,
#   2017,
#   6.7,
#   58,
#   'Jungle (I)',
#   '  Daniel Radcliffe',
#   ' Thomas Kretschmann',
#   ' Alex Russell',
#   ' Joel Jackson',
#   59813,
#   'Action',
#   ' Adventure',
#   ' Biography',
#   ' ',
#   'PG'),
#  (724,
#   'Harriet (I)',
#   'Kasi Lemmons ',
#   'None',
#   125,
#   2019,
#   6.7,
#   49,
#   'Harriet (I)',
#   '  Cynthia Erivo',
#   ' Janelle MonÃƒÂ¡e',
#   ' Leslie Odom Jr.',
#   ' Joe Alwyn',
#   28833,
#   'Action',
#   ' Biography',
#   ' Drama',
#   ' ',
#   'R'),
#  (736,
#   'Blood and Bone',
#   'Ben Ramsey ',
#   'None',
#   93,
#   2009,
#   6.7,
#   45,
#   'Blood and Bone',
#   '  Michael Jai White',
#   ' Julian Sands',
#   ' Eamonn Walker',
#   ' Dante Basco',
#   34664,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'Not Rated'),
#  (743,
#   'Antim: The Final Truth',
#   'Mahesh Manjrekar ',
#   'None',
#   138,
#   2021,
#   6.7,
#   59,
#   'Antim: The Final Truth',
#   '  Salman Khan',
#   ' Aayush Sharma',
#   ' Mahima Makwana',
#   ' Mahesh Manjrekar',
#   41639,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG'),
#  (756,
#   'The Old Guard',
#   'Gina Prince-Bythewood ',
#   'None',
#   125,
#   2020,
#   6.6,
#   55,
#   'The Old Guard',
#   '  Charlize Theron',
#   ' KiKi Layne',
#   ' Matthias Schoenaerts',
#   ' Marwan Kenzari',
#   172804,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (759,
#   'Enola Holmes',
#   'Harry Bradbeer ',
#   'None',
#   123,
#   2020,
#   6.6,
#   48,
#   'Enola Holmes',
#   '  Millie Bobby Brown',
#   ' Henry Cavill',
#   ' Sam Claflin',
#   ' Helena Bonham Carter',
#   203986,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (767,
#   'The Harder They Fall',
#   'Jeymes Samuel ',
#   'None',
#   139,
#   2021,
#   6.6,
#   61,
#   'The Harder They Fall',
#   '  Jonathan Majors',
#   ' Zazie Beetz',
#   ' RJ Cyler',
#   ' Edi Gathegi',
#   66974,
#   'Action',
#   ' Drama',
#   ' Western',
#   ' ',
#   'PG-13'),
#  (784,
#   'The Aeronauts',
#   'Tom Harper ',
#   'None',
#   100,
#   2019,
#   6.6,
#   44,
#   'The Aeronauts',
#   '  Felicity Jones',
#   ' Eddie Redmayne',
#   ' Himesh Patel',
#   ' Vincent Perez',
#   35343,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  (796,
#   'The Informer',
#   'Andrea Di Stefano ',
#   'None',
#   113,
#   2019,
#   6.6,
#   66,
#   'The Informer',
#   '  Joel Kinnaman',
#   ' Rosamund Pike',
#   ' Common',
#   ' Mateusz Kosciukiewicz',
#   39635,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG'),
#  (800,
#   'The Girl with All the Gifts',
#   'Colm McCarthy ',
#   'None',
#   111,
#   2016,
#   6.6,
#   64,
#   'The Girl with All the Gifts',
#   '  Sennia Nanua',
#   ' Fisayo Akinade',
#   ' Dominique Tipper',
#   ' Paddy Considine',
#   62209,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'Approved'),
#  (829,
#   '22 Bullets',
#   'Richard Berry ',
#   'None',
#   117,
#   2010,
#   6.6,
#   65,
#   '22 Bullets',
#   '  Jean Reno',
#   ' Kad Merad',
#   ' Jean-Pierre Darroussin',
#   ' Marina FoÃƒÂ¯s',
#   35637,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (831,
#   'Wanted (I)',
#   'Prabhu Deva ',
#   'None',
#   147,
#   2009,
#   6.6,
#   45,
#   'Wanted (I)',
#   '  Salman Khan',
#   ' Ayesha Takia',
#   ' Prakash Raj',
#   ' Vinod Khanna',
#   25075,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'PG'),
#  (833,
#   'Plane',
#   ' Jean-FranÃ§ois Richet',
#   'None',
#   107,
#   2023,
#   6.5,
#   50,
#   'Plane',
#   '  Gerard Butler',
#   ' Mike Colter',
#   ' Tony Goldwyn',
#   ' Yoson An',
#   52965,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   ' ',
#   'R'),
#  (835,
#   'The Gray Man',
#   ' Anthony Russo',
#   'Joe Russo ',
#   122,
#   2022,
#   6.5,
#   56,
#   'The Gray Man',
#   '  Ryan Gosling',
#   ' Chris Evans',
#   ' Ana de Armas',
#   ' Billy Bob Thornton',
#   217192,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (839,
#   'The Tomorrow War',
#   'Chris McKay ',
#   'None',
#   138,
#   2021,
#   6.5,
#   40,
#   'The Tomorrow War',
#   '  Chris Pratt',
#   ' Yvonne Strahovski',
#   ' J.K. Simmons',
#   ' Betty Gilpin',
#   214288,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  (855,
#   'Flash Gordon',
#   'Mike Hodges ',
#   'None',
#   111,
#   1980,
#   6.5,
#   57,
#   'Flash Gordon',
#   '  Sam J. Jones',
#   ' Melody Anderson',
#   ' Max von Sydow',
#   ' Topol',
#   58967,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   ' ',
#   'PG'),
#  (888,
#   'Batman: The Movie',
#   'Leslie H. Martinson ',
#   'None',
#   105,
#   1966,
#   6.5,
#   59,
#   'Batman: The Movie',
#   '  Adam West',
#   ' Burt Ward',
#   ' Lee Meriwether',
#   ' Cesar Romero',
#   34516,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG-13'),
#  (896,
#   'Space Sweepers',
#   'Sung-hee Jo ',
#   'None',
#   136,
#   2021,
#   6.5,
#   52,
#   'Space Sweepers',
#   '  Song Joong-ki',
#   ' Kim Tae-ri',
#   ' Jin Seon-kyu',
#   ' Hae-Jin Yoo',
#   27092,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (902,
#   'War',
#   'Siddharth Anand ',
#   'None',
#   154,
#   2019,
#   6.5,
#   40,
#   'War',
#   '  Hrithik Roshan',
#   ' Tiger Shroff',
#   ' Vaani Kapoor',
#   ' Ashutosh Rana',
#   29425,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   ' ',
#   'Not Rated'),
#  (916,
#   'Triple Frontier',
#   'J.C. Chandor ',
#   'None',
#   125,
#   2019,
#   6.4,
#   59,
#   'Triple Frontier',
#   '  Ben Affleck',
#   ' Oscar Isaac',
#   ' Charlie Hunnam',
#   ' Garrett Hedlund',
#   136009,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'R'),
#  (917,
#   'Greenland',
#   'Ric Roman Waugh ',
#   'None',
#   119,
#   2020,
#   6.4,
#   34,
#   'Greenland',
#   '  Gerard Butler',
#   ' Morena Baccarin',
#   ' Roger Dale Floyd',
#   ' Scott Glenn',
#   123655,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (925,
#   'Army of Thieves',
#   'Matthias SchweighÃ¶fer ',
#   'None',
#   127,
#   2021,
#   6.4,
#   46,
#   'Army of Thieves',
#   '  Matthias SchweighÃƒÂ¶fer',
#   ' Nathalie Emmanuel',
#   ' Ruby O. Fee',
#   ' Stuart Martin',
#   82169,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (940,
#   'The Vault',
#   ' Jaume BalaguerÃ³',
#   'None',
#   118,
#   2021,
#   6.4,
#   52,
#   'The Vault',
#   '  Freddie Highmore',
#   ' Astrid BergÃƒÂ¨s-Frisbey',
#   ' Sam Riley',
#   ' Liam Cunningham',
#   28033,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (952,
#   'Chaos (II)',
#   'Tony Giglio ',
#   'None',
#   106,
#   2005,
#   6.4,
#   57,
#   'Chaos (II)',
#   '  Jason Statham',
#   ' Ryan Phillippe',
#   ' Wesley Snipes',
#   ' Henry Czerny',
#   56176,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (970,
#   'Blood Father',
#   'Jean-FranÃ§ois Richet ',
#   'None',
#   88,
#   2016,
#   6.4,
#   63,
#   'Blood Father',
#   '  Mel Gibson',
#   ' Erin Moriarty',
#   ' Diego Luna',
#   ' Michael Parks',
#   65965,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (986,
#   'Resident Evil: Degeneration',
#   'Makoto Kamiya ',
#   'None',
#   98,
#   2008,
#   6.4,
#   40,
#   'Resident Evil: Degeneration',
#   '  Paul Mercier',
#   ' Alyson Court',
#   ' Laura Bailey',
#   ' Roger Craig Smith',
#   32167,
#   'Animation',
#   ' Action',
#   ' Horror',
#   ' ',
#   'PG-13'),
#  (988,
#   'Redirected',
#   'Emilis Velyvis ',
#   'None',
#   99,
#   2014,
#   6.4,
#   58,
#   'Redirected',
#   '  Vinnie Jones',
#   ' Scot Williams',
#   ' Gil Darnell',
#   ' Oliver Jackson',
#   34322,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (989,
#   'Fast X',
#   'Louis Leterrier ',
#   'None',
#   141,
#   2023,
#   6.3,
#   42,
#   'Fast X',
#   '  Vin Diesel',
#   ' Michelle Rodriguez',
#   ' Jason Statham',
#   ' Jordana Brewster',
#   30775,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (990,
#   'Operation Fortune: Ruse de Guerre',
#   'Guy Ritchie ',
#   'None',
#   114,
#   2023,
#   6.3,
#   44,
#   'Operation Fortune: Ruse de Guerre',
#   '  Jason Statham',
#   ' Aubrey Plaza',
#   ' Cary Elwes',
#   ' Hugh Grant',
#   55109,
#   'Action',
#   ' Comedy',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (998,
#   'Red Notice',
#   'Rawson Marshall Thurber ',
#   'None',
#   118,
#   2021,
#   6.3,
#   43,
#   'Red Notice',
#   '  Dwayne Johnson',
#   ' Ryan Reynolds',
#   ' Gal Gadot',
#   ' Ritu Arya',
#   290777,
#   'Action',
#   ' Comedy',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (1005,
#   'Polar (I)',
#   ' Jonas Ã…kerlund ',
#   'None',
#   118,
#   2019,
#   6.3,
#   69,
#   'Polar (I)',
#   '  Mads Mikkelsen',
#   ' Vanessa Hudgens',
#   ' Katheryn Winnick',
#   ' Fei Ren',
#   94190,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'R'),
#  (1019,
#   'Run Hide Fight',
#   'Kyle Rankin ',
#   'None',
#   109,
#   2020,
#   6.3,
#   41,
#   'Run Hide Fight',
#   '  Isabel May',
#   ' Radha Mitchell',
#   ' Thomas Jane',
#   ' Eli Brown',
#   25327,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (1021,
#   'My Spy',
#   'Peter Segal ',
#   'None',
#   99,
#   2020,
#   6.3,
#   39,
#   'My Spy',
#   '  Dave Bautista',
#   ' Chloe Coleman',
#   ' Parisa Fitz-Henley',
#   ' Kristen Schaal',
#   32416,
#   'Action',
#   ' Comedy',
#   'None',
#   ' ',
#   'TV-MA'),
#  (1026,
#   'Bright (I)',
#   'David Ayer ',
#   'None',
#   117,
#   2017,
#   6.3,
#   30,
#   'Bright (I)',
#   '  Will Smith',
#   ' Joel Edgerton',
#   ' Noomi Rapace',
#   ' Edgar RamÃƒÂ\xadrez',
#   194878,
#   'Action',
#   ' Fantasy',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (1028,
#   'Spectral',
#   'Nic Mathieu ',
#   'None',
#   107,
#   2016,
#   6.3,
#   35,
#   'Spectral',
#   '  James Badge Dale',
#   ' Emily Mortimer',
#   ' Bruce Greenwood',
#   ' Max Martini',
#   61689,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   ' ',
#   'R'),
#  (1032,
#   'Sand Castle',
#   'Fernando Coimbra ',
#   'None',
#   113,
#   2017,
#   6.3,
#   47,
#   'Sand Castle',
#   '  Nicholas Hoult',
#   ' Logan Marshall-Green',
#   ' Henry Cavill',
#   ' Glen Powell',
#   25262,
#   'Action',
#   ' Drama',
#   ' War',
#   ' ',
#   'R'),
#  (1037,
#   'Unlocked (I)',
#   'Michael Apted ',
#   'None',
#   98,
#   2017,
#   6.3,
#   45,
#   'Unlocked (I)',
#   '  Noomi Rapace',
#   ' Orlando Bloom',
#   ' Toni Collette',
#   ' John Malkovich',
#   37024,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG'),
#  (1038,
#   'Guns Akimbo',
#   'Jason Howden ',
#   'None',
#   98,
#   2019,
#   6.3,
#   47,
#   'Guns Akimbo',
#   '  Daniel Radcliffe',
#   ' Samara Weaving',
#   ' Ned Dennehy',
#   ' Natasha Liu Bordizzo',
#   64719,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'TV-MA'),
#  (1043,
#   '#Alive',
#   'Il Cho ',
#   'None',
#   98,
#   2020,
#   6.3,
#   51,
#   '#Alive',
#   '  Yoo Ah-in',
#   ' Park Shin-Hye',
#   ' Jeon Bae-soo',
#   ' Hyun-Wook Lee',
#   43435,
#   'Action',
#   ' Drama',
#   ' Horror',
#   ' ',
#   'PG-13'),
#  (1059,
#   'Assault on Precinct 13',
#   'Jean-FranÃ§ois RichetÂ\xa0',
#   'None',
#   109,
#   2005,
#   6.3,
#   36,
#   'Assault on Precinct 13',
#   '  Austin Stoker',
#   ' Darwin Joston',
#   ' Laurie Zimmer',
#   ' Martin West',
#   52831,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'Not Rated'),
#  (1063,
#   'ARQ',
#   'Tony Elliott ',
#   'None',
#   88,
#   2016,
#   6.3,
#   46,
#   'ARQ',
#   '  Robbie Amell',
#   ' Rachael Taylor',
#   ' Shaun Benson',
#   ' Gray Powell',
#   40483,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (1064,
#   '7500',
#   'Patrick Vollrath ',
#   'None',
#   93,
#   2019,
#   6.3,
#   63,
#   '7500',
#   '  Joseph Gordon-Levitt',
#   ' Omid Memar',
#   ' Aylin Tezel',
#   ' Carlo Kitzlinger',
#   30486,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (1066,
#   'Toofaan',
#   'Rakeysh Omprakash Mehra ',
#   'None',
#   163,
#   2021,
#   6.3,
#   35,
#   'Toofaan',
#   '  Farhan Akhtar',
#   ' Mrunal Thakur',
#   ' Paresh Rawal',
#   ' Mohan Agashe',
#   51775,
#   'Action',
#   ' Drama',
#   ' Sport',
#   ' ',
#   'PG-13'),
#  (1067,
#   'Ant-Man and the Wasp: Quantumania',
#   'Peyton Reed ',
#   'None',
#   124,
#   2023,
#   6.2,
#   48,
#   'Ant-Man and the Wasp: Quantumania',
#   '  Paul Rudd',
#   ' Evangeline Lilly',
#   ' Michael Douglas',
#   ' Michelle Pfeiffer',
#   159859,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'R'),
#  (1085,
#   'Kate (I)',
#   'Cedric Nicolas-Troyan ',
#   'None',
#   106,
#   2021,
#   6.2,
#   50,
#   'Kate (I)',
#   '  Mary Elizabeth Winstead',
#   ' Woody Harrelson',
#   ' Miku Patricia Martineau',
#   ' Tadanobu Asano',
#   65903,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (1095,
#   'In the Shadow of the Moon',
#   'Jim Mickle ',
#   'None',
#   115,
#   2019,
#   6.2,
#   58,
#   'In the Shadow of the Moon',
#   '  Boyd Holbrook',
#   ' Cleopatra Coleman',
#   ' Bokeem Woodbine',
#   ' Michael C. Hall',
#   56429,
#   'Action',
#   ' Crime',
#   ' Mystery',
#   ' ',
#   'Not Rated'),
#  (1100,
#   'Time Trap',
#   ' Mark Dennis',
#   'Ben Foster ',
#   87,
#   2017,
#   6.2,
#   58,
#   'Time Trap',
#   '  Reiley McClendon',
#   ' Cassidy Gifford',
#   ' Brianne Howey',
#   ' Olivia Draguicevich',
#   39858,
#   'Action',
#   ' Adventure',
#   ' Mystery',
#   ' ',
#   'R'),
#  (1101,
#   'Spenser Confidential',
#   'Peter Berg ',
#   'None',
#   111,
#   2020,
#   6.2,
#   49,
#   'Spenser Confidential',
#   '  Mark Wahlberg',
#   ' Winston Duke',
#   ' Alan Arkin',
#   ' Iliza Shlesinger',
#   92640,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'R'),
#  (1115,
#   'Copshop',
#   'Joe Carnahan ',
#   'None',
#   107,
#   2021,
#   6.2,
#   44,
#   'Copshop',
#   '  Gerard Butler',
#   ' Frank Grillo',
#   ' Alexis Louder',
#   ' Toby Huss',
#   34534,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (1116,
#   'War',
#   'Philip G. Atwell ',
#   'None',
#   103,
#   2007,
#   6.2,
#   60,
#   'War',
#   '  Hrithik Roshan',
#   ' Tiger Shroff',
#   ' Vaani Kapoor',
#   ' Ashutosh Rana',
#   29425,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   ' ',
#   'Not Rated'),
#  (1118,
#   'The Silencing',
#   'Robin Pront ',
#   'None',
#   93,
#   2020,
#   6.2,
#   52,
#   'The Silencing',
#   '  Nikolaj Coster-Waldau',
#   ' Caleb Ellsworth-Clark',
#   ' Josh Cruddas',
#   ' Annabelle Wallis',
#   28283,
#   'Action',
#   ' Crime',
#   ' Mystery',
#   ' ',
#   'PG-13'),
#  (1133,
#   'The Toxic Avenger',
#   ' Michael Herz',
#   'Lloyd Kaufman ',
#   82,
#   1984,
#   6.2,
#   42,
#   'The Toxic Avenger',
#   '  Andree Maranda',
#   ' Mitch Cohen',
#   ' Jennifer Babtist',
#   ' Cindy Manion',
#   30049,
#   'Action',
#   ' Comedy',
#   ' Horror',
#   ' ',
#   'R'),
#  (1134,
#   'The Outsider (I)',
#   'Martin Zandvliet ',
#   'None',
#   120,
#   2018,
#   6.2,
#   52,
#   'The Outsider (I)',
#   '  Jared Leto',
#   ' Tadanobu Asano',
#   ' Kippei ShÃƒÂ®na',
#   ' Shioli Kutsuna',
#   27529,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (1151,
#   'Last Knights',
#   'Kazuaki Kiriya ',
#   'None',
#   115,
#   2015,
#   6.2,
#   54,
#   'Last Knights',
#   '  Clive Owen',
#   ' Morgan Freeman',
#   ' Aksel Hennie',
#   ' Payman Maadi',
#   44281,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'R'),
#  (1153,
#   'A Lonely Place to Die',
#   'Julian Gilbey ',
#   'None',
#   99,
#   2011,
#   6.2,
#   31,
#   'A Lonely Place to Die',
#   '  Alec Newman',
#   ' Ed Speleers',
#   ' Melissa George',
#   ' Kate Magowan',
#   30026,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   ' ',
#   'Not Rated'),
#  (1157,
#   'The Legend of Tomiris',
#   'Akan Satayev ',
#   'None',
#   156,
#   2019,
#   6.2,
#   23,
#   'The Legend of Tomiris',
#   '  Ghassan Massoud',
#   ' Aizhan Lighg',
#   ' Eduardo Minett',
#   ' Yerden Telemissov',
#   42622,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'PG-13'),
#  (1166,
#   '6 Underground',
#   'Michael Bay ',
#   'None',
#   128,
#   2019,
#   6.1,
#   52,
#   '6 Underground',
#   '  Ryan Reynolds',
#   ' MÃƒÂ©lanie Laurent',
#   ' Manuel Garcia-Rulfo',
#   ' Ben Hardy',
#   185400,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (1167,
#   'Lou (I)',
#   'Anna Foerster ',
#   'None',
#   107,
#   2022,
#   6.1,
#   44,
#   'Lou (I)',
#   '  Allison Janney',
#   ' Jurnee Smollett',
#   ' Logan Marshall-Green',
#   ' Ridley Asha Bateman',
#   29667,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'R'),
#  (1168,
#   'Day Shift',
#   'J.J. Perry ',
#   'None',
#   113,
#   2022,
#   6.1,
#   38,
#   'Day Shift',
#   '  Jamie Foxx',
#   ' Dave Franco',
#   ' Natasha Liu Bordizzo',
#   ' Meagan Good',
#   83130,
#   'Action',
#   ' Comedy',
#   ' Fantasy',
#   ' ',
#   'TV-MA'),
#  (1172,
#   'Hitmans Wifes Bodyguard',
#   'Patrick Hughes ',
#   'None',
#   100,
#   2021,
#   6.1,
#   49,
#   'Hitmans Wifes Bodyguard',
#   '  Ryan Reynolds',
#   ' Samuel L. Jackson',
#   ' Salma Hayek',
#   ' Antonio Banderas',
#   99570,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'PG-13'),
#  (1173,
#   'Blood Red Sky',
#   'Peter Thorwarth ',
#   'None',
#   121,
#   2021,
#   6.1,
#   53,
#   'Blood Red Sky',
#   '  Peri Baumeister',
#   ' Carl Anton Koch',
#   ' Alexander Scheer',
#   ' Kais Setti',
#   51502,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (1180,
#   'Code 8',
#   'Jeff Chan ',
#   'None',
#   98,
#   2019,
#   6.1,
#   42,
#   'Code 8',
#   '  Kari Matchett',
#   ' Robbie Amell',
#   ' Penny Eizenga',
#   ' Lawrence Bayne',
#   41936,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (1196,
#   'Blitz',
#   'Elliott Lester ',
#   'None',
#   97,
#   2011,
#   6.1,
#   34,
#   'Blitz',
#   '  Jason Statham',
#   ' Paddy Considine',
#   ' Aidan Gillen',
#   ' Zawe Ashton',
#   88886,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'R'),
#  (1208,
#   'The Promise (II)',
#   'Terry George ',
#   'None',
#   133,
#   2016,
#   6.1,
#   32,
#   'The Promise (II)',
#   '  Oscar Isaac',
#   ' Charlotte Le Bon',
#   ' Christian Bale',
#   ' Daniel GimÃƒÂ©nez Cacho',
#   177222,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  (1217,
#   'Heist (III)',
#   'Scott Mann ',
#   'None',
#   93,
#   2015,
#   6.1,
#   37,
#   'Heist (III)',
#   '  Robert De Niro',
#   ' Jeffrey Dean Morgan',
#   ' Dave Bautista',
#   ' Kate Bosworth',
#   31542,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (1220,
#   'Solomon Kane',
#   'M.J. Bassett ',
#   'None',
#   104,
#   2009,
#   6.1,
#   49,
#   'Solomon Kane',
#   '  James Purefoy',
#   ' Max von Sydow',
#   ' Rachel Hurd-Wood',
#   ' Pete Postlethwaite',
#   74862,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   ' ',
#   'R'),
#  (1225,
#   'Big Stan',
#   'Rob Schneider ',
#   'None',
#   105,
#   2007,
#   6.1,
#   39,
#   'Big Stan',
#   '  Rob Schneider',
#   ' David Carradine',
#   ' Sally Kirkland',
#   ' Jennifer Morrison',
#   45872,
#   'Action',
#   ' Comedy',
#   'None',
#   ' ',
#   'PG'),
#  (1228,
#   'Ironclad',
#   'Jonathan English ',
#   'None',
#   121,
#   2011,
#   6.1,
#   34,
#   'Ironclad',
#   '  Paul Giamatti',
#   ' Jason Flemyng',
#   ' Brian Cox',
#   ' James Purefoy',
#   42871,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'R'),
#  (1231,
#   'Tomorrow When the War Began',
#   'Stuart Beattie ',
#   'None',
#   104,
#   2010,
#   6.1,
#   38,
#   'Tomorrow When the War Began',
#   '  Caitlin Stasey',
#   ' Rachel Hurd-Wood',
#   ' Lincoln Lewis',
#   ' Deniz Akdeniz',
#   31565,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'R'),
#  (1238,
#   'The Lovebirds',
#   'Michael Showalter ',
#   'None',
#   86,
#   2020,
#   6.1,
#   43,
#   'The Lovebirds',
#   '  Issa Rae',
#   ' Kumail Nanjiani',
#   ' Paul Sparks',
#   ' Anna Camp',
#   26913,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'UA'),
#  (1242,
#   'Thunivu',
#   'H. Vinoth ',
#   'None',
#   145,
#   2023,
#   6.1,
#   42,
#   'Thunivu',
#   '  Ajith Kumar',
#   ' Manju Warrier',
#   ' Samuthirakani',
#   ' John Kokken',
#   27542,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'R'),
#  (1243,
#   'Sooryavanshi',
#   'Rohit Shetty ',
#   'None',
#   145,
#   2021,
#   6.1,
#   35,
#   'Sooryavanshi',
#   '  Akshay Kumar',
#   ' Katrina Kaif',
#   ' Ajay Devgn',
#   ' Ranveer Singh',
#   77917,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'R'),
#  (1245,
#   'Shazam! Fury of the Gods',
#   'David F. Sandberg ',
#   'None',
#   130,
#   2023,
#   6,
#   40,
#   'Shazam! Fury of the Gods',
#   '  Zachary Levi',
#   ' Asher Angel',
#   ' Jack Dylan Grazer',
#   ' Rachel Zegler',
#   76524,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG-13'),
#  (1249,
#   'Murder Mystery',
#   'Kyle Newacheck ',
#   'None',
#   97,
#   2019,
#   6,
#   48,
#   'Murder Mystery',
#   '  Adam Sandler',
#   ' Jennifer Aniston',
#   ' Luke Evans',
#   ' Terence Stamp',
#   155453,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'R'),
#  (1256,
#   'Gunpowder Milkshake',
#   'Navot Papushado ',
#   'None',
#   114,
#   2021,
#   6,
#   49,
#   'Gunpowder Milkshake',
#   '  Karen Gillan',
#   ' Lena Headey',
#   ' Carla Gugino',
#   ' Michelle Yeoh',
#   47701,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'R'),
#  (1260,
#   'Those Who Wish Me Dead',
#   'Taylor Sheridan ',
#   'None',
#   100,
#   2021,
#   6,
#   37,
#   'Those Who Wish Me Dead',
#   '  Angelina Jolie',
#   ' Nicholas Hoult',
#   ' Finn Little',
#   ' Jon Bernthal',
#   65635,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (1268,
#   'Project Power',
#   ' Henry Joost',
#   ' Ariel Schulman ',
#   113,
#   2020,
#   6,
#   63,
#   'Project Power',
#   '  Jamie Foxx',
#   ' Joseph Gordon-Levitt',
#   ' Dominique Fishback',
#   ' Rodrigo Santoro',
#   92991,
#   'Action',
#   ' Crime',
#   ' Sci-Fi',
#   ' ',
#   'R'),
#  (1288,
#   'Erased',
#   ' Philipp StÃ¶lzl',
#   'None',
#   100,
#   2012,
#   6,
#   37,
#   'Erased',
#   '  Aaron Eckhart',
#   ' Nick Alachiotis',
#   ' Liana Liberato',
#   ' Olga Kurylenko',
#   31891,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (1296,
#   'Varisu',
#   'Vamshi Paidipally ',
#   'None',
#   169,
#   2023,
#   6,
#   54,
#   'Varisu',
#   '  Joseph Vijay',
#   ' Rashmika Mandanna',
#   ' Shaam',
#   ' Prabhu',
#   34319,
#   'Action',
#   ' Drama',
#   'None',
#   ' ',
#   'PG-13'),
#  (1298,
#   'Automata (I)',
#   'Gabe IbÃ¡Ã±ez ',
#   'None',
#   109,
#   2014,
#   6,
#   22,
#   'Automata (I)',
#   '  Antonio Banderas',
#   ' Birgitte Hjort SÃƒÂ¸rensen',
#   ' Dylan McDermott',
#   ' Melanie Griffith',
#   58014,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   ' ',
#   'R'),
#  (1302,
#   'The Code (I)',
#   'Mimi Leder ',
#   'None',
#   104,
#   2009,
#   6,
#   49,
#   'The Code (I)',
#   '  Ivan Petrushinov',
#   ' Victor Boichev',
#   ' Nickolay Hadjiminev',
#   ' Rade Serbedzija',
#   35297,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (1303,
#   'The Machine (I)',
#   'Caradog W. James ',
#   'None',
#   91,
#   2013,
#   6,
#   41,
#   'The Machine (I)',
#   '  Toby Stephens',
#   ' Caity Lotz',
#   ' Denis Lawson',
#   ' Sam Hazeldine',
#   31676,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   ' ',
#   'R'),
#  (1304,
#   'The Tournament',
#   'Scott Mann ',
#   'None',
#   95,
#   2009,
#   6,
#   48,
#   'The Tournament',
#   '  Ving Rhames',
#   ' Robert Carlyle',
#   ' Kelly Hu',
#   ' Ian Somerhalder',
#   35742,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (1316,
#   'Pathaan',
#   'Siddharth Anand ',
#   'None',
#   146,
#   2023,
#   5.9,
#   45,
#   'Pathaan',
#   '  Shah Rukh Khan',
#   ' Deepika Padukone',
#   ' John Abraham',
#   ' Dimple Kapadia',
#   139639,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (1329,
#   'Iron Sky',
#   'Timo Vuorensola ',
#   'None',
#   93,
#   2012,
#   5.9,
#   54,
#   'Iron Sky',
#   '  Julia Dietze',
#   ' Christopher Kirby',
#   ' GÃƒÂ¶tz Otto',
#   ' Udo Kier',
#   95370,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG'),
#  (1331,
#   'Braven',
#   'Lin Oeding ',
#   'None',
#   94,
#   2018,
#   5.9,
#   36,
#   'Braven',
#   '  Jason Momoa',
#   ' Garret Dillahunt',
#   ' Jill Wagner',
#   ' Stephen Lang',
#   40783,
#   'Action',
#   ' Thriller',
#   'None',
#   ' ',
#   'PG-13'),
#  (1333,
#   'The Black Hole',
#   'Gary Nelson ',
#   'None',
#   98,
#   1979,
#   5.9,
#   29,
#   'The Black Hole',
#   '  Maximilian Schell',
#   ' Anthony Perkins',
#   ' Robert Forster',
#   ' Joseph Bottoms',
#   26779,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   ' ',
#   'PG'),
#  (1353,
#   'Fatman',
#   ' Eshom Nelms',
#   ' Ian Nelms ',
#   100,
#   2020,
#   5.9,
#   28,
#   'Fatman',
#   '  Mel Gibson',
#   ' Walton Goggins',
#   ' Marianne Jean-Baptiste',
#   ' Chance Hurstfield',
#   27782,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'Not Rated'),
#  (1357,
#   'The Double (I)',
#   'Michael Brandt ',
#   'None',
#   98,
#   2011,
#   5.9,
#   39,
#   'The Double (I)',
#   '  Richard Gere',
#   ' Topher Grace',
#   ' Martin Sheen',
#   ' Tamer Hassan',
#   31014,
#   'Action',
#   ' Crime',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (1359,
#   'Ghosted (I)',
#   'Dexter Fletcher ',
#   'None',
#   116,
#   2023,
#   5.8,
#   41,
#   'Ghosted (I)',
#   '  Chris Evans',
#   ' Ana de Armas',
#   ' Adrien Brody',
#   ' Mike Moh',
#   40088,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'PG-13'),
#  (1360,
#   'The School for Good and Evil',
#   'Paul Feig ',
#   'None',
#   147,
#   2022,
#   5.8,
#   37,
#   'The School for Good and Evil',
#   '  Kit Young',
#   ' Sophia Anne Caruso',
#   ' Cate Blanchett',
#   ' Liam Woon',
#   31455,
#   'Action',
#   ' Comedy',
#   ' Drama',
#   ' ',
#   'R'),
#  (1369,
#   'The Man from Toronto',
#   'Patrick Hughes ',
#   'None',
#   110,
#   2022,
#   5.8,
#   46,
#   'The Man from Toronto',
#   '  Kevin Hart',
#   ' Woody Harrelson',
#   ' Jasmine Mathews',
#   ' Kaley Cuoco',
#   53624,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   ' ',
#   'TV-14'),
#  (1374,
#   'Troll',
#   'Roar Uthaug ',
#   'None',
#   101,
#   2022,
#   5.8,
#   55,
#   'Troll',
#   '  Ine Marie Wilmann',
#   ' Kim Falck',
#   ' Mads SjÃƒÂ¸gÃƒÂ¥rd Pettersen',
#   ' Gard B. Eidsvold',
#   44573,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (1381,
#   'Without Remorse (II)',
#   'Stefano Sollima ',
#   'None',
#   109,
#   2021,
#   5.8,
#   43,
#   'Without Remorse (II)',
#   '  Michael B. Jordan',
#   ' Jodie Turner-Smith',
#   ' Jamie Bell',
#   ' Guy Pearce',
#   61064,
#   'Action',
#   ' Thriller',
#   ' War',
#   ' ',
#   'TV-MA'),
#  (1386,
#   'Extinction',
#   'Ben Young ',
#   'None',
#   95,
#   2018,
#   5.8,
#   27,
#   'Extinction',
#   '  Michael PeÃƒÂ±a',
#   ' Lizzy Caplan',
#   ' Amelia Crouch',
#   ' Erica Tremblay',
#   55085,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   ' ',
#   'R'),
#  (1409,
#   'Samrat Prithviraj',
#   'Chandra Prakash Dwivedi ',
#   'None',
#   135,
#   2022,
#   5.8,
#   31,
#   'Samrat Prithviraj',
#   '  Akshay Kumar',
#   ' Sanjay Dutt',
#   ' Ashutosh Rana',
#   ' Sonu Sood',
#   53146,
#   'Action',
#   ' Drama',
#   ' History',
#   ' ',
#   'PG-13'),
#  (1411,
#   'Murder Mystery 2',
#   'Jeremy Garelick ',
#   'None',
#   90,
#   2023,
#   5.7,
#   21,
#   'Murder Mystery 2',
#   '  Adam Sandler',
#   ' Jennifer Aniston',
#   ' Mark Strong',
#   ' MÃƒÂ©lanie Laurent',
#   52181,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   ' ',
#   'R'),
#  (1412,
#   'The Matrix Resurrections (I)',
#   'Lana Wachowski ',
#   'None',
#   148,
#   2021,
#   5.7,
#   27,
#   'The Matrix Resurrections (I)',
#   '  Keanu Reeves',
#   ' Carrie-Anne Moss',
#   ' Yahya Abdul-Mateen II',
#   ' Jonathan Groff',
#   261074,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   ' ',
#   'R'),
#  (1415,
#   'Mulan',
#   'Niki Caro ',
#   'None',
#   115,
#   2020,
#   5.7,
#   45,
#   'Mulan',
#   '  Liu Yifei',
#   ' Donnie Yen',
#   ' Gong Li',
#   ' Jet Li',
#   152707,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   ' ',
#   'PG-13'),
#  (1416,
#   'Memory (I)',
#   'Martin Campbell ',
#   'None',
#   114,
#   2022,
#   5.7,
#   51,
#   'Memory (I)',
#   '  Liam Neeson',
#   ' Guy Pearce',
#   ' Taj Atwal',
#   ' Harold Torres',
#   30211,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   ' ',
#   'PG-13'),
#  (1421,
#   'Samaritan',
#   'Julius Avery ',
#   'None',
#   102,
#   2022,
#   5.7,
#   40,
#   'Samaritan',
#   '  Sylvester Stallone',
#   ' Javon Wanna Walton',
#   ' Pilou AsbÃƒÂ¦k',
#   ' Dascha Polanco',
#   50224,
#   'Action',
#   ' Drama',
#   ' Fantasy',
#   ' ',
#   'PG-13'),
#  (136,
#   'Star Wars: Episode VII - The Force Awakens',
#   'J.J. Abrams ',
#   'None',
#   138,
#   2015,
#   7.8,
#   87,
#   'Star Wars: Episode VII - The Force Awakens',
#   '  Daisy Ridley',
#   ' John Boyega',
#   ' Oscar Isaac',
#   ' Domhnall Gleeson',
#   947209,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   936.66,
#   'PG-13'),
#  (17,
#   'Avengers: Endgame',
#   'Anthony Russo',
#   'Joe Russo',
#   181,
#   2019,
#   8.4,
#   68,
#   'Avengers: Endgame',
#   '  Robert Downey Jr.',
#   ' Chris Evans',
#   ' Mark Ruffalo',
#   ' Chris Hemsworth',
#   1179423,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   858.37,
#   'PG-13'),
#  (37,
#   'Spider-Man: No Way Home',
#   'Jon Watts ',
#   'None',
#   148,
#   2021,
#   8.2,
#   89,
#   'Spider-Man: No Way Home',
#   '  Tom Holland',
#   ' Zendaya',
#   ' Benedict Cumberbatch',
#   ' Jacob Batalon',
#   796509,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   804.75,
#   'PG-13'),
#  (108,
#   'Avatar',
#   'James Cameron ',
#   'None',
#   162,
#   2009,
#   7.9,
#   82,
#   'Avatar',
#   '  Sam Worthington',
#   ' Zoe Saldana',
#   ' Sigourney Weaver',
#   ' Michelle Rodriguez',
#   1341931,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   760.51,
#   'PG-13'),
#  (25,
#   'Top Gun: Maverick',
#   'Joseph Kosinski ',
#   'None',
#   130,
#   2022,
#   8.3,
#   98,
#   'Top Gun: Maverick',
#   '  Tom Cruise',
#   ' Jennifer Connelly',
#   ' Miles Teller',
#   ' Val Kilmer',
#   588695,
#   'Action',
#   ' Drama',
#   'None',
#   718.73,
#   'PG-13'),
#  (330,
#   'Black Panther',
#   'Ryan Coogler ',
#   'None',
#   134,
#   2018,
#   7.3,
#   75,
#   'Black Panther',
#   '  Chadwick Boseman, Michael B. Jordan, Lupita Nyongo, Danai Gurira',
#   'None',
#   'None',
#   'None',
#   801782,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   700.06,
#   'R'),
#  (19,
#   'Avengers: Infinity War',
#   'Anthony Russo',
#   'Joe Russo',
#   149,
# ...
#   '  Benjamin Walker',
#   ' Rufus Sewell',
#   ' Dominic Cooper',
#   ' Anthony Mackie',
#   158490,
#   'Action',
#   ' Fantasy',
#   ' Horror',
#   37.52,
#   'PG'),
#  (356,
#   'Invictus',
#   'Clint Eastwood ',
#   'None',
#   134,
#   2009,
#   7.3,
#   83,
#   'Invictus',
#   '  Morgan Freeman',
#   ' Matt Damon',
#   ' Tony Kgoroge',
#   ' Patrick Mofokeng',
#   163463,
#   'Action',
#   ' Adventure',
#   ' Biography',
#   37.49,
#   'R'),
#  (996,
#   'The Kings Man',
#   'Matthew Vaughn ',
#   'None',
#   131,
#   2021,
#   6.3,
#   61,
#   'The Kings Man',
#   '  Ralph Fiennes',
#   ' Gemma Arterton',
#   ' Rhys Ifans',
#   ' Harris Dickinson',
#   157898,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   37.18,
#   'PG'),
#  (1224,
#   '30 Minutes or Less',
#   'Ruben Fleischer ',
#   'None',
#   83,
#   2011,
#   6.1,
#   49,
#   '30 Minutes or Less',
#   '  Jesse Eisenberg',
#   ' Danny McBride',
#   ' Nick Swardson',
#   ' Aziz Ansari',
#   104078,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   37.05,
#   'R'),
#  (1218,
#   'Sphere',
#   'Barry Levinson ',
#   'None',
#   134,
#   1998,
#   6.1,
#   34,
#   'Sphere',
#   '  Dustin Hoffman',
#   ' Sharon Stone',
#   ' Samuel L. Jackson',
#   ' Peter Coyote',
#   109192,
#   'Action',
#   ' Mystery',
#   ' Sci-Fi',
#   37.02,
#   'R'),
#  (826,
#   '16 Blocks',
#   'Richard Donner ',
#   'None',
#   102,
#   2006,
#   6.6,
#   46,
#   '16 Blocks',
#   '  Bruce Willis',
#   ' Yasiin Bey',
#   ' David Morse',
#   ' Jenna Stern',
#   132729,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   36.9,
#   'Not Rated'),
#  (1055,
#   'Risen',
#   'Kevin Reynolds ',
#   'None',
#   107,
#   2016,
#   6.3,
#   35,
#   'Risen',
#   '  Joseph Fiennes',
#   ' Tom Felton',
#   ' Peter Firth',
#   ' Cliff Curtis',
#   29547,
#   'Action',
#   ' Drama',
#   ' History',
#   36.87,
#   'R'),
#  (810,
#   'Kiss of the Dragon',
#   'Chris Nahon ',
#   'None',
#   98,
#   2001,
#   6.6,
#   64,
#   'Kiss of the Dragon',
#   '  Jet Li',
#   ' Bridget Fonda',
#   ' TchÃƒÂ©ky Karyo',
#   ' Ric Young',
#   65167,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   36.85,
#   'R'),
#  (971,
#   'Just Cause',
#   'Arne Glimcher ',
#   'None',
#   102,
#   1995,
#   6.4,
#   40,
#   'Just Cause',
#   '  Sean Connery',
#   ' Laurence Fishburne',
#   ' Kate Capshaw',
#   ' Blair Underwood',
#   28245,
#   'Action',
#   ' Crime',
#   ' Drama',
#   36.85,
#   'R'),
#  (737,
#   'The Brave One',
#   'Neil Jordan ',
#   'None',
#   122,
#   2007,
#   6.7,
#   39,
#   'The Brave One',
#   '  Jodie Foster',
#   ' Terrence Howard',
#   ' Naveen Andrews',
#   ' Nicky Katt',
#   62130,
#   'Action',
#   ' Crime',
#   ' Drama',
#   36.79,
#   'PG-13'),
#  (365,
#   'The Getaway',
#   'Sam Peckinpah ',
#   'None',
#   123,
#   1972,
#   7.3,
#   57,
#   'The Getaway',
#   '  Steve McQueen',
#   ' Ali MacGraw',
#   ' Ben Johnson',
#   ' Sally Struthers',
#   33918,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   36.73,
#   'Not Rated'),
#  (935,
#   'Colombiana',
#   'Olivier Megaton ',
#   'None',
#   108,
#   2011,
#   6.4,
#   43,
#   'Colombiana',
#   '  Zoe Saldana',
#   ' Michael Vartan',
#   ' Callum Blue',
#   ' Jordi MollÃƒÂ\xa0',
#   104073,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   36.67,
#   'R'),
#  (132,
#   'The Gentlemen',
#   'Guy Ritchie ',
#   'None',
#   113,
#   2019,
#   7.8,
#   61,
#   'The Gentlemen',
#   '  Matthew McConaughey',
#   ' Charlie Hunnam',
#   ' Michelle Dockery',
#   ' Jeremy Strong',
#   360399,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   36.47,
#   'R'),
#  (1255,
#   'Sucker Punch',
#   'Zack Snyder ',
#   'None',
#   110,
#   2011,
#   6,
#   34,
#   'Sucker Punch',
#   '  Emily Browning',
#   ' Vanessa Hudgens',
#   ' Abbie Cornish',
#   ' Jena Malone',
#   246578,
#   'Action',
#   ' Adventure',
#   ' Fantasy',
#   36.39,
#   'R'),
#  (1496,
#   'National Security',
#   'Dennis Dugan ',
#   'None',
#   88,
#   2003,
#   5.6,
#   18,
#   'National Security',
#   '  Martin Lawrence',
#   ' Steve Zahn',
#   ' Colm Feore',
#   ' Bill Duke',
#   52455,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   36.38,
#   'R'),
#  (1031,
#   'The Commuter (I)',
#   'Jaume Collet-Serra ',
#   'None',
#   104,
#   2018,
#   6.3,
#   45,
#   'The Commuter (I)',
#   '  Liam Neeson',
#   ' Vera Farmiga',
#   ' Patrick Wilson',
#   ' Jonathan Banks',
#   119590,
#   'Action',
#   ' Mystery',
#   ' Thriller',
#   36.34,
#   'PG'),
#  (921,
#   'Death Race',
#   'Paul W.S. Anderson ',
#   'None',
#   105,
#   2008,
#   6.4,
#   46,
#   'Death Race',
#   '  Jason Statham',
#   ' Joan Allen',
#   ' Tyrese Gibson',
#   ' Ian McShane',
#   213595,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   36.32,
#   'R'),
#  (1200,
#   'Universal Soldier',
#   'Roland Emmerich ',
#   'None',
#   102,
#   1992,
#   6.1,
#   37,
#   'Universal Soldier',
#   '  Jean-Claude Van Damme',
#   ' Dolph Lundgren',
#   ' Ally Walker',
#   ' Ed ORoss',
#   92881,
#   'Action',
#   ' Sci-Fi',
#   'None',
#   36.3,
#   'PG'),
#  (1171,
#   'The Sentinel',
#   'Clark Johnson ',
#   'None',
#   108,
#   2006,
#   6.1,
#   42,
#   'The Sentinel',
#   '  Michael Douglas',
#   ' Kiefer Sutherland',
#   ' Kim Basinger',
#   ' Eva Longoria',
#   50862,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   36.28,
#   'PG'),
#  (328,
#   'The Nice Guys',
#   'Shane Black ',
#   'None',
#   116,
#   2016,
#   7.3,
#   55,
#   'The Nice Guys',
#   '  Russell Crowe',
#   ' Ryan Gosling',
#   ' Angourie Rice',
#   ' Matt Bomer',
#   342428,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   36.26,
#   'PG-13'),
#  (1084,
#   'American Assassin',
#   'Michael Cuesta ',
#   'None',
#   111,
#   2017,
#   6.2,
#   64,
#   'American Assassin',
#   '  Dylan OBrien',
#   ' Michael Keaton',
#   ' Sanaa Lathan',
#   ' Taylor Kitsch',
#   85696,
#   'Action',
#   ' Thriller',
#   'None',
#   36.25,
#   'PG'),
#  (1068,
#   'Mad Max Beyond Thunderdome',
#   ' George Miller',
#   'George Ogilvie ',
#   107,
#   1985,
#   6.2,
#   65,
#   'Mad Max Beyond Thunderdome',
#   '  Mel Gibson',
#   ' Tina Turner',
#   ' Bruce Spence',
#   ' Adam Cockburn',
#   141421,
#   'Action',
#   ' Adventure',
#   ' Sci-Fi',
#   36.2,
#   'PG-13'),
#  (1186,
#   'Mile 22',
#   'Peter Berg ',
#   'None',
#   94,
#   2018,
#   6.1,
#   51,
#   'Mile 22',
#   '  Mark Wahlberg',
#   ' Lauren Cohan',
#   ' Iko Uwais',
#   ' John Malkovich',
#   83218,
#   'Action',
#   ' Thriller',
#   'None',
#   36.11,
#   'PG-13'),
#  (1504,
#   'The Pink Panther 2',
#   'Harald Zwart ',
#   'None',
#   92,
#   2009,
#   5.6,
#   33,
#   'The Pink Panther 2',
#   '  Steve Martin',
#   ' Jean Reno',
#   ' Emily Mortimer',
#   ' Andy Garcia',
#   46662,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   35.92,
#   'PG-13'),
#  (182,
#   'Dirty Harry',
#   'Don Siegel',
#   'Clint Eastwood ',
#   102,
#   1971,
#   7.7,
#   72,
#   'Dirty Harry',
#   '  Clint Eastwood',
#   ' Andrew Robinson',
#   ' Harry Guardino',
#   ' Reni Santoni',
#   161710,
#   'Action',
#   ' Crime',
#   ' Thriller',
#   35.9,
#   'PG-13'),
#  (820,
#   'Alpha (II)',
#   'Albert Hughes ',
#   'None',
#   96,
#   2018,
#   6.6,
#   59,
#   'Alpha (II)',
#   '  Kodi Smit-McPhee',
#   ' JÃƒÂ³hannes Haukur JÃƒÂ³hannesson',
#   ' Marcin Kowalczyk',
#   ' Jens HultÃƒÂ©n',
#   64374,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   35.85,
#   'PG-13'),
#  (634,
#   'The Island',
#   'Michael Bay ',
#   'None',
#   136,
#   2005,
#   6.8,
#   60,
#   'The Island',
#   '  Scarlett Johansson',
#   ' Ewan McGregor',
#   ' Djimon Hounsou',
#   ' Steve Buscemi',
#   321034,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   35.82,
#   'R'),
#  (758,
#   'Smokin Aces',
#   'Joe Carnahan ',
#   'None',
#   108,
#   2006,
#   6.6,
#   60,
#   'Smokin Aces',
#   '  Jeremy Piven',
#   ' Ryan Reynolds',
#   ' Ray Liotta',
#   ' Joseph Ruskin',
#   148632,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   35.66,
#   'R'),
#  (1018,
#   'The American',
#   'Anton Corbijn ',
#   'None',
#   105,
#   2010,
#   6.3,
#   56,
#   'The American',
#   '  George Clooney',
#   ' Paolo Bonacelli',
#   ' Violante Placido',
#   ' Irina BjÃƒÂ¶rklund',
#   99905,
#   'Action',
#   ' Crime',
#   ' Drama',
#   35.61,
#   'R'),
#  (112,
#   'Children of Men',
#   'Alfonso CuarÃ³n',
#   'None',
#   109,
#   2006,
#   7.9,
#   66,
#   'Children of Men',
#   '  Julianne Moore',
#   ' Clive Owen',
#   ' Chiwetel Ejiofor',
#   ' Michael Caine',
#   511555,
#   'Action',
#   ' Drama',
#   ' Sci-Fi',
#   35.55,
#   'R'),
#  (461,
#   'No Way Out',
#   'Roger Donaldson ',
#   'None',
#   114,
#   1987,
#   7.1,
#   60,
#   'No Way Out',
#   '  Kevin Costner',
#   ' Gene Hackman',
#   ' Sean Young',
#   ' Will Patton',
#   42804,
#   'Action',
#   ' Crime',
#   ' Drama',
#   35.51,
#   'R'),
#  (880,
#   'Peppermint',
#   'Pierre Morel ',
#   'None',
#   101,
#   2018,
#   6.5,
#   46,
#   'Peppermint',
#   '  Jennifer Garner',
#   ' John Gallagher Jr.',
#   ' John Ortiz',
#   ' Juan Pablo Raba',
#   67396,
#   'Action',
#   ' Thriller',
#   'None',
#   35.42,
#   'PG-13'),
#  (707,
#   'Live and Let Die',
#   'Guy Hamilton ',
#   'None',
#   121,
#   1973,
#   6.7,
#   43,
#   'Live and Let Die',
#   '  Roger Moore',
#   ' Yaphet Kotto',
#   ' Jane Seymour',
#   ' Clifton James',
#   111152,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   35.38,
#   'PG'),
#  (1457,
#   'Money Train',
#   'Joseph Ruben ',
#   'None',
#   110,
#   1995,
#   5.7,
#   34,
#   'Money Train',
#   '  Wesley Snipes',
#   ' Woody Harrelson',
#   ' Jennifer Lopez',
#   ' Robert Blake',
#   42088,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   35.32,
#   'R'),
#  (1334,
#   'Star Wars: The Clone Wars',
#   'Dave Filoni ',
#   'None',
#   98,
#   2008,
#   5.9,
#   44,
#   'Star Wars: The Clone Wars',
#   '  Matt Lanter',
#   ' Nika Futterman',
#   ' Tom Kane',
#   ' Ashley Eckstein',
#   69153,
#   'Animation',
#   ' Action',
#   ' Adventure',
#   35.16,
#   'PG-13'),
#  (548,
#   'Dragon: The Bruce Lee Story',
#   'Rob Cohen ',
#   'None',
#   120,
#   1993,
#   7,
#   29,
#   'Dragon: The Bruce Lee Story',
#   '  Jason Scott Lee',
#   ' Lauren Holly',
#   ' Robert Wagner',
#   ' Michael Learned',
#   31972,
#   'Action',
#   ' Biography',
#   ' Drama',
#   35.11,
#   'Not Rated'),
#  (684,
#   'Commando',
#   'Mark L. Lester ',
#   'None',
#   90,
#   1985,
#   6.7,
#   60,
#   'Commando',
#   '  Arnold Schwarzenegger',
#   ' Rae Dawn Chong',
#   ' Dan Hedaya',
#   ' Vernon Wells',
#   167240,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   35.1,
#   'R'),
#  (1430,
#   'Pan',
#   'Joe Wright ',
#   'None',
#   111,
#   2015,
#   5.7,
#   21,
#   'Pan',
#   '  Levi Miller',
#   ' Hugh Jackman',
#   ' Garrett Hedlund',
#   ' Rooney Mara',
#   65873,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   35.09,
#   'PG-13'),
#  (134,
#   'Drive (I)',
#   'Nicolas Winding Refn ',
#   'None',
#   100,
#   2011,
#   7.8,
#   78,
#   'Drive (I)',
#   '  Ryan Gosling',
#   ' Carey Mulligan',
#   ' Bryan Cranston',
#   ' Albert Brooks',
#   664299,
#   'Action',
#   ' Drama',
#   'None',
#   35.06,
#   'PG-13'),
#  (663,
#   'Green Zone',
#   'Paul Greengrass ',
#   'None',
#   115,
#   2010,
#   6.8,
#   38,
#   'Green Zone',
#   '  Matt Damon',
#   ' Jason Isaacs',
#   ' Greg Kinnear',
#   ' Igal Naor',
#   139706,
#   'Action',
#   ' Drama',
#   ' Thriller',
#   35.05,
#   'R'),
#  (1500,
#   'The Skulls',
#   'Rob Cohen ',
#   'None',
#   106,
#   2000,
#   5.6,
#   26,
#   'The Skulls',
#   '  Joshua Jackson',
#   ' Paul Walker',
#   ' Hill Harper',
#   ' Leslie Bibb',
#   32998,
#   'Action',
#   ' Crime',
#   ' Drama',
#   35.05,
#   'R'),
#  (1215,
#   'Red Heat',
#   'Walter Hill ',
#   'None',
#   104,
#   1988,
#   6.1,
#   34,
#   'Red Heat',
#   '  Arnold Schwarzenegger',
#   ' Jim Belushi',
#   ' Peter Boyle',
#   ' Ed ORoss',
#   73327,
#   'Action',
#   ' Comedy',
#   ' Crime',
#   34.99,
#   'R'),
#  (1406,
#   'Cradle 2 the Grave',
#   'Andrzej Bartkowiak ',
#   'None',
#   101,
#   2003,
#   5.8,
#   24,
#   'Cradle 2 the Grave',
#   '  Jet Li',
#   ' DMX',
#   ' Mark Dacascos',
#   ' Anthony Anderson',
#   45792,
#   'Action',
#   ' Crime',
#   ' Drama',
#   34.71,
#   'PG-13'),
#  (1483,
#   'Judge Dredd',
#   'Danny Cannon ',
#   'None',
#   96,
#   1995,
#   5.6,
#   31,
#   'Judge Dredd',
#   '  Sylvester Stallone',
#   ' Armand Assante',
#   ' Rob Schneider',
#   ' JÃƒÂ¼rgen Prochnow',
#   121234,
#   'Action',
#   ' Crime',
#   ' Sci-Fi',
#   34.69,
#   'PG-13'),
#  (762,
#   'Licence to Kill',
#   'John Glen ',
#   'None',
#   133,
#   1989,
#   6.6,
#   52,
#   'Licence to Kill',
#   '  Timothy Dalton',
#   ' Robert Davi',
#   ' Carey Lowell',
#   ' Talisa Soto',
#   108095,
#   'Action',
#   ' Adventure',
#   ' Thriller',
#   34.67,
#   'R'),
#  (897,
#   'Hostage',
#   'Florent-Emilio Siri ',
#   'None',
#   113,
#   2005,
#   6.5,
#   66,
#   'Hostage',
#   '  Bruce Willis',
#   ' Kevin Pollak',
#   ' Serena Scott Thomas',
#   ' Jimmy Bennett',
#   112161,
#   'Action',
#   ' Crime',
#   ' Drama',
#   34.64,
#   'Not Rated'),
#  (1337,
#   'The 6th Day',
#   'Roger Spottiswoode ',
#   'None',
#   123,
#   2000,
#   5.9,
#   36,
#   'The 6th Day',
#   '  Arnold Schwarzenegger',
#   ' Michael Rapaport',
#   ' Tony Goldwyn',
#   ' Michael Rooker',
#   125071,
#   'Action',
#   ' Mystery',
#   ' Sci-Fi',
#   34.6,
#   'R'),
#  (531,
#   'The Foreigner (I)',
#   'Martin Campbell ',
#   'None',
#   113,
#   2017,
#   7,
#   64,
#   'The Foreigner (I)',
#   '  Katie Leung',
#   ' Jackie Chan',
#   ' Rufus Jones',
#   ' Mark Tandy',
#   118385,
#   'Action',
#   ' Thriller',
#   'None',
#   34.39,
#   'PG'),
#  (1102,
#   'Inferno (I)',
#   'Ron Howard ',
#   'None',
#   121,
#   2016,
#   6.2,
#   54,
#   'Inferno (I)',
#   '  Tom Hanks',
#   ' Felicity Jones',
#   ' Irrfan Khan',
#   ' Ben Foster',
#   182229,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   34.34,
#   'PG-13'),
#  (1477,
#   'Alexander',
#   'Oliver Stone ',
#   'None',
#   175,
#   2004,
#   5.6,
#   34,
#   'Alexander',
#   '  Colin Farrell',
#   ' Anthony Hopkins',
#   ' Rosario Dawson',
#   ' Angelina Jolie',
#   172892,
#   'Action',
#   ' Biography',
#   ' Drama',
#   34.3,
#   'R'),
#  (1289,
#   'The Hunted',
#   'William Friedkin ',
#   'None',
#   94,
#   2003,
#   6,
#   33,
#   'The Hunted',
#   '  Tommy Lee Jones',
#   ' Benicio Del Toro',
#   ' Connie Nielsen',
#   ' Leslie Stefanson',
#   49224,
#   'Action',
#   ' Crime',
#   ' Drama',
#   34.24,
#   'PG-13'),
#  (494,
#   'The Northman',
#   'Robert Eggers ',
#   'None',
#   137,
#   2022,
#   7,
#   52,
#   'The Northman',
#   '  Alexander SkarsgÃƒÂ¥rd',
#   ' Nicole Kidman',
#   ' Claes Bang',
#   ' Ethan Hawke',
#   228072,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   34.23,
#   'R'),
#  (594,
#   'Death Wish',
#   'Michael Winner ',
#   'None',
#   93,
#   1974,
#   6.9,
#   64,
#   'Death Wish',
#   '  Bruce Willis',
#   ' Vincent DOnofrio',
#   ' Elisabeth Shue',
#   ' Camila Morrone',
#   74080,
#   'Action',
#   ' Crime',
#   ' Drama',
#   34.02,
#   'R'),
#  (1025,
#   'Death Wish',
#   'Eli Roth ',
#   'None',
#   107,
#   2018,
#   6.3,
#   38,
#   'Death Wish',
#   '  Bruce Willis',
#   ' Vincent DOnofrio',
#   ' Elisabeth Shue',
#   ' Camila Morrone',
#   74080,
#   'Action',
#   ' Crime',
#   ' Drama',
#   34.02,
#   'R'),
#  (1526,
#   'Snakes on a Plane',
#   'David R. Ellis ',
#   'None',
#   105,
#   2006,
#   5.5,
#   19,
#   'Snakes on a Plane',
#   '  Samuel L. Jackson',
#   ' Julianna Margulies',
#   ' Nathan Phillips',
#   ' Rachel Blanchard',
#   141939,
#   'Action',
#   ' Adventure',
#   ' Crime',
#   34.02,
#   'PG-13'),
#  (958,
#   'Darkman',
#   'Sam Raimi ',
#   'None',
#   96,
#   1990,
#   6.4,
#   42,
#   'Darkman',
#   '  Liam Neeson',
#   ' Frances McDormand',
#   ' Colin Friels',
#   ' Larry Drake',
#   67131,
#   'Action',
#   ' Sci-Fi',
#   ' Thriller',
#   33.88,
#   'R'),
#  (911,
#   'The Punisher',
#   'Jonathan Hensleigh ',
#   'None',
#   124,
#   2004,
#   6.4,
#   43,
#   'The Punisher',
#   '  Thomas Jane',
#   ' John Travolta',
#   ' Samantha Mathis',
#   ' Laura Harring',
#   164786,
#   'Action',
#   ' Crime',
#   ' Drama',
#   33.81,
#   'R'),
#  (1468,
#   'R.I.P.D.',
#   'Robert Schwentke ',
#   'None',
#   96,
#   2013,
#   5.6,
#   54,
#   'R.I.P.D.',
#   '  Ryan Reynolds',
#   ' Jeff Bridges',
#   ' Mary-Louise Parker',
#   ' Kevin Bacon',
#   139640,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   33.62,
#   'PG'),
#  (606,
#   'Muppet Treasure Island',
#   ' Brian Henson',
#   'David Lane ',
#   99,
#   1996,
#   6.9,
#   63,
#   'Muppet Treasure Island',
#   '  Tim Curry',
#   ' Billy Connolly',
#   ' Jennifer Saunders',
#   ' Kevin Bishop',
#   25289,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   33.61,
#   'R'),
#  (470,
#   'Flags of Our Fathers',
#   'Clint Eastwood ',
#   'None',
#   135,
#   2006,
#   7.1,
#   70,
#   'Flags of Our Fathers',
#   '  Ryan Phillippe',
#   ' Barry Pepper',
#   ' Joseph Cross',
#   ' Jesse Bradford',
#   126138,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   33.6,
#   'TV-MA'),
#  (1266,
#   'The Spy Who Dumped Me',
#   'Susanna Fogel ',
#   'None',
#   117,
#   2018,
#   6,
#   35,
#   'The Spy Who Dumped Me',
#   '  Justin Theroux',
#   ' Kate McKinnon',
#   ' Blanka GyÃƒÂ¶rfi-TÃƒÂ³th',
#   ' Mila Kunis',
#   80081,
#   'Action',
#   ' Adventure',
#   ' Comedy',
#   33.56,
#   'R'),
#  (633,
#   'The Long Kiss Goodnight',
#   'Renny Harlin ',
#   'None',
#   121,
#   1996,
#   6.8,
#   64,
#   'The Long Kiss Goodnight',
#   '  Geena Davis',
#   ' Samuel L. Jackson',
#   ' Yvonne Zima',
#   ' Craig Bierko',
#   82402,
#   'Action',
#   ' Crime',
#   ' Drama',
#   33.33,
#   'R'),
#  (409,
#   'Silverado',
#   'Lawrence Kasdan ',
#   'None',
#   133,
#   1985,
#   7.2,
#   62,
#   'Silverado',
#   '  Kevin Kline',
#   ' Scott Glenn',
#   ' Kevin Costner',
#   ' Danny Glover',
#   46317,
#   'Action',
#   ' Crime',
#   ' Drama',
#   33.2,
#   'R'),
#  (1339,
#   'Daylight',
#   'Rob Cohen ',
#   'None',
#   114,
#   1996,
#   5.9,
#   28,
#   'Daylight',
#   '  Sylvester Stallone',
#   ' Amy Brenneman',
#   ' Viggo Mortensen',
#   ' Dan Hedaya',
#   74734,
#   'Action',
#   ' Adventure',
#   ' Drama',
#   33.02,
#   'PG-13'),
#  ...]

# %% [markdown]
# 4) Display all details from both tables with the highest ratings

# %%
high_ratings=c.execute("select * from table1 INNER JOIN table2 ON table1.Movie_Name=table2.Movie_Name order by ratings_out_of10 desc ")
high_ratings.fetchone()
# Out:
# (1,
#  'The Dark Knight',
#  'Christopher Nolan ',
#  'None',
#  152,
#  2008,
#  9,
#  84,
#  'The Dark Knight',
#  'Christian Bale',
#  'Heath Ledger',
#  'Aaron Eckhart',
#  'Michael Caine',
#  2717521,
#  'Action',
#  ' Crime',
#  ' Drama',
#  534.86,
#  'PG-13')

# %% [markdown]
# 5) Display all details from both tables with the lowest gross collection and lowest ratings

# %%
low_ratings=c.execute("select * from table1 INNER JOIN table2 ON table1.Movie_Name=table2.Movie_Name order by ratings_out_of10 asc ")
low_ratings.fetchone()
# Out:
# (1549,
#  '65',
#  ' Scott Beck',
#  'Bryan Woods ',
#  93,
#  2023,
#  5.4,
#  12,
#  '65',
#  '  Adam Driver',
#  ' Ariana Greenblatt',
#  ' Chloe Coleman',
#  ' Nika King',
#  45103,
#  'Action',
#  ' Adventure',
#  ' Drama',
#  0,
#  'R')

# %%
low_gross=c.execute("select * from table1 INNER JOIN table2 ON table1.Movie_Name=table2.Movie_Name order by Grosscollection asc ")
low_gross.fetchone()
# Out:
# (8,
#  'Soorarai Pottru',
#  'Sudha Kongara ',
#  'None',
#  153,
#  2020,
#  8.7,
#  90,
#  'Soorarai Pottru',
#  '  Suriya',
#  ' Paresh Rawal',
#  ' Aparna Balamurali',
#  ' Urvashi',
#  119469,
#  'Action',
#  ' Drama',
#  'None',
#  0,
#  'TV-MA')

# %% [markdown]
# # PANDAS SQL

# %% [markdown]
# INSTALLING PANDASQL

# %%
# !pip install pandasql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandasql in c:\users\s.ramaa devi\appdata\roaming\python\python39\site-packages (0.7.3)
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (from pandasql) (1.4.32)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from pandasql) (1.21.5)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from pandasql) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pandasql) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy->pandasql) (1.1.1)

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
from pandasql import sqldf
import pandas as pd

# %%
pysqldf = lambda q: sqldf(q, globals())

# %% [markdown]
# # GETTING THE FIRST DATAFRAME(df1)

# %%
df1=pd.read_csv('movie1.csv')
df1.head()
# Out:
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    2      The Lord of the Rings: The Return of the King      Peter Jackson
# 2    3                                          Inception  Christopher Nolan
# 3    4  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
# 4    5              The Lord of the Rings: The Two Towers      Peter Jackson
#
#   Director_2  Duration_in_mins  year  ratings_out_of_10  Metascore
# 0       None               152  2008                9.0         84
# 1       None               201  2003                9.0         94
# 2       None               148  2010                8.8         74
# 3       None               178  2001                8.8         92
# 4       None               179  2002                8.8         87

# %% [markdown]
# # QUERYING df1

# %% [markdown]
# Table 1: Sno, MovieName, Director Name, Duration, genre, ratings
#
# 1) Display all the details of movies created by directors Christopher and Matt Reeves.
#
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.
#
# 3) Display all details of movies with ratings above 7 in ascending order.
#
# 4) Display all movie names in descending order.
#
# 5) Display movie name starts with ‘P’ and their rating is greater than 7.

# %% [markdown]
# 1) Display all the details of movies created by directors Christopher and Matt Reeves.

# %%
christ="select * from df1 where Director_1 like ('Christopher%')"
details=pysqldf(christ)
print(len(details))
details.tail()
# Out:
# 13
#      Sno                             Movie_Name              Director_1  \
# 8    497                           Jack Reacher  Christopher McQuarrie
# 9    642                             Young Guns       Christopher Cain
# 10   824                     The Way of the Gun  Christopher McQuarrie
# 11   972                            Black Death      Christopher Smith
# 12  1024  Scouts Guide to the Zombie Apocalypse     Christopher Landon
#
#    Director_2  Duration_in_mins  year  ratings_out_of_10  Metascore
# 8        None               130  2012                7.0         63
# 9        None               107  1988                6.8         60
# 10       None               119  2000                6.6         49
# 11       None               102  2010                6.4         68
# 12       None                93  2015                6.3         56

# %%
christ1="select * from df1 where Director_2 like ('Christopher%')"
details1=pysqldf(christ1)
print(len(details1))
details1.tail()
# Out:
# 3
#    Sno      Movie_Name  Director_1           Director_2  Duration_in_mins  \
# 0  171  The Lego Movie   Phil Lord  Christopher Miller                100
# 1  381  21 Jump Street   Phil Lord  Christopher Miller                109
# 2  519  22 Jump Street   Phil Lord  Christopher Miller                112
#
#    year  ratings_out_of_10  Metascore
# 0  2014                7.7         68
# 1  2012                7.2         56
# 2  2014                7.0         87

# %%
reeves="select * from df1 where Director_1 like ('Matt Reeve%')"
details2=pysqldf(reeves)
print(len(details2))
details2.head()
# Out:
# 4
#    Sno                      Movie_Name    Director_1 Director_2  \
# 0  130                      The Batman  Matt Reeves        None
# 1  224  Dawn of the Planet of the Apes  Matt Reeves        None
# 2  305  War for the Planet of the Apes  Matt Reeves        None
# 3  503                     Cloverfield  Matt Reeves        None
#
#    Duration_in_mins  year  ratings_out_of_10  Metascore
# 0               176  2022                7.8         73
# 1               130  2014                7.6         66
# 2               140  2017                7.4         73
# 3                85  2008                7.0         57

# %%
reeves1="select * from df1 where Director_2 like ('Matt Reeve%')"
details3=pysqldf(reeves1)
print(len(details3))
details3.head()
# Out:
# 0
# Empty DataFrame
# Columns: [Sno, Movie_Name, Director_1, Director_2, Duration_in_mins, year, ratings_out_of_10, Metascore]
# Index: []

# %% [markdown]
# 2) Display all the details of movies with a duration of 140 minutes to 190 minutes.

# %%
dura="select * from df1 where Duration_in_mins >=140 and Duration_in_mins <= 190"
duration=pysqldf(dura)
print(len(duration))
duration.head()
# Out:
# 187
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    3                                          Inception  Christopher Nolan
# 2    4  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
# 3    5              The Lord of the Rings: The Two Towers      Peter Jackson
# 4    8                                    Soorarai Pottru      Sudha Kongara
#
#   Director_2  Duration_in_mins  year  ratings_out_of_10  Metascore
# 0       None               152  2008                9.0         84
# 1       None               148  2010                8.8         74
# 2       None               178  2001                8.8         92
# 3       None               179  2002                8.8         87
# 4       None               153  2020                8.7         90

# %% [markdown]
# 3) Display all details of movies with ratings above 7 in ascending order.

# %%
rate="select * from df1 where ratings_out_of_10 > 7 order by ratings_out_of_10 asc"
ratings=pysqldf(rate)
print(len(ratings))
ratings.head()
# Out:
# 487
#    Sno           Movie_Name        Director_1 Director_2  Duration_in_mins  \
# 0  430            Furious 7        James Wan        None               137
# 1  431            The Mummy  Stephen Sommers        None               124
# 2  432  Mission: Impossible   Brian De Palma        None               110
# 3  433             Free Guy       Shawn Levy        None               115
# 4  434         Wrath of Man      Guy Ritchie        None               119
#
#    year  ratings_out_of_10  Metascore
# 0  2015                7.1         42
# 1  1999                7.1         61
# 2  1996                7.1         64
# 3  2021                7.1         57
# 4  2021                7.1         49

# %% [markdown]
# 4) Display all movie names in descending order

# %%
desc="select Movie_Name from df1 order by Movie_Name desc"
descending=pysqldf(desc)
print(len(descending))
descending.head()
# Out:
# 1551
#                     Movie_Name
# 0                          xXx
# 1       Zombieland: Double Tap
# 2                   Zombieland
# 3   Zathura: A Space Adventure
# 4  Zack Snyders Justice League

# %% [markdown]
# 5) Display movie name starts with ‘P’ and their rating is greater than 7

# %%
p_movie="select Movie_Name,ratings_out_of_10 from df1 where Movie_Name like 'P%'and ratings_out_of_10 > 7 "
p_movie_rate_7=pysqldf(p_movie)
print(len(p_movie_rate_7))
p_movie_rate_7.head()
# Out:
# 15
#                                           Movie_Name  ratings_out_of_10
# 0                                  Princess Mononoke                8.3
# 1                                   Paan Singh Tomar                8.2
# 2  Pirates of the Caribbean: The Curse of the Bla...                8.1
# 3                                           Predator                7.8
# 4                            Ponniyin Selvan: Part I                7.7

# %% [markdown]
# # GETTING THE SECOND DATAFRAME (df2)

# %%
df2=pd.read_csv('movie2.csv')
df2.head()
# Out:
#                                           Movie_Name               star_1  \
# 0                                    The Dark Knight       Christian Bale
# 1      The Lord of the Rings: The Return of the King          Elijah Wood
# 2                                          Inception    Leonardo DiCaprio
# 3  The Lord of the Rings: The Fellowship of the Ring          Elijah Wood
# 4              The Lord of the Rings: The Two Towers          Elijah Wood
#
#                  star_2           star_3          star_4    votes Genre_1  \
# 0          Heath Ledger    Aaron Eckhart   Michael Caine  2717521  Action
# 1       Viggo Mortensen     Ian McKellen   Orlando Bloom  1886645  Action
# 2  Joseph Gordon-Levitt      Elliot Page    Ken Watanabe  2412332  Action
# 3          Ian McKellen    Orlando Bloom       Sean Bean  1915355  Action
# 4          Ian McKellen  Viggo Mortensen   Orlando Bloom  1702927  Action
#
#       Genre_2  Genre_3 Gross_collection Certification
# 0       Crime    Drama           534.86         PG-13
# 1   Adventure    Drama           377.85         PG-13
# 2   Adventure   Sci-Fi           292.58         PG-13
# 3   Adventure    Drama           315.54         PG-13
# 4   Adventure    Drama           342.55         PG-13

# %% [markdown]
# # QUERYING df2

# %% [markdown]
# Table 2: Movie Name, stars, votes, Genre, Gross collection, Certification
#
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.
#
# 2 2) Display all details of the movie with the highest number of votes.
#
# 3) Display movie names with gross collections in descending order.
#
# 4) Display the gross collection of movies with the star Arnold.
#
# 5) Display all details of movies with comedy and action genres.

# %% [markdown]
# 1) Display all movie names with star Arnold Schwarzenegger in ascending order.

# %%
arnold="select Movie_Name from df2 where star_1 like 'Arnold%' order by Movie_Name asc "
arnold_asc=pysqldf(arnold)
print(len(arnold_asc))
arnold_asc.head()
# Out:
# 0
# Empty DataFrame
# Columns: [Movie_Name]
# Index: []

# %% [markdown]
# 2) Display all details of the movie with the highest number of votes

# %%
votes="select * from df2 order by votes desc "
high_votes=pysqldf(votes)
print(len(high_votes))
high_votes.head(1)
# Out:
# 1551
#         Movie_Name          star_1        star_2         star_3  \
# 0  The Dark Knight  Christian Bale  Heath Ledger  Aaron Eckhart
#
#           star_4    votes Genre_1 Genre_2 Genre_3 Gross_collection  \
# 0  Michael Caine  2717521  Action   Crime   Drama           534.86
#
#   Certification
# 0         PG-13

# %% [markdown]
# 3) Display movie names with gross collections in descending order

# %%
gross="select Movie_Name from df2 order by Gross_collection desc "
high_gross=pysqldf(gross)
print(len(high_gross))
high_gross.head(10)
# Out:
# 1551
#                                         Movie_Name
# 0                               Olympus Has Fallen
# 1                                 The Green Hornet
# 2                                   Public Enemies
# 3                                  The Book of Eli
# 4                                The Mask of Zorro
# 5       Star Wars: Episode VII - The Force Awakens
# 6  Master and Commander: The Far Side of the World
# 7                          DC League of Super-Pets
# 8                                  The Fighter (I)
# 9                                     Tomorrowland

# %% [markdown]
# 4) Display the gross collection of movies with the star Arnold

# %%
arn="select Movie_Name,Gross_collection,star_1 from df2 where star_1 like 'Arnol%'"
arn_gross=pysqldf(arn)
print(len(arn_gross))
arn_gross.head(10)
# Out:
# 0
# Empty DataFrame
# Columns: [Movie_Name, Gross_collection, star_1]
# Index: []

# %% [markdown]
# 5) Display all details of movies with comedy and action genres

# %%
genre="select * from df2 where Genre_1 in ('Comedy','Action')"
com_act=pysqldf(genre)
print(len(com_act))
com_act.head()
# Out:
# 1483
#                                           Movie_Name               star_1  \
# 0                                    The Dark Knight       Christian Bale
# 1      The Lord of the Rings: The Return of the King          Elijah Wood
# 2                                          Inception    Leonardo DiCaprio
# 3  The Lord of the Rings: The Fellowship of the Ring          Elijah Wood
# 4              The Lord of the Rings: The Two Towers          Elijah Wood
#
#                  star_2           star_3          star_4    votes Genre_1  \
# 0          Heath Ledger    Aaron Eckhart   Michael Caine  2717521  Action
# 1       Viggo Mortensen     Ian McKellen   Orlando Bloom  1886645  Action
# 2  Joseph Gordon-Levitt      Elliot Page    Ken Watanabe  2412332  Action
# 3          Ian McKellen    Orlando Bloom       Sean Bean  1915355  Action
# 4          Ian McKellen  Viggo Mortensen   Orlando Bloom  1702927  Action
#
#       Genre_2  Genre_3 Gross_collection Certification
# 0       Crime    Drama           534.86         PG-13
# 1   Adventure    Drama           377.85         PG-13
# 2   Adventure   Sci-Fi           292.58         PG-13
# 3   Adventure    Drama           315.54         PG-13
# 4   Adventure    Drama           342.55         PG-13

# %% [markdown]
# # SUBQUERIES IN PANDASQL

# %% [markdown]
# Make subquery :
#
# 1) Display all details from both tables where movie names are the same.
#
# 2) Display all movie names, Director, ratings, and gross collection where the genre is action.
#
# 3) Display all details from both tables with the highest gross collection.
#
# 4) Display all details from both tables with the highest ratings
#
# 5) Display all details from both tables with the lowest gross collection and lowest ratings

# %% [markdown]
# # CREATING dfnew BY MERGING df1 AND df2

# %%
dfnew=df1.merge(df2)
dfnew.head()
# Out:
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    2      The Lord of the Rings: The Return of the King      Peter Jackson
# 2    3                                          Inception  Christopher Nolan
# 3    4  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
# 4    5              The Lord of the Rings: The Two Towers      Peter Jackson
#
#   Director_2  Duration_in_mins  year  ratings_out_of_10  Metascore  \
# 0       None               152  2008                9.0         84
# 1       None               201  2003                9.0         94
# 2       None               148  2010                8.8         74
# 3       None               178  2001                8.8         92
# 4       None               179  2002                8.8         87
#
#                 star_1                star_2           star_3          star_4  \
# 0       Christian Bale          Heath Ledger    Aaron Eckhart   Michael Caine
# 1          Elijah Wood       Viggo Mortensen     Ian McKellen   Orlando Bloom
# 2    Leonardo DiCaprio  Joseph Gordon-Levitt      Elliot Page    Ken Watanabe
# 3          Elijah Wood          Ian McKellen    Orlando Bloom       Sean Bean
# 4          Elijah Wood          Ian McKellen  Viggo Mortensen   Orlando Bloom
#
#      votes Genre_1     Genre_2  Genre_3 Gross_collection Certification
# 0  2717521  Action       Crime    Drama           534.86         PG-13
# 1  1886645  Action   Adventure    Drama           377.85         PG-13
# 2  2412332  Action   Adventure   Sci-Fi           292.58         PG-13
# 3  1915355  Action   Adventure    Drama           315.54         PG-13
# 4  1702927  Action   Adventure    Drama           342.55         PG-13

# %% [markdown]
# # SUBQUERYING dfnew

# %% [markdown]
# 1) Display all details from both tables where movie names are the same.

# %%
same="select Movie_Name from dfnew  "
movie_names=pysqldf(same)
print(len(movie_names))
movie_names.head()
# Out:
# 1579
#                                           Movie_Name
# 0                                    The Dark Knight
# 1      The Lord of the Rings: The Return of the King
# 2                                          Inception
# 3  The Lord of the Rings: The Fellowship of the Ring
# 4              The Lord of the Rings: The Two Towers

# %% [markdown]
# 2) Display all movie names, Director, ratings, and gross collection where the genre is action.

# %%
six="select Movie_Name,Director_1,Director_2,ratings_out_of_10,Gross_collection,Genre_1 from dfnew where Genre_1 = 'Action'" 
six_names=pysqldf(six)
print(len(six_names))
six_names.head()
# Out:
# 1511
#                                           Movie_Name          Director_1  \
# 0                                    The Dark Knight  Christopher Nolan
# 1      The Lord of the Rings: The Return of the King      Peter Jackson
# 2                                          Inception  Christopher Nolan
# 3  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
# 4              The Lord of the Rings: The Two Towers      Peter Jackson
#
#   Director_2  ratings_out_of_10 Gross_collection Genre_1
# 0       None                9.0           534.86  Action
# 1       None                9.0           377.85  Action
# 2       None                8.8           292.58  Action
# 3       None                8.8           315.54  Action
# 4       None                8.8           342.55  Action

# %% [markdown]
# 3) Display all details from both tables with the highest gross collection.

# %%
gross="select * from dfnew order by Gross_collection desc"
high_gross=pysqldf(gross)
print(len(high_gross))
high_gross.head(1)
# Out:
# 1579
#    Sno          Movie_Name      Director_1 Director_2  Duration_in_mins  year  \
# 0  847  Olympus Has Fallen  Antoine Fuqua        None               119  2013
#
#    ratings_out_of_10  Metascore           star_1          star_2  \
# 0                6.5         49    Gerard Butler   Aaron Eckhart
#
#             star_3           star_4   votes Genre_1    Genre_2 Genre_3  \
# 0   Morgan Freeman   Angela Bassett  283443  Action   Thriller    None
#
#   Gross_collection Certification
# 0            98.93         PG-13

# %% [markdown]
# 4) Display all details from both tables with the highest ratings

# %%
rating="select * from dfnew order by ratings_out_of_10 desc"
high_rating=pysqldf(rating)
print(len(high_rating))
high_rating.head(1)
# Out:
# 1579
#    Sno       Movie_Name          Director_1 Director_2  Duration_in_mins  \
# 0    1  The Dark Knight  Christopher Nolan        None               152
#
#    year  ratings_out_of_10  Metascore          star_1        star_2  \
# 0  2008                9.0         84  Christian Bale  Heath Ledger
#
#           star_3         star_4    votes Genre_1 Genre_2 Genre_3  \
# 0  Aaron Eckhart  Michael Caine  2717521  Action   Crime   Drama
#
#   Gross_collection Certification
# 0           534.86         PG-13

# %% [markdown]
# 5) Display all details from both tables with the lowest gross collection and lowest ratings

# %%
g="select * from dfnew  order by Gross_collection asc"
low_g=pysqldf(g)
print(len(low_g))
low_g.head(1)
# Out:
# 1579
#    Sno    Movie_Name          Director_1 Director_2  Duration_in_mins  year  \
# 0  157  Ninja Scroll  Yoshiaki Kawajiri        None                94  1993
#
#    ratings_out_of_10  Metascore              star_1          star_2  \
# 0                7.8         56    KÃ´ichi Yamadera   Emi Shinohara
#
#           star_3       star_4  votes    Genre_1  Genre_2     Genre_3  \
# 0   Takeshi Aono   Osamu Saka  38856  Animation   Action   Adventure
#
#   Gross_collection Certification
# 0                              R

# %%
r="select * from dfnew  order by ratings_out_of_10 asc"
low_r=pysqldf(r)
print(len(low_r))
low_r.head(1)
# Out:
# 1579
#     Sno Movie_Name   Director_1    Director_2  Duration_in_mins  year  \
# 0  1549         65   Scott Beck  Bryan Woods                 93  2023
#
#    ratings_out_of_10  Metascore         star_1              star_2  \
# 0                5.4         12    Adam Driver   Ariana Greenblatt
#
#            star_3      star_4  votes Genre_1     Genre_2 Genre_3  \
# 0   Chloe Coleman   Nika King  45103  Action   Adventure   Drama
#
#   Gross_collection Certification
# 0                0             R
